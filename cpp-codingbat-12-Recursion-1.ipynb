// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
namespace testns { template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
} } using namespace testns;
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # Recursion-1 > factorial

// %%
/*
Given n of 1 or more, return the factorial of n, which is n * (n-1) * (n-2) ...
1. Compute the result recursively (without loops).

factorial(1) → 1
factorial(2) → 2
factorial(3) → 6
*/

int factorial(int n) {
    return 0;
}


// tests:
printTest( "factorial(1) → 1", factorial(1), 1 );
printTest( "factorial(2) → 2", factorial(2), 2 );
printTest( "factorial(3) → 6", factorial(3), 6 );
printTest( "factorial(4) → 24", factorial(4), 24 );
printTest( "factorial(5) → 120", factorial(5), 120 );
printTest( "factorial(6) → 720", factorial(6), 720 );
printTest( "factorial(7) → 5040", factorial(7), 5040 );
printTest( "factorial(8) → 40320", factorial(8), 40320 );
printTest( "factorial(12) → 479001600", factorial(12), 479001600 );

// %% [markdown]
// # Recursion-1 > bunnyEars

// %%
/*
We have a number of bunnies and each bunny has two big floppy ears. We want to
compute the total number of ears across all the bunnies recursively (without
loops or multiplication).

bunnyEars(0) → 0
bunnyEars(1) → 2
bunnyEars(2) → 4
*/

int bunnyEars(int bunnies) {
    return 0;
}


// tests:
printTest( "bunnyEars(0) → 0", bunnyEars(0), 0 );
printTest( "bunnyEars(1) → 2", bunnyEars(1), 2 );
printTest( "bunnyEars(2) → 4", bunnyEars(2), 4 );
printTest( "bunnyEars(3) → 6", bunnyEars(3), 6 );
printTest( "bunnyEars(4) → 8", bunnyEars(4), 8 );
printTest( "bunnyEars(5) → 10", bunnyEars(5), 10 );
printTest( "bunnyEars(12) → 24", bunnyEars(12), 24 );
printTest( "bunnyEars(50) → 100", bunnyEars(50), 100 );
printTest( "bunnyEars(234) → 468", bunnyEars(234), 468 );

// %% [markdown]
// # Recursion-1 > fibonacci

// %%
/*
The fibonacci sequence is a famous bit of mathematics, and it happens to have a
recursive definition. The first two values in the sequence are 0 and 1
(essentially 2 base cases). Each subsequent value is the sum of the previous two
values, so the whole sequence is: 0, 1, 1, 2, 3, 5, 8, 13, 21 and so on. Define
a recursive fibonacci(n) method that returns the nth fibonacci number, with n=0
representing the start of the sequence.

fibonacci(0) → 0
fibonacci(1) → 1
fibonacci(2) → 1
*/

int fibonacci(int n) {
    return 0;
}


// tests:
printTest( "fibonacci(0) → 0", fibonacci(0), 0 );
printTest( "fibonacci(1) → 1", fibonacci(1), 1 );
printTest( "fibonacci(2) → 1", fibonacci(2), 1 );
printTest( "fibonacci(3) → 2", fibonacci(3), 2 );
printTest( "fibonacci(4) → 3", fibonacci(4), 3 );
printTest( "fibonacci(5) → 5", fibonacci(5), 5 );
printTest( "fibonacci(6) → 8", fibonacci(6), 8 );
printTest( "fibonacci(7) → 13", fibonacci(7), 13 );

// %% [markdown]
// # Recursion-1 > bunnyEars2

// %%
/*
We have bunnies standing in a line, numbered 1, 2, ... The odd bunnies (1, 3,
..) have the normal 2 ears. The even bunnies (2, 4, ..) weʼll say have 3 ears,
because they each have a raised foot. Recursively return the number of "ears" in
the bunny line 1, 2, ... n (without loops or multiplication).

bunnyEars2(0) → 0
bunnyEars2(1) → 2
bunnyEars2(2) → 5
*/

int bunnyEars2(int bunnies) {
    return 0;
}


// tests:
printTest( "bunnyEars2(0) → 0", bunnyEars2(0), 0 );
printTest( "bunnyEars2(1) → 2", bunnyEars2(1), 2 );
printTest( "bunnyEars2(2) → 5", bunnyEars2(2), 5 );
printTest( "bunnyEars2(3) → 7", bunnyEars2(3), 7 );
printTest( "bunnyEars2(4) → 10", bunnyEars2(4), 10 );
printTest( "bunnyEars2(5) → 12", bunnyEars2(5), 12 );
printTest( "bunnyEars2(6) → 15", bunnyEars2(6), 15 );
printTest( "bunnyEars2(10) → 25", bunnyEars2(10), 25 );

// %% [markdown]
// # Recursion-1 > triangle

// %%
/*
We have triangle made of blocks. The topmost row has 1 block, the next row down
has 2 blocks, the next row has 3 blocks, and so on. Compute recursively (no
loops or multiplication) the total number of blocks in such a triangle with the
given number of rows.

triangle(0) → 0
triangle(1) → 1
triangle(2) → 3
*/

int triangle(int rows) {
    return 0;
}


// tests:
printTest( "triangle(0) → 0", triangle(0), 0 );
printTest( "triangle(1) → 1", triangle(1), 1 );
printTest( "triangle(2) → 3", triangle(2), 3 );
printTest( "triangle(3) → 6", triangle(3), 6 );
printTest( "triangle(4) → 10", triangle(4), 10 );
printTest( "triangle(5) → 15", triangle(5), 15 );
printTest( "triangle(6) → 21", triangle(6), 21 );
printTest( "triangle(7) → 28", triangle(7), 28 );

// %% [markdown]
// # Recursion-1 > sumDigits

// %%
/*
Given a non-negative int n, return the sum of its digits recursively (no loops).
Note that mod (%) by 10 yields the rightmost digit (126 % 10 is 6), while divide
(/) by 10 removes the rightmost digit (126 / 10 is 12).

sumDigits(126) → 9
sumDigits(49) → 13
sumDigits(12) → 3
*/

int sumDigits(int n) {
    return 0;
}


// tests:
printTest( "sumDigits(126) → 9", sumDigits(126), 9 );
printTest( "sumDigits(49) → 13", sumDigits(49), 13 );
printTest( "sumDigits(12) → 3", sumDigits(12), 3 );
printTest( "sumDigits(10) → 1", sumDigits(10), 1 );
printTest( "sumDigits(1) → 1", sumDigits(1), 1 );
printTest( "sumDigits(0) → 0", sumDigits(0), 0 );
printTest( "sumDigits(730) → 10", sumDigits(730), 10 );
printTest( "sumDigits(1111) → 4", sumDigits(1111), 4 );
printTest( "sumDigits(11111) → 5", sumDigits(11111), 5 );
printTest( "sumDigits(10110) → 3", sumDigits(10110), 3 );
printTest( "sumDigits(235) → 10", sumDigits(235), 10 );

// %% [markdown]
// # Recursion-1 > count7

// %%
/*
Given a non-negative int n, return the count of the occurrences of 7 as a digit,
so for example 717 yields 2. (no loops). Note that mod (%) by 10 yields the
rightmost digit (126 % 10 is 6), while divide (/) by 10 removes the rightmost
digit (126 / 10 is 12).

count7(717) → 2
count7(7) → 1
count7(123) → 0
*/

int count7(int n) {
    return 0;
}


// tests:
printTest( "count7(717) → 2", count7(717), 2 );
printTest( "count7(7) → 1", count7(7), 1 );
printTest( "count7(123) → 0", count7(123), 0 );
printTest( "count7(77) → 2", count7(77), 2 );
printTest( "count7(7123) → 1", count7(7123), 1 );
printTest( "count7(771237) → 3", count7(771237), 3 );
printTest( "count7(771737) → 4", count7(771737), 4 );
printTest( "count7(47571) → 2", count7(47571), 2 );
printTest( "count7(777777) → 6", count7(777777), 6 );
printTest( "count7(70701277) → 4", count7(70701277), 4 );
printTest( "count7(777576197) → 5", count7(777576197), 5 );
printTest( "count7(99999) → 0", count7(99999), 0 );
printTest( "count7(99799) → 1", count7(99799), 1 );

// %% [markdown]
// # Recursion-1 > count8

// %%
/*
Given a non-negative int n, compute recursively (no loops) the count of the
occurrences of 8 as a digit, except that an 8 with another 8 immediately to its
left counts double, so 8818 yields 4. Note that mod (%) by 10 yields the
rightmost digit (126 % 10 is 6), while divide (/) by 10 removes the rightmost
digit (126 / 10 is 12).

count8(8) → 1
count8(818) → 2
count8(8818) → 4
*/

int count8(int n) {
    return 0;
}


// tests:
printTest( "count8(8) → 1", count8(8), 1 );
printTest( "count8(818) → 2", count8(818), 2 );
printTest( "count8(8818) → 4", count8(8818), 4 );
printTest( "count8(8088) → 4", count8(8088), 4 );
printTest( "count8(123) → 0", count8(123), 0 );
printTest( "count8(81238) → 2", count8(81238), 2 );
printTest( "count8(88788) → 6", count8(88788), 6 );
printTest( "count8(8234) → 1", count8(8234), 1 );
printTest( "count8(2348) → 1", count8(2348), 1 );
printTest( "count8(23884) → 3", count8(23884), 3 );
printTest( "count8(0) → 0", count8(0), 0 );
printTest( "count8(1818188) → 5", count8(1818188), 5 );
printTest( "count8(8818181) → 5", count8(8818181), 5 );
printTest( "count8(1080) → 1", count8(1080), 1 );
printTest( "count8(188) → 3", count8(188), 3 );
printTest( "count8(88888) → 9", count8(88888), 9 );
printTest( "count8(9898) → 2", count8(9898), 2 );
printTest( "count8(78) → 1", count8(78), 1 );

// %% [markdown]
// # Recursion-1 > powerN

// %%
/*
Given base and n that are both 1 or more, compute recursively (no loops) the
value of base to the n power, so powerN(3, 2) is 9 (3 squared).

powerN(3, 1) → 3
powerN(3, 2) → 9
powerN(3, 3) → 27
*/

int powerN(int base, int n) {
    return 0;
}


// tests:
printTest( "powerN(3, 1) → 3", powerN(3, 1), 3 );
printTest( "powerN(3, 2) → 9", powerN(3, 2), 9 );
printTest( "powerN(3, 3) → 27", powerN(3, 3), 27 );
printTest( "powerN(2, 1) → 2", powerN(2, 1), 2 );
printTest( "powerN(2, 2) → 4", powerN(2, 2), 4 );
printTest( "powerN(2, 3) → 8", powerN(2, 3), 8 );
printTest( "powerN(2, 4) → 16", powerN(2, 4), 16 );
printTest( "powerN(2, 5) → 32", powerN(2, 5), 32 );
printTest( "powerN(10, 1) → 10", powerN(10, 1), 10 );
printTest( "powerN(10, 2) → 100", powerN(10, 2), 100 );
printTest( "powerN(10, 3) → 1000", powerN(10, 3), 1000 );

// %% [markdown]
// # Recursion-1 > countX

// %%
/*
Given a string, compute recursively (no loops) the number of lowercase 'x' chars
in the string.

countX("xxhixx") → 4
countX("xhixhix") → 3
countX("hi") → 0
*/

int countX(string str) {
    return 0;
}


// tests:
printTest( "countX(\"xxhixx\") → 4", countX("xxhixx"), 4 );
printTest( "countX(\"xhixhix\") → 3", countX("xhixhix"), 3 );
printTest( "countX(\"hi\") → 0", countX("hi"), 0 );
printTest( "countX(\"h\") → 0", countX("h"), 0 );
printTest( "countX(\"x\") → 1", countX("x"), 1 );
printTest( "countX(\"\") → 0", countX(""), 0 );
printTest( "countX(\"hihi\") → 0", countX("hihi"), 0 );
printTest( "countX(\"hiAAhi12hi\") → 0", countX("hiAAhi12hi"), 0 );

// %% [markdown]
// # Recursion-1 > countHi

// %%
/*
Given a string, compute recursively (no loops) the number of times lowercase
"hi" appears in the string.

countHi("xxhixx") → 1
countHi("xhixhix") → 2
countHi("hi") → 1
*/

int countHi(string str) {
    return 0;
}


// tests:
printTest( "countHi(\"xxhixx\") → 1", countHi("xxhixx"), 1 );
printTest( "countHi(\"xhixhix\") → 2", countHi("xhixhix"), 2 );
printTest( "countHi(\"hi\") → 1", countHi("hi"), 1 );
printTest( "countHi(\"hihih\") → 2", countHi("hihih"), 2 );
printTest( "countHi(\"h\") → 0", countHi("h"), 0 );
printTest( "countHi(\"\") → 0", countHi(""), 0 );
printTest( "countHi(\"ihihihihih\") → 4", countHi("ihihihihih"), 4 );
printTest( "countHi(\"ihihihihihi\") → 5", countHi("ihihihihihi"), 5 );
printTest( "countHi(\"hiAAhi12hi\") → 3", countHi("hiAAhi12hi"), 3 );
printTest( "countHi(\"xhixhxihihhhih\") → 3", countHi("xhixhxihihhhih"), 3 );
printTest( "countHi(\"ship\") → 1", countHi("ship"), 1 );

// %% [markdown]
// # Recursion-1 > changeXY

// %%
/*
Given a string, compute recursively (no loops) a new string where all the
lowercase 'x' chars have been changed to 'y' chars.

changeXY("codex") → "codey"
changeXY("xxhixx") → "yyhiyy"
changeXY("xhixhix") → "yhiyhiy"
*/

string changeXY(string str) {
    return "";
}


// tests:
printTest( "changeXY(\"codex\") → \"codey\"", changeXY("codex"), "codey" );
printTest( "changeXY(\"xxhixx\") → \"yyhiyy\"", changeXY("xxhixx"), "yyhiyy" );
printTest( "changeXY(\"xhixhix\") → \"yhiyhiy\"", changeXY("xhixhix"), "yhiyhiy" );
printTest( "changeXY(\"hiy\") → \"hiy\"", changeXY("hiy"), "hiy" );
printTest( "changeXY(\"h\") → \"h\"", changeXY("h"), "h" );
printTest( "changeXY(\"x\") → \"y\"", changeXY("x"), "y" );
printTest( "changeXY(\"\") → \"\"", changeXY(""), "" );
printTest( "changeXY(\"xxx\") → \"yyy\"", changeXY("xxx"), "yyy" );
printTest( "changeXY(\"yyhxyi\") → \"yyhyyi\"", changeXY("yyhxyi"), "yyhyyi" );
printTest( "changeXY(\"hihi\") → \"hihi\"", changeXY("hihi"), "hihi" );

// %% [markdown]
// # Recursion-1 > changePi

// %%
/*
Given a string, compute recursively (no loops) a new string where all
appearances of "pi" have been replaced by "3.14".

changePi("xpix") → "x3.14x"
changePi("pipi") → "3.143.14"
changePi("pip") → "3.14p"
*/

string changePi(string str) {
    return "";
}


// tests:
printTest( "changePi(\"xpix\") → \"x3.14x\"", changePi("xpix"), "x3.14x" );
printTest( "changePi(\"pipi\") → \"3.143.14\"", changePi("pipi"), "3.143.14" );
printTest( "changePi(\"pip\") → \"3.14p\"", changePi("pip"), "3.14p" );
printTest( "changePi(\"pi\") → \"3.14\"", changePi("pi"), "3.14" );
printTest( "changePi(\"hip\") → \"hip\"", changePi("hip"), "hip" );
printTest( "changePi(\"p\") → \"p\"", changePi("p"), "p" );
printTest( "changePi(\"x\") → \"x\"", changePi("x"), "x" );
printTest( "changePi(\"\") → \"\"", changePi(""), "" );
printTest( "changePi(\"pixx\") → \"3.14xx\"", changePi("pixx"), "3.14xx" );
printTest( "changePi(\"xyzzy\") → \"xyzzy\"", changePi("xyzzy"), "xyzzy" );

// %% [markdown]
// # Recursion-1 > noX

// %%
/*
Given a string, compute recursively a new string where all the 'x' chars have
been removed.

noX("xaxb") → "ab"
noX("abc") → "abc"
noX("xx") → ""
*/

string noX(string str) {
    return "";
}


// tests:
printTest( "noX(\"xaxb\") → \"ab\"", noX("xaxb"), "ab" );
printTest( "noX(\"abc\") → \"abc\"", noX("abc"), "abc" );
printTest( "noX(\"xx\") → \"\"", noX("xx"), "" );
printTest( "noX(\"\") → \"\"", noX(""), "" );
printTest( "noX(\"axxbxx\") → \"ab\"", noX("axxbxx"), "ab" );
printTest( "noX(\"Hellox\") → \"Hello\"", noX("Hellox"), "Hello" );

// %% [markdown]
// # Recursion-1 > array6

// %%
/*
Given an array of ints, compute recursively if the array contains a 6. Weʼll use
the convention of considering only the part of the array that begins at the
given index. In this way, a recursive call can pass index+1 to move down the
array. The initial call will pass in index as 0.

array6([1, 6, 4], 0) → true
array6([1, 4], 0) → false
array6([6], 0) → true
*/

bool array6(vector<int> nums, int index) {
    return false;
}


// tests:
printTest( "array6([1, 6, 4], 0) → true", array6({1, 6, 4}, 0), true );
printTest( "array6([1, 4], 0) → false", array6({1, 4}, 0), false );
printTest( "array6([6], 0) → true", array6({6}, 0), true );
printTest( "array6([], 0) → false", array6({}, 0), false );
printTest( "array6([6, 2, 2], 0) → true", array6({6, 2, 2}, 0), true );
printTest( "array6([2, 5], 0) → false", array6({2, 5}, 0), false );
printTest( "array6([1, 9, 4, 6, 6], 0) → true", array6({1, 9, 4, 6, 6}, 0), true );
printTest( "array6([2, 5, 6], 0) → true", array6({2, 5, 6}, 0), true );

// %% [markdown]
// # Recursion-1 > array11

// %%
/*
Given an array of ints, compute recursively the number of times that the value
11 appears in the array. Weʼll use the convention of considering only the part
of the array that begins at the given index. In this way, a recursive call can
pass index+1 to move down the array. The initial call will pass in index as 0.

array11([1, 2, 11], 0) → 1
array11([11, 11], 0) → 2
array11([1, 2, 3, 4], 0) → 0
*/

int array11(vector<int> nums, int index) {
    return 0;
}


// tests:
printTest( "array11([1, 2, 11], 0) → 1", array11({1, 2, 11}, 0), 1 );
printTest( "array11([11, 11], 0) → 2", array11({11, 11}, 0), 2 );
printTest( "array11([1, 2, 3, 4], 0) → 0", array11({1, 2, 3, 4}, 0), 0 );
printTest( "array11([1, 11, 3, 11, 11], 0) → 3", array11({1, 11, 3, 11, 11}, 0), 3 );
printTest( "array11([11], 0) → 1", array11({11}, 0), 1 );
printTest( "array11([1], 0) → 0", array11({1}, 0), 0 );
printTest( "array11([], 0) → 0", array11({}, 0), 0 );
printTest( "array11([11, 2, 3, 4, 11, 5], 0) → 2", array11({11, 2, 3, 4, 11, 5}, 0), 2 );
printTest( "array11([11, 5, 11], 0) → 2", array11({11, 5, 11}, 0), 2 );

// %% [markdown]
// # Recursion-1 > array220

// %%
/*
Given an array of ints, compute recursively if the array contains somewhere a
value followed in the array by that value times 10. Weʼll use the convention of
considering only the part of the array that begins at the given index. In this
way, a recursive call can pass index+1 to move down the array. The initial call
will pass in index as 0.

array220([1, 2, 20], 0) → true
array220([3, 30], 0) → true
array220([3], 0) → false
*/

bool array220(vector<int> nums, int index) {
    return false;
}


// tests:
printTest( "array220([1, 2, 20], 0) → true", array220({1, 2, 20}, 0), true );
printTest( "array220([3, 30], 0) → true", array220({3, 30}, 0), true );
printTest( "array220([3], 0) → false", array220({3}, 0), false );
printTest( "array220([], 0) → false", array220({}, 0), false );
printTest( "array220([3, 3, 30, 4], 0) → true", array220({3, 3, 30, 4}, 0), true );
printTest( "array220([2, 19, 4], 0) → false", array220({2, 19, 4}, 0), false );
printTest( "array220([20, 2, 21], 0) → false", array220({20, 2, 21}, 0), false );
printTest( "array220([20, 2, 21, 210], 0) → true", array220({20, 2, 21, 210}, 0), true );
printTest( "array220([2, 200, 2000], 0) → true", array220({2, 200, 2000}, 0), true );
printTest( "array220([0, 0], 0) → true", array220({0, 0}, 0), true );
printTest( "array220([1, 2, 3, 4, 5, 6], 0) → false", array220({1, 2, 3, 4, 5, 6}, 0), false );
printTest( "array220([1, 2, 3, 4, 5, 50, 6], 0) → true", array220({1, 2, 3, 4, 5, 50, 6}, 0), true );
printTest( "array220([1, 2, 3, 4, 5, 51, 6], 0) → false", array220({1, 2, 3, 4, 5, 51, 6}, 0), false );
printTest( "array220([1, 2, 3, 4, 4, 50, 500, 6], 0) → true", array220({1, 2, 3, 4, 4, 50, 500, 6}, 0), true );

// %% [markdown]
// # Recursion-1 > allStar

// %%
/*
Given a string, compute recursively a new string where all the adjacent chars
are now separated by a "*".

allStar("hello") → "h*e*l*l*o"
allStar("abc") → "a*b*c"
allStar("ab") → "a*b"
*/

string allStar(string str) {
    return "";
}


// tests:
printTest( "allStar(\"hello\") → \"h*e*l*l*o\"", allStar("hello"), "h*e*l*l*o" );
printTest( "allStar(\"abc\") → \"a*b*c\"", allStar("abc"), "a*b*c" );
printTest( "allStar(\"ab\") → \"a*b\"", allStar("ab"), "a*b" );
printTest( "allStar(\"a\") → \"a\"", allStar("a"), "a" );
printTest( "allStar(\"\") → \"\"", allStar(""), "" );
printTest( "allStar(\"3.14\") → \"3*.*1*4\"", allStar("3.14"), "3*.*1*4" );
printTest( "allStar(\"Chocolate\") → \"C*h*o*c*o*l*a*t*e\"", allStar("Chocolate"), "C*h*o*c*o*l*a*t*e" );
printTest( "allStar(\"1234\") → \"1*2*3*4\"", allStar("1234"), "1*2*3*4" );

// %% [markdown]
// # Recursion-1 > pairStar

// %%
/*
Given a string, compute recursively a new string where identical chars that are
adjacent in the original string are separated from each other by a "*".

pairStar("hello") → "hel*lo"
pairStar("xxyy") → "x*xy*y"
pairStar("aaaa") → "a*a*a*a"
*/

string pairStar(string str) {
    return "";
}


// tests:
printTest( "pairStar(\"hello\") → \"hel*lo\"", pairStar("hello"), "hel*lo" );
printTest( "pairStar(\"xxyy\") → \"x*xy*y\"", pairStar("xxyy"), "x*xy*y" );
printTest( "pairStar(\"aaaa\") → \"a*a*a*a\"", pairStar("aaaa"), "a*a*a*a" );
printTest( "pairStar(\"aaab\") → \"a*a*ab\"", pairStar("aaab"), "a*a*ab" );
printTest( "pairStar(\"aa\") → \"a*a\"", pairStar("aa"), "a*a" );
printTest( "pairStar(\"a\") → \"a\"", pairStar("a"), "a" );
printTest( "pairStar(\"\") → \"\"", pairStar(""), "" );
printTest( "pairStar(\"noadjacent\") → \"noadjacent\"", pairStar("noadjacent"), "noadjacent" );
printTest( "pairStar(\"abba\") → \"ab*ba\"", pairStar("abba"), "ab*ba" );
printTest( "pairStar(\"abbba\") → \"ab*b*ba\"", pairStar("abbba"), "ab*b*ba" );

// %% [markdown]
// # Recursion-1 > endX

// %%
/*
Given a string, compute recursively a new string where all the lowercase 'x'
chars have been moved to the end of the string.

endX("xxre") → "rexx"
endX("xxhixx") → "hixxxx"
endX("xhixhix") → "hihixxx"
*/

string endX(string str) {
    return "";
}


// tests:
printTest( "endX(\"xxre\") → \"rexx\"", endX("xxre"), "rexx" );
printTest( "endX(\"xxhixx\") → \"hixxxx\"", endX("xxhixx"), "hixxxx" );
printTest( "endX(\"xhixhix\") → \"hihixxx\"", endX("xhixhix"), "hihixxx" );
printTest( "endX(\"hiy\") → \"hiy\"", endX("hiy"), "hiy" );
printTest( "endX(\"h\") → \"h\"", endX("h"), "h" );
printTest( "endX(\"x\") → \"x\"", endX("x"), "x" );
printTest( "endX(\"xx\") → \"xx\"", endX("xx"), "xx" );
printTest( "endX(\"\") → \"\"", endX(""), "" );
printTest( "endX(\"bxx\") → \"bxx\"", endX("bxx"), "bxx" );
printTest( "endX(\"bxax\") → \"baxx\"", endX("bxax"), "baxx" );
printTest( "endX(\"axaxax\") → \"aaaxxx\"", endX("axaxax"), "aaaxxx" );
printTest( "endX(\"xxhxi\") → \"hixxx\"", endX("xxhxi"), "hixxx" );

// %% [markdown]
// # Recursion-1 > countPairs

// %%
/*
Weʼll say that a "pair" in a string is two instances of a char separated by a
char. So "AxA" the Aʼs make a pair. Pairʼs can overlap, so "AxAxA" contains 3
pairs -- 2 for A and 1 for x. Recursively compute the number of pairs in the
given string.

countPairs("axa") → 1
countPairs("axax") → 2
countPairs("axbx") → 1
*/

int countPairs(string str) {
    return 0;
}


// tests:
printTest( "countPairs(\"axa\") → 1", countPairs("axa"), 1 );
printTest( "countPairs(\"axax\") → 2", countPairs("axax"), 2 );
printTest( "countPairs(\"axbx\") → 1", countPairs("axbx"), 1 );
printTest( "countPairs(\"hi\") → 0", countPairs("hi"), 0 );
printTest( "countPairs(\"hihih\") → 3", countPairs("hihih"), 3 );
printTest( "countPairs(\"ihihhh\") → 3", countPairs("ihihhh"), 3 );
printTest( "countPairs(\"ihjxhh\") → 0", countPairs("ihjxhh"), 0 );
printTest( "countPairs(\"\") → 0", countPairs(""), 0 );
printTest( "countPairs(\"a\") → 0", countPairs("a"), 0 );
printTest( "countPairs(\"aa\") → 0", countPairs("aa"), 0 );
printTest( "countPairs(\"aaa\") → 1", countPairs("aaa"), 1 );

// %% [markdown]
// # Recursion-1 > countAbc

// %%
/*
Count recursively the total number of "abc" and "aba" substrings that appear in
the given string.

countAbc("abc") → 1
countAbc("abcxxabc") → 2
countAbc("abaxxaba") → 2
*/

int countAbc(string str) {
    return 0;
}


// tests:
printTest( "countAbc(\"abc\") → 1", countAbc("abc"), 1 );
printTest( "countAbc(\"abcxxabc\") → 2", countAbc("abcxxabc"), 2 );
printTest( "countAbc(\"abaxxaba\") → 2", countAbc("abaxxaba"), 2 );
printTest( "countAbc(\"ababc\") → 2", countAbc("ababc"), 2 );
printTest( "countAbc(\"abxbc\") → 0", countAbc("abxbc"), 0 );
printTest( "countAbc(\"aaabc\") → 1", countAbc("aaabc"), 1 );
printTest( "countAbc(\"hello\") → 0", countAbc("hello"), 0 );
printTest( "countAbc(\"\") → 0", countAbc(""), 0 );
printTest( "countAbc(\"ab\") → 0", countAbc("ab"), 0 );
printTest( "countAbc(\"aba\") → 1", countAbc("aba"), 1 );
printTest( "countAbc(\"aca\") → 0", countAbc("aca"), 0 );
printTest( "countAbc(\"aaa\") → 0", countAbc("aaa"), 0 );

// %% [markdown]
// # Recursion-1 > count11

// %%
/*
Given a string, compute recursively (no loops) the number of "11" substrings in
the string. The "11" substrings should not overlap.

count11("11abc11") → 2
count11("abc11x11x11") → 3
count11("111") → 1
*/

int count11(string str) {
    return 0;
}


// tests:
printTest( "count11(\"11abc11\") → 2", count11("11abc11"), 2 );
printTest( "count11(\"abc11x11x11\") → 3", count11("abc11x11x11"), 3 );
printTest( "count11(\"111\") → 1", count11("111"), 1 );
printTest( "count11(\"1111\") → 2", count11("1111"), 2 );
printTest( "count11(\"1\") → 0", count11("1"), 0 );
printTest( "count11(\"\") → 0", count11(""), 0 );
printTest( "count11(\"hi\") → 0", count11("hi"), 0 );
printTest( "count11(\"11x111x1111\") → 4", count11("11x111x1111"), 4 );
printTest( "count11(\"1x111\") → 1", count11("1x111"), 1 );
printTest( "count11(\"1Hello1\") → 0", count11("1Hello1"), 0 );
printTest( "count11(\"Hello\") → 0", count11("Hello"), 0 );

// %% [markdown]
// # Recursion-1 > stringClean

// %%
/*
Given a string, return recursively a "cleaned" string where adjacent chars that
are the same have been reduced to a single char. So "yyzzza" yields "yza".

stringClean("yyzzza") → "yza"
stringClean("abbbcdd") → "abcd"
stringClean("Hello") → "Helo"
*/

string stringClean(string str) {
    return "";
}


// tests:
printTest( "stringClean(\"yyzzza\") → \"yza\"", stringClean("yyzzza"), "yza" );
printTest( "stringClean(\"abbbcdd\") → \"abcd\"", stringClean("abbbcdd"), "abcd" );
printTest( "stringClean(\"Hello\") → \"Helo\"", stringClean("Hello"), "Helo" );
printTest( "stringClean(\"XXabcYY\") → \"XabcY\"", stringClean("XXabcYY"), "XabcY" );
printTest( "stringClean(\"112ab445\") → \"12ab45\"", stringClean("112ab445"), "12ab45" );
printTest( "stringClean(\"Hello Bookkeeper\") → \"Helo Bokeper\"", stringClean("Hello Bookkeeper"), "Helo Bokeper" );

// %% [markdown]
// # Recursion-1 > countHi2

// %%
/*
Given a string, compute recursively the number of times lowercase "hi" appears
in the string, however do not count "hi" that have an 'x' immedately before
them.

countHi2("ahixhi") → 1
countHi2("ahibhi") → 2
countHi2("xhixhi") → 0
*/

int countHi2(string str) {
    return 0;
}


// tests:
printTest( "countHi2(\"ahixhi\") → 1", countHi2("ahixhi"), 1 );
printTest( "countHi2(\"ahibhi\") → 2", countHi2("ahibhi"), 2 );
printTest( "countHi2(\"xhixhi\") → 0", countHi2("xhixhi"), 0 );
printTest( "countHi2(\"hixhi\") → 1", countHi2("hixhi"), 1 );
printTest( "countHi2(\"hixhhi\") → 2", countHi2("hixhhi"), 2 );
printTest( "countHi2(\"hihihi\") → 3", countHi2("hihihi"), 3 );
printTest( "countHi2(\"hihihix\") → 3", countHi2("hihihix"), 3 );
printTest( "countHi2(\"xhihihix\") → 2", countHi2("xhihihix"), 2 );
printTest( "countHi2(\"xxhi\") → 0", countHi2("xxhi"), 0 );
printTest( "countHi2(\"hixxhi\") → 1", countHi2("hixxhi"), 1 );
printTest( "countHi2(\"hi\") → 1", countHi2("hi"), 1 );
printTest( "countHi2(\"xxxx\") → 0", countHi2("xxxx"), 0 );
printTest( "countHi2(\"h\") → 0", countHi2("h"), 0 );
printTest( "countHi2(\"x\") → 0", countHi2("x"), 0 );
printTest( "countHi2(\"\") → 0", countHi2(""), 0 );
printTest( "countHi2(\"Hellohi\") → 1", countHi2("Hellohi"), 1 );

// %% [markdown]
// # Recursion-1 > parenBit

// %%
/*
Given a string that contains a single pair of parenthesis, compute recursively a
new string made of only of the parenthesis and their contents, so "xyz(abc)123"
yields "(abc)".

parenBit("xyz(abc)123") → "(abc)"
parenBit("x(hello)") → "(hello)"
parenBit("(xy)1") → "(xy)"
*/

string parenBit(string str) {
    return "";
}


// tests:
printTest( "parenBit(\"xyz(abc)123\") → \"(abc)\"", parenBit("xyz(abc)123"), "(abc)" );
printTest( "parenBit(\"x(hello)\") → \"(hello)\"", parenBit("x(hello)"), "(hello)" );
printTest( "parenBit(\"(xy)1\") → \"(xy)\"", parenBit("(xy)1"), "(xy)" );
printTest( "parenBit(\"not really (possible)\") → \"(possible)\"", parenBit("not really (possible)"), "(possible)" );
printTest( "parenBit(\"(abc)\") → \"(abc)\"", parenBit("(abc)"), "(abc)" );
printTest( "parenBit(\"(abc)xyz\") → \"(abc)\"", parenBit("(abc)xyz"), "(abc)" );
printTest( "parenBit(\"(abc)x\") → \"(abc)\"", parenBit("(abc)x"), "(abc)" );
printTest( "parenBit(\"(x)\") → \"(x)\"", parenBit("(x)"), "(x)" );
printTest( "parenBit(\"()\") → \"()\"", parenBit("()"), "()" );
printTest( "parenBit(\"res (ipsa) loquitor\") → \"(ipsa)\"", parenBit("res (ipsa) loquitor"), "(ipsa)" );
printTest( "parenBit(\"hello(not really)there\") → \"(not really)\"", parenBit("hello(not really)there"), "(not really)" );
printTest( "parenBit(\"ab(ab)ab\") → \"(ab)\"", parenBit("ab(ab)ab"), "(ab)" );

// %% [markdown]
// # Recursion-1 > nestParen

// %%
/*
Given a string, return true if it is a nesting of zero or more pairs of
parenthesis, like "(())" or "((()))". Suggestion: check the first and last
chars, and then recur on whatʼs inside them.

nestParen("(())") → true
nestParen("((()))") → true
nestParen("(((x))") → false
*/

bool nestParen(string str) {
    return false;
}


// tests:
printTest( "nestParen(\"(())\") → true", nestParen("(())"), true );
printTest( "nestParen(\"((()))\") → true", nestParen("((()))"), true );
printTest( "nestParen(\"(((x))\") → false", nestParen("(((x))"), false );
printTest( "nestParen(\"((())\") → false", nestParen("((())"), false );
printTest( "nestParen(\"((()()\") → false", nestParen("((()()"), false );
printTest( "nestParen(\"()\") → true", nestParen("()"), true );
printTest( "nestParen(\"\") → true", nestParen(""), true );
printTest( "nestParen(\"(yy)\") → false", nestParen("(yy)"), false );
printTest( "nestParen(\"(())\") → true", nestParen("(())"), true );
printTest( "nestParen(\"(((y))\") → false", nestParen("(((y))"), false );
printTest( "nestParen(\"((y)))\") → false", nestParen("((y)))"), false );
printTest( "nestParen(\"((()))\") → true", nestParen("((()))"), true );
printTest( "nestParen(\"(())))\") → false", nestParen("(())))"), false );
printTest( "nestParen(\"((yy())))\") → false", nestParen("((yy())))"), false );
printTest( "nestParen(\"(((())))\") → true", nestParen("(((())))"), true );

// %% [markdown]
// # Recursion-1 > strCount

// %%
/*
Given a string and a non-empty substring sub, compute recursively the number of
times that sub appears in the string, without the sub strings overlapping.

strCount("catcowcat", "cat") → 2
strCount("catcowcat", "cow") → 1
strCount("catcowcat", "dog") → 0
*/

int strCount(string str, string sub) {
    return 0;
}


// tests:
printTest( "strCount(\"catcowcat\", \"cat\") → 2", strCount("catcowcat", "cat"), 2 );
printTest( "strCount(\"catcowcat\", \"cow\") → 1", strCount("catcowcat", "cow"), 1 );
printTest( "strCount(\"catcowcat\", \"dog\") → 0", strCount("catcowcat", "dog"), 0 );
printTest( "strCount(\"cacatcowcat\", \"cat\") → 2", strCount("cacatcowcat", "cat"), 2 );
printTest( "strCount(\"xyx\", \"x\") → 2", strCount("xyx", "x"), 2 );
printTest( "strCount(\"iiiijj\", \"i\") → 4", strCount("iiiijj", "i"), 4 );
printTest( "strCount(\"iiiijj\", \"ii\") → 2", strCount("iiiijj", "ii"), 2 );
printTest( "strCount(\"iiiijj\", \"iii\") → 1", strCount("iiiijj", "iii"), 1 );
printTest( "strCount(\"iiiijj\", \"j\") → 2", strCount("iiiijj", "j"), 2 );
printTest( "strCount(\"iiiijj\", \"jj\") → 1", strCount("iiiijj", "jj"), 1 );
printTest( "strCount(\"aaabababab\", \"ab\") → 4", strCount("aaabababab", "ab"), 4 );
printTest( "strCount(\"aaabababab\", \"aa\") → 1", strCount("aaabababab", "aa"), 1 );
printTest( "strCount(\"aaabababab\", \"a\") → 6", strCount("aaabababab", "a"), 6 );
printTest( "strCount(\"aaabababab\", \"b\") → 4", strCount("aaabababab", "b"), 4 );

// %% [markdown]
// # Recursion-1 > strCopies

// %%
/*
Given a string and a non-empty substring sub, compute recursively if at least n
copies of sub appear in the string somewhere, possibly with overlapping. N will
be non-negative.

strCopies("catcowcat", "cat", 2) → true
strCopies("catcowcat", "cow", 2) → false
strCopies("catcowcat", "cow", 1) → true
*/

bool strCopies(string str, string sub, int n) {
    return false;
}


// tests:
printTest( "strCopies(\"catcowcat\", \"cat\", 2) → true", strCopies("catcowcat", "cat", 2), true );
printTest( "strCopies(\"catcowcat\", \"cow\", 2) → false", strCopies("catcowcat", "cow", 2), false );
printTest( "strCopies(\"catcowcat\", \"cow\", 1) → true", strCopies("catcowcat", "cow", 1), true );
printTest( "strCopies(\"iiijjj\", \"i\", 3) → true", strCopies("iiijjj", "i", 3), true );
printTest( "strCopies(\"iiijjj\", \"i\", 4) → false", strCopies("iiijjj", "i", 4), false );
printTest( "strCopies(\"iiijjj\", \"ii\", 2) → true", strCopies("iiijjj", "ii", 2), true );
printTest( "strCopies(\"iiijjj\", \"ii\", 3) → false", strCopies("iiijjj", "ii", 3), false );
printTest( "strCopies(\"iiijjj\", \"x\", 3) → false", strCopies("iiijjj", "x", 3), false );
printTest( "strCopies(\"iiijjj\", \"x\", 0) → true", strCopies("iiijjj", "x", 0), true );
printTest( "strCopies(\"iiiiij\", \"iii\", 3) → true", strCopies("iiiiij", "iii", 3), true );
printTest( "strCopies(\"iiiiij\", \"iii\", 4) → false", strCopies("iiiiij", "iii", 4), false );
printTest( "strCopies(\"ijiiiiij\", \"iiii\", 2) → true", strCopies("ijiiiiij", "iiii", 2), true );
printTest( "strCopies(\"ijiiiiij\", \"iiii\", 3) → false", strCopies("ijiiiiij", "iiii", 3), false );
printTest( "strCopies(\"dogcatdogcat\", \"dog\", 2) → true", strCopies("dogcatdogcat", "dog", 2), true );

// %% [markdown]
// # Recursion-1 > strDist

// %%
/*
Given a string and a non-empty substring sub, compute recursively the largest
substring which starts and ends with sub and return its length.

strDist("catcowcat", "cat") → 9
strDist("catcowcat", "cow") → 3
strDist("cccatcowcatxx", "cat") → 9
*/

int strDist(string str, string sub) {
    return 0;
}


// tests:
printTest( "strDist(\"catcowcat\", \"cat\") → 9", strDist("catcowcat", "cat"), 9 );
printTest( "strDist(\"catcowcat\", \"cow\") → 3", strDist("catcowcat", "cow"), 3 );
printTest( "strDist(\"cccatcowcatxx\", \"cat\") → 9", strDist("cccatcowcatxx", "cat"), 9 );
printTest( "strDist(\"abccatcowcatcatxyz\", \"cat\") → 12", strDist("abccatcowcatcatxyz", "cat"), 12 );
printTest( "strDist(\"xyx\", \"x\") → 3", strDist("xyx", "x"), 3 );
printTest( "strDist(\"xyx\", \"y\") → 1", strDist("xyx", "y"), 1 );
printTest( "strDist(\"xyx\", \"z\") → 0", strDist("xyx", "z"), 0 );
printTest( "strDist(\"z\", \"z\") → 1", strDist("z", "z"), 1 );
printTest( "strDist(\"x\", \"z\") → 0", strDist("x", "z"), 0 );
printTest( "strDist(\"\", \"z\") → 0", strDist("", "z"), 0 );
printTest( "strDist(\"hiHellohihihi\", \"hi\") → 13", strDist("hiHellohihihi", "hi"), 13 );
printTest( "strDist(\"hiHellohihihi\", \"hih\") → 5", strDist("hiHellohihihi", "hih"), 5 );
printTest( "strDist(\"hiHellohihihi\", \"o\") → 1", strDist("hiHellohihihi", "o"), 1 );
printTest( "strDist(\"hiHellohihihi\", \"ll\") → 2", strDist("hiHellohihihi", "ll"), 2 );
