// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
}
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # String-1 > helloName

// %%
/*
Given a string name, e.g. "Bob", return a greeting of the form "Hello Bob!".

helloName("Bob") → "Hello Bob!"
helloName("Alice") → "Hello Alice!"
helloName("X") → "Hello X!"
*/

string helloName(string name) {
    return "";
}


// tests:
printTest( "helloName(\"Bob\") → \"Hello Bob!\"", helloName("Bob"), "Hello Bob!" );
printTest( "helloName(\"Alice\") → \"Hello Alice!\"", helloName("Alice"), "Hello Alice!" );
printTest( "helloName(\"X\") → \"Hello X!\"", helloName("X"), "Hello X!" );
printTest( "helloName(\"Dolly\") → \"Hello Dolly!\"", helloName("Dolly"), "Hello Dolly!" );
printTest( "helloName(\"Alpha\") → \"Hello Alpha!\"", helloName("Alpha"), "Hello Alpha!" );
printTest( "helloName(\"Omega\") → \"Hello Omega!\"", helloName("Omega"), "Hello Omega!" );
printTest( "helloName(\"Goodbye\") → \"Hello Goodbye!\"", helloName("Goodbye"), "Hello Goodbye!" );
printTest( "helloName(\"ho ho ho\") → \"Hello ho ho ho!\"", helloName("ho ho ho"), "Hello ho ho ho!" );
printTest( "helloName(\"xyz!\") → \"Hello xyz!!\"", helloName("xyz!"), "Hello xyz!!" );
printTest( "helloName(\"Hello\") → \"Hello Hello!\"", helloName("Hello"), "Hello Hello!" );

// %% [markdown]
// # String-1 > makeAbba

// %%
/*
Given two strings, a and b, return the result of putting them together in the
order abba, e.g. "Hi" and "Bye" returns "HiByeByeHi".

makeAbba("Hi", "Bye") → "HiByeByeHi"
makeAbba("Yo", "Alice") → "YoAliceAliceYo"
makeAbba("What", "Up") → "WhatUpUpWhat"
*/

string makeAbba(string a, string b) {
    return "";
}


// tests:
printTest( "makeAbba(\"Hi\", \"Bye\") → \"HiByeByeHi\"", makeAbba("Hi", "Bye"), "HiByeByeHi" );
printTest( "makeAbba(\"Yo\", \"Alice\") → \"YoAliceAliceYo\"", makeAbba("Yo", "Alice"), "YoAliceAliceYo" );
printTest( "makeAbba(\"What\", \"Up\") → \"WhatUpUpWhat\"", makeAbba("What", "Up"), "WhatUpUpWhat" );
printTest( "makeAbba(\"aaa\", \"bbb\") → \"aaabbbbbbaaa\"", makeAbba("aaa", "bbb"), "aaabbbbbbaaa" );
printTest( "makeAbba(\"x\", \"y\") → \"xyyx\"", makeAbba("x", "y"), "xyyx" );
printTest( "makeAbba(\"x\", \"\") → \"xx\"", makeAbba("x", ""), "xx" );
printTest( "makeAbba(\"\", \"y\") → \"yy\"", makeAbba("", "y"), "yy" );
printTest( "makeAbba(\"Bo\", \"Ya\") → \"BoYaYaBo\"", makeAbba("Bo", "Ya"), "BoYaYaBo" );
printTest( "makeAbba(\"Ya\", \"Ya\") → \"YaYaYaYa\"", makeAbba("Ya", "Ya"), "YaYaYaYa" );

// %% [markdown]
// # String-1 > makeTags

// %%
/*
The web is built with HTML strings like "<i>Yay</i>" which draws Yay as italic
text. In this example, the "i" tag makes <i> and </i> which surround the word
"Yay". Given tag and word strings, create the HTML string with tags around the
word, e.g. "<i>Yay</i>".

makeTags("i", "Yay") → "<i>Yay</i>"
makeTags("i", "Hello") → "<i>Hello</i>"
makeTags("cite", "Yay") → "<cite>Yay</cite>"
*/

string makeTags(string tag, string word) {
    return "";
}


// tests:
printTest( "makeTags(\"i\", \"Yay\") → \"<i>Yay</i>\"", makeTags("i", "Yay"), "<i>Yay</i>" );
printTest( "makeTags(\"i\", \"Hello\") → \"<i>Hello</i>\"", makeTags("i", "Hello"), "<i>Hello</i>" );
printTest( "makeTags(\"cite\", \"Yay\") → \"<cite>Yay</cite>\"", makeTags("cite", "Yay"), "<cite>Yay</cite>" );
printTest( "makeTags(\"address\", \"here\") → \"<address>here</address>\"", makeTags("address", "here"), "<address>here</address>" );
printTest( "makeTags(\"body\", \"Heart\") → \"<body>Heart</body>\"", makeTags("body", "Heart"), "<body>Heart</body>" );
printTest( "makeTags(\"i\", \"i\") → \"<i>i</i>\"", makeTags("i", "i"), "<i>i</i>" );
printTest( "makeTags(\"i\", \"\") → \"<i></i>\"", makeTags("i", ""), "<i></i>" );

// %% [markdown]
// # String-1 > makeOutWord

// %%
/*
Given an "out" string length 4, such as "<<>>", and a word, return a new string
where the word is in the middle of the out string, e.g. "<<word>>". Note: use
str.substring(i, j) to extract the String starting at index i and going up to
but not including index j.

makeOutWord("<<>>", "Yay") → "<<Yay>>"
makeOutWord("<<>>", "WooHoo") → "<<WooHoo>>"
makeOutWord("[[]]", "word") → "[[word]]"
*/

string makeOutWord(string out, string word) {
    return "";
}


// tests:
printTest( "makeOutWord(\"<<>>\", \"Yay\") → \"<<Yay>>\"", makeOutWord("<<>>", "Yay"), "<<Yay>>" );
printTest( "makeOutWord(\"<<>>\", \"WooHoo\") → \"<<WooHoo>>\"", makeOutWord("<<>>", "WooHoo"), "<<WooHoo>>" );
printTest( "makeOutWord(\"[[]]\", \"word\") → \"[[word]]\"", makeOutWord("{{}}", "word"), "{{word}}" );
printTest( "makeOutWord(\"HHoo\", \"Hello\") → \"HHHellooo\"", makeOutWord("HHoo", "Hello"), "HHHellooo" );
printTest( "makeOutWord(\"abyz\", \"YAY\") → \"abYAYyz\"", makeOutWord("abyz", "YAY"), "abYAYyz" );

// %% [markdown]
// # String-1 > extraEnd

// %%
/*
Given a string, return a new string made of 3 copies of the last 2 chars of the
original string. The string length will be at least 2.

extraEnd("Hello") → "lololo"
extraEnd("ab") → "ababab"
extraEnd("Hi") → "HiHiHi"
*/

string extraEnd(string str) {
    return "";
}


// tests:
printTest( "extraEnd(\"Hello\") → \"lololo\"", extraEnd("Hello"), "lololo" );
printTest( "extraEnd(\"ab\") → \"ababab\"", extraEnd("ab"), "ababab" );
printTest( "extraEnd(\"Hi\") → \"HiHiHi\"", extraEnd("Hi"), "HiHiHi" );
printTest( "extraEnd(\"Candy\") → \"dydydy\"", extraEnd("Candy"), "dydydy" );
printTest( "extraEnd(\"Code\") → \"dedede\"", extraEnd("Code"), "dedede" );

// %% [markdown]
// # String-1 > firstTwo

// %%
/*
Given a string, return the string made of its first two chars, so the String
"Hello" yields "He". If the string is shorter than length 2, return whatever
there is, so "X" yields "X", and the empty string "" yields the empty string "".
Note that str.length() returns the length of a string.

firstTwo("Hello") → "He"
firstTwo("abcdefg") → "ab"
firstTwo("ab") → "ab"
*/

string firstTwo(string str) {
    return "";
}


// tests:
printTest( "firstTwo(\"Hello\") → \"He\"", firstTwo("Hello"), "He" );
printTest( "firstTwo(\"abcdefg\") → \"ab\"", firstTwo("abcdefg"), "ab" );
printTest( "firstTwo(\"ab\") → \"ab\"", firstTwo("ab"), "ab" );
printTest( "firstTwo(\"a\") → \"a\"", firstTwo("a"), "a" );
printTest( "firstTwo(\"\") → \"\"", firstTwo(""), "" );
printTest( "firstTwo(\"Kitten\") → \"Ki\"", firstTwo("Kitten"), "Ki" );
printTest( "firstTwo(\"hi\") → \"hi\"", firstTwo("hi"), "hi" );
printTest( "firstTwo(\"hiya\") → \"hi\"", firstTwo("hiya"), "hi" );

// %% [markdown]
// # String-1 > firstHalf

// %%
/*
Given a string of even length, return the first half. So the string "WooHoo"
yields "Woo".

firstHalf("WooHoo") → "Woo"
firstHalf("HelloThere") → "Hello"
firstHalf("abcdef") → "abc"
*/

string firstHalf(string str) {
    return "";
}


// tests:
printTest( "firstHalf(\"WooHoo\") → \"Woo\"", firstHalf("WooHoo"), "Woo" );
printTest( "firstHalf(\"HelloThere\") → \"Hello\"", firstHalf("HelloThere"), "Hello" );
printTest( "firstHalf(\"abcdef\") → \"abc\"", firstHalf("abcdef"), "abc" );
printTest( "firstHalf(\"ab\") → \"a\"", firstHalf("ab"), "a" );
printTest( "firstHalf(\"\") → \"\"", firstHalf(""), "" );
printTest( "firstHalf(\"0123456789\") → \"01234\"", firstHalf("0123456789"), "01234" );
printTest( "firstHalf(\"kitten\") → \"kit\"", firstHalf("kitten"), "kit" );

// %% [markdown]
// # String-1 > withoutEnd

// %%
/*
Given a string, return a version without the first and last char, so "Hello"
yields "ell". The string length will be at least 2.

withoutEnd("Hello") → "ell"
withoutEnd("java") → "av"
withoutEnd("coding") → "odin"
*/

string withoutEnd(string str) {
    return "";
}


// tests:
printTest( "withoutEnd(\"Hello\") → \"ell\"", withoutEnd("Hello"), "ell" );
printTest( "withoutEnd(\"java\") → \"av\"", withoutEnd("java"), "av" );
printTest( "withoutEnd(\"coding\") → \"odin\"", withoutEnd("coding"), "odin" );
printTest( "withoutEnd(\"code\") → \"od\"", withoutEnd("code"), "od" );
printTest( "withoutEnd(\"ab\") → \"\"", withoutEnd("ab"), "" );
printTest( "withoutEnd(\"Chocolate!\") → \"hocolate\"", withoutEnd("Chocolate!"), "hocolate" );
printTest( "withoutEnd(\"kitten\") → \"itte\"", withoutEnd("kitten"), "itte" );
printTest( "withoutEnd(\"woohoo\") → \"ooho\"", withoutEnd("woohoo"), "ooho" );

// %% [markdown]
// # String-1 > comboString

// %%
/*
Given 2 strings, a and b, return a string of the form short+long+short, with the
shorter string on the outside and the longer string on the inside. The strings
will not be the same length, but they may be empty (length 0).

comboString("Hello", "hi") → "hiHellohi"
comboString("hi", "Hello") → "hiHellohi"
comboString("aaa", "b") → "baaab"
*/

string comboString(string a, string b) {
    return "";
}


// tests:
printTest( "comboString(\"Hello\", \"hi\") → \"hiHellohi\"", comboString("Hello", "hi"), "hiHellohi" );
printTest( "comboString(\"hi\", \"Hello\") → \"hiHellohi\"", comboString("hi", "Hello"), "hiHellohi" );
printTest( "comboString(\"aaa\", \"b\") → \"baaab\"", comboString("aaa", "b"), "baaab" );
printTest( "comboString(\"b\", \"aaa\") → \"baaab\"", comboString("b", "aaa"), "baaab" );
printTest( "comboString(\"aaa\", \"\") → \"aaa\"", comboString("aaa", ""), "aaa" );
printTest( "comboString(\"\", \"bb\") → \"bb\"", comboString("", "bb"), "bb" );
printTest( "comboString(\"aaa\", \"1234\") → \"aaa1234aaa\"", comboString("aaa", "1234"), "aaa1234aaa" );
printTest( "comboString(\"aaa\", \"bb\") → \"bbaaabb\"", comboString("aaa", "bb"), "bbaaabb" );
printTest( "comboString(\"a\", \"bb\") → \"abba\"", comboString("a", "bb"), "abba" );
printTest( "comboString(\"bb\", \"a\") → \"abba\"", comboString("bb", "a"), "abba" );
printTest( "comboString(\"xyz\", \"ab\") → \"abxyzab\"", comboString("xyz", "ab"), "abxyzab" );

// %% [markdown]
// # String-1 > nonStart

// %%
/*
Given 2 strings, return their concatenation, except omit the first char of each.
The strings will be at least length 1.

nonStart("Hello", "There") → "ellohere"
nonStart("java", "code") → "avaode"
nonStart("shotl", "java") → "hotlava"
*/

string nonStart(string a, string b) {
    return "";
}


// tests:
printTest( "nonStart(\"Hello\", \"There\") → \"ellohere\"", nonStart("Hello", "There"), "ellohere" );
printTest( "nonStart(\"java\", \"code\") → \"avaode\"", nonStart("java", "code"), "avaode" );
printTest( "nonStart(\"shotl\", \"java\") → \"hotlava\"", nonStart("shotl", "java"), "hotlava" );
printTest( "nonStart(\"ab\", \"xy\") → \"by\"", nonStart("ab", "xy"), "by" );
printTest( "nonStart(\"ab\", \"x\") → \"b\"", nonStart("ab", "x"), "b" );
printTest( "nonStart(\"x\", \"ac\") → \"c\"", nonStart("x", "ac"), "c" );
printTest( "nonStart(\"a\", \"x\") → \"\"", nonStart("a", "x"), "" );
printTest( "nonStart(\"kit\", \"kat\") → \"itat\"", nonStart("kit", "kat"), "itat" );
printTest( "nonStart(\"mart\", \"dart\") → \"artart\"", nonStart("mart", "dart"), "artart" );

// %% [markdown]
// # String-1 > left2

// %%
/*
Given a string, return a "rotated left 2" version where the first 2 chars are
moved to the end. The string length will be at least 2.

left2("Hello") → "lloHe"
left2("java") → "vaja"
left2("Hi") → "Hi"
*/

string left2(string str) {
    return "";
}


// tests:
printTest( "left2(\"Hello\") → \"lloHe\"", left2("Hello"), "lloHe" );
printTest( "left2(\"java\") → \"vaja\"", left2("java"), "vaja" );
printTest( "left2(\"Hi\") → \"Hi\"", left2("Hi"), "Hi" );
printTest( "left2(\"code\") → \"deco\"", left2("code"), "deco" );
printTest( "left2(\"cat\") → \"tca\"", left2("cat"), "tca" );
printTest( "left2(\"12345\") → \"34512\"", left2("12345"), "34512" );
printTest( "left2(\"Chocolate\") → \"ocolateCh\"", left2("Chocolate"), "ocolateCh" );
printTest( "left2(\"bricks\") → \"icksbr\"", left2("bricks"), "icksbr" );

// %% [markdown]
// # String-1 > right2

// %%
/*
Given a string, return a "rotated right 2" version where the last 2 chars are
moved to the start. The string length will be at least 2.

right2("Hello") → "loHel"
right2("java") → "vaja"
right2("Hi") → "Hi"
*/

string right2(string str) {
    return "";
}


// tests:
printTest( "right2(\"Hello\") → \"loHel\"", right2("Hello"), "loHel" );
printTest( "right2(\"java\") → \"vaja\"", right2("java"), "vaja" );
printTest( "right2(\"Hi\") → \"Hi\"", right2("Hi"), "Hi" );
printTest( "right2(\"code\") → \"deco\"", right2("code"), "deco" );
printTest( "right2(\"cat\") → \"atc\"", right2("cat"), "atc" );
printTest( "right2(\"12345\") → \"45123\"", right2("12345"), "45123" );

// %% [markdown]
// # String-1 > theEnd

// %%
/*


theEnd("Hello", true) → "H"
theEnd("Hello", false) → "o"
theEnd("oh", true) → "o"
*/

string theEnd(string str, bool front) {
    return "";
}


// tests:
printTest( "theEnd(\"Hello\", true) → \"H\"", theEnd("Hello", true), "H" );
printTest( "theEnd(\"Hello\", false) → \"o\"", theEnd("Hello", false), "o" );
printTest( "theEnd(\"oh\", true) → \"o\"", theEnd("oh", true), "o" );
printTest( "theEnd(\"oh\", false) → \"h\"", theEnd("oh", false), "h" );
printTest( "theEnd(\"x\", true) → \"x\"", theEnd("x", true), "x" );
printTest( "theEnd(\"x\", false) → \"x\"", theEnd("x", false), "x" );
printTest( "theEnd(\"java\", true) → \"j\"", theEnd("java", true), "j" );
printTest( "theEnd(\"chocolate\", false) → \"e\"", theEnd("chocolate", false), "e" );
printTest( "theEnd(\"1234\", true) → \"1\"", theEnd("1234", true), "1" );
printTest( "theEnd(\"code\", false) → \"e\"", theEnd("code", false), "e" );

// %% [markdown]
// # String-1 > withouEnd2

// %%
/*
Given a string, return a version without both the first and last char of the
string. The string may be any length, including 0.

withouEnd2("Hello") → "ell"
withouEnd2("abc") → "b"
withouEnd2("ab") → ""
*/

string withouEnd2(string str) {
    return "";
}


// tests:
printTest( "withouEnd2(\"Hello\") → \"ell\"", withouEnd2("Hello"), "ell" );
printTest( "withouEnd2(\"abc\") → \"b\"", withouEnd2("abc"), "b" );
printTest( "withouEnd2(\"ab\") → \"\"", withouEnd2("ab"), "" );
printTest( "withouEnd2(\"a\") → \"\"", withouEnd2("a"), "" );
printTest( "withouEnd2(\"\") → \"\"", withouEnd2(""), "" );
printTest( "withouEnd2(\"coldy\") → \"old\"", withouEnd2("coldy"), "old" );
printTest( "withouEnd2(\"java code\") → \"ava cod\"", withouEnd2("java code"), "ava cod" );

// %% [markdown]
// # String-1 > middleTwo

// %%
/*
Given a string of even length, return a string made of the middle two chars, so
the string "string" yields "ri". The string length will be at least 2.

middleTwo("string") → "ri"
middleTwo("code") → "od"
middleTwo("Practice") → "ct"
*/

string middleTwo(string str) {
    return "";
}


// tests:
printTest( "middleTwo(\"string\") → \"ri\"", middleTwo("string"), "ri" );
printTest( "middleTwo(\"code\") → \"od\"", middleTwo("code"), "od" );
printTest( "middleTwo(\"Practice\") → \"ct\"", middleTwo("Practice"), "ct" );
printTest( "middleTwo(\"ab\") → \"ab\"", middleTwo("ab"), "ab" );
printTest( "middleTwo(\"0123456789\") → \"45\"", middleTwo("0123456789"), "45" );

// %% [markdown]
// # String-1 > endsLy

// %%
/*
Given a string, return true if it ends in "ly".

endsLy("oddly") → true
endsLy("y") → false
endsLy("oddy") → false
*/

bool endsLy(string str) {
    return false;
}


// tests:
printTest( "endsLy(\"oddly\") → true", endsLy("oddly"), true );
printTest( "endsLy(\"y\") → false", endsLy("y"), false );
printTest( "endsLy(\"oddy\") → false", endsLy("oddy"), false );
printTest( "endsLy(\"oddl\") → false", endsLy("oddl"), false );
printTest( "endsLy(\"olydd\") → false", endsLy("olydd"), false );
printTest( "endsLy(\"ly\") → true", endsLy("ly"), true );
printTest( "endsLy(\"\") → false", endsLy(""), false );
printTest( "endsLy(\"falsey\") → false", endsLy("falsey"), false );
printTest( "endsLy(\"evenly\") → true", endsLy("evenly"), true );

// %% [markdown]
// # String-1 > nTwice

// %%
/*
Given a string and an int n, return a string made of the first and last n chars
from the string. The string length will be at least n.

nTwice("Hello", 2) → "Helo"
nTwice("Chocolate", 3) → "Choate"
nTwice("Chocolate", 1) → "Ce"
*/

string nTwice(string str, int n) {
    return "";
}


// tests:
printTest( "nTwice(\"Hello\", 2) → \"Helo\"", nTwice("Hello", 2), "Helo" );
printTest( "nTwice(\"Chocolate\", 3) → \"Choate\"", nTwice("Chocolate", 3), "Choate" );
printTest( "nTwice(\"Chocolate\", 1) → \"Ce\"", nTwice("Chocolate", 1), "Ce" );
printTest( "nTwice(\"Chocolate\", 0) → \"\"", nTwice("Chocolate", 0), "" );
printTest( "nTwice(\"Hello\", 4) → \"Hellello\"", nTwice("Hello", 4), "Hellello" );
printTest( "nTwice(\"Code\", 4) → \"CodeCode\"", nTwice("Code", 4), "CodeCode" );
printTest( "nTwice(\"Code\", 2) → \"Code\"", nTwice("Code", 2), "Code" );

// %% [markdown]
// # String-1 > twoChar

// %%
/*
Given a string and an index, return a string length 2 starting at the given
index. If the index is too big or too small to define a string length 2, use the
first 2 chars. The string length will be at least 2.

twoChar("java", 0) → "ja"
twoChar("java", 2) → "va"
twoChar("java", 3) → "ja"
*/

string twoChar(string str, int index) {
    return "";
}


// tests:
printTest( "twoChar(\"java\", 0) → \"ja\"", twoChar("java", 0), "ja" );
printTest( "twoChar(\"java\", 2) → \"va\"", twoChar("java", 2), "va" );
printTest( "twoChar(\"java\", 3) → \"ja\"", twoChar("java", 3), "ja" );
printTest( "twoChar(\"java\", 4) → \"ja\"", twoChar("java", 4), "ja" );
printTest( "twoChar(\"java\", -1) → \"ja\"", twoChar("java", -1), "ja" );
printTest( "twoChar(\"Hello\", 0) → \"He\"", twoChar("Hello", 0), "He" );
printTest( "twoChar(\"Hello\", 1) → \"el\"", twoChar("Hello", 1), "el" );
printTest( "twoChar(\"Hello\", 99) → \"He\"", twoChar("Hello", 99), "He" );
printTest( "twoChar(\"Hello\", 3) → \"lo\"", twoChar("Hello", 3), "lo" );
printTest( "twoChar(\"Hello\", 4) → \"He\"", twoChar("Hello", 4), "He" );
printTest( "twoChar(\"Hello\", 5) → \"He\"", twoChar("Hello", 5), "He" );
printTest( "twoChar(\"Hello\", -7) → \"He\"", twoChar("Hello", -7), "He" );
printTest( "twoChar(\"Hello\", 6) → \"He\"", twoChar("Hello", 6), "He" );
printTest( "twoChar(\"Hello\", -1) → \"He\"", twoChar("Hello", -1), "He" );
printTest( "twoChar(\"yay\", 0) → \"ya\"", twoChar("yay", 0), "ya" );

// %% [markdown]
// # String-1 > middleThree

// %%
/*
Given a string of odd length, return the string length 3 from its middle, so
"Candy" yields "and". The string length will be at least 3.

middleThree("Candy") → "and"
middleThree("and") → "and"
middleThree("solving") → "lvi"
*/

string middleThree(string str) {
    return "";
}


// tests:
printTest( "middleThree(\"Candy\") → \"and\"", middleThree("Candy"), "and" );
printTest( "middleThree(\"and\") → \"and\"", middleThree("and"), "and" );
printTest( "middleThree(\"solving\") → \"lvi\"", middleThree("solving"), "lvi" );
printTest( "middleThree(\"Hi yet Hi\") → \"yet\"", middleThree("Hi yet Hi"), "yet" );
printTest( "middleThree(\"java yet java\") → \"yet\"", middleThree("java yet java"), "yet" );
printTest( "middleThree(\"Chocolate\") → \"col\"", middleThree("Chocolate"), "col" );
printTest( "middleThree(\"XabcxyzabcX\") → \"xyz\"", middleThree("XabcxyzabcX"), "xyz" );

// %% [markdown]
// # String-1 > hasBad

// %%
/*
Given a string, return true if "bad" appears starting at index 0 or 1 in the
string, such as with "badxxx" or "xbadxx" but not "xxbadxx". The string may be
any length, including 0. Note: use .equals() to compare 2 strings.

hasBad("badxx") → true
hasBad("xbadxx") → true
hasBad("xxbadxx") → false
*/

bool hasBad(string str) {
    return false;
}


// tests:
printTest( "hasBad(\"badxx\") → true", hasBad("badxx"), true );
printTest( "hasBad(\"xbadxx\") → true", hasBad("xbadxx"), true );
printTest( "hasBad(\"xxbadxx\") → false", hasBad("xxbadxx"), false );
printTest( "hasBad(\"code\") → false", hasBad("code"), false );
printTest( "hasBad(\"bad\") → true", hasBad("bad"), true );
printTest( "hasBad(\"ba\") → false", hasBad("ba"), false );
printTest( "hasBad(\"xba\") → false", hasBad("xba"), false );
printTest( "hasBad(\"xbad\") → true", hasBad("xbad"), true );
printTest( "hasBad(\"\") → false", hasBad(""), false );
printTest( "hasBad(\"badyy\") → true", hasBad("badyy"), true );

// %% [markdown]
// # String-1 > atFirst

// %%
/*
Given a string, return a string length 2 made of its first 2 chars. If the
string length is less than 2, use '@' for the missing chars.

atFirst("hello") → "he"
atFirst("hi") → "hi"
atFirst("h") → "h@"
*/

string atFirst(string str) {
    return "";
}


// tests:
printTest( "atFirst(\"hello\") → \"he\"", atFirst("hello"), "he" );
printTest( "atFirst(\"hi\") → \"hi\"", atFirst("hi"), "hi" );
printTest( "atFirst(\"h\") → \"h@\"", atFirst("h"), "h@" );
printTest( "atFirst(\"\") → \"@@\"", atFirst(""), "@@" );
printTest( "atFirst(\"kitten\") → \"ki\"", atFirst("kitten"), "ki" );
printTest( "atFirst(\"java\") → \"ja\"", atFirst("java"), "ja" );
printTest( "atFirst(\"j\") → \"j@\"", atFirst("j"), "j@" );

// %% [markdown]
// # String-1 > lastChars

// %%
/*
Given 2 strings, a and b, return a new string made of the first char of a and
the last char of b, so "yo" and "java" yields "ya". If either string is length
0, use '@' for its missing char.

lastChars("last", "chars") → "ls"
lastChars("yo", "java") → "ya"
lastChars("hi", "") → "h@"
*/

string lastChars(string a, string b) {
    return "";
}


// tests:
printTest( "lastChars(\"last\", \"chars\") → \"ls\"", lastChars("last", "chars"), "ls" );
printTest( "lastChars(\"yo\", \"java\") → \"ya\"", lastChars("yo", "java"), "ya" );
printTest( "lastChars(\"hi\", \"\") → \"h@\"", lastChars("hi", ""), "h@" );
printTest( "lastChars(\"\", \"hello\") → \"@o\"", lastChars("", "hello"), "@o" );
printTest( "lastChars(\"\", \"\") → \"@@\"", lastChars("", ""), "@@" );
printTest( "lastChars(\"kitten\", \"hi\") → \"ki\"", lastChars("kitten", "hi"), "ki" );
printTest( "lastChars(\"k\", \"zip\") → \"kp\"", lastChars("k", "zip"), "kp" );
printTest( "lastChars(\"kitten\", \"\") → \"k@\"", lastChars("kitten", ""), "k@" );
printTest( "lastChars(\"kitten\", \"zip\") → \"kp\"", lastChars("kitten", "zip"), "kp" );

// %% [markdown]
// # String-1 > conCat

// %%
/*
Given two strings, append them together (known as "concatenation") and return
the result. However, if the concatenation creates a double-char, then omit one
of the chars, so "abc" and "cat" yields "abcat".

conCat("abc", "cat") → "abcat"
conCat("dog", "cat") → "dogcat"
conCat("abc", "") → "abc"
*/

string conCat(string a, string b) {
    return "";
}


// tests:
printTest( "conCat(\"abc\", \"cat\") → \"abcat\"", conCat("abc", "cat"), "abcat" );
printTest( "conCat(\"dog\", \"cat\") → \"dogcat\"", conCat("dog", "cat"), "dogcat" );
printTest( "conCat(\"abc\", \"\") → \"abc\"", conCat("abc", ""), "abc" );
printTest( "conCat(\"\", \"cat\") → \"cat\"", conCat("", "cat"), "cat" );
printTest( "conCat(\"pig\", \"g\") → \"pig\"", conCat("pig", "g"), "pig" );
printTest( "conCat(\"pig\", \"doggy\") → \"pigdoggy\"", conCat("pig", "doggy"), "pigdoggy" );

// %% [markdown]
// # String-1 > lastTwo

// %%
/*
Given a string of any length, return a new string where the last 2 chars, if
present, are swapped, so "coding" yields "codign".

lastTwo("coding") → "codign"
lastTwo("cat") → "cta"
lastTwo("ab") → "ba"
*/

string lastTwo(string str) {
    return "";
}


// tests:
printTest( "lastTwo(\"coding\") → \"codign\"", lastTwo("coding"), "codign" );
printTest( "lastTwo(\"cat\") → \"cta\"", lastTwo("cat"), "cta" );
printTest( "lastTwo(\"ab\") → \"ba\"", lastTwo("ab"), "ba" );
printTest( "lastTwo(\"a\") → \"a\"", lastTwo("a"), "a" );
printTest( "lastTwo(\"\") → \"\"", lastTwo(""), "" );

// %% [markdown]
// # String-1 > seeColor

// %%
/*
Given a string, if the string begins with "red" or "blue" return that color
string, otherwise return the empty string.

seeColor("redxx") → "red"
seeColor("xxred") → ""
seeColor("blueTimes") → "blue"
*/

string seeColor(string str) {
    return "";
}


// tests:
printTest( "seeColor(\"redxx\") → \"red\"", seeColor("redxx"), "red" );
printTest( "seeColor(\"xxred\") → \"\"", seeColor("xxred"), "" );
printTest( "seeColor(\"blueTimes\") → \"blue\"", seeColor("blueTimes"), "blue" );
printTest( "seeColor(\"NoColor\") → \"\"", seeColor("NoColor"), "" );
printTest( "seeColor(\"red\") → \"red\"", seeColor("red"), "red" );
printTest( "seeColor(\"re\") → \"\"", seeColor("re"), "" );
printTest( "seeColor(\"blu\") → \"\"", seeColor("blu"), "" );
printTest( "seeColor(\"blue\") → \"blue\"", seeColor("blue"), "blue" );
printTest( "seeColor(\"a\") → \"\"", seeColor("a"), "" );
printTest( "seeColor(\"\") → \"\"", seeColor(""), "" );
printTest( "seeColor(\"xyzred\") → \"\"", seeColor("xyzred"), "" );

// %% [markdown]
// # String-1 > frontAgain

// %%
/*
Given a string, return true if the first 2 chars in the string also appear at
the end of the string, such as with "edited".

frontAgain("edited") → true
frontAgain("edit") → false
frontAgain("ed") → true
*/

bool frontAgain(string str) {
    return false;
}


// tests:
printTest( "frontAgain(\"edited\") → true", frontAgain("edited"), true );
printTest( "frontAgain(\"edit\") → false", frontAgain("edit"), false );
printTest( "frontAgain(\"ed\") → true", frontAgain("ed"), true );
printTest( "frontAgain(\"jj\") → true", frontAgain("jj"), true );
printTest( "frontAgain(\"jjj\") → true", frontAgain("jjj"), true );
printTest( "frontAgain(\"jjjj\") → true", frontAgain("jjjj"), true );
printTest( "frontAgain(\"jjjk\") → false", frontAgain("jjjk"), false );
printTest( "frontAgain(\"x\") → false", frontAgain("x"), false );
printTest( "frontAgain(\"\") → false", frontAgain(""), false );
printTest( "frontAgain(\"java\") → false", frontAgain("java"), false );
printTest( "frontAgain(\"javaja\") → true", frontAgain("javaja"), true );

// %% [markdown]
// # String-1 > minCat

// %%
/*
Given two strings, append them together (known as "concatenation") and return
the result. However, if the strings are different lengths, omit chars from the
longer string so it is the same length as the shorter string. So "Hello" and
"Hi" yield "loHi". The strings may be any length.

minCat("Hello", "Hi") → "loHi"
minCat("Hello", "java") → "ellojava"
minCat("java", "Hello") → "javaello"
*/

string minCat(string a, string b) {
    return "";
}


// tests:
printTest( "minCat(\"Hello\", \"Hi\") → \"loHi\"", minCat("Hello", "Hi"), "loHi" );
printTest( "minCat(\"Hello\", \"java\") → \"ellojava\"", minCat("Hello", "java"), "ellojava" );
printTest( "minCat(\"java\", \"Hello\") → \"javaello\"", minCat("java", "Hello"), "javaello" );
printTest( "minCat(\"abc\", \"x\") → \"cx\"", minCat("abc", "x"), "cx" );
printTest( "minCat(\"x\", \"abc\") → \"xc\"", minCat("x", "abc"), "xc" );
printTest( "minCat(\"abc\", \"\") → \"\"", minCat("abc", ""), "" );

// %% [markdown]
// # String-1 > extraFront

// %%
/*
Given a string, return a new string made of 3 copies of the first 2 chars of the
original string. The string may be any length. If there are fewer than 2 chars,
use whatever is there.

extraFront("Hello") → "HeHeHe"
extraFront("ab") → "ababab"
extraFront("H") → "HHH"
*/

string extraFront(string str) {
    return "";
}


// tests:
printTest( "extraFront(\"Hello\") → \"HeHeHe\"", extraFront("Hello"), "HeHeHe" );
printTest( "extraFront(\"ab\") → \"ababab\"", extraFront("ab"), "ababab" );
printTest( "extraFront(\"H\") → \"HHH\"", extraFront("H"), "HHH" );
printTest( "extraFront(\"\") → \"\"", extraFront(""), "" );
printTest( "extraFront(\"Candy\") → \"CaCaCa\"", extraFront("Candy"), "CaCaCa" );
printTest( "extraFront(\"Code\") → \"CoCoCo\"", extraFront("Code"), "CoCoCo" );

// %% [markdown]
// # String-1 > without2

// %%
/*
Given a string, if a length 2 substring appears at both its beginning and end,
return a string without the substring at the beginning, so "HelloHe" yields
"lloHe". The substring may overlap with itself, so "Hi" yields "". Otherwise,
return the original string unchanged.

without2("HelloHe") → "lloHe"
without2("HelloHi") → "HelloHi"
without2("Hi") → ""
*/

string without2(string str) {
    return "";
}


// tests:
printTest( "without2(\"HelloHe\") → \"lloHe\"", without2("HelloHe"), "lloHe" );
printTest( "without2(\"HelloHi\") → \"HelloHi\"", without2("HelloHi"), "HelloHi" );
printTest( "without2(\"Hi\") → \"\"", without2("Hi"), "" );
printTest( "without2(\"Chocolate\") → \"Chocolate\"", without2("Chocolate"), "Chocolate" );
printTest( "without2(\"xxx\") → \"x\"", without2("xxx"), "x" );
printTest( "without2(\"xx\") → \"\"", without2("xx"), "" );
printTest( "without2(\"x\") → \"x\"", without2("x"), "x" );
printTest( "without2(\"\") → \"\"", without2(""), "" );
printTest( "without2(\"Fruits\") → \"Fruits\"", without2("Fruits"), "Fruits" );

// %% [markdown]
// # String-1 > deFront

// %%
/*
Given a string, return a version without the first 2 chars. Except keep the
first char if it is 'a' and keep the second char if it is 'b'. The string may be
any length. Harder than it looks.

deFront("Hello") → "llo"
deFront("java") → "va"
deFront("away") → "aay"
*/

string deFront(string str) {    
    return "";
}


// tests:
printTest( "deFront(\"Hello\") → \"llo\"", deFront("Hello"), "llo" );
printTest( "deFront(\"java\") → \"va\"", deFront("java"), "va" );
printTest( "deFront(\"away\") → \"aay\"", deFront("away"), "aay" );
printTest( "deFront(\"axy\") → \"ay\"", deFront("axy"), "ay" );
printTest( "deFront(\"abc\") → \"abc\"", deFront("abc"), "abc" );
printTest( "deFront(\"xby\") → \"by\"", deFront("xby"), "by" );
printTest( "deFront(\"ab\") → \"ab\"", deFront("ab"), "ab" );
printTest( "deFront(\"ax\") → \"a\"", deFront("ax"), "a" );
printTest( "deFront(\"axb\") → \"ab\"", deFront("axb"), "ab" );
printTest( "deFront(\"aaa\") → \"aa\"", deFront("aaa"), "aa" );
printTest( "deFront(\"xbc\") → \"bc\"", deFront("xbc"), "bc" );
printTest( "deFront(\"bbb\") → \"bb\"", deFront("bbb"), "bb" );
printTest( "deFront(\"bazz\") → \"zz\"", deFront("bazz"), "zz" );
printTest( "deFront(\"ba\") → \"\"", deFront("ba"), "" );
printTest( "deFront(\"abxyz\") → \"abxyz\"", deFront("abxyz"), "abxyz" );
printTest( "deFront(\"hi\") → \"\"", deFront("hi"), "" );
printTest( "deFront(\"his\") → \"s\"", deFront("his"), "s" );
printTest( "deFront(\"xz\") → \"\"", deFront("xz"), "" );
printTest( "deFront(\"zzz\") → \"z\"", deFront("zzz"), "z" );

// %% [markdown]
// # String-1 > startWord

// %%
/*
Given a string and a second "word" string, we'll say that the word matches the
string if it appears at the front of the string, except its first char does not
need to match exactly. On a match, return the front of the string, or otherwise
return the empty string. So, so with the string "hippo" the word "hi" returns
"hi" and "xip" returns "hip". The word will be at least length 1.

startWord("hippo", "hi") → "hi"
startWord("hippo", "xip") → "hip"
startWord("hippo", "i") → "h"
*/

string startWord(string str, string word) {
    return "";
}


// tests:
printTest( "startWord(\"hippo\", \"hi\") → \"hi\"", startWord("hippo", "hi"), "hi" );
printTest( "startWord(\"hippo\", \"xip\") → \"hip\"", startWord("hippo", "xip"), "hip" );
printTest( "startWord(\"hippo\", \"i\") → \"h\"", startWord("hippo", "i"), "h" );
printTest( "startWord(\"hippo\", \"ix\") → \"\"", startWord("hippo", "ix"), "" );
printTest( "startWord(\"h\", \"ix\") → \"\"", startWord("h", "ix"), "" );
printTest( "startWord(\"\", \"i\") → \"\"", startWord("", "i"), "" );
printTest( "startWord(\"hip\", \"zi\") → \"hi\"", startWord("hip", "zi"), "hi" );
printTest( "startWord(\"hip\", \"zip\") → \"hip\"", startWord("hip", "zip"), "hip" );
printTest( "startWord(\"hip\", \"zig\") → \"\"", startWord("hip", "zig"), "" );
printTest( "startWord(\"h\", \"z\") → \"h\"", startWord("h", "z"), "h" );
printTest( "startWord(\"hippo\", \"xippo\") → \"hippo\"", startWord("hippo", "xippo"), "hippo" );
printTest( "startWord(\"hippo\", \"xyz\") → \"\"", startWord("hippo", "xyz"), "" );
printTest( "startWord(\"hippo\", \"hip\") → \"hip\"", startWord("hippo", "hip"), "hip" );
printTest( "startWord(\"kitten\", \"cit\") → \"kit\"", startWord("kitten", "cit"), "kit" );
printTest( "startWord(\"kit\", \"cit\") → \"kit\"", startWord("kit", "cit"), "kit" );

// %% [markdown]
// # String-1 > withoutX

// %%
/*
Given a string, if the first or last chars are 'x', return the string without
those 'x' chars, and otherwise return the string unchanged.

withoutX("xHix") → "Hi"
withoutX("xHi") → "Hi"
withoutX("Hxix") → "Hxi"
*/

string withoutX(string str) {
    return "";
}


// tests:
printTest( "withoutX(\"xHix\") → \"Hi\"", withoutX("xHix"), "Hi" );
printTest( "withoutX(\"xHi\") → \"Hi\"", withoutX("xHi"), "Hi" );
printTest( "withoutX(\"Hxix\") → \"Hxi\"", withoutX("Hxix"), "Hxi" );
printTest( "withoutX(\"Hi\") → \"Hi\"", withoutX("Hi"), "Hi" );
printTest( "withoutX(\"xxHi\") → \"xHi\"", withoutX("xxHi"), "xHi" );
printTest( "withoutX(\"Hix\") → \"Hi\"", withoutX("Hix"), "Hi" );
printTest( "withoutX(\"xaxbx\") → \"axb\"", withoutX("xaxbx"), "axb" );
printTest( "withoutX(\"xx\") → \"\"", withoutX("xx"), "" );
printTest( "withoutX(\"x\") → \"\"", withoutX("x"), "" );
printTest( "withoutX(\"\") → \"\"", withoutX(""), "" );
printTest( "withoutX(\"Hello\") → \"Hello\"", withoutX("Hello"), "Hello" );
printTest( "withoutX(\"Hexllo\") → \"Hexllo\"", withoutX("Hexllo"), "Hexllo" );

// %% [markdown]
// # String-1 > withoutX2

// %%
/*
Given a string, if one or both of the first 2 chars is 'x', return the string
without those 'x' chars, and otherwise return the string unchanged. This is a
little harder than it looks.

withoutX2("xHi") → "Hi"
withoutX2("Hxi") → "Hi"
withoutX2("Hi") → "Hi"
*/

string withoutX2(string str) {
    return "";
}


// tests:
printTest( "withoutX2(\"xHi\") → \"Hi\"", withoutX2("xHi"), "Hi" );
printTest( "withoutX2(\"Hxi\") → \"Hi\"", withoutX2("Hxi"), "Hi" );
printTest( "withoutX2(\"Hi\") → \"Hi\"", withoutX2("Hi"), "Hi" );
printTest( "withoutX2(\"xxHi\") → \"Hi\"", withoutX2("xxHi"), "Hi" );
printTest( "withoutX2(\"Hix\") → \"Hix\"", withoutX2("Hix"), "Hix" );
printTest( "withoutX2(\"xaxb\") → \"axb\"", withoutX2("xaxb"), "axb" );
printTest( "withoutX2(\"xx\") → \"\"", withoutX2("xx"), "" );
printTest( "withoutX2(\"x\") → \"\"", withoutX2("x"), "" );
printTest( "withoutX2(\"\") → \"\"", withoutX2(""), "" );
printTest( "withoutX2(\"Hello\") → \"Hello\"", withoutX2("Hello"), "Hello" );
printTest( "withoutX2(\"Hexllo\") → \"Hexllo\"", withoutX2("Hexllo"), "Hexllo" );
printTest( "withoutX2(\"xHxllo\") → \"Hxllo\"", withoutX2("xHxllo"), "Hxllo" );
