// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
}
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # String-2 > doubleChar

// %%
/*
Given a string, return a string where for every char in the original, there are
two chars.

doubleChar("The") → "TThhee"
doubleChar("AAbb") → "AAAAbbbb"
doubleChar("Hi-There") → "HHii--TThheerree"
*/

string doubleChar(string str) {
    return "";
}


// tests:
printTest( "doubleChar(\"The\") → \"TThhee\"", doubleChar("The"), "TThhee" );
printTest( "doubleChar(\"AAbb\") → \"AAAAbbbb\"", doubleChar("AAbb"), "AAAAbbbb" );
printTest( "doubleChar(\"Hi-There\") → \"HHii--TThheerree\"", doubleChar("Hi-There"), "HHii--TThheerree" );
printTest( "doubleChar(\"Word!\") → \"WWoorrdd!!\"", doubleChar("Word!"), "WWoorrdd!!" );
printTest( "doubleChar(\"!!\") → \"!!!!\"", doubleChar("!!"), "!!!!" );
printTest( "doubleChar(\"\") → \"\"", doubleChar(""), "" );
printTest( "doubleChar(\"a\") → \"aa\"", doubleChar("a"), "aa" );
printTest( "doubleChar(\".\") → \"..\"", doubleChar("."), ".." );
printTest( "doubleChar(\"aa\") → \"aaaa\"", doubleChar("aa"), "aaaa" );

// %% [markdown]
// # String-2 > countHi

// %%
/*
Return the number of times that the string "hi" appears anywhere in the given
string.

countHi("abc hi ho") → 1
countHi("ABChi hi") → 2
countHi("hihi") → 2
*/

int countHi(string str) {
    return 0;
}


// tests:
printTest( "countHi(\"abc hi ho\") → 1", countHi("abc hi ho"), 1 );
printTest( "countHi(\"ABChi hi\") → 2", countHi("ABChi hi"), 2 );
printTest( "countHi(\"hihi\") → 2", countHi("hihi"), 2 );
printTest( "countHi(\"hiHIhi\") → 2", countHi("hiHIhi"), 2 );
printTest( "countHi(\"\") → 0", countHi(""), 0 );
printTest( "countHi(\"h\") → 0", countHi("h"), 0 );
printTest( "countHi(\"hi\") → 1", countHi("hi"), 1 );
printTest( "countHi(\"Hi is no HI on ahI\") → 0", countHi("Hi is no HI on ahI"), 0 );
printTest( "countHi(\"hiho not HOHIhi\") → 2", countHi("hiho not HOHIhi"), 2 );

// %% [markdown]
// # String-2 > catDog

// %%
/*
Return true if the string "cat" and "dog" appear the same number of times in the
given string.

catDog("catdog") → true
catDog("catcat") → false
catDog("1cat1cadodog") → true
*/

bool catDog(string str) {
    return false;
}


// tests:
printTest( "catDog(\"catdog\") → true", catDog("catdog"), true );
printTest( "catDog(\"catcat\") → false", catDog("catcat"), false );
printTest( "catDog(\"1cat1cadodog\") → true", catDog("1cat1cadodog"), true );
printTest( "catDog(\"catxxdogxxxdog\") → false", catDog("catxxdogxxxdog"), false );
printTest( "catDog(\"catxdogxdogxcat\") → true", catDog("catxdogxdogxcat"), true );
printTest( "catDog(\"catxdogxdogxca\") → false", catDog("catxdogxdogxca"), false );
printTest( "catDog(\"dogdogcat\") → false", catDog("dogdogcat"), false );
printTest( "catDog(\"dogogcat\") → true", catDog("dogogcat"), true );
printTest( "catDog(\"dog\") → false", catDog("dog"), false );
printTest( "catDog(\"cat\") → false", catDog("cat"), false );
printTest( "catDog(\"ca\") → true", catDog("ca"), true );
printTest( "catDog(\"c\") → true", catDog("c"), true );
printTest( "catDog(\"\") → true", catDog(""), true );

// %% [markdown]
// # String-2 > countCode

// %%
/*
Return the number of times that the string "code" appears anywhere in the given
string, except we'll accept any letter for the 'd', so "cope" and "cooe" count.

countCode("aaacodebbb") → 1
countCode("codexxcode") → 2
countCode("cozexxcope") → 2
*/

int countCode(string str) {
    return 0;
}


// tests:
printTest( "countCode(\"aaacodebbb\") → 1", countCode("aaacodebbb"), 1 );
printTest( "countCode(\"codexxcode\") → 2", countCode("codexxcode"), 2 );
printTest( "countCode(\"cozexxcope\") → 2", countCode("cozexxcope"), 2 );
printTest( "countCode(\"cozfxxcope\") → 1", countCode("cozfxxcope"), 1 );
printTest( "countCode(\"xxcozeyycop\") → 1", countCode("xxcozeyycop"), 1 );
printTest( "countCode(\"cozcop\") → 0", countCode("cozcop"), 0 );
printTest( "countCode(\"abcxyz\") → 0", countCode("abcxyz"), 0 );
printTest( "countCode(\"code\") → 1", countCode("code"), 1 );
printTest( "countCode(\"ode\") → 0", countCode("ode"), 0 );
printTest( "countCode(\"c\") → 0", countCode("c"), 0 );
printTest( "countCode(\"\") → 0", countCode(""), 0 );
printTest( "countCode(\"AAcodeBBcoleCCccoreDD\") → 3", countCode("AAcodeBBcoleCCccoreDD"), 3 );
printTest( "countCode(\"AAcodeBBcoleCCccorfDD\") → 2", countCode("AAcodeBBcoleCCccorfDD"), 2 );
printTest( "countCode(\"coAcodeBcoleccoreDD\") → 3", countCode("coAcodeBcoleccoreDD"), 3 );

// %% [markdown]
// # String-2 > endOther

// %%
/*
Given two strings, return true if either of the strings appears at the very end
of the other string, ignoring upper/lower case differences (in other words, the
computation should not be "case sensitive"). Note:  str.toLowerCase() returns
the lowercase version of a string.

endOther("Hiabc", "abc") → true
endOther("AbC", "HiaBc") → true
endOther("abc", "abXabc") → true
*/

bool endOther(string a, string b) {
    return false;
}


// tests:
printTest( "endOther(\"Hiabc\", \"abc\") → true", endOther("Hiabc", "abc"), true );
printTest( "endOther(\"AbC\", \"HiaBc\") → true", endOther("AbC", "HiaBc"), true );
printTest( "endOther(\"abc\", \"abXabc\") → true", endOther("abc", "abXabc"), true );
printTest( "endOther(\"Hiabc\", \"abcd\") → false", endOther("Hiabc", "abcd"), false );
printTest( "endOther(\"Hiabc\", \"bc\") → true", endOther("Hiabc", "bc"), true );
printTest( "endOther(\"Hiabcx\", \"bc\") → false", endOther("Hiabcx", "bc"), false );
printTest( "endOther(\"abc\", \"abc\") → true", endOther("abc", "abc"), true );
printTest( "endOther(\"xyz\", \"12xyz\") → true", endOther("xyz", "12xyz"), true );
printTest( "endOther(\"yz\", \"12xz\") → false", endOther("yz", "12xz"), false );
printTest( "endOther(\"Z\", \"12xz\") → true", endOther("Z", "12xz"), true );
printTest( "endOther(\"12\", \"12\") → true", endOther("12", "12"), true );
printTest( "endOther(\"abcXYZ\", \"abcDEF\") → false", endOther("abcXYZ", "abcDEF"), false );
printTest( "endOther(\"ab\", \"ab12\") → false", endOther("ab", "ab12"), false );
printTest( "endOther(\"ab\", \"12ab\") → true", endOther("ab", "12ab"), true );

// %% [markdown]
// # String-2 > xyzThere

// %%
/*
Return true if the given string contains an appearance of "xyz" where the xyz is
not directly preceeded by a period (.). So "xxyz" counts but "x.xyz" does not.

xyzThere("abcxyz") → true
xyzThere("abc.xyz") → false
xyzThere("xyz.abc") → true
*/

bool xyzThere(string str) {
    return false;
}


// tests:
printTest( "xyzThere(\"abcxyz\") → true", xyzThere("abcxyz"), true );
printTest( "xyzThere(\"abc.xyz\") → false", xyzThere("abc.xyz"), false );
printTest( "xyzThere(\"xyz.abc\") → true", xyzThere("xyz.abc"), true );
printTest( "xyzThere(\"abcxy\") → false", xyzThere("abcxy"), false );
printTest( "xyzThere(\"xyz\") → true", xyzThere("xyz"), true );
printTest( "xyzThere(\"xy\") → false", xyzThere("xy"), false );
printTest( "xyzThere(\"x\") → false", xyzThere("x"), false );
printTest( "xyzThere(\"\") → false", xyzThere(""), false );
printTest( "xyzThere(\"abc.xyzxyz\") → true", xyzThere("abc.xyzxyz"), true );
printTest( "xyzThere(\"abc.xxyz\") → true", xyzThere("abc.xxyz"), true );
printTest( "xyzThere(\".xyz\") → false", xyzThere(".xyz"), false );
printTest( "xyzThere(\"12.xyz\") → false", xyzThere("12.xyz"), false );
printTest( "xyzThere(\"12xyz\") → true", xyzThere("12xyz"), true );
printTest( "xyzThere(\"1.xyz.xyz2.xyz\") → false", xyzThere("1.xyz.xyz2.xyz"), false );

// %% [markdown]
// # String-2 > bobThere

// %%
/*
Return true if the given string contains a "bob" string, but where the middle
'o' char can be any char.

bobThere("abcbob") → true
bobThere("b9b") → true
bobThere("bac") → false
*/

bool bobThere(string str) {
    return false;
}


// tests:
printTest( "bobThere(\"abcbob\") → true", bobThere("abcbob"), true );
printTest( "bobThere(\"b9b\") → true", bobThere("b9b"), true );
printTest( "bobThere(\"bac\") → false", bobThere("bac"), false );
printTest( "bobThere(\"bbb\") → true", bobThere("bbb"), true );
printTest( "bobThere(\"abcdefb\") → false", bobThere("abcdefb"), false );
printTest( "bobThere(\"123abcbcdbabxyz\") → true", bobThere("123abcbcdbabxyz"), true );
printTest( "bobThere(\"b12\") → false", bobThere("b12"), false );
printTest( "bobThere(\"b1b\") → true", bobThere("b1b"), true );
printTest( "bobThere(\"b12b1b\") → true", bobThere("b12b1b"), true );
printTest( "bobThere(\"bbc\") → false", bobThere("bbc"), false );
printTest( "bobThere(\"bbb\") → true", bobThere("bbb"), true );
printTest( "bobThere(\"bb\") → false", bobThere("bb"), false );
printTest( "bobThere(\"b\") → false", bobThere("b"), false );

// %% [markdown]
// # String-2 > xyBalance

// %%
/*
We'll say that a String is xy-balanced if for all the 'x' chars in the string,
there exists a 'y' char somewhere later in the string. So "xxy" is balanced, but
"xyx" is not. One 'y' can balance multiple 'x's. Return true if the given string
is xy-balanced.

xyBalance("aaxbby") → true
xyBalance("aaxbb") → false
xyBalance("yaaxbb") → false
*/

bool xyBalance(string str) {
    return false;
}


// tests:
printTest( "xyBalance(\"aaxbby\") → true", xyBalance("aaxbby"), true );
printTest( "xyBalance(\"aaxbb\") → false", xyBalance("aaxbb"), false );
printTest( "xyBalance(\"yaaxbb\") → false", xyBalance("yaaxbb"), false );
printTest( "xyBalance(\"yaaxbby\") → true", xyBalance("yaaxbby"), true );
printTest( "xyBalance(\"xaxxbby\") → true", xyBalance("xaxxbby"), true );
printTest( "xyBalance(\"xaxxbbyx\") → false", xyBalance("xaxxbbyx"), false );
printTest( "xyBalance(\"xxbxy\") → true", xyBalance("xxbxy"), true );
printTest( "xyBalance(\"xxbx\") → false", xyBalance("xxbx"), false );
printTest( "xyBalance(\"bbb\") → true", xyBalance("bbb"), true );
printTest( "xyBalance(\"bxbb\") → false", xyBalance("bxbb"), false );
printTest( "xyBalance(\"bxyb\") → true", xyBalance("bxyb"), true );
printTest( "xyBalance(\"xy\") → true", xyBalance("xy"), true );
printTest( "xyBalance(\"y\") → true", xyBalance("y"), true );
printTest( "xyBalance(\"x\") → false", xyBalance("x"), false );
printTest( "xyBalance(\"\") → true", xyBalance(""), true );
printTest( "xyBalance(\"yxyxyxyx\") → false", xyBalance("yxyxyxyx"), false );
printTest( "xyBalance(\"yxyxyxyxy\") → true", xyBalance("yxyxyxyxy"), true );
printTest( "xyBalance(\"12xabxxydxyxyzz\") → true", xyBalance("12xabxxydxyxyzz"), true );

// %% [markdown]
// # String-2 > mixString

// %%
/*


mixString("abc", "xyz") → "axbycz"
mixString("Hi", "There") → "HTihere"
mixString("xxxx", "There") → "xTxhxexre"
*/

string mixString(string a, string b) {
    return "";
}


// tests:
printTest( "mixString(\"abc\", \"xyz\") → \"axbycz\"", mixString("abc", "xyz"), "axbycz" );
printTest( "mixString(\"Hi\", \"There\") → \"HTihere\"", mixString("Hi", "There"), "HTihere" );
printTest( "mixString(\"xxxx\", \"There\") → \"xTxhxexre\"", mixString("xxxx", "There"), "xTxhxexre" );
printTest( "mixString(\"xxx\", \"X\") → \"xXxx\"", mixString("xxx", "X"), "xXxx" );
printTest( "mixString(\"2/\", \"27 around\") → \"22/7 around\"", mixString("2/", "27 around"), "22/7 around" );
printTest( "mixString(\"\", \"Hello\") → \"Hello\"", mixString("", "Hello"), "Hello" );
printTest( "mixString(\"Abc\", \"\") → \"Abc\"", mixString("Abc", ""), "Abc" );
printTest( "mixString(\"\", \"\") → \"\"", mixString("", ""), "" );
printTest( "mixString(\"a\", \"b\") → \"ab\"", mixString("a", "b"), "ab" );
printTest( "mixString(\"ax\", \"b\") → \"abx\"", mixString("ax", "b"), "abx" );
printTest( "mixString(\"a\", \"bx\") → \"abx\"", mixString("a", "bx"), "abx" );
printTest( "mixString(\"So\", \"Long\") → \"SLoong\"", mixString("So", "Long"), "SLoong" );
printTest( "mixString(\"Long\", \"So\") → \"LSoong\"", mixString("Long", "So"), "LSoong" );

// %% [markdown]
// # String-2 > repeatEnd

// %%
/*
Given a string and an int n, return a string made of n repetitions of the last n
characters of the string. You may assume that n is between 0 and the length of
the string, inclusive.

repeatEnd("Hello", 3) → "llollollo"
repeatEnd("Hello", 2) → "lolo"
repeatEnd("Hello", 1) → "o"
*/

string repeatEnd(string str, int n) {
    return "";
}


// tests:
printTest( "repeatEnd(\"Hello\", 3) → \"llollollo\"", repeatEnd("Hello", 3), "llollollo" );
printTest( "repeatEnd(\"Hello\", 2) → \"lolo\"", repeatEnd("Hello", 2), "lolo" );
printTest( "repeatEnd(\"Hello\", 1) → \"o\"", repeatEnd("Hello", 1), "o" );
printTest( "repeatEnd(\"Hello\", 0) → \"\"", repeatEnd("Hello", 0), "" );
printTest( "repeatEnd(\"abc\", 3) → \"abcabcabc\"", repeatEnd("abc", 3), "abcabcabc" );
printTest( "repeatEnd(\"1234\", 2) → \"3434\"", repeatEnd("1234", 2), "3434" );
printTest( "repeatEnd(\"1234\", 3) → \"234234234\"", repeatEnd("1234", 3), "234234234" );
printTest( "repeatEnd(\"\", 0) → \"\"", repeatEnd("", 0), "" );

// %% [markdown]
// # String-2 > repeatFront

// %%
/*
Given a string and an int n, return a string made of the first n characters of
the string, followed by the first n-1 characters of the string, and so on. You
may assume that n is between 0 and the length of the string, inclusive (i.e. n
>= 0 and n <= str.length()).

repeatFront("Chocolate", 4) → "ChocChoChC"
repeatFront("Chocolate", 3) → "ChoChC"
repeatFront("Ice Cream", 2) → "IcI"
*/

string repeatFront(string str, int n) {
    return "";
}


// tests:
printTest( "repeatFront(\"Chocolate\", 4) → \"ChocChoChC\"", repeatFront("Chocolate", 4), "ChocChoChC" );
printTest( "repeatFront(\"Chocolate\", 3) → \"ChoChC\"", repeatFront("Chocolate", 3), "ChoChC" );
printTest( "repeatFront(\"Ice Cream\", 2) → \"IcI\"", repeatFront("Ice Cream", 2), "IcI" );
printTest( "repeatFront(\"Ice Cream\", 1) → \"I\"", repeatFront("Ice Cream", 1), "I" );
printTest( "repeatFront(\"Ice Cream\", 0) → \"\"", repeatFront("Ice Cream", 0), "" );
printTest( "repeatFront(\"xyz\", 3) → \"xyzxyx\"", repeatFront("xyz", 3), "xyzxyx" );
printTest( "repeatFront(\"\", 0) → \"\"", repeatFront("", 0), "" );
printTest( "repeatFront(\"Java\", 4) → \"JavaJavJaJ\"", repeatFront("Java", 4), "JavaJavJaJ" );
printTest( "repeatFront(\"Java\", 1) → \"J\"", repeatFront("Java", 1), "J" );

// %% [markdown]
// # String-2 > repeatSeparator

// %%
/*


repeatSeparator("Word", "X", 3) → "WordXWordXWord"
repeatSeparator("This", "And", 2) → "ThisAndThis"
repeatSeparator("This", "And", 1) → "This"
*/

string repeatSeparator(string word, string sep, int count) {
    return "";
}


// tests:
printTest( "repeatSeparator(\"Word\", \"X\", 3) → \"WordXWordXWord\"", repeatSeparator("Word", "X", 3), "WordXWordXWord" );
printTest( "repeatSeparator(\"This\", \"And\", 2) → \"ThisAndThis\"", repeatSeparator("This", "And", 2), "ThisAndThis" );
printTest( "repeatSeparator(\"This\", \"And\", 1) → \"This\"", repeatSeparator("This", "And", 1), "This" );
printTest( "repeatSeparator(\"Hi\", \"-n-\", 2) → \"Hi-n-Hi\"", repeatSeparator("Hi", "-n-", 2), "Hi-n-Hi" );
printTest( "repeatSeparator(\"AAA\", \"\", 1) → \"AAA\"", repeatSeparator("AAA", "", 1), "AAA" );
printTest( "repeatSeparator(\"AAA\", \"\", 0) → \"\"", repeatSeparator("AAA", "", 0), "" );
printTest( "repeatSeparator(\"A\", \"B\", 5) → \"ABABABABA\"", repeatSeparator("A", "B", 5), "ABABABABA" );
printTest( "repeatSeparator(\"abc\", \"XX\", 3) → \"abcXXabcXXabc\"", repeatSeparator("abc", "XX", 3), "abcXXabcXXabc" );
printTest( "repeatSeparator(\"abc\", \"XX\", 2) → \"abcXXabc\"", repeatSeparator("abc", "XX", 2), "abcXXabc" );
printTest( "repeatSeparator(\"abc\", \"XX\", 1) → \"abc\"", repeatSeparator("abc", "XX", 1), "abc" );
printTest( "repeatSeparator(\"XYZ\", \"a\", 2) → \"XYZaXYZ\"", repeatSeparator("XYZ", "a", 2), "XYZaXYZ" );

// %% [markdown]
// # String-2 > prefixAgain

// %%
/*
Given a string, consider the prefix string made of the first N chars of the
string. Does that prefix string appear somewhere else in the string? Assume that
the string is not empty and that N is in the range 1..str.length().

prefixAgain("abXYabc", 1) → true
prefixAgain("abXYabc", 2) → true
prefixAgain("abXYabc", 3) → false
*/

bool prefixAgain(string str, int n) {
    return false;
}


// tests:
printTest( "prefixAgain(\"abXYabc\", 1) → true", prefixAgain("abXYabc", 1), true );
printTest( "prefixAgain(\"abXYabc\", 2) → true", prefixAgain("abXYabc", 2), true );
printTest( "prefixAgain(\"abXYabc\", 3) → false", prefixAgain("abXYabc", 3), false );
printTest( "prefixAgain(\"xyzxyxyxy\", 2) → true", prefixAgain("xyzxyxyxy", 2), true );
printTest( "prefixAgain(\"xyzxyxyxy\", 3) → false", prefixAgain("xyzxyxyxy", 3), false );
printTest( "prefixAgain(\"Hi12345Hi6789Hi10\", 1) → true", prefixAgain("Hi12345Hi6789Hi10", 1), true );
printTest( "prefixAgain(\"Hi12345Hi6789Hi10\", 2) → true", prefixAgain("Hi12345Hi6789Hi10", 2), true );
printTest( "prefixAgain(\"Hi12345Hi6789Hi10\", 3) → true", prefixAgain("Hi12345Hi6789Hi10", 3), true );
printTest( "prefixAgain(\"Hi12345Hi6789Hi10\", 4) → false", prefixAgain("Hi12345Hi6789Hi10", 4), false );
printTest( "prefixAgain(\"a\", 1) → false", prefixAgain("a", 1), false );
printTest( "prefixAgain(\"aa\", 1) → true", prefixAgain("aa", 1), true );
printTest( "prefixAgain(\"ab\", 1) → false", prefixAgain("ab", 1), false );

// %% [markdown]
// # String-2 > xyzMiddle

// %%
/*
Given a string, does "xyz" appear in the middle of the string? To define middle,
we'll say that the number of chars to the left and right of the "xyz" must
differ by at most one. This problem is harder than it looks.

xyzMiddle("AAxyzBB") → true
xyzMiddle("AxyzBB") → true
xyzMiddle("AxyzBBB") → false
*/

bool xyzMiddle(string str) {
    return false;
}


// tests:
printTest( "xyzMiddle(\"AAxyzBB\") → true", xyzMiddle("AAxyzBB"), true );
printTest( "xyzMiddle(\"AxyzBB\") → true", xyzMiddle("AxyzBB"), true );
printTest( "xyzMiddle(\"AxyzBBB\") → false", xyzMiddle("AxyzBBB"), false );
printTest( "xyzMiddle(\"AxyzBBBB\") → false", xyzMiddle("AxyzBBBB"), false );
printTest( "xyzMiddle(\"AAAxyzB\") → false", xyzMiddle("AAAxyzB"), false );
printTest( "xyzMiddle(\"AAAxyzBB\") → true", xyzMiddle("AAAxyzBB"), true );
printTest( "xyzMiddle(\"AAAAxyzBB\") → false", xyzMiddle("AAAAxyzBB"), false );
printTest( "xyzMiddle(\"AAAAAxyzBBB\") → false", xyzMiddle("AAAAAxyzBBB"), false );
printTest( "xyzMiddle(\"1x345xyz12x4\") → true", xyzMiddle("1x345xyz12x4"), true );
printTest( "xyzMiddle(\"xyzAxyzBBB\") → true", xyzMiddle("xyzAxyzBBB"), true );
printTest( "xyzMiddle(\"xyzAxyzBxyz\") → true", xyzMiddle("xyzAxyzBxyz"), true );
printTest( "xyzMiddle(\"xyzxyzAxyzBxyzxyz\") → true", xyzMiddle("xyzxyzAxyzBxyzxyz"), true );
printTest( "xyzMiddle(\"xyzxyzxyzBxyzxyz\") → true", xyzMiddle("xyzxyzxyzBxyzxyz"), true );
printTest( "xyzMiddle(\"xyzxyzAxyzxyzxyz\") → true", xyzMiddle("xyzxyzAxyzxyzxyz"), true );
printTest( "xyzMiddle(\"xyzxyzAxyzxyzxy\") → false", xyzMiddle("xyzxyzAxyzxyzxy"), false );
printTest( "xyzMiddle(\"AxyzxyzBB\") → false", xyzMiddle("AxyzxyzBB"), false );
printTest( "xyzMiddle(\"\") → false", xyzMiddle(""), false );
printTest( "xyzMiddle(\"x\") → false", xyzMiddle("x"), false );
printTest( "xyzMiddle(\"xy\") → false", xyzMiddle("xy"), false );
printTest( "xyzMiddle(\"xyz\") → true", xyzMiddle("xyz"), true );
printTest( "xyzMiddle(\"xyzz\") → true", xyzMiddle("xyzz"), true );

// %% [markdown]
// # String-2 > getSandwich

// %%
/*
A sandwich is two pieces of bread with something in between. Return the string
that is between the first and last appearance of "bread" in the given string, or
return the empty string "" if there are not two pieces of bread.

getSandwich("breadjambread") → "jam"
getSandwich("xxbreadjambreadyy") → "jam"
getSandwich("xxbreadyy") → ""
*/

string getSandwich(string str) {
    return "";
}


// tests:
printTest( "getSandwich(\"breadjambread\") → \"jam\"", getSandwich("breadjambread"), "jam" );
printTest( "getSandwich(\"xxbreadjambreadyy\") → \"jam\"", getSandwich("xxbreadjambreadyy"), "jam" );
printTest( "getSandwich(\"xxbreadyy\") → \"\"", getSandwich("xxbreadyy"), "" );
printTest( "getSandwich(\"xxbreadbreadjambreadyy\") → \"breadjam\"", getSandwich("xxbreadbreadjambreadyy"), "breadjam" );
printTest( "getSandwich(\"breadAbread\") → \"A\"", getSandwich("breadAbread"), "A" );
printTest( "getSandwich(\"breadbread\") → \"\"", getSandwich("breadbread"), "" );
printTest( "getSandwich(\"abcbreaz\") → \"\"", getSandwich("abcbreaz"), "" );
printTest( "getSandwich(\"xyz\") → \"\"", getSandwich("xyz"), "" );
printTest( "getSandwich(\"\") → \"\"", getSandwich(""), "" );
printTest( "getSandwich(\"breadbreaxbread\") → \"breax\"", getSandwich("breadbreaxbread"), "breax" );
printTest( "getSandwich(\"breaxbreadybread\") → \"y\"", getSandwich("breaxbreadybread"), "y" );
printTest( "getSandwich(\"breadbreadbreadbread\") → \"breadbread\"", getSandwich("breadbreadbreadbread"), "breadbread" );

// %% [markdown]
// # String-2 > sameStarChar

// %%
/*
Returns true if for every '*' (star) in the string, if there are chars both
immediately before and after the star, they are the same.

sameStarChar("xy*yzz") → true
sameStarChar("xy*zzz") → false
sameStarChar("*xa*az") → true
*/

bool sameStarChar(string str) {
    return false;
}


// tests:
printTest( "sameStarChar(\"xy*yzz\") → true", sameStarChar("xy*yzz"), true );
printTest( "sameStarChar(\"xy*zzz\") → false", sameStarChar("xy*zzz"), false );
printTest( "sameStarChar(\"*xa*az\") → true", sameStarChar("*xa*az"), true );
printTest( "sameStarChar(\"*xa*bz\") → false", sameStarChar("*xa*bz"), false );
printTest( "sameStarChar(\"*xa*a*\") → true", sameStarChar("*xa*a*"), true );
printTest( "sameStarChar(\"\") → true", sameStarChar(""), true );
printTest( "sameStarChar(\"*xa*a*a\") → true", sameStarChar("*xa*a*a"), true );
printTest( "sameStarChar(\"*xa*a*b\") → false", sameStarChar("*xa*a*b"), false );
printTest( "sameStarChar(\"*12*2*2\") → true", sameStarChar("*12*2*2"), true );
printTest( "sameStarChar(\"12*2*3*\") → false", sameStarChar("12*2*3*"), false );
printTest( "sameStarChar(\"abcDEF\") → true", sameStarChar("abcDEF"), true );
printTest( "sameStarChar(\"XY*YYYY*Z*\") → false", sameStarChar("XY*YYYY*Z*"), false );
printTest( "sameStarChar(\"XY*YYYY*Y*\") → true", sameStarChar("XY*YYYY*Y*"), true );
printTest( "sameStarChar(\"12*2*3*\") → false", sameStarChar("12*2*3*"), false );
printTest( "sameStarChar(\"*\") → true", sameStarChar("*"), true );
printTest( "sameStarChar(\"**\") → true", sameStarChar("**"), true );

// %% [markdown]
// # String-2 > oneTwo

// %%
/*
Given a string, compute a new string by moving the first char to come after the
next two chars, so "abc" yields "bca". Repeat this process for each subsequent
group of 3 chars, so "abcdef" yields "bcaefd". Ignore any group of fewer than 3
chars at the end.

oneTwo("abc") → "bca"
oneTwo("tca") → "cat"
oneTwo("tcagdo") → "catdog"
*/

string oneTwo(string str) {
    return "";
}


// tests:
printTest( "oneTwo(\"abc\") → \"bca\"", oneTwo("abc"), "bca" );
printTest( "oneTwo(\"tca\") → \"cat\"", oneTwo("tca"), "cat" );
printTest( "oneTwo(\"tcagdo\") → \"catdog\"", oneTwo("tcagdo"), "catdog" );
printTest( "oneTwo(\"chocolate\") → \"hocolctea\"", oneTwo("chocolate"), "hocolctea" );
printTest( "oneTwo(\"1234567890\") → \"231564897\"", oneTwo("1234567890"), "231564897" );
printTest( "oneTwo(\"xabxabxabxabxabxabxab\") → \"abxabxabxabxabxabxabx\"", oneTwo("xabxabxabxabxabxabxab"), "abxabxabxabxabxabxabx" );
printTest( "oneTwo(\"abcdefx\") → \"bcaefd\"", oneTwo("abcdefx"), "bcaefd" );
printTest( "oneTwo(\"abcdefxy\") → \"bcaefd\"", oneTwo("abcdefxy"), "bcaefd" );
printTest( "oneTwo(\"abcdefxyz\") → \"bcaefdyzx\"", oneTwo("abcdefxyz"), "bcaefdyzx" );
printTest( "oneTwo(\"\") → \"\"", oneTwo(""), "" );
printTest( "oneTwo(\"x\") → \"\"", oneTwo("x"), "" );
printTest( "oneTwo(\"xy\") → \"\"", oneTwo("xy"), "" );
printTest( "oneTwo(\"xyz\") → \"yzx\"", oneTwo("xyz"), "yzx" );
printTest( "oneTwo(\"abcdefghijklkmnopqrstuvwxyz1234567890\") → \"bcaefdhigkljmnkpqostrvwuyzx231564897\"", oneTwo("abcdefghijklkmnopqrstuvwxyz1234567890"), "bcaefdhigkljmnkpqostrvwuyzx231564897" );
printTest( "oneTwo(\"abcdefghijklkmnopqrstuvwxyz123456789\") → \"bcaefdhigkljmnkpqostrvwuyzx231564897\"", oneTwo("abcdefghijklkmnopqrstuvwxyz123456789"), "bcaefdhigkljmnkpqostrvwuyzx231564897" );
printTest( "oneTwo(\"abcdefghijklkmnopqrstuvwxyz12345678\") → \"bcaefdhigkljmnkpqostrvwuyzx231564\"", oneTwo("abcdefghijklkmnopqrstuvwxyz12345678"), "bcaefdhigkljmnkpqostrvwuyzx231564" );

// %% [markdown]
// # String-2 > zipZap

// %%
/*
Look for patterns like "zip" and "zap" in the string -- length-3, starting with
'z' and ending with 'p'. Return a string where for all such words, the middle
letter is gone, so "zipXzap" yields "zpXzp".

zipZap("zipXzap") → "zpXzp"
zipZap("zopzop") → "zpzp"
zipZap("zzzopzop") → "zzzpzp"
*/

string zipZap(string str) {
    return "";
}


// tests:
printTest( "zipZap(\"zipXzap\") → \"zpXzp\"", zipZap("zipXzap"), "zpXzp" );
printTest( "zipZap(\"zopzop\") → \"zpzp\"", zipZap("zopzop"), "zpzp" );
printTest( "zipZap(\"zzzopzop\") → \"zzzpzp\"", zipZap("zzzopzop"), "zzzpzp" );
printTest( "zipZap(\"zibzap\") → \"zibzp\"", zipZap("zibzap"), "zibzp" );
printTest( "zipZap(\"zip\") → \"zp\"", zipZap("zip"), "zp" );
printTest( "zipZap(\"zi\") → \"zi\"", zipZap("zi"), "zi" );
printTest( "zipZap(\"z\") → \"z\"", zipZap("z"), "z" );
printTest( "zipZap(\"\") → \"\"", zipZap(""), "" );
printTest( "zipZap(\"zzp\") → \"zp\"", zipZap("zzp"), "zp" );
printTest( "zipZap(\"abcppp\") → \"abcppp\"", zipZap("abcppp"), "abcppp" );
printTest( "zipZap(\"azbcppp\") → \"azbcppp\"", zipZap("azbcppp"), "azbcppp" );
printTest( "zipZap(\"azbcpzpp\") → \"azbcpzp\"", zipZap("azbcpzpp"), "azbcpzp" );

// %% [markdown]
// # String-2 > starOut

// %%
/*
Return a version of the given string, where for every star (*) in the string the
star and the chars immediately to its left and right are gone. So "ab*cd" yields
"ad" and "ab**cd" also yields "ad".

starOut("ab*cd") → "ad"
starOut("ab**cd") → "ad"
starOut("sm*eilly") → "silly"
*/

string starOut(string str) {
    return "";
}


// tests:
printTest( "starOut(\"ab*cd\") → \"ad\"", starOut("ab*cd"), "ad" );
printTest( "starOut(\"ab**cd\") → \"ad\"", starOut("ab**cd"), "ad" );
printTest( "starOut(\"sm*eilly\") → \"silly\"", starOut("sm*eilly"), "silly" );
printTest( "starOut(\"sm*eil*ly\") → \"siy\"", starOut("sm*eil*ly"), "siy" );
printTest( "starOut(\"sm**eil*ly\") → \"siy\"", starOut("sm**eil*ly"), "siy" );
printTest( "starOut(\"sm***eil*ly\") → \"siy\"", starOut("sm***eil*ly"), "siy" );
printTest( "starOut(\"stringy*\") → \"string\"", starOut("stringy*"), "string" );
printTest( "starOut(\"*stringy\") → \"tringy\"", starOut("*stringy"), "tringy" );
printTest( "starOut(\"*str*in*gy\") → \"ty\"", starOut("*str*in*gy"), "ty" );
printTest( "starOut(\"abc\") → \"abc\"", starOut("abc"), "abc" );
printTest( "starOut(\"a*bc\") → \"c\"", starOut("a*bc"), "c" );
printTest( "starOut(\"ab\") → \"ab\"", starOut("ab"), "ab" );
printTest( "starOut(\"a*b\") → \"\"", starOut("a*b"), "" );
printTest( "starOut(\"a\") → \"a\"", starOut("a"), "a" );
printTest( "starOut(\"a*\") → \"\"", starOut("a*"), "" );
printTest( "starOut(\"*a\") → \"\"", starOut("*a"), "" );
printTest( "starOut(\"*\") → \"\"", starOut("*"), "" );
printTest( "starOut(\"\") → \"\"", starOut(""), "" );

// %% [markdown]
// # String-2 > plusOut

// %%
/*


plusOut("12xy34", "xy") → "++xy++"
plusOut("12xy34", "1") → "1+++++"
plusOut("12xy34xyabcxy", "xy") → "++xy++xy+++xy"
*/

string plusOut(string str, string word) {
    return "";
}


// tests:
printTest( "plusOut(\"12xy34\", \"xy\") → \"++xy++\"", plusOut("12xy34", "xy"), "++xy++" );
printTest( "plusOut(\"12xy34\", \"1\") → \"1+++++\"", plusOut("12xy34", "1"), "1+++++" );
printTest( "plusOut(\"12xy34xyabcxy\", \"xy\") → \"++xy++xy+++xy\"", plusOut("12xy34xyabcxy", "xy"), "++xy++xy+++xy" );
printTest( "plusOut(\"abXYabcXYZ\", \"ab\") → \"ab++ab++++\"", plusOut("abXYabcXYZ", "ab"), "ab++ab++++" );
printTest( "plusOut(\"abXYabcXYZ\", \"abc\") → \"++++abc+++\"", plusOut("abXYabcXYZ", "abc"), "++++abc+++" );
printTest( "plusOut(\"abXYabcXYZ\", \"XY\") → \"++XY+++XY+\"", plusOut("abXYabcXYZ", "XY"), "++XY+++XY+" );
printTest( "plusOut(\"abXYxyzXYZ\", \"XYZ\") → \"+++++++XYZ\"", plusOut("abXYxyzXYZ", "XYZ"), "+++++++XYZ" );
printTest( "plusOut(\"--++ab\", \"++\") → \"++++++\"", plusOut("--++ab", "++"), "++++++" );
printTest( "plusOut(\"aaxxxxbb\", \"xx\") → \"++xxxx++\"", plusOut("aaxxxxbb", "xx"), "++xxxx++" );
printTest( "plusOut(\"123123\", \"3\") → \"++3++3\"", plusOut("123123", "3"), "++3++3" );

// %% [markdown]
// # String-2 > wordEnds

// %%
/*


wordEnds("abcXY123XYijk", "XY") → "c13i"
wordEnds("XY123XY", "XY") → "13"
wordEnds("XY1XY", "XY") → "11"
*/

string wordEnds(string str, string word) {
    return "";
}


// tests:
printTest( "wordEnds(\"abcXY123XYijk\", \"XY\") → \"c13i\"", wordEnds("abcXY123XYijk", "XY"), "c13i" );
printTest( "wordEnds(\"XY123XY\", \"XY\") → \"13\"", wordEnds("XY123XY", "XY"), "13" );
printTest( "wordEnds(\"XY1XY\", \"XY\") → \"11\"", wordEnds("XY1XY", "XY"), "11" );
printTest( "wordEnds(\"XYXY\", \"XY\") → \"XY\"", wordEnds("XYXY", "XY"), "XY" );
printTest( "wordEnds(\"XY\", \"XY\") → \"\"", wordEnds("XY", "XY"), "" );
printTest( "wordEnds(\"Hi\", \"XY\") → \"\"", wordEnds("Hi", "XY"), "" );
printTest( "wordEnds(\"\", \"XY\") → \"\"", wordEnds("", "XY"), "" );
printTest( "wordEnds(\"abc1xyz1i1j\", \"1\") → \"cxziij\"", wordEnds("abc1xyz1i1j", "1"), "cxziij" );
printTest( "wordEnds(\"abc1xyz1\", \"1\") → \"cxz\"", wordEnds("abc1xyz1", "1"), "cxz" );
printTest( "wordEnds(\"abc1xyz11\", \"1\") → \"cxz11\"", wordEnds("abc1xyz11", "1"), "cxz11" );
printTest( "wordEnds(\"abc1xyz1abc\", \"abc\") → \"11\"", wordEnds("abc1xyz1abc", "abc"), "11" );
printTest( "wordEnds(\"abc1xyz1abc\", \"b\") → \"acac\"", wordEnds("abc1xyz1abc", "b"), "acac" );
printTest( "wordEnds(\"abc1abc1abc\", \"abc\") → \"1111\"", wordEnds("abc1abc1abc", "abc"), "1111" );
