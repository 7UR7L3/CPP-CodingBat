// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
namespace testns { template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
} } using namespace testns;
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # AP-1 > scoresIncreasing

// %%
/*
Given an array of scores, return true if each score is equal or greater than the
one before. The array will be length 2 or more.

scoresIncreasing([1, 3, 4]) → true
scoresIncreasing([1, 3, 2]) → false
scoresIncreasing([1, 1, 4]) → true
*/

bool scoresIncreasing(vector<int> scores) {
    return false;
}


// tests:
printTest( "scoresIncreasing([1, 3, 4]) → true", scoresIncreasing({1, 3, 4}), true );
printTest( "scoresIncreasing([1, 3, 2]) → false", scoresIncreasing({1, 3, 2}), false );
printTest( "scoresIncreasing([1, 1, 4]) → true", scoresIncreasing({1, 1, 4}), true );
printTest( "scoresIncreasing([1, 1, 2, 4, 4, 7]) → true", scoresIncreasing({1, 1, 2, 4, 4, 7}), true );
printTest( "scoresIncreasing([1, 1, 2, 4, 3, 7]) → false", scoresIncreasing({1, 1, 2, 4, 3, 7}), false );
printTest( "scoresIncreasing([-5, 4, 11]) → true", scoresIncreasing({-5, 4, 11}), true );

// %% [markdown]
// # AP-1 > scores100

// %%
/*
Given an array of scores, return true if there are scores of 100 next to each
other in the array. The array length will be at least 2.

scores100([1, 100, 100]) → true
scores100([1, 100, 99, 100]) → false
scores100([100, 1, 100, 100]) → true
*/

bool scores100(vector<int> scores) {
    return false;
}


// tests:
printTest( "scores100([1, 100, 100]) → true", scores100({1, 100, 100}), true );
printTest( "scores100([1, 100, 99, 100]) → false", scores100({1, 100, 99, 100}), false );
printTest( "scores100([100, 1, 100, 100]) → true", scores100({100, 1, 100, 100}), true );
printTest( "scores100([100, 1, 100, 1]) → false", scores100({100, 1, 100, 1}), false );
printTest( "scores100([1, 2, 3, 4, 5]) → false", scores100({1, 2, 3, 4, 5}), false );
printTest( "scores100([1, 2, 100, 4, 5]) → false", scores100({1, 2, 100, 4, 5}), false );

// %% [markdown]
// # AP-1 > scoresClump

// %%
/*
Given an array of scores sorted in increasing order, return true if the array
contains 3 adjacent scores that differ from each other by at most 2, such as
with {3, 4, 5} or {3, 5, 5}.

scoresClump([3, 4, 5]) → true
scoresClump([3, 4, 6]) → false
scoresClump([1, 3, 5, 5]) → true
*/

bool scoresClump(vector<int> scores) {
    return false;
}


// tests:
printTest( "scoresClump([3, 4, 5]) → true", scoresClump({3, 4, 5}), true );
printTest( "scoresClump([3, 4, 6]) → false", scoresClump({3, 4, 6}), false );
printTest( "scoresClump([1, 3, 5, 5]) → true", scoresClump({1, 3, 5, 5}), true );
printTest( "scoresClump([2, 4, 5, 6]) → true", scoresClump({2, 4, 5, 6}), true );
printTest( "scoresClump([2, 4, 5, 7]) → false", scoresClump({2, 4, 5, 7}), false );
printTest( "scoresClump([2, 4, 4, 7]) → true", scoresClump({2, 4, 4, 7}), true );
printTest( "scoresClump([3, 3, 6, 7, 9]) → false", scoresClump({3, 3, 6, 7, 9}), false );
printTest( "scoresClump([3, 3, 7, 7, 9]) → true", scoresClump({3, 3, 7, 7, 9}), true );
printTest( "scoresClump([4, 5, 8]) → false", scoresClump({4, 5, 8}), false );

// %% [markdown]
// # AP-1 > scoresAverage

// %%
/*
Given an array of scores, compute the int average of the first half and the
second half, and return whichever is larger. Weʼll say that the second half
begins at index length/2. The array length will be at least 2. To practice
decomposition, write a separate helper method int average(int[] scores, int
start, int end) {  which computes the average of the elements between indexes
start..end. Call your helper method twice to implement scoresAverage(). Write
your helper method after your scoresAverage() method in the JavaBat text area.
Normally you would compute averages with doubles, but here we use ints so the
expected results are exact.

scoresAverage([2, 2, 4, 4]) → 4
scoresAverage([4, 4, 4, 2, 2, 2]) → 4
scoresAverage([3, 4, 5, 1, 2, 3]) → 4
*/

int scoresAverage(vector<int> scores) {
    return 0;
}


// tests:
printTest( "scoresAverage([2, 2, 4, 4]) → 4", scoresAverage({2, 2, 4, 4}), 4 );
printTest( "scoresAverage([4, 4, 4, 2, 2, 2]) → 4", scoresAverage({4, 4, 4, 2, 2, 2}), 4 );
printTest( "scoresAverage([3, 4, 5, 1, 2, 3]) → 4", scoresAverage({3, 4, 5, 1, 2, 3}), 4 );
printTest( "scoresAverage([5, 6]) → 6", scoresAverage({5, 6}), 6 );
printTest( "scoresAverage([5, 4]) → 5", scoresAverage({5, 4}), 5 );
printTest( "scoresAverage([5, 4, 5, 6, 2, 1, 2, 3]) → 5", scoresAverage({5, 4, 5, 6, 2, 1, 2, 3}), 5 );

// %% [markdown]
// # AP-1 > wordsCount

// %%
/*
Given an array of strings, return the count of the number of strings with the
given length.

wordsCount(["a", "bb", "b", "ccc"], 1) → 2
wordsCount(["a", "bb", "b", "ccc"], 3) → 1
wordsCount(["a", "bb", "b", "ccc"], 4) → 0
*/

int wordsCount(vector<string> words, int len) {
    return 0;
}


// tests:
printTest( "wordsCount([\"a\", \"bb\", \"b\", \"ccc\"], 1) → 2", wordsCount({"a", "bb", "b", "ccc"}, 1), 2 );
printTest( "wordsCount([\"a\", \"bb\", \"b\", \"ccc\"], 3) → 1", wordsCount({"a", "bb", "b", "ccc"}, 3), 1 );
printTest( "wordsCount([\"a\", \"bb\", \"b\", \"ccc\"], 4) → 0", wordsCount({"a", "bb", "b", "ccc"}, 4), 0 );
printTest( "wordsCount([\"xx\", \"yyy\", \"x\", \"yy\", \"z\"], 1) → 2", wordsCount({"xx", "yyy", "x", "yy", "z"}, 1), 2 );
printTest( "wordsCount([\"xx\", \"yyy\", \"x\", \"yy\", \"z\"], 2) → 2", wordsCount({"xx", "yyy", "x", "yy", "z"}, 2), 2 );
printTest( "wordsCount([\"xx\", \"yyy\", \"x\", \"yy\", \"z\"], 3) → 1", wordsCount({"xx", "yyy", "x", "yy", "z"}, 3), 1 );

// %% [markdown]
// # AP-1 > wordsFront

// %%
/*
Given an array of strings, return a new array containing the first N strings. N
will be in the range 1..length.

wordsFront(["a", "b", "c", "d"], 1) → ["a"]
wordsFront(["a", "b", "c", "d"], 2) → ["a", "b"]
wordsFront(["a", "b", "c", "d"], 3) → ["a", "b", "c"]
*/

std::vector<string> wordsFront(vector<string> words, int n) {
    return new vector<string>{};
}


// tests:
printTest( "wordsFront([\"a\", \"b\", \"c\", \"d\"], 1) → [\"a\"]", wordsFront({"a", "b", "c", "d"}, 1), {"a"} );
printTest( "wordsFront([\"a\", \"b\", \"c\", \"d\"], 2) → [\"a\", \"b\"]", wordsFront({"a", "b", "c", "d"}, 2), {"a", "b"} );
printTest( "wordsFront([\"a\", \"b\", \"c\", \"d\"], 3) → [\"a\", \"b\", \"c\"]", wordsFront({"a", "b", "c", "d"}, 3), {"a", "b", "c"} );
printTest( "wordsFront([\"a\", \"b\", \"c\", \"d\"], 4) → [\"a\", \"b\", \"c\", \"d\"]", wordsFront({"a", "b", "c", "d"}, 4), {"a", "b", "c", "d"} );
printTest( "wordsFront([\"Hi\", \"There\"], 1) → [\"Hi\"]", wordsFront({"Hi", "There"}, 1), {"Hi"} );
printTest( "wordsFront([\"Hi\", \"There\"], 2) → [\"Hi\", \"There\"]", wordsFront({"Hi", "There"}, 2), {"Hi", "There"} );

// %% [markdown]
// # AP-1 > wordsWithoutList

// %%
/*
Given an array of strings, return a new List (e.g. an ArrayList) where all the
strings of the given length are omitted. See wordsWithout() below which is more
difficult because it uses arrays.

wordsWithoutList(["a", "bb", "b", "ccc"], 1) → ["bb", "ccc"]
wordsWithoutList(["a", "bb", "b", "ccc"], 3) → ["a", "bb", "b"]
wordsWithoutList(["a", "bb", "b", "ccc"], 4) → ["a", "bb", "b", "ccc"]
*/

vector wordsWithoutvector(vector<string> words, int len) {
    return null;
}


// tests:
printTest( "wordsWithoutList([\"a\", \"bb\", \"b\", \"ccc\"], 1) → [\"bb\", \"ccc\"]", wordsWithoutList({"a", "bb", "b", "ccc"}, 1), {"bb", "ccc"} );
printTest( "wordsWithoutList([\"a\", \"bb\", \"b\", \"ccc\"], 3) → [\"a\", \"bb\", \"b\"]", wordsWithoutList({"a", "bb", "b", "ccc"}, 3), {"a", "bb", "b"} );
printTest( "wordsWithoutList([\"a\", \"bb\", \"b\", \"ccc\"], 4) → [\"a\", \"bb\", \"b\", \"ccc\"]", wordsWithoutList({"a", "bb", "b", "ccc"}, 4), {"a", "bb", "b", "ccc"} );
printTest( "wordsWithoutList([\"xx\", \"yyy\", \"x\", \"yy\", \"z\"], 1) → [\"xx\", \"yyy\", \"yy\"]", wordsWithoutList({"xx", "yyy", "x", "yy", "z"}, 1), {"xx", "yyy", "yy"} );
printTest( "wordsWithoutList([\"xx\", \"yyy\", \"x\", \"yy\", \"z\"], 2) → [\"yyy\", \"x\", \"z\"]", wordsWithoutList({"xx", "yyy", "x", "yy", "z"}, 2), {"yyy", "x", "z"} );

// %% [markdown]
// # AP-1 > hasOne

// %%
/*
Given a positive int n, return true if it contains a 1 digit. Note: use % to get
the rightmost digit, and / to discard the rightmost digit.

hasOne(10) → true
hasOne(22) → false
hasOne(220) → false
*/

bool hasOne(int n) {
    return false;
}


// tests:
printTest( "hasOne(10) → true", hasOne(10), true );
printTest( "hasOne(22) → false", hasOne(22), false );
printTest( "hasOne(220) → false", hasOne(220), false );
printTest( "hasOne(212) → true", hasOne(212), true );
printTest( "hasOne(1) → true", hasOne(1), true );
printTest( "hasOne(9) → false", hasOne(9), false );
printTest( "hasOne(211112) → true", hasOne(211112), true );
printTest( "hasOne(121121) → true", hasOne(121121), true );
printTest( "hasOne(222222) → false", hasOne(222222), false );
printTest( "hasOne(56156) → true", hasOne(56156), true );
printTest( "hasOne(56556) → false", hasOne(56556), false );

// %% [markdown]
// # AP-1 > dividesSelf

// %%
/*
We'll say that a positive int divides itself if every digit in the number
divides into the number evenly. So for example 128 divides itself since 1, 2,
and 8 all divide into 128 evenly. We'll say that 0 does not divide into anything
evenly, so no number with a 0 digit divides itself. Note: use % to get the
rightmost digit, and / to discard the rightmost digit.

dividesSelf(128) → true
dividesSelf(12) → true
dividesSelf(120) → false
*/

bool dividesSelf(int n) {
    return false;
}


// tests:
printTest( "dividesSelf(128) → true", dividesSelf(128), true );
printTest( "dividesSelf(12) → true", dividesSelf(12), true );
printTest( "dividesSelf(120) → false", dividesSelf(120), false );
printTest( "dividesSelf(122) → true", dividesSelf(122), true );
printTest( "dividesSelf(13) → false", dividesSelf(13), false );
printTest( "dividesSelf(32) → false", dividesSelf(32), false );
printTest( "dividesSelf(22) → true", dividesSelf(22), true );
printTest( "dividesSelf(42) → false", dividesSelf(42), false );
printTest( "dividesSelf(212) → true", dividesSelf(212), true );
printTest( "dividesSelf(213) → false", dividesSelf(213), false );
printTest( "dividesSelf(162) → true", dividesSelf(162), true );

// %% [markdown]
// # AP-1 > copyEvens

// %%
/*
Given an array of positive ints, return a new array of length "count" containing
the first even numbers from the original array. The original array will contain
at least "count" even numbers.

copyEvens([3, 2, 4, 5, 8], 2) → [2, 4]
copyEvens([3, 2, 4, 5, 8], 3) → [2, 4, 8]
copyEvens([6, 1, 2, 4, 5, 8], 3) → [6, 2, 4]
*/

std::vector<int> copyEvens(vector<int> nums, int count) {
    return vector<int>{};
}


// tests:
printTest( "copyEvens([3, 2, 4, 5, 8], 2) → [2, 4]", copyEvens({3, 2, 4, 5, 8}, 2), {2, 4} );
printTest( "copyEvens([3, 2, 4, 5, 8], 3) → [2, 4, 8]", copyEvens({3, 2, 4, 5, 8}, 3), {2, 4, 8} );
printTest( "copyEvens([6, 1, 2, 4, 5, 8], 3) → [6, 2, 4]", copyEvens({6, 1, 2, 4, 5, 8}, 3), {6, 2, 4} );
printTest( "copyEvens([6, 1, 2, 4, 5, 8], 4) → [6, 2, 4, 8]", copyEvens({6, 1, 2, 4, 5, 8}, 4), {6, 2, 4, 8} );
printTest( "copyEvens([3, 1, 4, 1, 5], 1) → [4]", copyEvens({3, 1, 4, 1, 5}, 1), {4} );
printTest( "copyEvens([2], 1) → [2]", copyEvens({2}, 1), {2} );
printTest( "copyEvens([6, 2, 4, 8], 2) → [6, 2]", copyEvens({6, 2, 4, 8}, 2), {6, 2} );
printTest( "copyEvens([6, 2, 4, 8], 3) → [6, 2, 4]", copyEvens({6, 2, 4, 8}, 3), {6, 2, 4} );
printTest( "copyEvens([6, 2, 4, 8], 4) → [6, 2, 4, 8]", copyEvens({6, 2, 4, 8}, 4), {6, 2, 4, 8} );
printTest( "copyEvens([1, 8, 4], 1) → [8]", copyEvens({1, 8, 4}, 1), {8} );
printTest( "copyEvens([1, 8, 4], 2) → [8, 4]", copyEvens({1, 8, 4}, 2), {8, 4} );
printTest( "copyEvens([2, 8, 4], 2) → [2, 8]", copyEvens({2, 8, 4}, 2), {2, 8} );

// %% [markdown]
// # AP-1 > copyEndy

// %%
/*
Weʼll say that a positive int n is "endy" if it is in the range 0..10 or 90..100
(inclusive). Given an array of positive ints, return a new array of length
"count" containing the first endy numbers from the original array. Decompose out
a separate isEndy(int n) method to test if a number is endy. The original array
will contain at least "count" endy numbers.

copyEndy([9, 11, 90, 22, 6], 2) → [9, 90]
copyEndy([9, 11, 90, 22, 6], 3) → [9, 90, 6]
copyEndy([12, 1, 1, 13, 0, 20], 2) → [1, 1]
*/

std::vector<int> copyEndy(vector<int> nums, int count) {
    return vector<int>{};
}


// tests:
printTest( "copyEndy([9, 11, 90, 22, 6], 2) → [9, 90]", copyEndy({9, 11, 90, 22, 6}, 2), {9, 90} );
printTest( "copyEndy([9, 11, 90, 22, 6], 3) → [9, 90, 6]", copyEndy({9, 11, 90, 22, 6}, 3), {9, 90, 6} );
printTest( "copyEndy([12, 1, 1, 13, 0, 20], 2) → [1, 1]", copyEndy({12, 1, 1, 13, 0, 20}, 2), {1, 1} );
printTest( "copyEndy([12, 1, 1, 13, 0, 20], 3) → [1, 1, 0]", copyEndy({12, 1, 1, 13, 0, 20}, 3), {1, 1, 0} );
printTest( "copyEndy([0], 1) → [0]", copyEndy({0}, 1), {0} );
printTest( "copyEndy([10, 11, 90], 2) → [10, 90]", copyEndy({10, 11, 90}, 2), {10, 90} );
printTest( "copyEndy([90, 22, 100], 2) → [90, 100]", copyEndy({90, 22, 100}, 2), {90, 100} );
printTest( "copyEndy([12, 11, 10, 89, 101, 4], 1) → [10]", copyEndy({12, 11, 10, 89, 101, 4}, 1), {10} );
printTest( "copyEndy([13, 2, 2, 0], 2) → [2, 2]", copyEndy({13, 2, 2, 0}, 2), {2, 2} );
printTest( "copyEndy([13, 2, 2, 0], 3) → [2, 2, 0]", copyEndy({13, 2, 2, 0}, 3), {2, 2, 0} );
printTest( "copyEndy([13, 2, 13, 2, 0, 30], 2) → [2, 2]", copyEndy({13, 2, 13, 2, 0, 30}, 2), {2, 2} );
printTest( "copyEndy([13, 2, 13, 2, 0, 30], 3) → [2, 2, 0]", copyEndy({13, 2, 13, 2, 0, 30}, 3), {2, 2, 0} );

// %% [markdown]
// # AP-1 > matchUp

// %%
/*
Given 2 arrays that are the same length containing strings, compare the 1st
string in one array to the 1st string in the other array, the 2nd to the 2nd and
so on. Count the number of times that the 2 strings are non-empty and start with
the same char. The strings may be any length, including 0.

matchUp(["aa", "bb", "cc"], ["aaa", "xx", "bb"]) → 1
matchUp(["aa", "bb", "cc"], ["aaa", "b", "bb"]) → 2
matchUp(["aa", "bb", "cc"], ["", "", "ccc"]) → 1
*/

int matchUp(vector<string> a, vector<string> b) {
    return 0;
}


// tests:
printTest( "matchUp([\"aa\", \"bb\", \"cc\"], [\"aaa\", \"xx\", \"bb\"]) → 1", matchUp({"aa", "bb", "cc"}, {"aaa", "xx", "bb"}), 1 );
printTest( "matchUp([\"aa\", \"bb\", \"cc\"], [\"aaa\", \"b\", \"bb\"]) → 2", matchUp({"aa", "bb", "cc"}, {"aaa", "b", "bb"}), 2 );
printTest( "matchUp([\"aa\", \"bb\", \"cc\"], [\"\", \"\", \"ccc\"]) → 1", matchUp({"aa", "bb", "cc"}, {"", "", "ccc"}), 1 );
printTest( "matchUp([\"\", \"\", \"ccc\"], [\"aa\", \"bb\", \"cc\"]) → 1", matchUp({"", "", "ccc"}, {"aa", "bb", "cc"}), 1 );
printTest( "matchUp([\"\", \"\", \"\"], [\"\", \"bb\", \"cc\"]) → 0", matchUp({"", "", ""}, {"", "bb", "cc"}), 0 );
printTest( "matchUp([\"aa\", \"bb\", \"cc\"], [\"\", \"\", \"\"]) → 0", matchUp({"aa", "bb", "cc"}, {"", "", ""}), 0 );
printTest( "matchUp([\"aa\", \"\", \"ccc\"], [\"\", \"bb\", \"cc\"]) → 1", matchUp({"aa", "", "ccc"}, {"", "bb", "cc"}), 1 );
printTest( "matchUp([\"x\", \"y\", \"z\"], [\"y\", \"z\", \"x\"]) → 0", matchUp({"x", "y", "z"}, {"y", "z", "x"}), 0 );
printTest( "matchUp([\"\", \"y\", \"z\"], [\"\", \"y\", \"x\"]) → 1", matchUp({"", "y", "z"}, {"", "y", "x"}), 1 );
printTest( "matchUp([\"x\", \"y\", \"z\"], [\"xx\", \"yyy\", \"zzz\"]) → 3", matchUp({"x", "y", "z"}, {"xx", "yyy", "zzz"}), 3 );
printTest( "matchUp([\"x\", \"y\", \"z\"], [\"xx\", \"yyy\", \"\"]) → 2", matchUp({"x", "y", "z"}, {"xx", "yyy", ""}), 2 );
printTest( "matchUp([\"b\", \"x\", \"y\", \"z\"], [\"a\", \"xx\", \"yyy\", \"zzz\"]) → 3", matchUp({"b", "x", "y", "z"}, {"a", "xx", "yyy", "zzz"}), 3 );
printTest( "matchUp([\"aaa\", \"bb\", \"c\"], [\"aaa\", \"xx\", \"bb\"]) → 1", matchUp({"aaa", "bb", "c"}, {"aaa", "xx", "bb"}), 1 );

// %% [markdown]
// # AP-1 > scoreUp

// %%
/*
The "key" array is an array containing the correct answers to an exam, like
{"a", "a", "b", "b"}. the "answers" array contains a studentʼs answers, with "?"
representing a question left blank. The two arrays are not empty and are the
same length. Return the score for this array of answers, giving +4 for each
correct answer, -1 for each incorrect answer, and +0 for each blank answer.

scoreUp(["a", "a", "b", "b"], ["a", "c", "b", "c"]) → 6
scoreUp(["a", "a", "b", "b"], ["a", "a", "b", "c"]) → 11
scoreUp(["a", "a", "b", "b"], ["a", "a", "b", "b"]) → 16
*/

int scoreUp(vector<string> key, vector<string> answers) {
    return 0;
}


// tests:
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\"], [\"a\", \"c\", \"b\", \"c\"]) → 6", scoreUp({"a", "a", "b", "b"}, {"a", "c", "b", "c"}), 6 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\"], [\"a\", \"a\", \"b\", \"c\"]) → 11", scoreUp({"a", "a", "b", "b"}, {"a", "a", "b", "c"}), 11 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\"], [\"a\", \"a\", \"b\", \"b\"]) → 16", scoreUp({"a", "a", "b", "b"}, {"a", "a", "b", "b"}), 16 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\"], [\"?\", \"c\", \"b\", \"?\"]) → 3", scoreUp({"a", "a", "b", "b"}, {"?", "c", "b", "?"}), 3 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\"], [\"?\", \"c\", \"?\", \"?\"]) → -1", scoreUp({"a", "a", "b", "b"}, {"?", "c", "?", "?"}), -1 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\"], [\"c\", \"?\", \"b\", \"b\"]) → 7", scoreUp({"a", "a", "b", "b"}, {"c", "?", "b", "b"}), 7 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\"], [\"c\", \"?\", \"b\", \"?\"]) → 3", scoreUp({"a", "a", "b", "b"}, {"c", "?", "b", "?"}), 3 );
printTest( "scoreUp([\"a\", \"b\", \"c\"], [\"a\", \"c\", \"b\"]) → 2", scoreUp({"a", "b", "c"}, {"a", "c", "b"}), 2 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\", \"c\", \"c\"], [\"a\", \"c\", \"a\", \"c\", \"a\", \"c\"]) → 4", scoreUp({"a", "a", "b", "b", "c", "c"}, {"a", "c", "a", "c", "a", "c"}), 4 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\", \"c\", \"c\"], [\"a\", \"c\", \"?\", \"?\", \"a\", \"c\"]) → 6", scoreUp({"a", "a", "b", "b", "c", "c"}, {"a", "c", "?", "?", "a", "c"}), 6 );
printTest( "scoreUp([\"a\", \"a\", \"b\", \"b\", \"c\", \"c\"], [\"a\", \"c\", \"?\", \"?\", \"c\", \"c\"]) → 11", scoreUp({"a", "a", "b", "b", "c", "c"}, {"a", "c", "?", "?", "c", "c"}), 11 );
printTest( "scoreUp([\"a\", \"b\", \"c\"], [\"a\", \"b\", \"c\"]) → 12", scoreUp({"a", "b", "c"}, {"a", "b", "c"}), 12 );

// %% [markdown]
// # AP-1 > wordsWithout

// %%
/*
Given an array of strings, return a new array without the strings that are equal
to the target string. One approach is to count the occurrences of the target
string, make a new array of the correct length, and then copy over the correct
strings.

wordsWithout(["a", "b", "c", "a"], "a") → ["b", "c"]
wordsWithout(["a", "b", "c", "a"], "b") → ["a", "c", "a"]
wordsWithout(["a", "b", "c", "a"], "c") → ["a", "b", "a"]
*/

std::vector<string> wordsWithout(vector<string> words, string target) {
    return new vector<string>{};
}


// tests:
printTest( "wordsWithout([\"a\", \"b\", \"c\", \"a\"], \"a\") → [\"b\", \"c\"]", wordsWithout({"a", "b", "c", "a"}, "a"), {"b", "c"} );
printTest( "wordsWithout([\"a\", \"b\", \"c\", \"a\"], \"b\") → [\"a\", \"c\", \"a\"]", wordsWithout({"a", "b", "c", "a"}, "b"), {"a", "c", "a"} );
printTest( "wordsWithout([\"a\", \"b\", \"c\", \"a\"], \"c\") → [\"a\", \"b\", \"a\"]", wordsWithout({"a", "b", "c", "a"}, "c"), {"a", "b", "a"} );
printTest( "wordsWithout([\"b\", \"c\", \"a\", \"a\"], \"b\") → [\"c\", \"a\", \"a\"]", wordsWithout({"b", "c", "a", "a"}, "b"), {"c", "a", "a"} );
printTest( "wordsWithout([\"xx\", \"yyy\", \"x\", \"yy\", \"x\"], \"x\") → [\"xx\", \"yyy\", \"yy\"]", wordsWithout({"xx", "yyy", "x", "yy", "x"}, "x"), {"xx", "yyy", "yy"} );
printTest( "wordsWithout([\"xx\", \"yyy\", \"x\", \"yy\", \"x\"], \"yy\") → [\"xx\", \"yyy\", \"x\", \"x\"]", wordsWithout({"xx", "yyy", "x", "yy", "x"}, "yy"), {"xx", "yyy", "x", "x"} );
printTest( "wordsWithout([\"aa\", \"ab\", \"ac\", \"aa\"], \"aa\") → [\"ab\", \"ac\"]", wordsWithout({"aa", "ab", "ac", "aa"}, "aa"), {"ab", "ac"} );

// %% [markdown]
// # AP-1 > scoresSpecial

// %%
/*
Given two arrays, A and B, of non-negative int scores. A "special" score is one
which is a multiple of 10, such as 40 or 90. Return the sum of largest special
score in A and the largest special score in B. To practice decomposition, write
a separate helper method which finds the largest special score in an array.
Write your helper method after your scoresSpecial() method in the JavaBat text
area.

scoresSpecial([12, 10, 4], [2, 20, 30]) → 40
scoresSpecial([20, 10, 4], [2, 20, 10]) → 40
scoresSpecial([12, 11, 4], [2, 20, 31]) → 20
*/

int scoresSpecial(vector<int> a, vector<int> b) {
    return 0;
}


// tests:
printTest( "scoresSpecial([12, 10, 4], [2, 20, 30]) → 40", scoresSpecial({12, 10, 4}, {2, 20, 30}), 40 );
printTest( "scoresSpecial([20, 10, 4], [2, 20, 10]) → 40", scoresSpecial({20, 10, 4}, {2, 20, 10}), 40 );
printTest( "scoresSpecial([12, 11, 4], [2, 20, 31]) → 20", scoresSpecial({12, 11, 4}, {2, 20, 31}), 20 );
printTest( "scoresSpecial([1, 20, 2, 50], [3, 4, 5]) → 50", scoresSpecial({1, 20, 2, 50}, {3, 4, 5}), 50 );
printTest( "scoresSpecial([3, 4, 5], [1, 50, 2, 20]) → 50", scoresSpecial({3, 4, 5}, {1, 50, 2, 20}), 50 );
printTest( "scoresSpecial([10, 4, 20, 30], [20]) → 50", scoresSpecial({10, 4, 20, 30}, {20}), 50 );
printTest( "scoresSpecial([10, 4, 20, 30], [20]) → 50", scoresSpecial({10, 4, 20, 30}, {20}), 50 );
printTest( "scoresSpecial([10, 4, 20, 30], [3, 20, 99]) → 50", scoresSpecial({10, 4, 20, 30}, {3, 20, 99}), 50 );
printTest( "scoresSpecial([10, 4, 20, 30], [30, 20, 99]) → 60", scoresSpecial({10, 4, 20, 30}, {30, 20, 99}), 60 );
printTest( "scoresSpecial([], [2]) → 0", scoresSpecial({}, {2}), 0 );
printTest( "scoresSpecial([], [20]) → 20", scoresSpecial({}, {20}), 20 );
printTest( "scoresSpecial([14, 10, 4], [4, 20, 30]) → 40", scoresSpecial({14, 10, 4}, {4, 20, 30}), 40 );

// %% [markdown]
// # AP-1 > sumHeights

// %%
/*
We have an array of heights, representing the altitude along a walking trail.
Given start/end indexes into the array, return the sum of the changes for a walk
beginning at the start index and ending at the end index. For example, with the
heights {5, 3, 6, 7, 2} and start=2, end=4 yields a sum of 1 + 5 = 6. The start
end end index will both be valid indexes into the array with start <= end.

sumHeights([5, 3, 6, 7, 2], 2, 4) → 6
sumHeights([5, 3, 6, 7, 2], 0, 1) → 2
sumHeights([5, 3, 6, 7, 2], 0, 4) → 11
*/

int sumHeights(vector<int> heights, int start, int end) {
    return 0;
}


// tests:
printTest( "sumHeights([5, 3, 6, 7, 2], 2, 4) → 6", sumHeights({5, 3, 6, 7, 2}, 2, 4), 6 );
printTest( "sumHeights([5, 3, 6, 7, 2], 0, 1) → 2", sumHeights({5, 3, 6, 7, 2}, 0, 1), 2 );
printTest( "sumHeights([5, 3, 6, 7, 2], 0, 4) → 11", sumHeights({5, 3, 6, 7, 2}, 0, 4), 11 );
printTest( "sumHeights([5, 3, 6, 7, 2], 1, 1) → 0", sumHeights({5, 3, 6, 7, 2}, 1, 1), 0 );
printTest( "sumHeights([1, 2, 3, 4, 5, 4, 3, 2, 10], 0, 3) → 3", sumHeights({1, 2, 3, 4, 5, 4, 3, 2, 10}, 0, 3), 3 );
printTest( "sumHeights([1, 2, 3, 4, 5, 4, 3, 2, 10], 4, 8) → 11", sumHeights({1, 2, 3, 4, 5, 4, 3, 2, 10}, 4, 8), 11 );
printTest( "sumHeights([1, 2, 3, 4, 5, 4, 3, 2, 10], 7, 8) → 8", sumHeights({1, 2, 3, 4, 5, 4, 3, 2, 10}, 7, 8), 8 );
printTest( "sumHeights([1, 2, 3, 4, 5, 4, 3, 2, 10], 8, 8) → 0", sumHeights({1, 2, 3, 4, 5, 4, 3, 2, 10}, 8, 8), 0 );
printTest( "sumHeights([1, 2, 3, 4, 5, 4, 3, 2, 10], 2, 2) → 0", sumHeights({1, 2, 3, 4, 5, 4, 3, 2, 10}, 2, 2), 0 );
printTest( "sumHeights([1, 2, 3, 4, 5, 4, 3, 2, 10], 3, 6) → 3", sumHeights({1, 2, 3, 4, 5, 4, 3, 2, 10}, 3, 6), 3 );
printTest( "sumHeights([10, 8, 7, 7, 7, 6, 7], 1, 4) → 1", sumHeights({10, 8, 7, 7, 7, 6, 7}, 1, 4), 1 );
printTest( "sumHeights([10, 8, 7, 7, 7, 6, 7], 1, 5) → 2", sumHeights({10, 8, 7, 7, 7, 6, 7}, 1, 5), 2 );

// %% [markdown]
// # AP-1 > sumHeights2

// %%
/*
(A variation on the sumHeights problem.) We have an array of heights,
representing the altitude along a walking trail. Given start/end indexes into
the array, return the sum of the changes for a walk beginning at the start index
and ending at the end index, however increases in height count double. For
example, with the heights {5, 3, 6, 7, 2} and start=2, end=4 yields a sum of 1*2
+ 5 = 7. The start end end index will both be valid indexes into the array with
start <= end.

sumHeights2([5, 3, 6, 7, 2], 2, 4) → 7
sumHeights2([5, 3, 6, 7, 2], 0, 1) → 2
sumHeights2([5, 3, 6, 7, 2], 0, 4) → 15
*/

int sumHeights2(vector<int> heights, int start, int end) {
    return 0;
}


// tests:
printTest( "sumHeights2([5, 3, 6, 7, 2], 2, 4) → 7", sumHeights2({5, 3, 6, 7, 2}, 2, 4), 7 );
printTest( "sumHeights2([5, 3, 6, 7, 2], 0, 1) → 2", sumHeights2({5, 3, 6, 7, 2}, 0, 1), 2 );
printTest( "sumHeights2([5, 3, 6, 7, 2], 0, 4) → 15", sumHeights2({5, 3, 6, 7, 2}, 0, 4), 15 );
printTest( "sumHeights2([5, 3, 6, 7, 2], 1, 1) → 0", sumHeights2({5, 3, 6, 7, 2}, 1, 1), 0 );
printTest( "sumHeights2([1, 2, 3, 4, 5, 4, 3, 2, 10], 0, 3) → 6", sumHeights2({1, 2, 3, 4, 5, 4, 3, 2, 10}, 0, 3), 6 );
printTest( "sumHeights2([1, 2, 3, 4, 5, 4, 3, 2, 10], 4, 8) → 19", sumHeights2({1, 2, 3, 4, 5, 4, 3, 2, 10}, 4, 8), 19 );
printTest( "sumHeights2([1, 2, 3, 4, 5, 4, 3, 2, 10], 7, 8) → 16", sumHeights2({1, 2, 3, 4, 5, 4, 3, 2, 10}, 7, 8), 16 );
printTest( "sumHeights2([1, 2, 3, 4, 5, 4, 3, 2, 10], 8, 8) → 0", sumHeights2({1, 2, 3, 4, 5, 4, 3, 2, 10}, 8, 8), 0 );
printTest( "sumHeights2([1, 2, 3, 4, 5, 4, 3, 2, 10], 2, 2) → 0", sumHeights2({1, 2, 3, 4, 5, 4, 3, 2, 10}, 2, 2), 0 );
printTest( "sumHeights2([1, 2, 3, 4, 5, 4, 3, 2, 10], 3, 6) → 4", sumHeights2({1, 2, 3, 4, 5, 4, 3, 2, 10}, 3, 6), 4 );
printTest( "sumHeights2([10, 8, 7, 7, 7, 6, 7], 1, 4) → 1", sumHeights2({10, 8, 7, 7, 7, 6, 7}, 1, 4), 1 );
printTest( "sumHeights2([10, 8, 7, 7, 7, 6, 7], 1, 5) → 2", sumHeights2({10, 8, 7, 7, 7, 6, 7}, 1, 5), 2 );

// %% [markdown]
// # AP-1 > bigHeights

// %%
/*
(A variation on the sumHeights problem.) We have an array of heights,
representing the altitude along a walking trail. Given start/end indexes into
the array, return the number of "big" steps for a walk starting at the start
index and ending at the end index. Weʼll say that  step is big if it is 5 or
more up or down. The start end end index will both be valid indexes into the
array with start <= end.

bigHeights([5, 3, 6, 7, 2], 2, 4) → 1
bigHeights([5, 3, 6, 7, 2], 0, 1) → 0
bigHeights([5, 3, 6, 7, 2], 0, 4) → 1
*/

int bigHeights(vector<int> heights, int start, int end) {
    return 0;
}


// tests:
printTest( "bigHeights([5, 3, 6, 7, 2], 2, 4) → 1", bigHeights({5, 3, 6, 7, 2}, 2, 4), 1 );
printTest( "bigHeights([5, 3, 6, 7, 2], 0, 1) → 0", bigHeights({5, 3, 6, 7, 2}, 0, 1), 0 );
printTest( "bigHeights([5, 3, 6, 7, 2], 0, 4) → 1", bigHeights({5, 3, 6, 7, 2}, 0, 4), 1 );
printTest( "bigHeights([5, 3, 6, 7, 3], 0, 4) → 0", bigHeights({5, 3, 6, 7, 3}, 0, 4), 0 );
printTest( "bigHeights([5, 3, 6, 7, 2], 1, 1) → 0", bigHeights({5, 3, 6, 7, 2}, 1, 1), 0 );
printTest( "bigHeights([5, 13, 6, 7, 2], 1, 2) → 1", bigHeights({5, 13, 6, 7, 2}, 1, 2), 1 );
printTest( "bigHeights([5, 13, 6, 7, 2], 0, 2) → 2", bigHeights({5, 13, 6, 7, 2}, 0, 2), 2 );
printTest( "bigHeights([5, 13, 6, 7, 2], 1, 4) → 2", bigHeights({5, 13, 6, 7, 2}, 1, 4), 2 );
printTest( "bigHeights([5, 13, 6, 7, 2], 0, 4) → 3", bigHeights({5, 13, 6, 7, 2}, 0, 4), 3 );
printTest( "bigHeights([5, 13, 6, 7, 2], 0, 3) → 2", bigHeights({5, 13, 6, 7, 2}, 0, 3), 2 );
printTest( "bigHeights([1, 2, 3, 4, 5, 4, 3, 2, 10], 0, 3) → 0", bigHeights({1, 2, 3, 4, 5, 4, 3, 2, 10}, 0, 3), 0 );
printTest( "bigHeights([1, 2, 3, 4, 5, 4, 3, 2, 10], 4, 8) → 1", bigHeights({1, 2, 3, 4, 5, 4, 3, 2, 10}, 4, 8), 1 );
printTest( "bigHeights([1, 2, 3, 14, 5, 4, 3, 2, 10], 0, 3) → 1", bigHeights({1, 2, 3, 14, 5, 4, 3, 2, 10}, 0, 3), 1 );
printTest( "bigHeights([1, 2, 3, 14, 5, 4, 3, 2, 10], 7, 8) → 1", bigHeights({1, 2, 3, 14, 5, 4, 3, 2, 10}, 7, 8), 1 );
printTest( "bigHeights([1, 2, 3, 14, 5, 4, 3, 2, 10], 3, 8) → 2", bigHeights({1, 2, 3, 14, 5, 4, 3, 2, 10}, 3, 8), 2 );
printTest( "bigHeights([1, 2, 3, 14, 5, 4, 3, 2, 10], 2, 8) → 3", bigHeights({1, 2, 3, 14, 5, 4, 3, 2, 10}, 2, 8), 3 );

// %% [markdown]
// # AP-1 > userCompare

// %%
/*
We have data for two users, A and B, each with a String name and an int id. The
goal is to order the users such as for sorting. Return -1 if A comes before B, 1
if A comes after B, and 0 if they are the same. Order first by the string names,
and then by the id numbers if the names are the same. Note: with Strings
str1.compareTo(str2) returns an int value which is negative/0/positive to
indicate how str1 is ordered to str2 (the value is not limited to -1/0/1). (On
the AP, there would be two User objects, but here the code simply takes the two
strings and two ints directly. The code logic is the same.)

userCompare("bb", 1, "zz", 2) → -1
userCompare("bb", 1, "aa", 2) → 1
userCompare("bb", 1, "bb", 1) → 0
*/

int userCompare(string aName, int aId, string bName, int bId) {
    return 0;
}


// tests:
printTest( "userCompare(\"bb\", 1, \"zz\", 2) → -1", userCompare("bb", 1, "zz", 2), -1 );
printTest( "userCompare(\"bb\", 1, \"aa\", 2) → 1", userCompare("bb", 1, "aa", 2), 1 );
printTest( "userCompare(\"bb\", 1, \"bb\", 1) → 0", userCompare("bb", 1, "bb", 1), 0 );
printTest( "userCompare(\"bb\", 5, \"bb\", 1) → 1", userCompare("bb", 5, "bb", 1), 1 );
printTest( "userCompare(\"bb\", 5, \"bb\", 10) → -1", userCompare("bb", 5, "bb", 10), -1 );
printTest( "userCompare(\"adam\", 1, \"bob\", 2) → -1", userCompare("adam", 1, "bob", 2), -1 );
printTest( "userCompare(\"bob\", 1, \"bob\", 2) → -1", userCompare("bob", 1, "bob", 2), -1 );
printTest( "userCompare(\"bzb\", 1, \"bob\", 2) → 1", userCompare("bzb", 1, "bob", 2), 1 );

// %% [markdown]
// # AP-1 > mergeTwo

// %%
/*
Start with two arrays of strings, A and B, each with its elements in
alphabetical order and without duplicates. Return a new array containing the
first N elements from the two arrays. The result array should be in alphabetical
order and without duplicates. A and B will both have a length which is N or
more. The best "linear" solution makes a single pass over A and B, taking
advantage of the fact that they are in alphabetical order, copying elements
directly to the new array.

mergeTwo(["a", "c", "z"], ["b", "f", "z"], 3) → ["a", "b", "c"]
mergeTwo(["a", "c", "z"], ["c", "f", "z"], 3) → ["a", "c", "f"]
mergeTwo(["f", "g", "z"], ["c", "f", "g"], 3) → ["c", "f", "g"]
*/

std::vector<string> mergeTwo(vector<string> a, vector<string> b, int n) {
    return new vector<string>{};
}


// tests:
printTest( "mergeTwo([\"a\", \"c\", \"z\"], [\"b\", \"f\", \"z\"], 3) → [\"a\", \"b\", \"c\"]", mergeTwo({"a", "c", "z"}, {"b", "f", "z"}, 3), {"a", "b", "c"} );
printTest( "mergeTwo([\"a\", \"c\", \"z\"], [\"c\", \"f\", \"z\"], 3) → [\"a\", \"c\", \"f\"]", mergeTwo({"a", "c", "z"}, {"c", "f", "z"}, 3), {"a", "c", "f"} );
printTest( "mergeTwo([\"f\", \"g\", \"z\"], [\"c\", \"f\", \"g\"], 3) → [\"c\", \"f\", \"g\"]", mergeTwo({"f", "g", "z"}, {"c", "f", "g"}, 3), {"c", "f", "g"} );
printTest( "mergeTwo([\"a\", \"c\", \"z\"], [\"a\", \"c\", \"z\"], 3) → [\"a\", \"c\", \"z\"]", mergeTwo({"a", "c", "z"}, {"a", "c", "z"}, 3), {"a", "c", "z"} );
printTest( "mergeTwo([\"a\", \"b\", \"c\", \"z\"], [\"a\", \"c\", \"z\"], 3) → [\"a\", \"b\", \"c\"]", mergeTwo({"a", "b", "c", "z"}, {"a", "c", "z"}, 3), {"a", "b", "c"} );
printTest( "mergeTwo([\"a\", \"c\", \"z\"], [\"a\", \"b\", \"c\", \"z\"], 3) → [\"a\", \"b\", \"c\"]", mergeTwo({"a", "c", "z"}, {"a", "b", "c", "z"}, 3), {"a", "b", "c"} );
printTest( "mergeTwo([\"a\", \"c\", \"z\"], [\"a\", \"c\", \"z\"], 2) → [\"a\", \"c\"]", mergeTwo({"a", "c", "z"}, {"a", "c", "z"}, 2), {"a", "c"} );
printTest( "mergeTwo([\"a\", \"c\", \"z\"], [\"a\", \"c\", \"y\", \"z\"], 3) → [\"a\", \"c\", \"y\"]", mergeTwo({"a", "c", "z"}, {"a", "c", "y", "z"}, 3), {"a", "c", "y"} );
printTest( "mergeTwo([\"x\", \"y\", \"z\"], [\"a\", \"b\", \"z\"], 3) → [\"a\", \"b\", \"x\"]", mergeTwo({"x", "y", "z"}, {"a", "b", "z"}, 3), {"a", "b", "x"} );

// %% [markdown]
// # AP-1 > commonTwo

// %%
/*
Start with two arrays of strings, a and b, each in alphabetical order, possibly
with duplicates. Return the count of the number of strings which appear in both
arrays. The best "linear" solution makes a single pass over both arrays, taking
advantage of the fact that they are in alphabetical order.

commonTwo(["a", "c", "x"], ["b", "c", "d", "x"]) → 2
commonTwo(["a", "c", "x"], ["a", "b", "c", "x", "z"]) → 3
commonTwo(["a", "b", "c"], ["a", "b", "c"]) → 3
*/

int commonTwo(vector<string> a, vector<string> b) {
    return 0;
}


// tests:
printTest( "commonTwo([\"a\", \"c\", \"x\"], [\"b\", \"c\", \"d\", \"x\"]) → 2", commonTwo({"a", "c", "x"}, {"b", "c", "d", "x"}), 2 );
printTest( "commonTwo([\"a\", \"c\", \"x\"], [\"a\", \"b\", \"c\", \"x\", \"z\"]) → 3", commonTwo({"a", "c", "x"}, {"a", "b", "c", "x", "z"}), 3 );
printTest( "commonTwo([\"a\", \"b\", \"c\"], [\"a\", \"b\", \"c\"]) → 3", commonTwo({"a", "b", "c"}, {"a", "b", "c"}), 3 );
printTest( "commonTwo([\"a\", \"a\", \"b\", \"b\", \"c\"], [\"a\", \"b\", \"c\"]) → 3", commonTwo({"a", "a", "b", "b", "c"}, {"a", "b", "c"}), 3 );
printTest( "commonTwo([\"a\", \"a\", \"b\", \"b\", \"c\"], [\"a\", \"b\", \"b\", \"b\", \"c\"]) → 3", commonTwo({"a", "a", "b", "b", "c"}, {"a", "b", "b", "b", "c"}), 3 );
printTest( "commonTwo([\"a\", \"a\", \"b\", \"b\", \"c\"], [\"a\", \"b\", \"b\", \"c\", \"c\"]) → 3", commonTwo({"a", "a", "b", "b", "c"}, {"a", "b", "b", "c", "c"}), 3 );
printTest( "commonTwo([\"b\", \"b\", \"b\", \"b\", \"c\"], [\"a\", \"b\", \"b\", \"b\", \"c\"]) → 2", commonTwo({"b", "b", "b", "b", "c"}, {"a", "b", "b", "b", "c"}), 2 );
printTest( "commonTwo([\"a\", \"b\", \"c\", \"c\", \"d\"], [\"a\", \"b\", \"b\", \"c\", \"d\", \"d\"]) → 4", commonTwo({"a", "b", "c", "c", "d"}, {"a", "b", "b", "c", "d", "d"}), 4 );
printTest( "commonTwo([\"a\", \"a\", \"b\", \"b\", \"c\"], [\"b\", \"b\", \"b\"]) → 1", commonTwo({"a", "a", "b", "b", "c"}, {"b", "b", "b"}), 1 );
printTest( "commonTwo([\"a\", \"a\", \"b\", \"b\", \"c\"], [\"c\", \"c\"]) → 1", commonTwo({"a", "a", "b", "b", "c"}, {"c", "c"}), 1 );
printTest( "commonTwo([\"a\", \"a\", \"b\", \"b\", \"c\"], [\"b\", \"b\", \"b\", \"x\"]) → 1", commonTwo({"a", "a", "b", "b", "c"}, {"b", "b", "b", "x"}), 1 );
printTest( "commonTwo([\"a\", \"a\", \"b\", \"b\", \"c\"], [\"b\", \"b\"]) → 1", commonTwo({"a", "a", "b", "b", "c"}, {"b", "b"}), 1 );
printTest( "commonTwo([\"a\"], [\"a\", \"b\"]) → 1", commonTwo({"a"}, {"a", "b"}), 1 );
printTest( "commonTwo([\"a\"], [\"b\"]) → 0", commonTwo({"a"}, {"b"}), 0 );
printTest( "commonTwo([\"a\", \"a\"], [\"b\", \"b\"]) → 0", commonTwo({"a", "a"}, {"b", "b"}), 0 );
printTest( "commonTwo([\"a\", \"b\"], [\"a\", \"b\"]) → 2", commonTwo({"a", "b"}, {"a", "b"}), 2 );
