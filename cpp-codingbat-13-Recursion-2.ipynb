// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
namespace testns { template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
} } using namespace testns;
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # Recursion-2 > groupSum

// %%
/*
Given an array of ints, is it possible to choose a group of some of the ints,
such that the group sums to the given target? This is a classic backtracking
recursion problem. Once you understand the recursive backtracking strategy in
this problem, you can use the same pattern for many problems to search a space
of choices. Rather than looking at the whole array, our convention is to
consider the part of the array starting at index start and continuing to the end
of the array. The caller can specify the whole array simply by passing start as
0. No loops are needed -- the recursive calls progress down the array.

groupSum(0, [2, 4, 8], 10) → true
groupSum(0, [2, 4, 8], 14) → true
groupSum(0, [2, 4, 8], 9) → false
*/

bool groupSum(int start, vector<int> nums, int target) {
    return false;
}


// tests:
printTest( "groupSum(0, [2, 4, 8], 10) → true", groupSum(0, {2, 4, 8}, 10), true );
printTest( "groupSum(0, [2, 4, 8], 14) → true", groupSum(0, {2, 4, 8}, 14), true );
printTest( "groupSum(0, [2, 4, 8], 9) → false", groupSum(0, {2, 4, 8}, 9), false );
printTest( "groupSum(0, [2, 4, 8], 8) → true", groupSum(0, {2, 4, 8}, 8), true );
printTest( "groupSum(1, [2, 4, 8], 8) → true", groupSum(1, {2, 4, 8}, 8), true );
printTest( "groupSum(1, [2, 4, 8], 2) → false", groupSum(1, {2, 4, 8}, 2), false );
printTest( "groupSum(0, [1], 1) → true", groupSum(0, {1}, 1), true );
printTest( "groupSum(0, [9], 1) → false", groupSum(0, {9}, 1), false );
printTest( "groupSum(1, [9], 0) → true", groupSum(1, {9}, 0), true );
printTest( "groupSum(0, [], 0) → true", groupSum(0, {}, 0), true );
printTest( "groupSum(0, [10, 2, 2, 5], 17) → true", groupSum(0, {10, 2, 2, 5}, 17), true );
printTest( "groupSum(0, [10, 2, 2, 5], 15) → true", groupSum(0, {10, 2, 2, 5}, 15), true );
printTest( "groupSum(0, [10, 2, 2, 5], 9) → true", groupSum(0, {10, 2, 2, 5}, 9), true );

// %% [markdown]
// # Recursion-2 > groupSum6

// %%
/*
Given an array of ints, is it possible to choose a group of some of the ints,
beginning at the start index, such that the group sums to the given target?
However, with the additional constraint that all 6ʼs must be chosen. (No loops
needed.)

groupSum6(0, [5, 6, 2], 8) → true
groupSum6(0, [5, 6, 2], 9) → false
groupSum6(0, [5, 6, 2], 7) → false
*/

bool groupSum6(int start, vector<int> nums, int target) {
    return false;
}


// tests:
printTest( "groupSum6(0, [5, 6, 2], 8) → true", groupSum6(0, {5, 6, 2}, 8), true );
printTest( "groupSum6(0, [5, 6, 2], 9) → false", groupSum6(0, {5, 6, 2}, 9), false );
printTest( "groupSum6(0, [5, 6, 2], 7) → false", groupSum6(0, {5, 6, 2}, 7), false );
printTest( "groupSum6(0, [1], 1) → true", groupSum6(0, {1}, 1), true );
printTest( "groupSum6(0, [9], 1) → false", groupSum6(0, {9}, 1), false );
printTest( "groupSum6(0, [], 0) → true", groupSum6(0, {}, 0), true );
printTest( "groupSum6(0, [3, 2, 4, 6], 8) → true", groupSum6(0, {3, 2, 4, 6}, 8), true );
printTest( "groupSum6(0, [6, 2, 4, 3], 8) → true", groupSum6(0, {6, 2, 4, 3}, 8), true );
printTest( "groupSum6(0, [5, 2, 4, 6], 9) → false", groupSum6(0, {5, 2, 4, 6}, 9), false );
printTest( "groupSum6(0, [6, 2, 4, 5], 9) → false", groupSum6(0, {6, 2, 4, 5}, 9), false );
printTest( "groupSum6(0, [3, 2, 4, 6], 3) → false", groupSum6(0, {3, 2, 4, 6}, 3), false );
printTest( "groupSum6(0, [1, 6, 2, 6, 4], 12) → true", groupSum6(0, {1, 6, 2, 6, 4}, 12), true );
printTest( "groupSum6(0, [1, 6, 2, 6, 4], 13) → true", groupSum6(0, {1, 6, 2, 6, 4}, 13), true );
printTest( "groupSum6(0, [1, 6, 2, 6, 4], 4) → false", groupSum6(0, {1, 6, 2, 6, 4}, 4), false );
printTest( "groupSum6(0, [1, 6, 2, 6, 4], 9) → false", groupSum6(0, {1, 6, 2, 6, 4}, 9), false );
printTest( "groupSum6(0, [1, 6, 2, 6, 5], 14) → true", groupSum6(0, {1, 6, 2, 6, 5}, 14), true );
printTest( "groupSum6(0, [1, 6, 2, 6, 5], 15) → true", groupSum6(0, {1, 6, 2, 6, 5}, 15), true );
printTest( "groupSum6(0, [1, 6, 2, 6, 5], 16) → false", groupSum6(0, {1, 6, 2, 6, 5}, 16), false );

// %% [markdown]
// # Recursion-2 > groupNoAdj

// %%
/*
Given an array of ints, is it possible to choose a group of some of the ints,
such that the group sums to the given target with this additional constraint: If
a value in the array is chosen to be in the group, the value immediately
following it in the array must not be chosen. (No loops needed.)

groupNoAdj(0, [2, 5, 10, 4], 12) → true
groupNoAdj(0, [2, 5, 10, 4], 14) → false
groupNoAdj(0, [2, 5, 10, 4], 7) → false
*/

bool groupNoAdj(int start, vector<int> nums, int target) {
    return false;
}


// tests:
printTest( "groupNoAdj(0, [2, 5, 10, 4], 12) → true", groupNoAdj(0, {2, 5, 10, 4}, 12), true );
printTest( "groupNoAdj(0, [2, 5, 10, 4], 14) → false", groupNoAdj(0, {2, 5, 10, 4}, 14), false );
printTest( "groupNoAdj(0, [2, 5, 10, 4], 7) → false", groupNoAdj(0, {2, 5, 10, 4}, 7), false );
printTest( "groupNoAdj(0, [2, 5, 10, 4, 2], 7) → true", groupNoAdj(0, {2, 5, 10, 4, 2}, 7), true );
printTest( "groupNoAdj(0, [2, 5, 10, 4], 9) → true", groupNoAdj(0, {2, 5, 10, 4}, 9), true );
printTest( "groupNoAdj(0, [10, 2, 2, 3, 3], 15) → true", groupNoAdj(0, {10, 2, 2, 3, 3}, 15), true );
printTest( "groupNoAdj(0, [10, 2, 2, 3, 3], 7) → false", groupNoAdj(0, {10, 2, 2, 3, 3}, 7), false );
printTest( "groupNoAdj(0, [], 0) → true", groupNoAdj(0, {}, 0), true );
printTest( "groupNoAdj(0, [1], 1) → true", groupNoAdj(0, {1}, 1), true );
printTest( "groupNoAdj(0, [9], 1) → false", groupNoAdj(0, {9}, 1), false );
printTest( "groupNoAdj(0, [9], 0) → true", groupNoAdj(0, {9}, 0), true );
printTest( "groupNoAdj(0, [5, 10, 4, 1], 11) → true", groupNoAdj(0, {5, 10, 4, 1}, 11), true );

// %% [markdown]
// # Recursion-2 > groupSum5

// %%
/*
Given an array of ints, is it possible to choose a group of some of the ints,
such that the group sums to the given target with these additional constraints:
all multiples of 5 in the array must be included in the group. If the value
immediately following a multiple of 5 is 1, it must not be chosen. (No loops
needed.)

groupSum5(0, [2, 5, 10, 4], 19) → true
groupSum5(0, [2, 5, 10, 4], 17) → true
groupSum5(0, [2, 5, 10, 4], 12) → false
*/

bool groupSum5(int start, vector<int> nums, int target) {
    return false;
}


// tests:
printTest( "groupSum5(0, [2, 5, 10, 4], 19) → true", groupSum5(0, {2, 5, 10, 4}, 19), true );
printTest( "groupSum5(0, [2, 5, 10, 4], 17) → true", groupSum5(0, {2, 5, 10, 4}, 17), true );
printTest( "groupSum5(0, [2, 5, 10, 4], 12) → false", groupSum5(0, {2, 5, 10, 4}, 12), false );
printTest( "groupSum5(0, [2, 5, 4, 10], 12) → false", groupSum5(0, {2, 5, 4, 10}, 12), false );
printTest( "groupSum5(0, [3, 5, 1], 4) → false", groupSum5(0, {3, 5, 1}, 4), false );
printTest( "groupSum5(0, [3, 5, 1], 5) → true", groupSum5(0, {3, 5, 1}, 5), true );
printTest( "groupSum5(0, [1, 3, 5], 5) → true", groupSum5(0, {1, 3, 5}, 5), true );
printTest( "groupSum5(0, [3, 5, 1], 9) → false", groupSum5(0, {3, 5, 1}, 9), false );
printTest( "groupSum5(0, [2, 5, 10, 4], 7) → false", groupSum5(0, {2, 5, 10, 4}, 7), false );
printTest( "groupSum5(0, [2, 5, 10, 4], 15) → true", groupSum5(0, {2, 5, 10, 4}, 15), true );
printTest( "groupSum5(0, [2, 5, 10, 4], 11) → false", groupSum5(0, {2, 5, 10, 4}, 11), false );
printTest( "groupSum5(0, [1], 1) → true", groupSum5(0, {1}, 1), true );
printTest( "groupSum5(0, [9], 1) → false", groupSum5(0, {9}, 1), false );
printTest( "groupSum5(0, [9], 0) → true", groupSum5(0, {9}, 0), true );
printTest( "groupSum5(0, [], 0) → true", groupSum5(0, {}, 0), true );

// %% [markdown]
// # Recursion-2 > groupSumClump

// %%
/*
Given an array of ints, is it possible to choose a group of some of the ints,
such that the group sums to the given target, with this additional constraint:
if there are numbers in the array that are adjacent and the identical value,
they must either all be chosen, or none of them chosen. For example, with the
array {1, 2, 2, 2, 5, 2}, either all three 2ʼs in the middle must be chosen or
not, all as a group. (one loop can be used to find the extent of the identical
values).

groupSumClump(0, [2, 4, 8], 10) → true
groupSumClump(0, [1, 2, 4, 8, 1], 14) → true
groupSumClump(0, [2, 4, 4, 8], 14) → false
*/

bool groupSumClump(int start, vector<int> nums, int target) {
    return false;
}


// tests:
printTest( "groupSumClump(0, [2, 4, 8], 10) → true", groupSumClump(0, {2, 4, 8}, 10), true );
printTest( "groupSumClump(0, [1, 2, 4, 8, 1], 14) → true", groupSumClump(0, {1, 2, 4, 8, 1}, 14), true );
printTest( "groupSumClump(0, [2, 4, 4, 8], 14) → false", groupSumClump(0, {2, 4, 4, 8}, 14), false );
printTest( "groupSumClump(0, [8, 2, 2, 1], 9) → true", groupSumClump(0, {8, 2, 2, 1}, 9), true );
printTest( "groupSumClump(0, [8, 2, 2, 1], 11) → false", groupSumClump(0, {8, 2, 2, 1}, 11), false );
printTest( "groupSumClump(0, [1], 1) → true", groupSumClump(0, {1}, 1), true );
printTest( "groupSumClump(0, [9], 1) → false", groupSumClump(0, {9}, 1), false );

// %% [markdown]
// # Recursion-2 > splitArray

// %%
/*
Given an array of ints, is it possible to divide the ints into two groups, so
that the sums of the two groups are the same. Every int must be in one group or
the other. Write a recursive helper method that takes whatever arguments you
like, and make the initial call to your recursive helper from splitArray(). (No
loops needed.)

splitArray([2, 2]) → true
splitArray([2, 3]) → false
splitArray([5, 2, 3]) → true
*/

bool splitArray(vector<int> nums) {
    return false;
}


// tests:
printTest( "splitArray([2, 2]) → true", splitArray({2, 2}), true );
printTest( "splitArray([2, 3]) → false", splitArray({2, 3}), false );
printTest( "splitArray([5, 2, 3]) → true", splitArray({5, 2, 3}), true );
printTest( "splitArray([5, 2, 2]) → false", splitArray({5, 2, 2}), false );
printTest( "splitArray([1, 1, 1, 1, 1, 1]) → true", splitArray({1, 1, 1, 1, 1, 1}), true );
printTest( "splitArray([1, 1, 1, 1, 1]) → false", splitArray({1, 1, 1, 1, 1}), false );
printTest( "splitArray([]) → true", splitArray({}), true );
printTest( "splitArray([1]) → false", splitArray({1}), false );
printTest( "splitArray([3, 5]) → false", splitArray({3, 5}), false );
printTest( "splitArray([5, 3, 2]) → true", splitArray({5, 3, 2}), true );
printTest( "splitArray([2, 2, 10, 10, 1, 1]) → true", splitArray({2, 2, 10, 10, 1, 1}), true );
printTest( "splitArray([1, 2, 2, 10, 10, 1, 1]) → false", splitArray({1, 2, 2, 10, 10, 1, 1}), false );
printTest( "splitArray([1, 2, 3, 10, 10, 1, 1]) → true", splitArray({1, 2, 3, 10, 10, 1, 1}), true );

// %% [markdown]
// # Recursion-2 > splitOdd10

// %%
/*
Given an array of ints, is it possible to divide the ints into two groups, so
that the sum of one group is a multiple of 10, and the sum of the other group is
odd. Every int must be in one group or the other. Write a recursive helper
method that takes whatever arguments you like, and make the initial call to your
recursive helper from splitOdd10(). (No loops needed.)

splitOdd10([5, 5, 5]) → true
splitOdd10([5, 5, 6]) → false
splitOdd10([5, 5, 6, 1]) → true
*/

bool splitOdd10(vector<int> nums) {
    return false;
}


// tests:
printTest( "splitOdd10([5, 5, 5]) → true", splitOdd10({5, 5, 5}), true );
printTest( "splitOdd10([5, 5, 6]) → false", splitOdd10({5, 5, 6}), false );
printTest( "splitOdd10([5, 5, 6, 1]) → true", splitOdd10({5, 5, 6, 1}), true );
printTest( "splitOdd10([6, 5, 5, 1]) → true", splitOdd10({6, 5, 5, 1}), true );
printTest( "splitOdd10([6, 5, 5, 1, 10]) → true", splitOdd10({6, 5, 5, 1, 10}), true );
printTest( "splitOdd10([6, 5, 5, 5, 1]) → false", splitOdd10({6, 5, 5, 5, 1}), false );
printTest( "splitOdd10([1]) → true", splitOdd10({1}), true );
printTest( "splitOdd10([]) → false", splitOdd10({}), false );
printTest( "splitOdd10([10, 7, 5, 5]) → true", splitOdd10({10, 7, 5, 5}), true );
printTest( "splitOdd10([10, 0, 5, 5]) → false", splitOdd10({10, 0, 5, 5}), false );
printTest( "splitOdd10([10, 7, 5, 5, 2]) → true", splitOdd10({10, 7, 5, 5, 2}), true );
printTest( "splitOdd10([10, 7, 5, 5, 1]) → false", splitOdd10({10, 7, 5, 5, 1}), false );

// %% [markdown]
// # Recursion-2 > split53

// %%
/*
Given an array of ints, is it possible to divide the ints into two groups, so
that the sum of the two groups is the same, with these constraints: all the
values that are multiple of 5 must be in one group, and all the values that are
a multiple of 3 (and not a multiple of 5) must be in the other. (No loops
needed.)

split53([1, 1]) → true
split53([1, 1, 1]) → false
split53([2, 4, 2]) → true
*/

bool split53(vector<int> nums) {
    return false;
}


// tests:
printTest( "split53([1, 1]) → true", split53({1, 1}), true );
printTest( "split53([1, 1, 1]) → false", split53({1, 1, 1}), false );
printTest( "split53([2, 4, 2]) → true", split53({2, 4, 2}), true );
printTest( "split53([2, 2, 2, 1]) → false", split53({2, 2, 2, 1}), false );
printTest( "split53([3, 3, 5, 1]) → true", split53({3, 3, 5, 1}), true );
printTest( "split53([3, 5, 8]) → false", split53({3, 5, 8}), false );
printTest( "split53([2, 4, 6]) → true", split53({2, 4, 6}), true );
printTest( "split53([3, 5, 6, 10, 3, 3]) → true", split53({3, 5, 6, 10, 3, 3}), true );
