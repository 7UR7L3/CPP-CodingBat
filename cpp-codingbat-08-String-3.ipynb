// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
template<class A>
void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
}
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A>
void printTest( string str, vector<A> run, vector<A> expected )
{
  string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
  if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
  string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
  if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
  printTest( str, runStr, expStr );
}

// %% [markdown]
// # String-3 > countYZ

// %%
/*
Given a string, count the number of words ending in 'y' or 'z' -- so the 'y' in
"heavy" and the 'z' in "fez" count, but not the 'y' in "yellow" (not case
sensitive). We'll say that a y or z is at the end of a word if there is not an
alphabetic letter immediately following it. (Note: Character.isLetter(char)
tests if a char is an alphabetic letter.)

countYZ("fez day") → 2
countYZ("day fez") → 2
countYZ("day fyyyz") → 2
*/

int countYZ(string str) {
    return 0;
}


// tests:
printTest( "countYZ(\"fez day\") → 2", countYZ("fez day"), 2 );
printTest( "countYZ(\"day fez\") → 2", countYZ("day fez"), 2 );
printTest( "countYZ(\"day fyyyz\") → 2", countYZ("day fyyyz"), 2 );
printTest( "countYZ(\"day yak\") → 1", countYZ("day yak"), 1 );
printTest( "countYZ(\"day:yak\") → 1", countYZ("day:yak"), 1 );
printTest( "countYZ(\"!!day--yaz!!\") → 2", countYZ("!!day--yaz!!"), 2 );
printTest( "countYZ(\"yak zak\") → 0", countYZ("yak zak"), 0 );
printTest( "countYZ(\"DAY abc XYZ\") → 2", countYZ("DAY abc XYZ"), 2 );
printTest( "countYZ(\"aaz yyz my\") → 3", countYZ("aaz yyz my"), 3 );
printTest( "countYZ(\"y2bz\") → 2", countYZ("y2bz"), 2 );
printTest( "countYZ(\"zxyx\") → 0", countYZ("zxyx"), 0 );

// %% [markdown]
// # String-3 > withoutString

// %%
/*


withoutString("Hello there", "llo") → "He there"
withoutString("Hello there", "e") → "Hllo thr"
withoutString("Hello there", "x") → "Hello there"
*/

string withoutString(string base, string remove) {
    return "";
}


// tests:
printTest( "withoutString(\"Hello there\", \"llo\") → \"He there\"", withoutString("Hello there", "llo"), "He there" );
printTest( "withoutString(\"Hello there\", \"e\") → \"Hllo thr\"", withoutString("Hello there", "e"), "Hllo thr" );
printTest( "withoutString(\"Hello there\", \"x\") → \"Hello there\"", withoutString("Hello there", "x"), "Hello there" );
printTest( "withoutString(\"This is a FISH\", \"IS\") → \"Th  a FH\"", withoutString("This is a FISH", "IS"), "Th  a FH" );
printTest( "withoutString(\"THIS is a FISH\", \"is\") → \"TH  a FH\"", withoutString("THIS is a FISH", "is"), "TH  a FH" );
printTest( "withoutString(\"THIS is a FISH\", \"iS\") → \"TH  a FH\"", withoutString("THIS is a FISH", "iS"), "TH  a FH" );
printTest( "withoutString(\"abxxxxab\", \"xx\") → \"abab\"", withoutString("abxxxxab", "xx"), "abab" );
printTest( "withoutString(\"abxxxab\", \"xx\") → \"abxab\"", withoutString("abxxxab", "xx"), "abxab" );
printTest( "withoutString(\"abxxxab\", \"x\") → \"abab\"", withoutString("abxxxab", "x"), "abab" );
printTest( "withoutString(\"xxx\", \"x\") → \"\"", withoutString("xxx", "x"), "" );
printTest( "withoutString(\"xxx\", \"xx\") → \"x\"", withoutString("xxx", "xx"), "x" );
printTest( "withoutString(\"xyzzy\", \"Y\") → \"xzz\"", withoutString("xyzzy", "Y"), "xzz" );
printTest( "withoutString(\"\", \"x\") → \"\"", withoutString("", "x"), "" );
printTest( "withoutString(\"abcabc\", \"b\") → \"acac\"", withoutString("abcabc", "b"), "acac" );
printTest( "withoutString(\"AA22bb\", \"2\") → \"AAbb\"", withoutString("AA22bb", "2"), "AAbb" );
printTest( "withoutString(\"1111\", \"1\") → \"\"", withoutString("1111", "1"), "" );
printTest( "withoutString(\"1111\", \"11\") → \"\"", withoutString("1111", "11"), "" );
printTest( "withoutString(\"MkjtMkx\", \"Mk\") → \"jtx\"", withoutString("MkjtMkx", "Mk"), "jtx" );
printTest( "withoutString(\"Hi HoHo\", \"Ho\") → \"Hi \"", withoutString("Hi HoHo", "Ho"), "Hi " );

// %% [markdown]
// # String-3 > equalIsNot

// %%
/*
Given a string, return true if the number of appearances of "is" anywhere in the
string is equal to the number of appearances of "not" anywhere in the string
(case sensitive).

equalIsNot("This is not") → false
equalIsNot("This is notnot") → true
equalIsNot("noisxxnotyynotxisi") → true
*/

bool equalIsNot(string str) {
    return false;
}


// tests:
printTest( "equalIsNot(\"This is not\") → false", equalIsNot("This is not"), false );
printTest( "equalIsNot(\"This is notnot\") → true", equalIsNot("This is notnot"), true );
printTest( "equalIsNot(\"noisxxnotyynotxisi\") → true", equalIsNot("noisxxnotyynotxisi"), true );
printTest( "equalIsNot(\"noisxxnotyynotxsi\") → false", equalIsNot("noisxxnotyynotxsi"), false );
printTest( "equalIsNot(\"xxxyyyzzzintint\") → true", equalIsNot("xxxyyyzzzintint"), true );
printTest( "equalIsNot(\"\") → true", equalIsNot(""), true );
printTest( "equalIsNot(\"isisnotnot\") → true", equalIsNot("isisnotnot"), true );
printTest( "equalIsNot(\"isisnotno7Not\") → false", equalIsNot("isisnotno7Not"), false );
printTest( "equalIsNot(\"isnotis\") → false", equalIsNot("isnotis"), false );
printTest( "equalIsNot(\"mis3notpotbotis\") → false", equalIsNot("mis3notpotbotis"), false );

// %% [markdown]
// # String-3 > gHappy

// %%
/*
We'll say that a lowercase 'g' in a string is "happy" if there is another 'g'
immediately to its left or right. Return true if all the g's in the given string
are happy.

gHappy("xxggxx") → true
gHappy("xxgxx") → false
gHappy("xxggyygxx") → false
*/

bool gHappy(string str) {
    return false;
}


// tests:
printTest( "gHappy(\"xxggxx\") → true", gHappy("xxggxx"), true );
printTest( "gHappy(\"xxgxx\") → false", gHappy("xxgxx"), false );
printTest( "gHappy(\"xxggyygxx\") → false", gHappy("xxggyygxx"), false );
printTest( "gHappy(\"g\") → false", gHappy("g"), false );
printTest( "gHappy(\"gg\") → true", gHappy("gg"), true );
printTest( "gHappy(\"\") → true", gHappy(""), true );
printTest( "gHappy(\"xxgggxyz\") → true", gHappy("xxgggxyz"), true );
printTest( "gHappy(\"xxgggxyg\") → false", gHappy("xxgggxyg"), false );
printTest( "gHappy(\"xxgggxygg\") → true", gHappy("xxgggxygg"), true );
printTest( "gHappy(\"mgm\") → false", gHappy("mgm"), false );
printTest( "gHappy(\"mggm\") → true", gHappy("mggm"), true );
printTest( "gHappy(\"yyygggxyy\") → true", gHappy("yyygggxyy"), true );

// %% [markdown]
// # String-3 > countTriple

// %%
/*
We'll say that a "triple" in a string is a char appearing three times in a row.
Return the number of triples in the given string. The triples may overlap.

countTriple("abcXXXabc") → 1
countTriple("xxxabyyyycd") → 3
countTriple("a") → 0
*/

int countTriple(string str) {
    return 0;
}


// tests:
printTest( "countTriple(\"abcXXXabc\") → 1", countTriple("abcXXXabc"), 1 );
printTest( "countTriple(\"xxxabyyyycd\") → 3", countTriple("xxxabyyyycd"), 3 );
printTest( "countTriple(\"a\") → 0", countTriple("a"), 0 );
printTest( "countTriple(\"\") → 0", countTriple(""), 0 );
printTest( "countTriple(\"XXXabc\") → 1", countTriple("XXXabc"), 1 );
printTest( "countTriple(\"XXXXabc\") → 2", countTriple("XXXXabc"), 2 );
printTest( "countTriple(\"XXXXXabc\") → 3", countTriple("XXXXXabc"), 3 );
printTest( "countTriple(\"222abyyycdXXX\") → 3", countTriple("222abyyycdXXX"), 3 );
printTest( "countTriple(\"abYYYabXXXXXab\") → 4", countTriple("abYYYabXXXXXab"), 4 );
printTest( "countTriple(\"abYYXabXXYXXab\") → 0", countTriple("abYYXabXXYXXab"), 0 );
printTest( "countTriple(\"abYYXabXXYXXab\") → 0", countTriple("abYYXabXXYXXab"), 0 );
printTest( "countTriple(\"122abhhh2\") → 1", countTriple("122abhhh2"), 1 );

// %% [markdown]
// # String-3 > sumDigits

// %%
/*
Given a string, return the sum of the digits 0-9 that appear in the string,
ignoring all other characters. Return 0 if there are no digits in the string.
(Note: Character.isDigit(char) tests if a char is one of the chars '0', '1', ..
'9'. Integer.parseInt(string) converts a string to an int.)

sumDigits("aa1bc2d3") → 6
sumDigits("aa11b33") → 8
sumDigits("Chocolate") → 0
*/

int sumDigits(string str) {
    return 0;
}


// tests:
printTest( "sumDigits(\"aa1bc2d3\") → 6", sumDigits("aa1bc2d3"), 6 );
printTest( "sumDigits(\"aa11b33\") → 8", sumDigits("aa11b33"), 8 );
printTest( "sumDigits(\"Chocolate\") → 0", sumDigits("Chocolate"), 0 );
printTest( "sumDigits(\"5hoco1a1e\") → 7", sumDigits("5hoco1a1e"), 7 );
printTest( "sumDigits(\"123abc123\") → 12", sumDigits("123abc123"), 12 );
printTest( "sumDigits(\"\") → 0", sumDigits(""), 0 );
printTest( "sumDigits(\"Hello\") → 0", sumDigits("Hello"), 0 );
printTest( "sumDigits(\"X1z9b2\") → 12", sumDigits("X1z9b2"), 12 );
printTest( "sumDigits(\"5432a\") → 14", sumDigits("5432a"), 14 );

// %% [markdown]
// # String-3 > sameEnds

// %%
/*
Given a string, return the longest substring that appears at both the beginning
and end of the string without overlapping. For example, sameEnds("abXab") is
"ab".

sameEnds("abXYab") → "ab"
sameEnds("xx") → "x"
sameEnds("xxx") → "x"
*/

string sameEnds(string string) {
    return "";
}


// tests:
printTest( "sameEnds(\"abXYab\") → \"ab\"", sameEnds("abXYab"), "ab" );
printTest( "sameEnds(\"xx\") → \"x\"", sameEnds("xx"), "x" );
printTest( "sameEnds(\"xxx\") → \"x\"", sameEnds("xxx"), "x" );
printTest( "sameEnds(\"xxxx\") → \"xx\"", sameEnds("xxxx"), "xx" );
printTest( "sameEnds(\"javaXYZjava\") → \"java\"", sameEnds("javaXYZjava"), "java" );
printTest( "sameEnds(\"javajava\") → \"java\"", sameEnds("javajava"), "java" );
printTest( "sameEnds(\"xavaXYZjava\") → \"\"", sameEnds("xavaXYZjava"), "" );
printTest( "sameEnds(\"Hello! and Hello!\") → \"Hello!\"", sameEnds("Hello! and Hello!"), "Hello!" );
printTest( "sameEnds(\"x\") → \"\"", sameEnds("x"), "" );
printTest( "sameEnds(\"\") → \"\"", sameEnds(""), "" );
printTest( "sameEnds(\"abcb\") → \"\"", sameEnds("abcb"), "" );
printTest( "sameEnds(\"mymmy\") → \"my\"", sameEnds("mymmy"), "my" );

// %% [markdown]
// # String-3 > mirrorEnds

// %%
/*
Given a string, look for a mirror image (backwards) string at both the beginning
and end of the given string. In other words, zero or more characters at the very
begining of the given string, and at the very end of the string in reverse order
(possibly overlapping). For example, the string "abXYZba" has the mirror end
"ab".

mirrorEnds("abXYZba") → "ab"
mirrorEnds("abca") → "a"
mirrorEnds("aba") → "aba"
*/

string mirrorEnds(string string) {
    return "";
}


// tests:
printTest( "mirrorEnds(\"abXYZba\") → \"ab\"", mirrorEnds("abXYZba"), "ab" );
printTest( "mirrorEnds(\"abca\") → \"a\"", mirrorEnds("abca"), "a" );
printTest( "mirrorEnds(\"aba\") → \"aba\"", mirrorEnds("aba"), "aba" );
printTest( "mirrorEnds(\"abab\") → \"\"", mirrorEnds("abab"), "" );
printTest( "mirrorEnds(\"xxx\") → \"xxx\"", mirrorEnds("xxx"), "xxx" );
printTest( "mirrorEnds(\"xxYxx\") → \"xxYxx\"", mirrorEnds("xxYxx"), "xxYxx" );
printTest( "mirrorEnds(\"Hi and iH\") → \"Hi \"", mirrorEnds("Hi and iH"), "Hi " );
printTest( "mirrorEnds(\"x\") → \"x\"", mirrorEnds("x"), "x" );
printTest( "mirrorEnds(\"\") → \"\"", mirrorEnds(""), "" );
printTest( "mirrorEnds(\"123and then 321\") → \"123\"", mirrorEnds("123and then 321"), "123" );
printTest( "mirrorEnds(\"band andab\") → \"ba\"", mirrorEnds("band andab"), "ba" );

// %% [markdown]
// # String-3 > maxBlock

// %%
/*
Given a string, return the length of the largest "block" in the string. A block
is a run of adjacent chars that are the same.

maxBlock("hoopla") → 2
maxBlock("abbCCCddBBBxx") → 3
maxBlock("") → 0
*/

int maxBlock(string str) {
    return 0;
}


// tests:
printTest( "maxBlock(\"hoopla\") → 2", maxBlock("hoopla"), 2 );
printTest( "maxBlock(\"abbCCCddBBBxx\") → 3", maxBlock("abbCCCddBBBxx"), 3 );
printTest( "maxBlock(\"\") → 0", maxBlock(""), 0 );
printTest( "maxBlock(\"xyz\") → 1", maxBlock("xyz"), 1 );
printTest( "maxBlock(\"xxyz\") → 2", maxBlock("xxyz"), 2 );
printTest( "maxBlock(\"xyzz\") → 2", maxBlock("xyzz"), 2 );
printTest( "maxBlock(\"abbbcbbbxbbbx\") → 3", maxBlock("abbbcbbbxbbbx"), 3 );
printTest( "maxBlock(\"XXBBBbbxx\") → 3", maxBlock("XXBBBbbxx"), 3 );
printTest( "maxBlock(\"XXBBBBbbxx\") → 4", maxBlock("XXBBBBbbxx"), 4 );
printTest( "maxBlock(\"XXBBBbbxxXXXX\") → 4", maxBlock("XXBBBbbxxXXXX"), 4 );
printTest( "maxBlock(\"XX2222BBBbbXX2222\") → 4", maxBlock("XX2222BBBbbXX2222"), 4 );

// %% [markdown]
// # String-3 > sumNumbers

// %%
/*
Given a string, return the sum of the numbers appearing in the string, ignoring
all other characters. A number is a series of 1 or more digit chars in a row.
(Note: Character.isDigit(char) tests if a char is one of the chars '0', '1', ..
'9'. Integer.parseInt(string) converts a string to an int.)

sumNumbers("abc123xyz") → 123
sumNumbers("aa11b33") → 44
sumNumbers("7 11") → 18
*/

int sumNumbers(string str) {
    return 0;
}


// tests:
printTest( "sumNumbers(\"abc123xyz\") → 123", sumNumbers("abc123xyz"), 123 );
printTest( "sumNumbers(\"aa11b33\") → 44", sumNumbers("aa11b33"), 44 );
printTest( "sumNumbers(\"7 11\") → 18", sumNumbers("7 11"), 18 );
printTest( "sumNumbers(\"Chocolate\") → 0", sumNumbers("Chocolate"), 0 );
printTest( "sumNumbers(\"5hoco1a1e\") → 7", sumNumbers("5hoco1a1e"), 7 );
printTest( "sumNumbers(\"5$$1;;1!!\") → 7", sumNumbers("5$$1;;1!!"), 7 );
printTest( "sumNumbers(\"a1234bb11\") → 1245", sumNumbers("a1234bb11"), 1245 );
printTest( "sumNumbers(\"\") → 0", sumNumbers(""), 0 );
printTest( "sumNumbers(\"a22bbb3\") → 25", sumNumbers("a22bbb3"), 25 );

// %% [markdown]
// # String-3 > notReplace

// %%
/*
Given a string, return a string where every appearance of the lowercase word
"is" has been replaced with "is not". The word "is" should not be immediately
preceeded or followed by a letter -- so for example the "is" in "this" does not
count. (Note: Character.isLetter(char) tests if a char is a letter.)

notReplace("is test") → "is not test"
notReplace("is-is") → "is not-is not"
notReplace("This is right") → "This is not right"
*/

string notReplace(string str) {
    return "";
}


// tests:
printTest( "notReplace(\"is test\") → \"is not test\"", notReplace("is test"), "is not test" );
printTest( "notReplace(\"is-is\") → \"is not-is not\"", notReplace("is-is"), "is not-is not" );
printTest( "notReplace(\"This is right\") → \"This is not right\"", notReplace("This is right"), "This is not right" );
printTest( "notReplace(\"This is isabell\") → \"This is not isabell\"", notReplace("This is isabell"), "This is not isabell" );
printTest( "notReplace(\"\") → \"\"", notReplace(""), "" );
printTest( "notReplace(\"is\") → \"is not\"", notReplace("is"), "is not" );
printTest( "notReplace(\"isis\") → \"isis\"", notReplace("isis"), "isis" );
printTest( "notReplace(\"Dis is bliss is\") → \"Dis is not bliss is not\"", notReplace("Dis is bliss is"), "Dis is not bliss is not" );
printTest( "notReplace(\"is his\") → \"is not his\"", notReplace("is his"), "is not his" );
printTest( "notReplace(\"xis yis\") → \"xis yis\"", notReplace("xis yis"), "xis yis" );
printTest( "notReplace(\"AAAis is\") → \"AAAis is not\"", notReplace("AAAis is"), "AAAis is not" );
