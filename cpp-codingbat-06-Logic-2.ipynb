// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
}
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # Logic-2 > makeBricks

// %%
/*


makeBricks(3, 1, 8) → true
makeBricks(3, 1, 9) → false
makeBricks(3, 2, 10) → true
*/

bool makeBricks(int small, int big, int goal) {
    return false;
}


// tests:
printTest( "makeBricks(3, 1, 8) → true", makeBricks(3, 1, 8), true );
printTest( "makeBricks(3, 1, 9) → false", makeBricks(3, 1, 9), false );
printTest( "makeBricks(3, 2, 10) → true", makeBricks(3, 2, 10), true );
printTest( "makeBricks(3, 2, 8) → true", makeBricks(3, 2, 8), true );
printTest( "makeBricks(3, 2, 9) → false", makeBricks(3, 2, 9), false );
printTest( "makeBricks(6, 1, 11) → true", makeBricks(6, 1, 11), true );
printTest( "makeBricks(6, 0, 11) → false", makeBricks(6, 0, 11), false );
printTest( "makeBricks(1, 4, 11) → true", makeBricks(1, 4, 11), true );
printTest( "makeBricks(0, 3, 10) → true", makeBricks(0, 3, 10), true );
printTest( "makeBricks(1, 4, 12) → false", makeBricks(1, 4, 12), false );
printTest( "makeBricks(3, 1, 7) → true", makeBricks(3, 1, 7), true );
printTest( "makeBricks(1, 1, 7) → false", makeBricks(1, 1, 7), false );
printTest( "makeBricks(2, 1, 7) → true", makeBricks(2, 1, 7), true );
printTest( "makeBricks(7, 1, 11) → true", makeBricks(7, 1, 11), true );
printTest( "makeBricks(7, 1, 8) → true", makeBricks(7, 1, 8), true );
printTest( "makeBricks(7, 1, 13) → false", makeBricks(7, 1, 13), false );
printTest( "makeBricks(43, 1, 46) → true", makeBricks(43, 1, 46), true );
printTest( "makeBricks(40, 1, 46) → false", makeBricks(40, 1, 46), false );
printTest( "makeBricks(40, 2, 47) → true", makeBricks(40, 2, 47), true );
printTest( "makeBricks(40, 2, 50) → true", makeBricks(40, 2, 50), true );
printTest( "makeBricks(40, 2, 52) → false", makeBricks(40, 2, 52), false );
printTest( "makeBricks(22, 2, 33) → false", makeBricks(22, 2, 33), false );
printTest( "makeBricks(0, 2, 10) → true", makeBricks(0, 2, 10), true );
printTest( "makeBricks(1000000, 1000, 1000100) → true", makeBricks(1000000, 1000, 1000100), true );
printTest( "makeBricks(2, 1000000, 100003) → false", makeBricks(2, 1000000, 100003), false );
printTest( "makeBricks(20, 0, 19) → true", makeBricks(20, 0, 19), true );
printTest( "makeBricks(20, 0, 21) → false", makeBricks(20, 0, 21), false );
printTest( "makeBricks(20, 4, 51) → false", makeBricks(20, 4, 51), false );
printTest( "makeBricks(20, 4, 39) → true", makeBricks(20, 4, 39), true );

// %% [markdown]
// # Logic-2 > loneSum

// %%
/*
Given 3 int values, a b c, return their sum. However, if one of the values is
the same as another of the values, it does not count towards the sum.

loneSum(1, 2, 3) → 6
loneSum(3, 2, 3) → 2
loneSum(3, 3, 3) → 0
*/

int loneSum(int a, int b, int c) {
    return 0;
}


// tests:
printTest( "loneSum(1, 2, 3) → 6", loneSum(1, 2, 3), 6 );
printTest( "loneSum(3, 2, 3) → 2", loneSum(3, 2, 3), 2 );
printTest( "loneSum(3, 3, 3) → 0", loneSum(3, 3, 3), 0 );
printTest( "loneSum(9, 2, 2) → 9", loneSum(9, 2, 2), 9 );
printTest( "loneSum(2, 2, 9) → 9", loneSum(2, 2, 9), 9 );
printTest( "loneSum(2, 9, 2) → 9", loneSum(2, 9, 2), 9 );
printTest( "loneSum(2, 9, 3) → 14", loneSum(2, 9, 3), 14 );
printTest( "loneSum(4, 2, 3) → 9", loneSum(4, 2, 3), 9 );
printTest( "loneSum(1, 3, 1) → 3", loneSum(1, 3, 1), 3 );

// %% [markdown]
// # Logic-2 > luckySum

// %%
/*
Given 3 int values, a b c, return their sum. However, if one of the values is 13
then it does not count towards the sum and values to its right do not count. So
for example, if b is 13, then both b and c do not count.

luckySum(1, 2, 3) → 6
luckySum(1, 2, 13) → 3
luckySum(1, 13, 3) → 1
*/

int luckySum(int a, int b, int c) {
    return 0;
}


// tests:
printTest( "luckySum(1, 2, 3) → 6", luckySum(1, 2, 3), 6 );
printTest( "luckySum(1, 2, 13) → 3", luckySum(1, 2, 13), 3 );
printTest( "luckySum(1, 13, 3) → 1", luckySum(1, 13, 3), 1 );
printTest( "luckySum(1, 13, 13) → 1", luckySum(1, 13, 13), 1 );
printTest( "luckySum(6, 5, 2) → 13", luckySum(6, 5, 2), 13 );
printTest( "luckySum(13, 2, 3) → 0", luckySum(13, 2, 3), 0 );
printTest( "luckySum(13, 2, 13) → 0", luckySum(13, 2, 13), 0 );
printTest( "luckySum(13, 13, 2) → 0", luckySum(13, 13, 2), 0 );
printTest( "luckySum(9, 4, 13) → 13", luckySum(9, 4, 13), 13 );
printTest( "luckySum(8, 13, 2) → 8", luckySum(8, 13, 2), 8 );
printTest( "luckySum(7, 2, 1) → 10", luckySum(7, 2, 1), 10 );
printTest( "luckySum(3, 3, 13) → 6", luckySum(3, 3, 13), 6 );

// %% [markdown]
// # Logic-2 > noTeenSum

// %%
/*
Given 3 int values, a b c, return their sum. However, if any of the values is a
teen -- in the range 13..19 inclusive -- then that value counts as 0, except 15
and 16 do not count as a teens. Write a separate helper "public int fixTeen(int
n) {"that takes in an int value and returns that value fixed for the teen rule.
In this way, you avoid repeating the teen code 3 times (i.e. "decomposition").
Define the helper below and at the same indent level as the main noTeenSum().

noTeenSum(1, 2, 3) → 6
noTeenSum(2, 13, 1) → 3
noTeenSum(2, 1, 14) → 3
*/

int noTeenSum(int a, int b, int c) {
    return 0;
}


// tests:
printTest( "noTeenSum(1, 2, 3) → 6", noTeenSum(1, 2, 3), 6 );
printTest( "noTeenSum(2, 13, 1) → 3", noTeenSum(2, 13, 1), 3 );
printTest( "noTeenSum(2, 1, 14) → 3", noTeenSum(2, 1, 14), 3 );
printTest( "noTeenSum(2, 1, 15) → 18", noTeenSum(2, 1, 15), 18 );
printTest( "noTeenSum(2, 1, 16) → 19", noTeenSum(2, 1, 16), 19 );
printTest( "noTeenSum(2, 1, 17) → 3", noTeenSum(2, 1, 17), 3 );
printTest( "noTeenSum(17, 1, 2) → 3", noTeenSum(17, 1, 2), 3 );
printTest( "noTeenSum(2, 15, 2) → 19", noTeenSum(2, 15, 2), 19 );
printTest( "noTeenSum(16, 17, 18) → 16", noTeenSum(16, 17, 18), 16 );
printTest( "noTeenSum(17, 18, 19) → 0", noTeenSum(17, 18, 19), 0 );
printTest( "noTeenSum(15, 16, 1) → 32", noTeenSum(15, 16, 1), 32 );
printTest( "noTeenSum(15, 15, 19) → 30", noTeenSum(15, 15, 19), 30 );
printTest( "noTeenSum(15, 19, 16) → 31", noTeenSum(15, 19, 16), 31 );
printTest( "noTeenSum(5, 17, 18) → 5", noTeenSum(5, 17, 18), 5 );
printTest( "noTeenSum(17, 18, 16) → 16", noTeenSum(17, 18, 16), 16 );
printTest( "noTeenSum(17, 19, 18) → 0", noTeenSum(17, 19, 18), 0 );

// %% [markdown]
// # Logic-2 > roundSum

// %%
/*
For this problem, we'll round an int value up to the next multiple of 10 if its
rightmost digit is 5 or more, so 15 rounds up to 20. Alternately, round down to
the previous multiple of 10 if its rightmost digit is less than 5, so 12 rounds
down to 10. Given 3 ints, a b c, return the sum of their rounded values. To
avoid code repetition, write a separate helper "public int round10(int num) {"
and call it 3 times. Write the helper entirely below and at the same indent
level as roundSum().

roundSum(16, 17, 18) → 60
roundSum(12, 13, 14) → 30
roundSum(6, 4, 4) → 10
*/

int roundSum(int a, int b, int c) {
    return 0;
}


// tests:
printTest( "roundSum(16, 17, 18) → 60", roundSum(16, 17, 18), 60 );
printTest( "roundSum(12, 13, 14) → 30", roundSum(12, 13, 14), 30 );
printTest( "roundSum(6, 4, 4) → 10", roundSum(6, 4, 4), 10 );
printTest( "roundSum(4, 6, 5) → 20", roundSum(4, 6, 5), 20 );
printTest( "roundSum(4, 4, 6) → 10", roundSum(4, 4, 6), 10 );
printTest( "roundSum(9, 4, 4) → 10", roundSum(9, 4, 4), 10 );
printTest( "roundSum(0, 0, 1) → 0", roundSum(0, 0, 1), 0 );
printTest( "roundSum(0, 9, 0) → 10", roundSum(0, 9, 0), 10 );
printTest( "roundSum(10, 10, 19) → 40", roundSum(10, 10, 19), 40 );
printTest( "roundSum(20, 30, 40) → 90", roundSum(20, 30, 40), 90 );
printTest( "roundSum(45, 21, 30) → 100", roundSum(45, 21, 30), 100 );
printTest( "roundSum(23, 11, 26) → 60", roundSum(23, 11, 26), 60 );
printTest( "roundSum(23, 24, 25) → 70", roundSum(23, 24, 25), 70 );
printTest( "roundSum(25, 24, 25) → 80", roundSum(25, 24, 25), 80 );
printTest( "roundSum(23, 24, 29) → 70", roundSum(23, 24, 29), 70 );
printTest( "roundSum(11, 24, 36) → 70", roundSum(11, 24, 36), 70 );
printTest( "roundSum(24, 36, 32) → 90", roundSum(24, 36, 32), 90 );
printTest( "roundSum(14, 12, 26) → 50", roundSum(14, 12, 26), 50 );
printTest( "roundSum(12, 10, 24) → 40", roundSum(12, 10, 24), 40 );

// %% [markdown]
// # Logic-2 > closeFar

// %%
/*
Given three ints, a b c, return true if one of b or c is "close" (differing from
a by at most 1), while the other is "far", differing from both other values by 2
or more. Note: Math.abs(num) computes the absolute value of a number.

closeFar(1, 2, 10) → true
closeFar(1, 2, 3) → false
closeFar(4, 1, 3) → true
*/

bool closeFar(int a, int b, int c) {
    return false;
}


// tests:
printTest( "closeFar(1, 2, 10) → true", closeFar(1, 2, 10), true );
printTest( "closeFar(1, 2, 3) → false", closeFar(1, 2, 3), false );
printTest( "closeFar(4, 1, 3) → true", closeFar(4, 1, 3), true );
printTest( "closeFar(4, 5, 3) → false", closeFar(4, 5, 3), false );
printTest( "closeFar(4, 3, 5) → false", closeFar(4, 3, 5), false );
printTest( "closeFar(-1, 10, 0) → true", closeFar(-1, 10, 0), true );
printTest( "closeFar(0, -1, 10) → true", closeFar(0, -1, 10), true );
printTest( "closeFar(10, 10, 8) → true", closeFar(10, 10, 8), true );
printTest( "closeFar(10, 8, 9) → false", closeFar(10, 8, 9), false );
printTest( "closeFar(8, 9, 10) → false", closeFar(8, 9, 10), false );
printTest( "closeFar(8, 9, 7) → false", closeFar(8, 9, 7), false );
printTest( "closeFar(8, 6, 9) → true", closeFar(8, 6, 9), true );

// %% [markdown]
// # Logic-2 > blackjack

// %%
/*
Given 2 int values greater than 0, return whichever value is nearest to 21
without going over. Return 0 if they both go over.

blackjack(19, 21) → 21
blackjack(21, 19) → 21
blackjack(19, 22) → 19
*/

int blackjack(int a, int b) {
    return 0;
}


// tests:
printTest( "blackjack(19, 21) → 21", blackjack(19, 21), 21 );
printTest( "blackjack(21, 19) → 21", blackjack(21, 19), 21 );
printTest( "blackjack(19, 22) → 19", blackjack(19, 22), 19 );
printTest( "blackjack(22, 19) → 19", blackjack(22, 19), 19 );
printTest( "blackjack(22, 50) → 0", blackjack(22, 50), 0 );
printTest( "blackjack(22, 22) → 0", blackjack(22, 22), 0 );
printTest( "blackjack(33, 1) → 1", blackjack(33, 1), 1 );
printTest( "blackjack(1, 2) → 2", blackjack(1, 2), 2 );
printTest( "blackjack(34, 33) → 0", blackjack(34, 33), 0 );
printTest( "blackjack(17, 19) → 19", blackjack(17, 19), 19 );
printTest( "blackjack(18, 17) → 18", blackjack(18, 17), 18 );
printTest( "blackjack(16, 23) → 16", blackjack(16, 23), 16 );
printTest( "blackjack(3, 4) → 4", blackjack(3, 4), 4 );
printTest( "blackjack(3, 2) → 3", blackjack(3, 2), 3 );
printTest( "blackjack(21, 20) → 21", blackjack(21, 20), 21 );

// %% [markdown]
// # Logic-2 > evenlySpaced

// %%
/*
Given three ints, a b c, one of them is small, one is medium and one is large.
Return true if the three values are evenly spaced, so the difference between
small and medium is the same as the difference between medium and large.

evenlySpaced(2, 4, 6) → true
evenlySpaced(4, 6, 2) → true
evenlySpaced(4, 6, 3) → false
*/

bool evenlySpaced(int a, int b, int c) {
    return false;
}


// tests:
printTest( "evenlySpaced(2, 4, 6) → true", evenlySpaced(2, 4, 6), true );
printTest( "evenlySpaced(4, 6, 2) → true", evenlySpaced(4, 6, 2), true );
printTest( "evenlySpaced(4, 6, 3) → false", evenlySpaced(4, 6, 3), false );
printTest( "evenlySpaced(6, 2, 4) → true", evenlySpaced(6, 2, 4), true );
printTest( "evenlySpaced(6, 2, 8) → false", evenlySpaced(6, 2, 8), false );
printTest( "evenlySpaced(2, 2, 2) → true", evenlySpaced(2, 2, 2), true );
printTest( "evenlySpaced(2, 2, 3) → false", evenlySpaced(2, 2, 3), false );
printTest( "evenlySpaced(9, 10, 11) → true", evenlySpaced(9, 10, 11), true );
printTest( "evenlySpaced(10, 9, 11) → true", evenlySpaced(10, 9, 11), true );
printTest( "evenlySpaced(10, 9, 9) → false", evenlySpaced(10, 9, 9), false );
printTest( "evenlySpaced(2, 4, 4) → false", evenlySpaced(2, 4, 4), false );
printTest( "evenlySpaced(2, 2, 4) → false", evenlySpaced(2, 2, 4), false );
printTest( "evenlySpaced(3, 6, 12) → false", evenlySpaced(3, 6, 12), false );
printTest( "evenlySpaced(12, 3, 6) → false", evenlySpaced(12, 3, 6), false );

// %% [markdown]
// # Logic-2 > makeChocolate

// %%
/*


makeChocolate(4, 1, 9) → 4
makeChocolate(4, 1, 10) → -1
makeChocolate(4, 1, 7) → 2
*/

int makeChocolate(int small, int big, int goal) {
    return 0;
}


// tests:
printTest( "makeChocolate(4, 1, 9) → 4", makeChocolate(4, 1, 9), 4 );
printTest( "makeChocolate(4, 1, 10) → -1", makeChocolate(4, 1, 10), -1 );
printTest( "makeChocolate(4, 1, 7) → 2", makeChocolate(4, 1, 7), 2 );
printTest( "makeChocolate(6, 2, 7) → 2", makeChocolate(6, 2, 7), 2 );
printTest( "makeChocolate(4, 1, 5) → 0", makeChocolate(4, 1, 5), 0 );
printTest( "makeChocolate(4, 1, 4) → 4", makeChocolate(4, 1, 4), 4 );
printTest( "makeChocolate(5, 4, 9) → 4", makeChocolate(5, 4, 9), 4 );
printTest( "makeChocolate(9, 3, 18) → 3", makeChocolate(9, 3, 18), 3 );
printTest( "makeChocolate(3, 1, 9) → -1", makeChocolate(3, 1, 9), -1 );
printTest( "makeChocolate(1, 2, 7) → -1", makeChocolate(1, 2, 7), -1 );
printTest( "makeChocolate(1, 2, 6) → 1", makeChocolate(1, 2, 6), 1 );
printTest( "makeChocolate(1, 2, 5) → 0", makeChocolate(1, 2, 5), 0 );
printTest( "makeChocolate(6, 1, 10) → 5", makeChocolate(6, 1, 10), 5 );
printTest( "makeChocolate(6, 1, 11) → 6", makeChocolate(6, 1, 11), 6 );
printTest( "makeChocolate(6, 1, 12) → -1", makeChocolate(6, 1, 12), -1 );
printTest( "makeChocolate(6, 1, 13) → -1", makeChocolate(6, 1, 13), -1 );
printTest( "makeChocolate(6, 2, 10) → 0", makeChocolate(6, 2, 10), 0 );
printTest( "makeChocolate(6, 2, 11) → 1", makeChocolate(6, 2, 11), 1 );
printTest( "makeChocolate(6, 2, 12) → 2", makeChocolate(6, 2, 12), 2 );
printTest( "makeChocolate(60, 100, 550) → 50", makeChocolate(60, 100, 550), 50 );
printTest( "makeChocolate(1000, 1000000, 5000006) → 6", makeChocolate(1000, 1000000, 5000006), 6 );
printTest( "makeChocolate(7, 1, 12) → 7", makeChocolate(7, 1, 12), 7 );
printTest( "makeChocolate(7, 1, 13) → -1", makeChocolate(7, 1, 13), -1 );
printTest( "makeChocolate(7, 2, 13) → 3", makeChocolate(7, 2, 13), 3 );
