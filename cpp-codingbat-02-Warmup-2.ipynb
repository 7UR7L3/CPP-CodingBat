// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
template<class A>
void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
}
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A>
void printTest( string str, vector<A> run, vector<A> expected )
{
  string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
  if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
  string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
  if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
  printTest( str, runStr, expStr );
}

// %% [markdown]
// # Warmup-2 > stringTimes

// %%
/*
Given a string and a non-negative int n, return a larger string that is n copies
of the original string.

stringTimes("Hi", 2) → "HiHi"
stringTimes("Hi", 3) → "HiHiHi"
stringTimes("Hi", 1) → "Hi"
*/

string stringTimes(string str, int n) {
    return "";
}


// tests:
printTest( "stringTimes(\"Hi\", 2) → \"HiHi\"", stringTimes("Hi", 2), "HiHi" );
printTest( "stringTimes(\"Hi\", 3) → \"HiHiHi\"", stringTimes("Hi", 3), "HiHiHi" );
printTest( "stringTimes(\"Hi\", 1) → \"Hi\"", stringTimes("Hi", 1), "Hi" );
printTest( "stringTimes(\"Hi\", 0) → \"\"", stringTimes("Hi", 0), "" );
printTest( "stringTimes(\"Hi\", 5) → \"HiHiHiHiHi\"", stringTimes("Hi", 5), "HiHiHiHiHi" );
printTest( "stringTimes(\"Oh Boy!\", 2) → \"Oh Boy!Oh Boy!\"", stringTimes("Oh Boy!", 2), "Oh Boy!Oh Boy!" );
printTest( "stringTimes(\"x\", 4) → \"xxxx\"", stringTimes("x", 4), "xxxx" );
printTest( "stringTimes(\"\", 4) → \"\"", stringTimes("", 4), "" );
printTest( "stringTimes(\"code\", 2) → \"codecode\"", stringTimes("code", 2), "codecode" );
printTest( "stringTimes(\"code\", 3) → \"codecodecode\"", stringTimes("code", 3), "codecodecode" );

// %% [markdown]
// # Warmup-2 > frontTimes

// %%
/*
Given a string and a non-negative int n, we'll say that the front of the string
is the first 3 chars, or whatever is there if the string is less than length 3.
Return n copies of the front;

frontTimes("Chocolate", 2) → "ChoCho"
frontTimes("Chocolate", 3) → "ChoChoCho"
frontTimes("Abc", 3) → "AbcAbcAbc"
*/

string frontTimes(string str, int n) {
    return "";
}


// tests:
printTest( "frontTimes(\"Chocolate\", 2) → \"ChoCho\"", frontTimes("Chocolate", 2), "ChoCho" );
printTest( "frontTimes(\"Chocolate\", 3) → \"ChoChoCho\"", frontTimes("Chocolate", 3), "ChoChoCho" );
printTest( "frontTimes(\"Abc\", 3) → \"AbcAbcAbc\"", frontTimes("Abc", 3), "AbcAbcAbc" );
printTest( "frontTimes(\"Ab\", 4) → \"AbAbAbAb\"", frontTimes("Ab", 4), "AbAbAbAb" );
printTest( "frontTimes(\"A\", 4) → \"AAAA\"", frontTimes("A", 4), "AAAA" );
printTest( "frontTimes(\"\", 4) → \"\"", frontTimes("", 4), "" );
printTest( "frontTimes(\"Abc\", 0) → \"\"", frontTimes("Abc", 0), "" );

// %% [markdown]
// # Warmup-2 > countXX

// %%
/*
Count the number of "xx" in the given string. We'll say that overlapping is
allowed, so "xxx" contains 2 "xx".

countXX("abcxx") → 1
countXX("xxx") → 2
countXX("xxxx") → 3
*/

int countXX(string str) {
    return 0;
}


// tests:
printTest( "countXX(\"abcxx\") → 1", countXX("abcxx"), 1 );
printTest( "countXX(\"xxx\") → 2", countXX("xxx"), 2 );
printTest( "countXX(\"xxxx\") → 3", countXX("xxxx"), 3 );
printTest( "countXX(\"abc\") → 0", countXX("abc"), 0 );
printTest( "countXX(\"Hello there\") → 0", countXX("Hello there"), 0 );
printTest( "countXX(\"Hexxo thxxe\") → 2", countXX("Hexxo thxxe"), 2 );
printTest( "countXX(\"\") → 0", countXX(""), 0 );
printTest( "countXX(\"Kittens\") → 0", countXX("Kittens"), 0 );
printTest( "countXX(\"Kittensxxx\") → 2", countXX("Kittensxxx"), 2 );

// %% [markdown]
// # Warmup-2 > doubleX

// %%
/*
Given a string, return true if the first instance of "x" in the string is
immediately followed by another "x".

doubleX("axxbb") → true
doubleX("axaxax") → false
doubleX("xxxxx") → true
*/

bool doubleX(string str) {
    return false;
}


// tests:
printTest( "doubleX(\"axxbb\") → true", doubleX("axxbb"), true );
printTest( "doubleX(\"axaxax\") → false", doubleX("axaxax"), false );
printTest( "doubleX(\"xxxxx\") → true", doubleX("xxxxx"), true );
printTest( "doubleX(\"xaxxx\") → false", doubleX("xaxxx"), false );
printTest( "doubleX(\"aaaax\") → false", doubleX("aaaax"), false );
printTest( "doubleX(\"\") → false", doubleX(""), false );
printTest( "doubleX(\"abc\") → false", doubleX("abc"), false );
printTest( "doubleX(\"x\") → false", doubleX("x"), false );
printTest( "doubleX(\"xx\") → true", doubleX("xx"), true );
printTest( "doubleX(\"xax\") → false", doubleX("xax"), false );
printTest( "doubleX(\"xaxx\") → false", doubleX("xaxx"), false );

// %% [markdown]
// # Warmup-2 > stringBits

// %%
/*
Given a string, return a new string made of every other char starting with the
first, so "Hello" yields "Hlo".

stringBits("Hello") → "Hlo"
stringBits("Hi") → "H"
stringBits("Heeololeo") → "Hello"
*/

string stringBits(string str) {
    return "";
}


// tests:
printTest( "stringBits(\"Hello\") → \"Hlo\"", stringBits("Hello"), "Hlo" );
printTest( "stringBits(\"Hi\") → \"H\"", stringBits("Hi"), "H" );
printTest( "stringBits(\"Heeololeo\") → \"Hello\"", stringBits("Heeololeo"), "Hello" );
printTest( "stringBits(\"HiHiHi\") → \"HHH\"", stringBits("HiHiHi"), "HHH" );
printTest( "stringBits(\"\") → \"\"", stringBits(""), "" );
printTest( "stringBits(\"Greetings\") → \"Getns\"", stringBits("Greetings"), "Getns" );
printTest( "stringBits(\"Chocoate\") → \"Coot\"", stringBits("Chocoate"), "Coot" );
printTest( "stringBits(\"pi\") → \"p\"", stringBits("pi"), "p" );
printTest( "stringBits(\"Hello Kitten\") → \"HloKte\"", stringBits("Hello Kitten"), "HloKte" );
printTest( "stringBits(\"hxaxpxpxy\") → \"happy\"", stringBits("hxaxpxpxy"), "happy" );

// %% [markdown]
// # Warmup-2 > stringSplosion

// %%
/*
Given a non-empty string like "Code" return a string like "CCoCodCode".

stringSplosion("Code") → "CCoCodCode"
stringSplosion("abc") → "aababc"
stringSplosion("ab") → "aab"
*/

string stringSplosion(string str) {
    return "";
}


// tests:
printTest( "stringSplosion(\"Code\") → \"CCoCodCode\"", stringSplosion("Code"), "CCoCodCode" );
printTest( "stringSplosion(\"abc\") → \"aababc\"", stringSplosion("abc"), "aababc" );
printTest( "stringSplosion(\"ab\") → \"aab\"", stringSplosion("ab"), "aab" );
printTest( "stringSplosion(\"x\") → \"x\"", stringSplosion("x"), "x" );
printTest( "stringSplosion(\"fade\") → \"ffafadfade\"", stringSplosion("fade"), "ffafadfade" );
printTest( "stringSplosion(\"There\") → \"TThTheTherThere\"", stringSplosion("There"), "TThTheTherThere" );
printTest( "stringSplosion(\"Kitten\") → \"KKiKitKittKitteKitten\"", stringSplosion("Kitten"), "KKiKitKittKitteKitten" );
printTest( "stringSplosion(\"Bye\") → \"BByBye\"", stringSplosion("Bye"), "BByBye" );
printTest( "stringSplosion(\"Good\") → \"GGoGooGood\"", stringSplosion("Good"), "GGoGooGood" );
printTest( "stringSplosion(\"Bad\") → \"BBaBad\"", stringSplosion("Bad"), "BBaBad" );

// %% [markdown]
// # Warmup-2 > last2

// %%
/*
Given a string, return the count of the number of times that a substring length
2 appears in the string and also as the last 2 chars of the string, so "hixxxhi"
yields 1 (we won't count the end substring).

last2("hixxhi") → 1
last2("xaxxaxaxx") → 1
last2("axxxaaxx") → 2
*/

int last2(string str) {
    return 0;
}


// tests:
printTest( "last2(\"hixxhi\") → 1", last2("hixxhi"), 1 );
printTest( "last2(\"xaxxaxaxx\") → 1", last2("xaxxaxaxx"), 1 );
printTest( "last2(\"axxxaaxx\") → 2", last2("axxxaaxx"), 2 );
printTest( "last2(\"xxaxxaxxaxx\") → 3", last2("xxaxxaxxaxx"), 3 );
printTest( "last2(\"xaxaxaxx\") → 0", last2("xaxaxaxx"), 0 );
printTest( "last2(\"xxxx\") → 2", last2("xxxx"), 2 );
printTest( "last2(\"13121312\") → 1", last2("13121312"), 1 );
printTest( "last2(\"11212\") → 1", last2("11212"), 1 );
printTest( "last2(\"13121311\") → 0", last2("13121311"), 0 );
printTest( "last2(\"1717171\") → 2", last2("1717171"), 2 );
printTest( "last2(\"hi\") → 0", last2("hi"), 0 );
printTest( "last2(\"h\") → 0", last2("h"), 0 );
printTest( "last2(\"\") → 0", last2(""), 0 );

// %% [markdown]
// # Warmup-2 > arrayCount9

// %%
/*
Given an array of ints, return the number of 9's in the array.

arrayCount9([1, 2, 9]) → 1
arrayCount9([1, 9, 9]) → 2
arrayCount9([1, 9, 9, 3, 9]) → 3
*/

int arrayCount9(vector<int> nums) {
    return 0;
}


// tests:
printTest( "arrayCount9([1, 2, 9]) → 1", arrayCount9({1, 2, 9}), 1 );
printTest( "arrayCount9([1, 9, 9]) → 2", arrayCount9({1, 9, 9}), 2 );
printTest( "arrayCount9([1, 9, 9, 3, 9]) → 3", arrayCount9({1, 9, 9, 3, 9}), 3 );
printTest( "arrayCount9([1, 2, 3]) → 0", arrayCount9({1, 2, 3}), 0 );
printTest( "arrayCount9([]) → 0", arrayCount9({}), 0 );
printTest( "arrayCount9([4, 2, 4, 3, 1]) → 0", arrayCount9({4, 2, 4, 3, 1}), 0 );
printTest( "arrayCount9([9, 2, 4, 3, 1]) → 1", arrayCount9({9, 2, 4, 3, 1}), 1 );

// %% [markdown]
// # Warmup-2 > arrayFront9

// %%
/*
Given an array of ints, return true if one of the first 4 elements in the array
is a 9. The array length may be less than 4.

arrayFront9([1, 2, 9, 3, 4]) → true
arrayFront9([1, 2, 3, 4, 9]) → false
arrayFront9([1, 2, 3, 4, 5]) → false
*/

bool arrayFront9(vector<int> nums) {
    return false;
}


// tests:
printTest( "arrayFront9([1, 2, 9, 3, 4]) → true", arrayFront9({1, 2, 9, 3, 4}), true );
printTest( "arrayFront9([1, 2, 3, 4, 9]) → false", arrayFront9({1, 2, 3, 4, 9}), false );
printTest( "arrayFront9([1, 2, 3, 4, 5]) → false", arrayFront9({1, 2, 3, 4, 5}), false );
printTest( "arrayFront9([9, 2, 3]) → true", arrayFront9({9, 2, 3}), true );
printTest( "arrayFront9([1, 9, 9]) → true", arrayFront9({1, 9, 9}), true );
printTest( "arrayFront9([1, 2, 3]) → false", arrayFront9({1, 2, 3}), false );
printTest( "arrayFront9([1, 9]) → true", arrayFront9({1, 9}), true );
printTest( "arrayFront9([5, 5]) → false", arrayFront9({5, 5}), false );
printTest( "arrayFront9([2]) → false", arrayFront9({2}), false );
printTest( "arrayFront9([9]) → true", arrayFront9({9}), true );
printTest( "arrayFront9([]) → false", arrayFront9({}), false );
printTest( "arrayFront9([3, 9, 2, 3, 3]) → true", arrayFront9({3, 9, 2, 3, 3}), true );

// %% [markdown]
// # Warmup-2 > array123

// %%
/*
Given an array of ints, return true if the sequence of numbers 1, 2, 3 appears
in the array somewhere.

array123([1, 1, 2, 3, 1]) → true
array123([1, 1, 2, 4, 1]) → false
array123([1, 1, 2, 1, 2, 3]) → true
*/

bool array123(vector<int> nums) {
    return false;
}


// tests:
printTest( "array123([1, 1, 2, 3, 1]) → true", array123({1, 1, 2, 3, 1}), true );
printTest( "array123([1, 1, 2, 4, 1]) → false", array123({1, 1, 2, 4, 1}), false );
printTest( "array123([1, 1, 2, 1, 2, 3]) → true", array123({1, 1, 2, 1, 2, 3}), true );
printTest( "array123([1, 1, 2, 1, 2, 1]) → false", array123({1, 1, 2, 1, 2, 1}), false );
printTest( "array123([1, 2, 3, 1, 2, 3]) → true", array123({1, 2, 3, 1, 2, 3}), true );
printTest( "array123([1, 2, 3]) → true", array123({1, 2, 3}), true );
printTest( "array123([1, 1, 1]) → false", array123({1, 1, 1}), false );
printTest( "array123([1, 2]) → false", array123({1, 2}), false );
printTest( "array123([1]) → false", array123({1}), false );
printTest( "array123([]) → false", array123({}), false );

// %% [markdown]
// # Warmup-2 > stringMatch

// %%
/*
Given 2 strings, a and b, return the number of the positions where they contain
the same length 2 substring. So "xxcaazz" and "xxbaaz" yields 3, since the "xx",
"aa", and "az" substrings appear in the same place in both strings.

stringMatch("xxcaazz", "xxbaaz") → 3
stringMatch("abc", "abc") → 2
stringMatch("abc", "axc") → 0
*/

int stringMatch(string a, string b) {
    return 0;
}


// tests:
printTest( "stringMatch(\"xxcaazz\", \"xxbaaz\") → 3", stringMatch("xxcaazz", "xxbaaz"), 3 );
printTest( "stringMatch(\"abc\", \"abc\") → 2", stringMatch("abc", "abc"), 2 );
printTest( "stringMatch(\"abc\", \"axc\") → 0", stringMatch("abc", "axc"), 0 );
printTest( "stringMatch(\"hello\", \"he\") → 1", stringMatch("hello", "he"), 1 );
printTest( "stringMatch(\"he\", \"hello\") → 1", stringMatch("he", "hello"), 1 );
printTest( "stringMatch(\"h\", \"hello\") → 0", stringMatch("h", "hello"), 0 );
printTest( "stringMatch(\"\", \"hello\") → 0", stringMatch("", "hello"), 0 );
printTest( "stringMatch(\"aabbccdd\", \"abbbxxd\") → 1", stringMatch("aabbccdd", "abbbxxd"), 1 );
printTest( "stringMatch(\"aaxxaaxx\", \"iaxxai\") → 3", stringMatch("aaxxaaxx", "iaxxai"), 3 );
printTest( "stringMatch(\"iaxxai\", \"aaxxaaxx\") → 3", stringMatch("iaxxai", "aaxxaaxx"), 3 );

// %% [markdown]
// # Warmup-2 > stringX

// %%
/*
Given a string, return a version where all the "x" have been removed. Except an
"x" at the very start or end should not be removed.

stringX("xxHxix") → "xHix"
stringX("abxxxcd") → "abcd"
stringX("xabxxxcdx") → "xabcdx"
*/

string stringX(string str) {
    return "";
}


// tests:
printTest( "stringX(\"xxHxix\") → \"xHix\"", stringX("xxHxix"), "xHix" );
printTest( "stringX(\"abxxxcd\") → \"abcd\"", stringX("abxxxcd"), "abcd" );
printTest( "stringX(\"xabxxxcdx\") → \"xabcdx\"", stringX("xabxxxcdx"), "xabcdx" );
printTest( "stringX(\"xKittenx\") → \"xKittenx\"", stringX("xKittenx"), "xKittenx" );
printTest( "stringX(\"Hello\") → \"Hello\"", stringX("Hello"), "Hello" );
printTest( "stringX(\"xx\") → \"xx\"", stringX("xx"), "xx" );
printTest( "stringX(\"x\") → \"x\"", stringX("x"), "x" );
printTest( "stringX(\"\") → \"\"", stringX(""), "" );

// %% [markdown]
// # Warmup-2 > altPairs

// %%
/*
Given a string, return a string made of the chars at indexes 0,1, 4,5, 8,9 ...
so "kittens" yields "kien".

altPairs("kitten") → "kien"
altPairs("Chocolate") → "Chole"
altPairs("CodingHorror") → "Congrr"
*/

string altPairs(string str) {
    return "";
}


// tests:
printTest( "altPairs(\"kitten\") → \"kien\"", altPairs("kitten"), "kien" );
printTest( "altPairs(\"Chocolate\") → \"Chole\"", altPairs("Chocolate"), "Chole" );
printTest( "altPairs(\"CodingHorror\") → \"Congrr\"", altPairs("CodingHorror"), "Congrr" );
printTest( "altPairs(\"yak\") → \"ya\"", altPairs("yak"), "ya" );
printTest( "altPairs(\"ya\") → \"ya\"", altPairs("ya"), "ya" );
printTest( "altPairs(\"y\") → \"y\"", altPairs("y"), "y" );
printTest( "altPairs(\"\") → \"\"", altPairs(""), "" );
printTest( "altPairs(\"ThisThatTheOther\") → \"ThThThth\"", altPairs("ThisThatTheOther"), "ThThThth" );

// %% [markdown]
// # Warmup-2 > stringYak

// %%
/*
Suppose the string "yak" is unlucky. Given a string, return a version where all
the "yak" are removed, but the "a" can be any char. The "yak" strings will not
overlap.

stringYak("yakpak") → "pak"
stringYak("pakyak") → "pak"
stringYak("yak123ya") → "123ya"
*/

string stringYak(string str) {
    return "";
}


// tests:
printTest( "stringYak(\"yakpak\") → \"pak\"", stringYak("yakpak"), "pak" );
printTest( "stringYak(\"pakyak\") → \"pak\"", stringYak("pakyak"), "pak" );
printTest( "stringYak(\"yak123ya\") → \"123ya\"", stringYak("yak123ya"), "123ya" );
printTest( "stringYak(\"yak\") → \"\"", stringYak("yak"), "" );
printTest( "stringYak(\"yakxxxyak\") → \"xxx\"", stringYak("yakxxxyak"), "xxx" );
printTest( "stringYak(\"HiyakHi\") → \"HiHi\"", stringYak("HiyakHi"), "HiHi" );
printTest( "stringYak(\"xxxyakyyyakzzz\") → \"xxxyyzzz\"", stringYak("xxxyakyyyakzzz"), "xxxyyzzz" );

// %% [markdown]
// # Warmup-2 > array667

// %%
/*
Given an array of ints, return the number of times that two 6's are next to each
other in the array. Also count instances where the second "6" is actually a 7.

array667([6, 6, 2]) → 1
array667([6, 6, 2, 6]) → 1
array667([6, 7, 2, 6]) → 1
*/

int array667(vector<int> nums) {
    return 0;
}


// tests:
printTest( "array667([6, 6, 2]) → 1", array667({6, 6, 2}), 1 );
printTest( "array667([6, 6, 2, 6]) → 1", array667({6, 6, 2, 6}), 1 );
printTest( "array667([6, 7, 2, 6]) → 1", array667({6, 7, 2, 6}), 1 );
printTest( "array667([6, 6, 2, 6, 7]) → 2", array667({6, 6, 2, 6, 7}), 2 );
printTest( "array667([1, 6, 3]) → 0", array667({1, 6, 3}), 0 );
printTest( "array667([6, 1]) → 0", array667({6, 1}), 0 );
printTest( "array667([]) → 0", array667({}), 0 );
printTest( "array667([3, 6, 7, 6]) → 1", array667({3, 6, 7, 6}), 1 );
printTest( "array667([3, 6, 6, 7]) → 2", array667({3, 6, 6, 7}), 2 );
printTest( "array667([6, 3, 6, 6]) → 1", array667({6, 3, 6, 6}), 1 );
printTest( "array667([6, 7, 6, 6]) → 2", array667({6, 7, 6, 6}), 2 );
printTest( "array667([1, 2, 3, 5, 6]) → 0", array667({1, 2, 3, 5, 6}), 0 );
printTest( "array667([1, 2, 3, 6, 6]) → 1", array667({1, 2, 3, 6, 6}), 1 );

// %% [markdown]
// # Warmup-2 > noTriples

// %%
/*
Given an array of ints, we'll say that a triple is a value appearing 3 times in
a row in the array. Return true if the array does not contain any triples.

noTriples([1, 1, 2, 2, 1]) → true
noTriples([1, 1, 2, 2, 2, 1]) → false
noTriples([1, 1, 1, 2, 2, 2, 1]) → false
*/

bool noTriples(vector<int> nums) {
    return false;
}


// tests:
printTest( "noTriples([1, 1, 2, 2, 1]) → true", noTriples({1, 1, 2, 2, 1}), true );
printTest( "noTriples([1, 1, 2, 2, 2, 1]) → false", noTriples({1, 1, 2, 2, 2, 1}), false );
printTest( "noTriples([1, 1, 1, 2, 2, 2, 1]) → false", noTriples({1, 1, 1, 2, 2, 2, 1}), false );
printTest( "noTriples([1, 1, 2, 2, 1, 2, 1]) → true", noTriples({1, 1, 2, 2, 1, 2, 1}), true );
printTest( "noTriples([1, 2, 1]) → true", noTriples({1, 2, 1}), true );
printTest( "noTriples([1, 1, 1]) → false", noTriples({1, 1, 1}), false );
printTest( "noTriples([1, 1]) → true", noTriples({1, 1}), true );
printTest( "noTriples([1]) → true", noTriples({1}), true );
printTest( "noTriples([]) → true", noTriples({}), true );

// %% [markdown]
// # Warmup-2 > has271

// %%
/*
Given an array of ints, return true if it contains a 2, 7, 1 pattern: a value,
followed by the value plus 5, followed by the value minus 1. Additionally the
271 counts even if the "1" differs by 2 or less from the correct value.

has271([1, 2, 7, 1]) → true
has271([1, 2, 8, 1]) → false
has271([2, 7, 1]) → true
*/

bool has271(vector<int> nums) {
    return false;
}


// tests:
printTest( "has271([1, 2, 7, 1]) → true", has271({1, 2, 7, 1}), true );
printTest( "has271([1, 2, 8, 1]) → false", has271({1, 2, 8, 1}), false );
printTest( "has271([2, 7, 1]) → true", has271({2, 7, 1}), true );
printTest( "has271([3, 8, 2]) → true", has271({3, 8, 2}), true );
printTest( "has271([2, 7, 3]) → true", has271({2, 7, 3}), true );
printTest( "has271([2, 7, 4]) → false", has271({2, 7, 4}), false );
printTest( "has271([2, 7, -1]) → true", has271({2, 7, -1}), true );
printTest( "has271([2, 7, -2]) → false", has271({2, 7, -2}), false );
printTest( "has271([4, 5, 3, 8, 0]) → true", has271({4, 5, 3, 8, 0}), true );
printTest( "has271([2, 7, 5, 10, 4]) → true", has271({2, 7, 5, 10, 4}), true );
printTest( "has271([2, 7, -2, 4, 9, 3]) → true", has271({2, 7, -2, 4, 9, 3}), true );
printTest( "has271([2, 7, 5, 10, 1]) → false", has271({2, 7, 5, 10, 1}), false );
printTest( "has271([2, 7, -2, 4, 10, 2]) → false", has271({2, 7, -2, 4, 10, 2}), false );
printTest( "has271([1, 1, 4, 9, 0]) → false", has271({1, 1, 4, 9, 0}), false );
printTest( "has271([1, 1, 4, 9, 4, 9, 2]) → true", has271({1, 1, 4, 9, 4, 9, 2}), true );
