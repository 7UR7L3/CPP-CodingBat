// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
namespace testns { template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
} } using namespace testns;
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # Map-2 > word0

// %%
/*
Given an array of strings, return a Map<String, Integer> containing a key for
every different string in the array, always with the value 0. For example the
string "hello" makes the pair "hello":0. Weʼll do more complicated counting
later, but for this problem the value is simply 0.

word0(["a", "b", "a", "b"]) → {"a": 0, "b": 0}
word0(["a", "b", "a", "c", "b"]) → {"a": 0, "b": 0, "c": 0}
word0(["c", "b", "a"]) → {"a": 0, "b": 0, "c": 0}
*/

Map<string, int> word0(vector<string> strings) {
    return null;
}


// tests:
printTest( "word0([\"a\", \"b\", \"a\", \"b\"]) → {\"a\": 0, \"b\": 0}", word0({"a", "b", "a", "b"}), {"a": 0, "b": 0} );
printTest( "word0([\"a\", \"b\", \"a\", \"c\", \"b\"]) → {\"a\": 0, \"b\": 0, \"c\": 0}", word0({"a", "b", "a", "c", "b"}), {"a": 0, "b": 0, "c": 0} );
printTest( "word0([\"c\", \"b\", \"a\"]) → {\"a\": 0, \"b\": 0, \"c\": 0}", word0({"c", "b", "a"}), {"a": 0, "b": 0, "c": 0} );
printTest( "word0([\"c\", \"c\", \"c\", \"c\"]) → {\"c\": 0}", word0({"c", "c", "c", "c"}), {"c": 0} );
printTest( "word0([]) → {}", word0({}), {} );

// %% [markdown]
// # Map-2 > wordLen

// %%
/*
Given an array of strings, return a Map<String, Integer> containing a key for
every different string in the array, and the value is that stringʼs length.

wordLen(["a", "bb", "a", "bb"]) → {"bb": 2, "a": 1}
wordLen(["this", "and", "that", "and"]) → {"that": 4, "and": 3, "this": 4}
wordLen(["code", "code", "code", "bug"]) → {"code": 4, "bug": 3}
*/

Map<string, int> wordLen(vector<string> strings) {
    return null;
}


// tests:
printTest( "wordLen([\"a\", \"bb\", \"a\", \"bb\"]) → {\"bb\": 2, \"a\": 1}", wordLen({"a", "bb", "a", "bb"}), {"bb": 2, "a": 1} );
printTest( "wordLen([\"this\", \"and\", \"that\", \"and\"]) → {\"that\": 4, \"and\": 3, \"this\": 4}", wordLen({"this", "and", "that", "and"}), {"that": 4, "and": 3, "this": 4} );
printTest( "wordLen([\"code\", \"code\", \"code\", \"bug\"]) → {\"code\": 4, \"bug\": 3}", wordLen({"code", "code", "code", "bug"}), {"code": 4, "bug": 3} );
printTest( "wordLen([]) → {}", wordLen({}), {} );
printTest( "wordLen([\"z\"]) → {\"z\": 1}", wordLen({"z"}), {"z": 1} );

// %% [markdown]
// # Map-2 > pairs

// %%
/*
Given an array of non-empty strings, create and return a Map<String, String> as
follows: for each string add its first character as a key with its last
character as the value.

pairs(["code", "bug"]) → {"b": "g", "c": "e"}
pairs(["man", "moon", "main"]) → {"m": "n"}
pairs(["man", "moon", "good", "night"]) → {"g": "d", "m": "n", "n": "t"}
*/

Map<string, string> pairs(vector<string> strings) {
    return null;
}


// tests:
printTest( "pairs([\"code\", \"bug\"]) → {\"b\": \"g\", \"c\": \"e\"}", pairs({"code", "bug"}), {"b": "g", "c": "e"} );
printTest( "pairs([\"man\", \"moon\", \"main\"]) → {\"m\": \"n\"}", pairs({"man", "moon", "main"}), {"m": "n"} );
printTest( "pairs([\"man\", \"moon\", \"good\", \"night\"]) → {\"g\": \"d\", \"m\": \"n\", \"n\": \"t\"}", pairs({"man", "moon", "good", "night"}), {"g": "d", "m": "n", "n": "t"} );
printTest( "pairs([]) → {}", pairs({}), {} );
printTest( "pairs([\"a\", \"b\"]) → {\"a\": \"a\", \"b\": \"b\"}", pairs({"a", "b"}), {"a": "a", "b": "b"} );
printTest( "pairs([\"are\", \"codes\", \"and\", \"cods\"]) → {\"a\": \"d\", \"c\": \"s\"}", pairs({"are", "codes", "and", "cods"}), {"a": "d", "c": "s"} );
printTest( "pairs([\"apple\", \"banana\", \"tea\", \"coffee\"]) → {\"a\": \"e\", \"b\": \"a\", \"c\": \"e\", \"t\": \"a\"}", pairs({"apple", "banana", "tea", "coffee"}), {"a": "e", "b": "a", "c": "e", "t": "a"} );

// %% [markdown]
// # Map-2 > wordCount

// %%
/*
The classic word-count algorithm: given an array of strings, return a
Map<String, Integer> with a key for each different string, with the value the
number of times that string appears in the array.

wordCount(["a", "b", "a", "c", "b"]) → {"a": 2, "b": 2, "c": 1}
wordCount(["c", "b", "a"]) → {"a": 1, "b": 1, "c": 1}
wordCount(["c", "c", "c", "c"]) → {"c": 4}
*/

Map<string, int> wordCount(vector<string> strings) {
    return null;
}


// tests:
printTest( "wordCount([\"a\", \"b\", \"a\", \"c\", \"b\"]) → {\"a\": 2, \"b\": 2, \"c\": 1}", wordCount({"a", "b", "a", "c", "b"}), {"a": 2, "b": 2, "c": 1} );
printTest( "wordCount([\"c\", \"b\", \"a\"]) → {\"a\": 1, \"b\": 1, \"c\": 1}", wordCount({"c", "b", "a"}), {"a": 1, "b": 1, "c": 1} );
printTest( "wordCount([\"c\", \"c\", \"c\", \"c\"]) → {\"c\": 4}", wordCount({"c", "c", "c", "c"}), {"c": 4} );
printTest( "wordCount([]) → {}", wordCount({}), {} );
printTest( "wordCount([\"this\", \"and\", \"this\", \"\"]) → {\"\": 1, \"and\": 1, \"this\": 2}", wordCount({"this", "and", "this", ""}), {"": 1, "and": 1, "this": 2} );
printTest( "wordCount([\"x\", \"y\", \"x\", \"Y\", \"X\"]) → {\"x\": 2, \"X\": 1, \"y\": 1, \"Y\": 1}", wordCount({"x", "y", "x", "Y", "X"}), {"x": 2, "X": 1, "y": 1, "Y": 1} );
printTest( "wordCount([\"123\", \"0\", \"123\", \"1\"]) → {\"0\": 1, \"1\": 1, \"123\": 2}", wordCount({"123", "0", "123", "1"}), {"0": 1, "1": 1, "123": 2} );
printTest( "wordCount([\"d\", \"a\", \"e\", \"d\", \"a\", \"d\", \"b\", \"b\", \"z\", \"a\", \"a\", \"b\", \"z\", \"x\", \"b\", \"f\", \"x\", \"two\", \"b\", \"one\", \"two\"]) → {\"a\": 4, \"b\": 5, \"d\": 3, \"e\": 1, \"f\": 1, \"one\": 1, \"x\": 2, \"z\": 2, \"two\": 2}", wordCount({"d", "a", "e", "d", "a", "d", "b", "b", "z", "a", "a", "b", "z", "x", "b", "f", "x", "two", "b", "one", "two"}), {"a": 4, "b": 5, "d": 3, "e": 1, "f": 1, "one": 1, "x": 2, "z": 2, "two": 2} );
printTest( "wordCount([\"apple\", \"banana\", \"apple\", \"apple\", \"tea\", \"coffee\", \"banana\"]) → {\"banana\": 2, \"apple\": 3, \"tea\": 1, \"coffee\": 1}", wordCount({"apple", "banana", "apple", "apple", "tea", "coffee", "banana"}), {"banana": 2, "apple": 3, "tea": 1, "coffee": 1} );

// %% [markdown]
// # Map-2 > firstChar

// %%
/*
Given an array of non-empty strings, return a Map<String, String> with a key for
every different first character seen, with the value of all the strings starting
with that character appended together in the order they appear in the array.

firstChar(["salt", "tea", "soda", "toast"]) → {"s": "saltsoda", "t": "teatoast"}
firstChar(["aa", "bb", "cc", "aAA", "cCC", "d"]) → {"a": "aaaAA", "b": "bb",
"c": "cccCC", "d": "d"}
firstChar([]) → {}
*/

Map<string, string> firstChar(vector<string> strings) {
    return null;
}


// tests:
printTest( "firstChar([\"salt\", \"tea\", \"soda\", \"toast\"]) → {\"s\": \"saltsoda\", \"t\": \"teatoast\"}", firstChar({"salt", "tea", "soda", "toast"}), {"s": "saltsoda", "t": "teatoast"} );
printTest( "firstChar([\"aa\", \"bb\", \"cc\", \"aAA\", \"cCC\", \"d\"]) → {\"a\": \"aaaAA\", \"b\": \"bb\", \"c\": \"cccCC\", \"d\": \"d\"}", firstChar({"aa", "bb", "cc", "aAA", "cCC", "d"}), {"a": "aaaAA", "b": "bb", "c": "cccCC", "d": "d"} );
printTest( "firstChar([]) → {}", firstChar({}), {} );
printTest( "firstChar([\"apple\", \"bells\", \"salt\", \"aardvark\", \"bells\", \"sun\", \"zen\", \"bells\"]) → {\"a\": \"appleaardvark\", \"b\": \"bellsbellsbells\", \"s\": \"saltsun\", \"z\": \"zen\"}", firstChar({"apple", "bells", "salt", "aardvark", "bells", "sun", "zen", "bells"}), {"a": "appleaardvark", "b": "bellsbellsbells", "s": "saltsun", "z": "zen"} );

// %% [markdown]
// # Map-2 > wordAppend

// %%
/*
Loop over the given array of strings to build a result string like this: when a
string appears the 2nd, 4th, 6th, etc. time in the array, append the string to
the result. Return the empty string if no string appears a 2nd time.

wordAppend(["a", "b", "a"]) → "a"
wordAppend(["a", "b", "a", "c", "a", "d", "a"]) → "aa"
wordAppend(["a", "", "a"]) → "a"
*/

string wordAppend(vector<string> strings) {
    return "";
}


// tests:
printTest( "wordAppend([\"a\", \"b\", \"a\"]) → \"a\"", wordAppend({"a", "b", "a"}), "a" );
printTest( "wordAppend([\"a\", \"b\", \"a\", \"c\", \"a\", \"d\", \"a\"]) → \"aa\"", wordAppend({"a", "b", "a", "c", "a", "d", "a"}), "aa" );
printTest( "wordAppend([\"a\", \"\", \"a\"]) → \"a\"", wordAppend({"a", "", "a"}), "a" );
printTest( "wordAppend([]) → \"\"", wordAppend({}), "" );
printTest( "wordAppend([\"a\", \"b\", \"b\", \"a\", \"a\"]) → \"ba\"", wordAppend({"a", "b", "b", "a", "a"}), "ba" );
printTest( "wordAppend([\"a\", \"b\", \"b\", \"b\", \"a\", \"c\", \"a\", \"a\"]) → \"baa\"", wordAppend({"a", "b", "b", "b", "a", "c", "a", "a"}), "baa" );
printTest( "wordAppend([\"a\", \"b\", \"b\", \"b\", \"a\", \"c\", \"a\", \"a\", \"a\", \"b\", \"a\"]) → \"baaba\"", wordAppend({"a", "b", "b", "b", "a", "c", "a", "a", "a", "b", "a"}), "baaba" );
printTest( "wordAppend([\"not\", \"and\", \"or\", \"and\", \"this\", \"and\", \"or\", \"that\", \"not\"]) → \"andornot\"", wordAppend({"not", "and", "or", "and", "this", "and", "or", "that", "not"}), "andornot" );
printTest( "wordAppend([\"a\", \"b\", \"c\"]) → \"\"", wordAppend({"a", "b", "c"}), "" );
printTest( "wordAppend([\"this\", \"or\", \"that\", \"and\", \"this\", \"and\", \"that\"]) → \"thisandthat\"", wordAppend({"this", "or", "that", "and", "this", "and", "that"}), "thisandthat" );
printTest( "wordAppend([\"xx\", \"xx\", \"yy\", \"xx\", \"zz\", \"yy\", \"zz\", \"xx\"]) → \"xxyyzzxx\"", wordAppend({"xx", "xx", "yy", "xx", "zz", "yy", "zz", "xx"}), "xxyyzzxx" );

// %% [markdown]
// # Map-2 > wordMultiple

// %%
/*
Given an array of strings, return a Map<String, Boolean> where each different
string is a key and its value is true if that string appears 2 or more times in
the array.

wordMultiple(["a", "b", "a", "c", "b"]) → {"a": true, "b": true, "c": false}
wordMultiple(["c", "b", "a"]) → {"a": false, "b": false, "c": false}
wordMultiple(["c", "c", "c", "c"]) → {"c": true}
*/

Map<string, Boolean> wordMultiple(vector<string> strings) {
    return null;
}


// tests:
printTest( "wordMultiple([\"a\", \"b\", \"a\", \"c\", \"b\"]) → {\"a\": true, \"b\": true, \"c\": false}", wordMultiple({"a", "b", "a", "c", "b"}), {"a": true, "b": true, "c": false} );
printTest( "wordMultiple([\"c\", \"b\", \"a\"]) → {\"a\": false, \"b\": false, \"c\": false}", wordMultiple({"c", "b", "a"}), {"a": false, "b": false, "c": false} );
printTest( "wordMultiple([\"c\", \"c\", \"c\", \"c\"]) → {\"c\": true}", wordMultiple({"c", "c", "c", "c"}), {"c": true} );
printTest( "wordMultiple([]) → {}", wordMultiple({}), {} );
printTest( "wordMultiple([\"this\", \"and\", \"this\"]) → {\"and\": false, \"this\": true}", wordMultiple({"this", "and", "this"}), {"and": false, "this": true} );
printTest( "wordMultiple([\"d\", \"a\", \"e\", \"d\", \"a\", \"d\", \"b\", \"b\", \"z\", \"a\", \"a\", \"b\", \"z\", \"x\"]) → {\"a\": true, \"b\": true, \"d\": true, \"e\": false, \"x\": false, \"z\": true}", wordMultiple({"d", "a", "e", "d", "a", "d", "b", "b", "z", "a", "a", "b", "z", "x"}), {"a": true, "b": true, "d": true, "e": false, "x": false, "z": true} );

// %% [markdown]
// # Map-2 > allSwap

// %%
/*
Weʼll say that 2 strings "match" if they are non-empty and their first chars are
the same. Loop over and then return the given array of non-empty strings as
follows: if a string matches an earlier string in the array, swap the 2 strings
in the array. When a position in the array has been swapped, it no longer
matches anything. Using a map, this can be solved making just one pass over the
array. More difficult than it looks.

allSwap(["ab", "ac"]) → ["ac", "ab"]
allSwap(["ax", "bx", "cx", "cy", "by", "ay", "aaa", "azz"]) → ["ay", "by", "cy",
"cx", "bx", "ax", "azz", "aaa"]
allSwap(["ax", "bx", "ay", "by", "ai", "aj", "bx", "by"]) → ["ay", "by", "ax",
"bx", "aj", "ai", "by", "bx"]
*/

std::vector<string> allSwap(vector<string> strings) {
    return new vector<string>{};
}


// tests:
printTest( "allSwap([\"ab\", \"ac\"]) → [\"ac\", \"ab\"]", allSwap({"ab", "ac"}), {"ac", "ab"} );
printTest( "allSwap([\"ax\", \"bx\", \"cx\", \"cy\", \"by\", \"ay\", \"aaa\", \"azz\"]) → [\"ay\", \"by\", \"cy\", \"cx\", \"bx\", \"ax\", \"azz\", \"aaa\"]", allSwap({"ax", "bx", "cx", "cy", "by", "ay", "aaa", "azz"}), {"ay", "by", "cy", "cx", "bx", "ax", "azz", "aaa"} );
printTest( "allSwap([\"ax\", \"bx\", \"ay\", \"by\", \"ai\", \"aj\", \"bx\", \"by\"]) → [\"ay\", \"by\", \"ax\", \"bx\", \"aj\", \"ai\", \"by\", \"bx\"]", allSwap({"ax", "bx", "ay", "by", "ai", "aj", "bx", "by"}), {"ay", "by", "ax", "bx", "aj", "ai", "by", "bx"} );
printTest( "allSwap([\"ax\", \"bx\", \"cx\", \"ay\", \"cy\", \"aaa\", \"abb\"]) → [\"ay\", \"bx\", \"cy\", \"ax\", \"cx\", \"abb\", \"aaa\"]", allSwap({"ax", "bx", "cx", "ay", "cy", "aaa", "abb"}), {"ay", "bx", "cy", "ax", "cx", "abb", "aaa"} );
printTest( "allSwap([\"easy\", \"does\", \"it\", \"every\", \"ice\", \"eaten\"]) → [\"every\", \"does\", \"ice\", \"easy\", \"it\", \"eaten\"]", allSwap({"easy", "does", "it", "every", "ice", "eaten"}), {"every", "does", "ice", "easy", "it", "eaten"} );
printTest( "allSwap([\"list\", \"of\", \"words\", \"swims\", \"over\", \"lily\", \"water\", \"wait\"]) → [\"lily\", \"over\", \"water\", \"swims\", \"of\", \"list\", \"words\", \"wait\"]", allSwap({"list", "of", "words", "swims", "over", "lily", "water", "wait"}), {"lily", "over", "water", "swims", "of", "list", "words", "wait"} );
printTest( "allSwap([\"4\", \"8\", \"15\", \"16\", \"23\", \"42\"]) → [\"42\", \"8\", \"16\", \"15\", \"23\", \"4\"]", allSwap({"4", "8", "15", "16", "23", "42"}), {"42", "8", "16", "15", "23", "4"} );
printTest( "allSwap([\"aaa\"]) → [\"aaa\"]", allSwap({"aaa"}), {"aaa"} );
printTest( "allSwap([]) → []", allSwap({}), {} );
printTest( "allSwap([\"a\", \"b\", \"c\", \"xx\", \"yy\", \"zz\"]) → [\"a\", \"b\", \"c\", \"xx\", \"yy\", \"zz\"]", allSwap({"a", "b", "c", "xx", "yy", "zz"}), {"a", "b", "c", "xx", "yy", "zz"} );

// %% [markdown]
// # Map-2 > firstSwap

// %%
/*
Weʼll say that 2 strings "match" if they are non-empty and their first chars are
the same. Loop over and then return the given array of non-empty strings as
follows: if a string matches an earlier string in the array, swap the 2 strings
in the array. A particular first char can only cause 1 swap, so once a char has
caused a swap, its later swaps are disabled. Using a map, this can be solved
making just one pass over the array. More difficult than it looks.

firstSwap(["ab", "ac"]) → ["ac", "ab"]
firstSwap(["ax", "bx", "cx", "cy", "by", "ay", "aaa", "azz"]) → ["ay", "by",
"cy", "cx", "bx", "ax", "aaa", "azz"]
firstSwap(["ax", "bx", "ay", "by", "ai", "aj", "bx", "by"]) → ["ay", "by", "ax",
"bx", "ai", "aj", "bx", "by"]
*/

std::vector<string> firstSwap(vector<string> strings) {
    return new vector<string>{};
}


// tests:
printTest( "firstSwap([\"ab\", \"ac\"]) → [\"ac\", \"ab\"]", firstSwap({"ab", "ac"}), {"ac", "ab"} );
printTest( "firstSwap([\"ax\", \"bx\", \"cx\", \"cy\", \"by\", \"ay\", \"aaa\", \"azz\"]) → [\"ay\", \"by\", \"cy\", \"cx\", \"bx\", \"ax\", \"aaa\", \"azz\"]", firstSwap({"ax", "bx", "cx", "cy", "by", "ay", "aaa", "azz"}), {"ay", "by", "cy", "cx", "bx", "ax", "aaa", "azz"} );
printTest( "firstSwap([\"ax\", \"bx\", \"ay\", \"by\", \"ai\", \"aj\", \"bx\", \"by\"]) → [\"ay\", \"by\", \"ax\", \"bx\", \"ai\", \"aj\", \"bx\", \"by\"]", firstSwap({"ax", "bx", "ay", "by", "ai", "aj", "bx", "by"}), {"ay", "by", "ax", "bx", "ai", "aj", "bx", "by"} );
printTest( "firstSwap([\"ax\", \"bx\", \"cx\", \"ay\", \"cy\", \"aaa\", \"abb\"]) → [\"ay\", \"bx\", \"cy\", \"ax\", \"cx\", \"aaa\", \"abb\"]", firstSwap({"ax", "bx", "cx", "ay", "cy", "aaa", "abb"}), {"ay", "bx", "cy", "ax", "cx", "aaa", "abb"} );
printTest( "firstSwap([\"easy\", \"does\", \"it\", \"every\", \"ice\", \"eaten\"]) → [\"every\", \"does\", \"ice\", \"easy\", \"it\", \"eaten\"]", firstSwap({"easy", "does", "it", "every", "ice", "eaten"}), {"every", "does", "ice", "easy", "it", "eaten"} );
printTest( "firstSwap([\"list\", \"of\", \"words\", \"swims\", \"over\", \"lily\", \"water\", \"wait\"]) → [\"lily\", \"over\", \"water\", \"swims\", \"of\", \"list\", \"words\", \"wait\"]", firstSwap({"list", "of", "words", "swims", "over", "lily", "water", "wait"}), {"lily", "over", "water", "swims", "of", "list", "words", "wait"} );
printTest( "firstSwap([\"4\", \"8\", \"15\", \"16\", \"23\", \"42\"]) → [\"42\", \"8\", \"16\", \"15\", \"23\", \"4\"]", firstSwap({"4", "8", "15", "16", "23", "42"}), {"42", "8", "16", "15", "23", "4"} );
printTest( "firstSwap([\"aaa\"]) → [\"aaa\"]", firstSwap({"aaa"}), {"aaa"} );
printTest( "firstSwap([]) → []", firstSwap({}), {} );
printTest( "firstSwap([\"a\", \"b\", \"c\", \"xx\", \"yy\", \"zz\"]) → [\"a\", \"b\", \"c\", \"xx\", \"yy\", \"zz\"]", firstSwap({"a", "b", "c", "xx", "yy", "zz"}), {"a", "b", "c", "xx", "yy", "zz"} );
