// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
template<class A>
void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
}
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A>
void printTest( string str, vector<A> run, vector<A> expected )
{
  string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
  if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
  string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
  if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
  printTest( str, runStr, expStr );
}

// %% [markdown]
// # Warmup-1 > sleepIn

// %%
/*
The parameter weekday is true if it is a weekday, and the parameter vacation is
true if we are on vacation. We sleep in if it is not a weekday or we're on
vacation. Return true if we sleep in.

sleepIn(false, false) → true
sleepIn(true, false) → false
sleepIn(false, true) → true
*/

bool sleepIn(bool weekday, bool vacation) {
    return false;
}


// tests:
printTest( "sleepIn(false, false) → true", sleepIn(false, false), true );
printTest( "sleepIn(true, false) → false", sleepIn(true, false), false );
printTest( "sleepIn(false, true) → true", sleepIn(false, true), true );
printTest( "sleepIn(true, true) → true", sleepIn(true, true), true );

// %% [markdown]
// # Warmup-1 > monkeyTrouble

// %%
/*
We have two monkeys, a and b, and the parameters aSmile and bSmile indicate if
each is smiling. We are in trouble if they are both smiling or if neither of
them is smiling. Return true if we are in trouble.

monkeyTrouble(true, true) → true
monkeyTrouble(false, false) → true
monkeyTrouble(true, false) → false
*/

bool monkeyTrouble(bool aSmile, bool bSmile) {
    return false;
}


// tests:
printTest( "monkeyTrouble(true, true) → true", monkeyTrouble(true, true), true );
printTest( "monkeyTrouble(false, false) → true", monkeyTrouble(false, false), true );
printTest( "monkeyTrouble(true, false) → false", monkeyTrouble(true, false), false );
printTest( "monkeyTrouble(false, true) → false", monkeyTrouble(false, true), false );

// %% [markdown]
// # Warmup-1 > sumDouble

// %%
/*
Given two int values, return their sum. Unless the two values are the same, then
return double their sum.

sumDouble(1, 2) → 3
sumDouble(3, 2) → 5
sumDouble(2, 2) → 8
*/

int sumDouble(int a, int b) {
    return 0;
}


// tests:
printTest( "sumDouble(1, 2) → 3", sumDouble(1, 2), 3 );
printTest( "sumDouble(3, 2) → 5", sumDouble(3, 2), 5 );
printTest( "sumDouble(2, 2) → 8", sumDouble(2, 2), 8 );
printTest( "sumDouble(-1, 0) → -1", sumDouble(-1, 0), -1 );
printTest( "sumDouble(3, 3) → 12", sumDouble(3, 3), 12 );
printTest( "sumDouble(0, 0) → 0", sumDouble(0, 0), 0 );
printTest( "sumDouble(0, 1) → 1", sumDouble(0, 1), 1 );
printTest( "sumDouble(3, 4) → 7", sumDouble(3, 4), 7 );

// %% [markdown]
// # Warmup-1 > diff21

// %%
/*
Given an int n, return the absolute difference between n and 21, except return
double the absolute difference if n is over 21.

diff21(19) → 2
diff21(10) → 11
diff21(21) → 0
*/

int diff21(int n) {
    return 0;
}


// tests:
printTest( "diff21(19) → 2", diff21(19), 2 );
printTest( "diff21(10) → 11", diff21(10), 11 );
printTest( "diff21(21) → 0", diff21(21), 0 );
printTest( "diff21(22) → 2", diff21(22), 2 );
printTest( "diff21(25) → 8", diff21(25), 8 );
printTest( "diff21(30) → 18", diff21(30), 18 );
printTest( "diff21(0) → 21", diff21(0), 21 );
printTest( "diff21(1) → 20", diff21(1), 20 );
printTest( "diff21(2) → 19", diff21(2), 19 );
printTest( "diff21(-1) → 22", diff21(-1), 22 );
printTest( "diff21(-2) → 23", diff21(-2), 23 );
printTest( "diff21(50) → 58", diff21(50), 58 );

// %% [markdown]
// # Warmup-1 > parrotTrouble

// %%
/*
We have a loud talking parrot. The "hour" parameter is the current hour time in
the range 0..23. We are in trouble if the parrot is talking and the hour is
before 7 or after 20. Return true if we are in trouble.

parrotTrouble(true, 6) → true
parrotTrouble(true, 7) → false
parrotTrouble(false, 6) → false
*/

bool parrotTrouble(bool talking, int hour) {
    return false;
}


// tests:
printTest( "parrotTrouble(true, 6) → true", parrotTrouble(true, 6), true );
printTest( "parrotTrouble(true, 7) → false", parrotTrouble(true, 7), false );
printTest( "parrotTrouble(false, 6) → false", parrotTrouble(false, 6), false );
printTest( "parrotTrouble(true, 21) → true", parrotTrouble(true, 21), true );
printTest( "parrotTrouble(false, 21) → false", parrotTrouble(false, 21), false );
printTest( "parrotTrouble(false, 20) → false", parrotTrouble(false, 20), false );
printTest( "parrotTrouble(true, 23) → true", parrotTrouble(true, 23), true );
printTest( "parrotTrouble(false, 23) → false", parrotTrouble(false, 23), false );
printTest( "parrotTrouble(true, 20) → false", parrotTrouble(true, 20), false );
printTest( "parrotTrouble(false, 12) → false", parrotTrouble(false, 12), false );

// %% [markdown]
// # Warmup-1 > makes10

// %%
/*
Given 2 ints, a and b, return true if one if them is 10 or if their sum is 10.

makes10(9, 10) → true
makes10(9, 9) → false
makes10(1, 9) → true
*/

bool makes10(int a, int b) {
    return false;
}


// tests:
printTest( "makes10(9, 10) → true", makes10(9, 10), true );
printTest( "makes10(9, 9) → false", makes10(9, 9), false );
printTest( "makes10(1, 9) → true", makes10(1, 9), true );
printTest( "makes10(10, 1) → true", makes10(10, 1), true );
printTest( "makes10(10, 10) → true", makes10(10, 10), true );
printTest( "makes10(8, 2) → true", makes10(8, 2), true );
printTest( "makes10(8, 3) → false", makes10(8, 3), false );
printTest( "makes10(10, 42) → true", makes10(10, 42), true );
printTest( "makes10(12, -2) → true", makes10(12, -2), true );

// %% [markdown]
// # Warmup-1 > nearHundred

// %%
/*
Given an int n, return true if it is within 10 of 100 or 200. Note:
Math.abs(num) computes the absolute value of a number.

nearHundred(93) → true
nearHundred(90) → true
nearHundred(89) → false
*/

bool nearHundred(int n) {
    return false;
}


// tests:
printTest( "nearHundred(93) → true", nearHundred(93), true );
printTest( "nearHundred(90) → true", nearHundred(90), true );
printTest( "nearHundred(89) → false", nearHundred(89), false );
printTest( "nearHundred(110) → true", nearHundred(110), true );
printTest( "nearHundred(111) → false", nearHundred(111), false );
printTest( "nearHundred(121) → false", nearHundred(121), false );
printTest( "nearHundred(-101) → false", nearHundred(-101), false );
printTest( "nearHundred(-209) → false", nearHundred(-209), false );
printTest( "nearHundred(190) → true", nearHundred(190), true );
printTest( "nearHundred(209) → true", nearHundred(209), true );
printTest( "nearHundred(0) → false", nearHundred(0), false );
printTest( "nearHundred(5) → false", nearHundred(5), false );
printTest( "nearHundred(-50) → false", nearHundred(-50), false );
printTest( "nearHundred(191) → true", nearHundred(191), true );
printTest( "nearHundred(189) → false", nearHundred(189), false );
printTest( "nearHundred(200) → true", nearHundred(200), true );
printTest( "nearHundred(210) → true", nearHundred(210), true );
printTest( "nearHundred(211) → false", nearHundred(211), false );
printTest( "nearHundred(290) → false", nearHundred(290), false );

// %% [markdown]
// # Warmup-1 > posNeg

// %%
/*
Given 2 int values, return true if one is negative and one is positive. Except
if the parameter "negative" is true, then return true only if both are negative.

posNeg(1, -1, false) → true
posNeg(-1, 1, false) → true
posNeg(-4, -5, true) → true
*/

bool posNeg(int a, int b, bool negative) {
    return false;
}


// tests:
printTest( "posNeg(1, -1, false) → true", posNeg(1, -1, false), true );
printTest( "posNeg(-1, 1, false) → true", posNeg(-1, 1, false), true );
printTest( "posNeg(-4, -5, true) → true", posNeg(-4, -5, true), true );
printTest( "posNeg(-4, -5, false) → false", posNeg(-4, -5, false), false );
printTest( "posNeg(-4, 5, false) → true", posNeg(-4, 5, false), true );
printTest( "posNeg(-4, 5, true) → false", posNeg(-4, 5, true), false );
printTest( "posNeg(1, 1, false) → false", posNeg(1, 1, false), false );
printTest( "posNeg(-1, -1, false) → false", posNeg(-1, -1, false), false );
printTest( "posNeg(1, -1, true) → false", posNeg(1, -1, true), false );
printTest( "posNeg(-1, 1, true) → false", posNeg(-1, 1, true), false );
printTest( "posNeg(1, 1, true) → false", posNeg(1, 1, true), false );
printTest( "posNeg(-1, -1, true) → true", posNeg(-1, -1, true), true );
printTest( "posNeg(5, -5, false) → true", posNeg(5, -5, false), true );
printTest( "posNeg(-6, 6, false) → true", posNeg(-6, 6, false), true );
printTest( "posNeg(-5, -6, false) → false", posNeg(-5, -6, false), false );
printTest( "posNeg(-2, -1, false) → false", posNeg(-2, -1, false), false );
printTest( "posNeg(1, 2, false) → false", posNeg(1, 2, false), false );
printTest( "posNeg(-5, 6, true) → false", posNeg(-5, 6, true), false );
printTest( "posNeg(-5, -5, true) → true", posNeg(-5, -5, true), true );

// %% [markdown]
// # Warmup-1 > notString

// %%
/*
Given a string, return a new string where "not " has been added to the front.
However, if the string already begins with "not", return the string unchanged.
Note: use .equals() to compare 2 strings.

notString("candy") → "not candy"
notString("x") → "not x"
notString("not bad") → "not bad"
*/

string notString(string str) {
    return "";
}


// tests:
printTest( "notString(\"candy\") → \"not candy\"", notString("candy"), "not candy" );
printTest( "notString(\"x\") → \"not x\"", notString("x"), "not x" );
printTest( "notString(\"not bad\") → \"not bad\"", notString("not bad"), "not bad" );
printTest( "notString(\"bad\") → \"not bad\"", notString("bad"), "not bad" );
printTest( "notString(\"not\") → \"not\"", notString("not"), "not" );
printTest( "notString(\"is not\") → \"not is not\"", notString("is not"), "not is not" );
printTest( "notString(\"no\") → \"not no\"", notString("no"), "not no" );

// %% [markdown]
// # Warmup-1 > missingChar

// %%
/*
Given a non-empty string and an int n, return a new string where the char at
index n has been removed. The value of n will be a valid index of a char in the
original string (i.e. n will be in the range 0..str.length()-1 inclusive).

missingChar("kitten", 1) → "ktten"
missingChar("kitten", 0) → "itten"
missingChar("kitten", 4) → "kittn"
*/

string missingChar(string str, int n) {
    return "";
}


// tests:
printTest( "missingChar(\"kitten\", 1) → \"ktten\"", missingChar("kitten", 1), "ktten" );
printTest( "missingChar(\"kitten\", 0) → \"itten\"", missingChar("kitten", 0), "itten" );
printTest( "missingChar(\"kitten\", 4) → \"kittn\"", missingChar("kitten", 4), "kittn" );
printTest( "missingChar(\"Hi\", 0) → \"i\"", missingChar("Hi", 0), "i" );
printTest( "missingChar(\"Hi\", 1) → \"H\"", missingChar("Hi", 1), "H" );
printTest( "missingChar(\"code\", 0) → \"ode\"", missingChar("code", 0), "ode" );
printTest( "missingChar(\"code\", 1) → \"cde\"", missingChar("code", 1), "cde" );
printTest( "missingChar(\"code\", 2) → \"coe\"", missingChar("code", 2), "coe" );
printTest( "missingChar(\"code\", 3) → \"cod\"", missingChar("code", 3), "cod" );
printTest( "missingChar(\"chocolate\", 8) → \"chocolat\"", missingChar("chocolate", 8), "chocolat" );

// %% [markdown]
// # Warmup-1 > frontBack

// %%
/*
Given a string, return a new string where the first and last chars have been
exchanged.

frontBack("code") → "eodc"
frontBack("a") → "a"
frontBack("ab") → "ba"
*/

string frontBack(string str) {
    return "";
}


// tests:
printTest( "frontBack(\"code\") → \"eodc\"", frontBack("code"), "eodc" );
printTest( "frontBack(\"a\") → \"a\"", frontBack("a"), "a" );
printTest( "frontBack(\"ab\") → \"ba\"", frontBack("ab"), "ba" );
printTest( "frontBack(\"abc\") → \"cba\"", frontBack("abc"), "cba" );
printTest( "frontBack(\"\") → \"\"", frontBack(""), "" );
printTest( "frontBack(\"Chocolate\") → \"ehocolatC\"", frontBack("Chocolate"), "ehocolatC" );
printTest( "frontBack(\"aavJ\") → \"Java\"", frontBack("aavJ"), "Java" );
printTest( "frontBack(\"hello\") → \"oellh\"", frontBack("hello"), "oellh" );

// %% [markdown]
// # Warmup-1 > front3

// %%
/*
Given a string, we'll say that the front is the first 3 chars of the string. If
the string length is less than 3, the front is whatever is there. Return a new
string which is 3 copies of the front.

front3("Java") → "JavJavJav"
front3("Chocolate") → "ChoChoCho"
front3("abc") → "abcabcabc"
*/

string front3(string str) {
    return "";
}


// tests:
printTest( "front3(\"Java\") → \"JavJavJav\"", front3("Java"), "JavJavJav" );
printTest( "front3(\"Chocolate\") → \"ChoChoCho\"", front3("Chocolate"), "ChoChoCho" );
printTest( "front3(\"abc\") → \"abcabcabc\"", front3("abc"), "abcabcabc" );
printTest( "front3(\"abcXYZ\") → \"abcabcabc\"", front3("abcXYZ"), "abcabcabc" );
printTest( "front3(\"ab\") → \"ababab\"", front3("ab"), "ababab" );
printTest( "front3(\"a\") → \"aaa\"", front3("a"), "aaa" );
printTest( "front3(\"\") → \"\"", front3(""), "" );

// %% [markdown]
// # Warmup-1 > backAround

// %%
/*
Given a string, take the last char and return a new string with the last char
added at the front and back, so "cat" yields "tcatt". The original string will
be length 1 or more.

backAround("cat") → "tcatt"
backAround("Hello") → "oHelloo"
backAround("a") → "aaa"
*/

string backAround(string str) {
    return "";
}


// tests:
printTest( "backAround(\"cat\") → \"tcatt\"", backAround("cat"), "tcatt" );
printTest( "backAround(\"Hello\") → \"oHelloo\"", backAround("Hello"), "oHelloo" );
printTest( "backAround(\"a\") → \"aaa\"", backAround("a"), "aaa" );
printTest( "backAround(\"abc\") → \"cabcc\"", backAround("abc"), "cabcc" );
printTest( "backAround(\"read\") → \"dreadd\"", backAround("read"), "dreadd" );
printTest( "backAround(\"boo\") → \"obooo\"", backAround("boo"), "obooo" );

// %% [markdown]
// # Warmup-1 > or35

// %%
/*


or35(3) → true
or35(10) → true
or35(8) → false
*/

bool or35(int n) {
    return false;
}


// tests:
printTest( "or35(3) → true", or35(3), true );
printTest( "or35(10) → true", or35(10), true );
printTest( "or35(8) → false", or35(8), false );
printTest( "or35(15) → true", or35(15), true );
printTest( "or35(5) → true", or35(5), true );
printTest( "or35(9) → true", or35(9), true );
printTest( "or35(4) → false", or35(4), false );
printTest( "or35(7) → false", or35(7), false );
printTest( "or35(6) → true", or35(6), true );
printTest( "or35(17) → false", or35(17), false );
printTest( "or35(18) → true", or35(18), true );
printTest( "or35(29) → false", or35(29), false );
printTest( "or35(20) → true", or35(20), true );
printTest( "or35(21) → true", or35(21), true );
printTest( "or35(22) → false", or35(22), false );
printTest( "or35(45) → true", or35(45), true );
printTest( "or35(99) → true", or35(99), true );
printTest( "or35(100) → true", or35(100), true );
printTest( "or35(101) → false", or35(101), false );
printTest( "or35(121) → false", or35(121), false );
printTest( "or35(122) → false", or35(122), false );
printTest( "or35(123) → true", or35(123), true );

// %% [markdown]
// # Warmup-1 > front22

// %%
/*
Given a string, take the first 2 chars and return the string with the 2 chars
added at both the front and back, so "kitten" yields"kikittenki". If the string
length is less than 2, use whatever chars are there.

front22("kitten") → "kikittenki"
front22("Ha") → "HaHaHa"
front22("abc") → "ababcab"
*/

string front22(string str) {
    return "";
}


// tests:
printTest( "front22(\"kitten\") → \"kikittenki\"", front22("kitten"), "kikittenki" );
printTest( "front22(\"Ha\") → \"HaHaHa\"", front22("Ha"), "HaHaHa" );
printTest( "front22(\"abc\") → \"ababcab\"", front22("abc"), "ababcab" );
printTest( "front22(\"ab\") → \"ababab\"", front22("ab"), "ababab" );
printTest( "front22(\"a\") → \"aaa\"", front22("a"), "aaa" );
printTest( "front22(\"\") → \"\"", front22(""), "" );
printTest( "front22(\"Logic\") → \"LoLogicLo\"", front22("Logic"), "LoLogicLo" );

// %% [markdown]
// # Warmup-1 > startHi

// %%
/*
Given a string, return true if the string starts with "hi" and false otherwise.

startHi("hi there") → true
startHi("hi") → true
startHi("hello hi") → false
*/

bool startHi(string str) {
    return false;
}


// tests:
printTest( "startHi(\"hi there\") → true", startHi("hi there"), true );
printTest( "startHi(\"hi\") → true", startHi("hi"), true );
printTest( "startHi(\"hello hi\") → false", startHi("hello hi"), false );
printTest( "startHi(\"he\") → false", startHi("he"), false );
printTest( "startHi(\"h\") → false", startHi("h"), false );
printTest( "startHi(\"\") → false", startHi(""), false );
printTest( "startHi(\"ho hi\") → false", startHi("ho hi"), false );
printTest( "startHi(\"hi ho\") → true", startHi("hi ho"), true );

// %% [markdown]
// # Warmup-1 > icyHot

// %%
/*
Given two temperatures, return true if one is less than 0 and the other is
greater than 100.

icyHot(120, -1) → true
icyHot(-1, 120) → true
icyHot(2, 120) → false
*/

bool icyHot(int temp1, int temp2) {
    return false;
}


// tests:
printTest( "icyHot(120, -1) → true", icyHot(120, -1), true );
printTest( "icyHot(-1, 120) → true", icyHot(-1, 120), true );
printTest( "icyHot(2, 120) → false", icyHot(2, 120), false );
printTest( "icyHot(-1, 100) → false", icyHot(-1, 100), false );
printTest( "icyHot(-2, -2) → false", icyHot(-2, -2), false );
printTest( "icyHot(120, 120) → false", icyHot(120, 120), false );

// %% [markdown]
// # Warmup-1 > in1020

// %%
/*
Given 2 int values, return true if either of them is in the range 10..20
inclusive.

in1020(12, 99) → true
in1020(21, 12) → true
in1020(8, 99) → false
*/

bool in1020(int a, int b) {
    return false;
}


// tests:
printTest( "in1020(12, 99) → true", in1020(12, 99), true );
printTest( "in1020(21, 12) → true", in1020(21, 12), true );
printTest( "in1020(8, 99) → false", in1020(8, 99), false );
printTest( "in1020(99, 10) → true", in1020(99, 10), true );
printTest( "in1020(20, 20) → true", in1020(20, 20), true );
printTest( "in1020(21, 21) → false", in1020(21, 21), false );
printTest( "in1020(9, 9) → false", in1020(9, 9), false );

// %% [markdown]
// # Warmup-1 > hasTeen

// %%
/*
We'll say that a number is "teen" if it is in the range 13..19 inclusive. Given
3 int values, return true if 1 or more of them are teen.

hasTeen(13, 20, 10) → true
hasTeen(20, 19, 10) → true
hasTeen(20, 10, 13) → true
*/

bool hasTeen(int a, int b, int c) {
    return false;
}


// tests:
printTest( "hasTeen(13, 20, 10) → true", hasTeen(13, 20, 10), true );
printTest( "hasTeen(20, 19, 10) → true", hasTeen(20, 19, 10), true );
printTest( "hasTeen(20, 10, 13) → true", hasTeen(20, 10, 13), true );
printTest( "hasTeen(1, 20, 12) → false", hasTeen(1, 20, 12), false );
printTest( "hasTeen(19, 20, 12) → true", hasTeen(19, 20, 12), true );
printTest( "hasTeen(12, 20, 19) → true", hasTeen(12, 20, 19), true );
printTest( "hasTeen(12, 9, 20) → false", hasTeen(12, 9, 20), false );
printTest( "hasTeen(12, 18, 20) → true", hasTeen(12, 18, 20), true );
printTest( "hasTeen(14, 2, 20) → true", hasTeen(14, 2, 20), true );
printTest( "hasTeen(4, 2, 20) → false", hasTeen(4, 2, 20), false );
printTest( "hasTeen(11, 22, 22) → false", hasTeen(11, 22, 22), false );

// %% [markdown]
// # Warmup-1 > loneTeen

// %%
/*
We'll say that a number is "teen" if it is in the range 13..19 inclusive. Given
2 int values, return true if one or the other is teen, but not both.

loneTeen(13, 99) → true
loneTeen(21, 19) → true
loneTeen(13, 13) → false
*/

bool loneTeen(int a, int b) {
    return false;
}


// tests:
printTest( "loneTeen(13, 99) → true", loneTeen(13, 99), true );
printTest( "loneTeen(21, 19) → true", loneTeen(21, 19), true );
printTest( "loneTeen(13, 13) → false", loneTeen(13, 13), false );
printTest( "loneTeen(14, 20) → true", loneTeen(14, 20), true );
printTest( "loneTeen(20, 15) → true", loneTeen(20, 15), true );
printTest( "loneTeen(16, 17) → false", loneTeen(16, 17), false );
printTest( "loneTeen(16, 9) → true", loneTeen(16, 9), true );
printTest( "loneTeen(16, 18) → false", loneTeen(16, 18), false );
printTest( "loneTeen(13, 19) → false", loneTeen(13, 19), false );
printTest( "loneTeen(13, 20) → true", loneTeen(13, 20), true );
printTest( "loneTeen(6, 18) → true", loneTeen(6, 18), true );
printTest( "loneTeen(99, 13) → true", loneTeen(99, 13), true );
printTest( "loneTeen(99, 99) → false", loneTeen(99, 99), false );

// %% [markdown]
// # Warmup-1 > delDel

// %%
/*
Given a string, if the string "del" appears starting at index 1, return a string
where that "del" has been deleted. Otherwise, return the string unchanged.

delDel("adelbc") → "abc"
delDel("adelHello") → "aHello"
delDel("adedbc") → "adedbc"
*/

string delDel(string str) {
    return "";
}


// tests:
printTest( "delDel(\"adelbc\") → \"abc\"", delDel("adelbc"), "abc" );
printTest( "delDel(\"adelHello\") → \"aHello\"", delDel("adelHello"), "aHello" );
printTest( "delDel(\"adedbc\") → \"adedbc\"", delDel("adedbc"), "adedbc" );
printTest( "delDel(\"abcdel\") → \"abcdel\"", delDel("abcdel"), "abcdel" );
printTest( "delDel(\"add\") → \"add\"", delDel("add"), "add" );
printTest( "delDel(\"ad\") → \"ad\"", delDel("ad"), "ad" );
printTest( "delDel(\"a\") → \"a\"", delDel("a"), "a" );
printTest( "delDel(\"\") → \"\"", delDel(""), "" );
printTest( "delDel(\"del\") → \"del\"", delDel("del"), "del" );
printTest( "delDel(\"adel\") → \"a\"", delDel("adel"), "a" );
printTest( "delDel(\"aadelbb\") → \"aadelbb\"", delDel("aadelbb"), "aadelbb" );

// %% [markdown]
// # Warmup-1 > mixStart

// %%
/*
Return true if the given string begins with "mix", except the 'm' can be
anything, so "pix", "9ix" .. all count.

mixStart("mix snacks") → true
mixStart("pix snacks") → true
mixStart("piz snacks") → false
*/

bool mixStart(string str) {
    return false;
}


// tests:
printTest( "mixStart(\"mix snacks\") → true", mixStart("mix snacks"), true );
printTest( "mixStart(\"pix snacks\") → true", mixStart("pix snacks"), true );
printTest( "mixStart(\"piz snacks\") → false", mixStart("piz snacks"), false );
printTest( "mixStart(\"nix\") → true", mixStart("nix"), true );
printTest( "mixStart(\"ni\") → false", mixStart("ni"), false );
printTest( "mixStart(\"n\") → false", mixStart("n"), false );
printTest( "mixStart(\"\") → false", mixStart(""), false );

// %% [markdown]
// # Warmup-1 > startOz

// %%
/*
Given a string, return a string made of the first 2 chars (if present), however
include first char only if it is 'o' and include the second only if it is 'z',
so "ozymandias" yields "oz".

startOz("ozymandias") → "oz"
startOz("bzoo") → "z"
startOz("oxx") → "o"
*/

string startOz(string str) {
    return "";
}


// tests:
printTest( "startOz(\"ozymandias\") → \"oz\"", startOz("ozymandias"), "oz" );
printTest( "startOz(\"bzoo\") → \"z\"", startOz("bzoo"), "z" );
printTest( "startOz(\"oxx\") → \"o\"", startOz("oxx"), "o" );
printTest( "startOz(\"oz\") → \"oz\"", startOz("oz"), "oz" );
printTest( "startOz(\"ounce\") → \"o\"", startOz("ounce"), "o" );
printTest( "startOz(\"o\") → \"o\"", startOz("o"), "o" );
printTest( "startOz(\"abc\") → \"\"", startOz("abc"), "" );
printTest( "startOz(\"\") → \"\"", startOz(""), "" );
printTest( "startOz(\"zoo\") → \"\"", startOz("zoo"), "" );
printTest( "startOz(\"aztec\") → \"z\"", startOz("aztec"), "z" );
printTest( "startOz(\"zzzz\") → \"z\"", startOz("zzzz"), "z" );
printTest( "startOz(\"oznic\") → \"oz\"", startOz("oznic"), "oz" );

// %% [markdown]
// # Warmup-1 > intMax

// %%
/*
Given three int values, a b c, return the largest.

intMax(1, 2, 3) → 3
intMax(1, 3, 2) → 3
intMax(3, 2, 1) → 3
*/

int intMax(int a, int b, int c) {
    return 0;
}


// tests:
printTest( "intMax(1, 2, 3) → 3", intMax(1, 2, 3), 3 );
printTest( "intMax(1, 3, 2) → 3", intMax(1, 3, 2), 3 );
printTest( "intMax(3, 2, 1) → 3", intMax(3, 2, 1), 3 );
printTest( "intMax(9, 3, 3) → 9", intMax(9, 3, 3), 9 );
printTest( "intMax(3, 9, 3) → 9", intMax(3, 9, 3), 9 );
printTest( "intMax(3, 3, 9) → 9", intMax(3, 3, 9), 9 );
printTest( "intMax(8, 2, 3) → 8", intMax(8, 2, 3), 8 );
printTest( "intMax(-3, -1, -2) → -1", intMax(-3, -1, -2), -1 );
printTest( "intMax(6, 2, 5) → 6", intMax(6, 2, 5), 6 );
printTest( "intMax(5, 6, 2) → 6", intMax(5, 6, 2), 6 );
printTest( "intMax(5, 2, 6) → 6", intMax(5, 2, 6), 6 );

// %% [markdown]
// # Warmup-1 > close10

// %%
/*
Given 2 int values, return whichever value is nearest to the value 10, or return
0 in the event of a tie. Note that Math.abs(n) returns the absolute value of a
number.

close10(8, 13) → 8
close10(13, 8) → 8
close10(13, 7) → 0
*/

int close10(int a, int b) {
    return 0;
}


// tests:
printTest( "close10(8, 13) → 8", close10(8, 13), 8 );
printTest( "close10(13, 8) → 8", close10(13, 8), 8 );
printTest( "close10(13, 7) → 0", close10(13, 7), 0 );
printTest( "close10(7, 13) → 0", close10(7, 13), 0 );
printTest( "close10(9, 13) → 9", close10(9, 13), 9 );
printTest( "close10(13, 8) → 8", close10(13, 8), 8 );
printTest( "close10(10, 12) → 10", close10(10, 12), 10 );
printTest( "close10(11, 10) → 10", close10(11, 10), 10 );
printTest( "close10(5, 21) → 5", close10(5, 21), 5 );
printTest( "close10(0, 20) → 0", close10(0, 20), 0 );
printTest( "close10(10, 10) → 0", close10(10, 10), 0 );

// %% [markdown]
// # Warmup-1 > in3050

// %%
/*
Given 2 int values, return true if they are both in the range 30..40 inclusive,
or they are both in the range 40..50 inclusive.

in3050(30, 31) → true
in3050(30, 41) → false
in3050(40, 50) → true
*/

bool in3050(int a, int b) {
    return false;
}


// tests:
printTest( "in3050(30, 31) → true", in3050(30, 31), true );
printTest( "in3050(30, 41) → false", in3050(30, 41), false );
printTest( "in3050(40, 50) → true", in3050(40, 50), true );
printTest( "in3050(40, 51) → false", in3050(40, 51), false );
printTest( "in3050(39, 50) → false", in3050(39, 50), false );
printTest( "in3050(50, 39) → false", in3050(50, 39), false );
printTest( "in3050(40, 39) → true", in3050(40, 39), true );
printTest( "in3050(49, 48) → true", in3050(49, 48), true );
printTest( "in3050(50, 40) → true", in3050(50, 40), true );
printTest( "in3050(50, 51) → false", in3050(50, 51), false );
printTest( "in3050(35, 36) → true", in3050(35, 36), true );
printTest( "in3050(35, 45) → false", in3050(35, 45), false );

// %% [markdown]
// # Warmup-1 > max1020

// %%
/*
Given 2 positive int values, return the larger value that is in the range 10..20
inclusive, or return 0 if neither is in that range.

max1020(11, 19) → 19
max1020(19, 11) → 19
max1020(11, 9) → 11
*/

int max1020(int a, int b) {
    return 0;
}


// tests:
printTest( "max1020(11, 19) → 19", max1020(11, 19), 19 );
printTest( "max1020(19, 11) → 19", max1020(19, 11), 19 );
printTest( "max1020(11, 9) → 11", max1020(11, 9), 11 );
printTest( "max1020(9, 21) → 0", max1020(9, 21), 0 );
printTest( "max1020(10, 21) → 10", max1020(10, 21), 10 );
printTest( "max1020(21, 10) → 10", max1020(21, 10), 10 );
printTest( "max1020(9, 11) → 11", max1020(9, 11), 11 );
printTest( "max1020(23, 10) → 10", max1020(23, 10), 10 );
printTest( "max1020(20, 10) → 20", max1020(20, 10), 20 );
printTest( "max1020(7, 20) → 20", max1020(7, 20), 20 );
printTest( "max1020(17, 16) → 17", max1020(17, 16), 17 );

// %% [markdown]
// # Warmup-1 > stringE

// %%
/*
Return true if the given string contains between 1 and 3 'e' chars.

stringE("Hello") → true
stringE("Heelle") → true
stringE("Heelele") → false
*/

bool stringE(string str) {
    return false;
}


// tests:
printTest( "stringE(\"Hello\") → true", stringE("Hello"), true );
printTest( "stringE(\"Heelle\") → true", stringE("Heelle"), true );
printTest( "stringE(\"Heelele\") → false", stringE("Heelele"), false );
printTest( "stringE(\"Hll\") → false", stringE("Hll"), false );
printTest( "stringE(\"e\") → true", stringE("e"), true );
printTest( "stringE(\"\") → false", stringE(""), false );

// %% [markdown]
// # Warmup-1 > lastDigit

// %%
/*
Given two non-negative int values, return true if they have the same last digit,
such as with 27 and 57. Note that the % "mod" operator computes remainders, so
17 % 10 is 7.

lastDigit(7, 17) → true
lastDigit(6, 17) → false
lastDigit(3, 113) → true
*/

bool lastDigit(int a, int b) {
    return false;
}


// tests:
printTest( "lastDigit(7, 17) → true", lastDigit(7, 17), true );
printTest( "lastDigit(6, 17) → false", lastDigit(6, 17), false );
printTest( "lastDigit(3, 113) → true", lastDigit(3, 113), true );
printTest( "lastDigit(114, 113) → false", lastDigit(114, 113), false );
printTest( "lastDigit(114, 4) → true", lastDigit(114, 4), true );
printTest( "lastDigit(10, 0) → true", lastDigit(10, 0), true );
printTest( "lastDigit(11, 0) → false", lastDigit(11, 0), false );

// %% [markdown]
// # Warmup-1 > endUp

// %%
/*
Given a string, return a new string where the last 3 chars are now in upper
case. If the string has less than 3 chars, uppercase whatever is there. Note
that str.toUpperCase() returns the uppercase version of a string.

endUp("Hello") → "HeLLO"
endUp("hi there") → "hi thERE"
endUp("hi") → "HI"
*/

string endUp(string str) {
    return "";
}


// tests:
printTest( "endUp(\"Hello\") → \"HeLLO\"", endUp("Hello"), "HeLLO" );
printTest( "endUp(\"hi there\") → \"hi thERE\"", endUp("hi there"), "hi thERE" );
printTest( "endUp(\"hi\") → \"HI\"", endUp("hi"), "HI" );
printTest( "endUp(\"woo hoo\") → \"woo HOO\"", endUp("woo hoo"), "woo HOO" );
printTest( "endUp(\"xyz12\") → \"xyZ12\"", endUp("xyz12"), "xyZ12" );
printTest( "endUp(\"x\") → \"X\"", endUp("x"), "X" );
printTest( "endUp(\"\") → \"\"", endUp(""), "" );

// %% [markdown]
// # Warmup-1 > everyNth

// %%
/*
Given a non-empty string and an int N, return the string made starting with char
0, and then every Nth char of the string. So if N is 3, use char 0, 3, 6, ...
and so on. N is 1 or more.

everyNth("Miracle", 2) → "Mrce"
everyNth("abcdefg", 2) → "aceg"
everyNth("abcdefg", 3) → "adg"
*/

string everyNth(string str, int n) {
    return "";
}


// tests:
printTest( "everyNth(\"Miracle\", 2) → \"Mrce\"", everyNth("Miracle", 2), "Mrce" );
printTest( "everyNth(\"abcdefg\", 2) → \"aceg\"", everyNth("abcdefg", 2), "aceg" );
printTest( "everyNth(\"abcdefg\", 3) → \"adg\"", everyNth("abcdefg", 3), "adg" );
printTest( "everyNth(\"Chocolate\", 3) → \"Cca\"", everyNth("Chocolate", 3), "Cca" );
printTest( "everyNth(\"Chocolates\", 3) → \"Ccas\"", everyNth("Chocolates", 3), "Ccas" );
printTest( "everyNth(\"Chocolates\", 4) → \"Coe\"", everyNth("Chocolates", 4), "Coe" );
printTest( "everyNth(\"Chocolates\", 100) → \"C\"", everyNth("Chocolates", 100), "C" );
