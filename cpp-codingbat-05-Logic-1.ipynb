// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
template<class A>
void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
}
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A>
void printTest( string str, vector<A> run, vector<A> expected )
{
  string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
  if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
  string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
  if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
  printTest( str, runStr, expStr );
}

// %% [markdown]
// # Logic-1 > cigarParty

// %%
/*
When squirrels get together for a party, they like to have cigars. A squirrel
party is successful when the number of cigars is between 40 and 60, inclusive.
Unless it is the weekend, in which case there is no upper bound on the number of
cigars. Return true if the party with the given values is successful, or false
otherwise.

cigarParty(30, false) → false
cigarParty(50, false) → true
cigarParty(70, true) → true
*/

bool cigarParty(int cigars, bool isWeekend) {
    return false;
}


// tests:
printTest( "cigarParty(30, false) → false", cigarParty(30, false), false );
printTest( "cigarParty(50, false) → true", cigarParty(50, false), true );
printTest( "cigarParty(70, true) → true", cigarParty(70, true), true );
printTest( "cigarParty(30, true) → false", cigarParty(30, true), false );
printTest( "cigarParty(50, true) → true", cigarParty(50, true), true );
printTest( "cigarParty(60, false) → true", cigarParty(60, false), true );
printTest( "cigarParty(61, false) → false", cigarParty(61, false), false );
printTest( "cigarParty(40, false) → true", cigarParty(40, false), true );
printTest( "cigarParty(39, false) → false", cigarParty(39, false), false );
printTest( "cigarParty(40, true) → true", cigarParty(40, true), true );
printTest( "cigarParty(39, true) → false", cigarParty(39, true), false );

// %% [markdown]
// # Logic-1 > dateFashion

// %%
/*
You and your date are trying to get a table at a restaurant. The parameter "you"
is the stylishness of your clothes, in the range 0..10, and "date" is the
stylishness of your date's clothes. The result getting the table is encoded as
an int value with 0=no, 1=maybe, 2=yes. If either of you is very stylish, 8 or
more, then the result is 2 (yes). With the exception that if either of you has
style of 2 or less, then the result is 0 (no). Otherwise the result is 1
(maybe).

dateFashion(5, 10) → 2
dateFashion(5, 2) → 0
dateFashion(5, 5) → 1
*/

int dateFashion(int you, int date) {
    return 0;
}


// tests:
printTest( "dateFashion(5, 10) → 2", dateFashion(5, 10), 2 );
printTest( "dateFashion(5, 2) → 0", dateFashion(5, 2), 0 );
printTest( "dateFashion(5, 5) → 1", dateFashion(5, 5), 1 );
printTest( "dateFashion(3, 3) → 1", dateFashion(3, 3), 1 );
printTest( "dateFashion(10, 2) → 0", dateFashion(10, 2), 0 );
printTest( "dateFashion(2, 9) → 0", dateFashion(2, 9), 0 );
printTest( "dateFashion(9, 9) → 2", dateFashion(9, 9), 2 );
printTest( "dateFashion(10, 5) → 2", dateFashion(10, 5), 2 );
printTest( "dateFashion(2, 2) → 0", dateFashion(2, 2), 0 );
printTest( "dateFashion(3, 7) → 1", dateFashion(3, 7), 1 );
printTest( "dateFashion(2, 7) → 0", dateFashion(2, 7), 0 );
printTest( "dateFashion(6, 2) → 0", dateFashion(6, 2), 0 );

// %% [markdown]
// # Logic-1 > squirrelPlay

// %%
/*
The squirrels in Palo Alto spend most of the day playing. In particular, they
play if the temperature is between 60 and 90 (inclusive). Unless it is summer,
then the upper limit is 100 instead of 90. Given an int temperature and a
boolean isSummer, return true if the squirrels play and false otherwise.

squirrelPlay(70, false) → true
squirrelPlay(95, false) → false
squirrelPlay(95, true) → true
*/

bool squirrelPlay(int temp, bool isSummer) {
    return false;
}


// tests:
printTest( "squirrelPlay(70, false) → true", squirrelPlay(70, false), true );
printTest( "squirrelPlay(95, false) → false", squirrelPlay(95, false), false );
printTest( "squirrelPlay(95, true) → true", squirrelPlay(95, true), true );
printTest( "squirrelPlay(90, false) → true", squirrelPlay(90, false), true );
printTest( "squirrelPlay(90, true) → true", squirrelPlay(90, true), true );
printTest( "squirrelPlay(50, false) → false", squirrelPlay(50, false), false );
printTest( "squirrelPlay(50, true) → false", squirrelPlay(50, true), false );
printTest( "squirrelPlay(100, false) → false", squirrelPlay(100, false), false );
printTest( "squirrelPlay(100, true) → true", squirrelPlay(100, true), true );
printTest( "squirrelPlay(105, true) → false", squirrelPlay(105, true), false );
printTest( "squirrelPlay(59, false) → false", squirrelPlay(59, false), false );
printTest( "squirrelPlay(59, true) → false", squirrelPlay(59, true), false );
printTest( "squirrelPlay(60, false) → true", squirrelPlay(60, false), true );

// %% [markdown]
// # Logic-1 > caughtSpeeding

// %%
/*
You are driving a little too fast, and a police officer stops you. Write code to
compute the result, encoded as an int value: 0=no ticket, 1=small ticket, 2=big
ticket. If speed is 60 or less, the result is 0. If speed is between 61 and 80
inclusive, the result is 1. If speed is 81 or more, the result is 2. Unless it
is your birthday -- on that day, your speed can be 5 higher in all cases.

caughtSpeeding(60, false) → 0
caughtSpeeding(65, false) → 1
caughtSpeeding(65, true) → 0
*/

int caughtSpeeding(int speed, bool isBirthday) {
    return 0;
}


// tests:
printTest( "caughtSpeeding(60, false) → 0", caughtSpeeding(60, false), 0 );
printTest( "caughtSpeeding(65, false) → 1", caughtSpeeding(65, false), 1 );
printTest( "caughtSpeeding(65, true) → 0", caughtSpeeding(65, true), 0 );
printTest( "caughtSpeeding(80, false) → 1", caughtSpeeding(80, false), 1 );
printTest( "caughtSpeeding(85, false) → 2", caughtSpeeding(85, false), 2 );
printTest( "caughtSpeeding(85, true) → 1", caughtSpeeding(85, true), 1 );
printTest( "caughtSpeeding(70, false) → 1", caughtSpeeding(70, false), 1 );
printTest( "caughtSpeeding(75, false) → 1", caughtSpeeding(75, false), 1 );
printTest( "caughtSpeeding(75, true) → 1", caughtSpeeding(75, true), 1 );
printTest( "caughtSpeeding(40, false) → 0", caughtSpeeding(40, false), 0 );
printTest( "caughtSpeeding(40, true) → 0", caughtSpeeding(40, true), 0 );
printTest( "caughtSpeeding(90, false) → 2", caughtSpeeding(90, false), 2 );

// %% [markdown]
// # Logic-1 > sortaSum

// %%
/*
Given 2 ints, a and b, return their sum. However, sums in the range 10..19
inclusive, are forbidden, so in that case just return 20.

sortaSum(3, 4) → 7
sortaSum(9, 4) → 20
sortaSum(10, 11) → 21
*/

int sortaSum(int a, int b) {
    return 0;
}


// tests:
printTest( "sortaSum(3, 4) → 7", sortaSum(3, 4), 7 );
printTest( "sortaSum(9, 4) → 20", sortaSum(9, 4), 20 );
printTest( "sortaSum(10, 11) → 21", sortaSum(10, 11), 21 );
printTest( "sortaSum(12, -3) → 9", sortaSum(12, -3), 9 );
printTest( "sortaSum(-3, 12) → 9", sortaSum(-3, 12), 9 );
printTest( "sortaSum(4, 5) → 9", sortaSum(4, 5), 9 );
printTest( "sortaSum(4, 6) → 20", sortaSum(4, 6), 20 );
printTest( "sortaSum(14, 7) → 21", sortaSum(14, 7), 21 );
printTest( "sortaSum(14, 6) → 20", sortaSum(14, 6), 20 );

// %% [markdown]
// # Logic-1 > alarmClock

// %%
/*
Given a day of the week encoded as 0=Sun, 1=Mon, 2=Tue, ...6=Sat, and a boolean
indicating if we are on vacation, return a string of the form "7:00" indicating
when the alarm clock should ring. Weekdays, the alarm should be "7:00" and on
the weekend it should be "10:00". Unless we are on vacation -- then on weekdays
it should be "10:00" and weekends it should be "off".

alarmClock(1, false) → "7:00"
alarmClock(5, false) → "7:00"
alarmClock(0, false) → "10:00"
*/

string alarmClock(int day, bool vacation) {
    return "";
}


// tests:
printTest( "alarmClock(1, false) → \"7:00\"", alarmClock(1, false), "7:00" );
printTest( "alarmClock(5, false) → \"7:00\"", alarmClock(5, false), "7:00" );
printTest( "alarmClock(0, false) → \"10:00\"", alarmClock(0, false), "10:00" );
printTest( "alarmClock(6, false) → \"10:00\"", alarmClock(6, false), "10:00" );
printTest( "alarmClock(0, true) → \"off\"", alarmClock(0, true), "off" );
printTest( "alarmClock(6, true) → \"off\"", alarmClock(6, true), "off" );
printTest( "alarmClock(1, true) → \"10:00\"", alarmClock(1, true), "10:00" );
printTest( "alarmClock(3, true) → \"10:00\"", alarmClock(3, true), "10:00" );
printTest( "alarmClock(5, true) → \"10:00\"", alarmClock(5, true), "10:00" );

// %% [markdown]
// # Logic-1 > love6

// %%
/*
The number 6 is a truly great number. Given two int values, a and b, return true
if either one is 6. Or if their sum or difference is 6. Note: the function
Math.abs(num) computes the absolute value of a number.

love6(6, 4) → true
love6(4, 5) → false
love6(1, 5) → true
*/

bool love6(int a, int b) {
    return false;
}


// tests:
printTest( "love6(6, 4) → true", love6(6, 4), true );
printTest( "love6(4, 5) → false", love6(4, 5), false );
printTest( "love6(1, 5) → true", love6(1, 5), true );
printTest( "love6(1, 6) → true", love6(1, 6), true );
printTest( "love6(1, 8) → false", love6(1, 8), false );
printTest( "love6(1, 7) → true", love6(1, 7), true );
printTest( "love6(7, 5) → false", love6(7, 5), false );
printTest( "love6(8, 2) → true", love6(8, 2), true );
printTest( "love6(6, 6) → true", love6(6, 6), true );
printTest( "love6(-6, 2) → false", love6(-6, 2), false );
printTest( "love6(-4, -10) → true", love6(-4, -10), true );
printTest( "love6(-7, 1) → false", love6(-7, 1), false );
printTest( "love6(7, -1) → true", love6(7, -1), true );
printTest( "love6(-6, 12) → true", love6(-6, 12), true );
printTest( "love6(-2, -4) → false", love6(-2, -4), false );
printTest( "love6(7, 1) → true", love6(7, 1), true );
printTest( "love6(0, 9) → false", love6(0, 9), false );
printTest( "love6(8, 3) → false", love6(8, 3), false );
printTest( "love6(3, 3) → true", love6(3, 3), true );
printTest( "love6(3, 4) → false", love6(3, 4), false );

// %% [markdown]
// # Logic-1 > in1To10

// %%
/*
Given a number n, return true if n is in the range 1..10, inclusive. Unless
outsideMode is true, in which case return true if the number is less or equal to
1, or greater or equal to 10.

in1To10(5, false) → true
in1To10(11, false) → false
in1To10(11, true) → true
*/

bool in1To10(int n, bool outsideMode) {
    return false;
}


// tests:
printTest( "in1To10(5, false) → true", in1To10(5, false), true );
printTest( "in1To10(11, false) → false", in1To10(11, false), false );
printTest( "in1To10(11, true) → true", in1To10(11, true), true );
printTest( "in1To10(10, false) → true", in1To10(10, false), true );
printTest( "in1To10(10, true) → true", in1To10(10, true), true );
printTest( "in1To10(9, false) → true", in1To10(9, false), true );
printTest( "in1To10(9, true) → false", in1To10(9, true), false );
printTest( "in1To10(1, false) → true", in1To10(1, false), true );
printTest( "in1To10(1, true) → true", in1To10(1, true), true );
printTest( "in1To10(0, false) → false", in1To10(0, false), false );
printTest( "in1To10(0, true) → true", in1To10(0, true), true );
printTest( "in1To10(-1, false) → false", in1To10(-1, false), false );
printTest( "in1To10(-1, true) → true", in1To10(-1, true), true );
printTest( "in1To10(99, false) → false", in1To10(99, false), false );
printTest( "in1To10(-99, true) → true", in1To10(-99, true), true );

// %% [markdown]
// # Logic-1 > specialEleven

// %%
/*


specialEleven(22) → true
specialEleven(23) → true
specialEleven(24) → false
*/

bool specialEleven(int n) {
    return false;
}


// tests:
printTest( "specialEleven(22) → true", specialEleven(22), true );
printTest( "specialEleven(23) → true", specialEleven(23), true );
printTest( "specialEleven(24) → false", specialEleven(24), false );
printTest( "specialEleven(21) → false", specialEleven(21), false );
printTest( "specialEleven(11) → true", specialEleven(11), true );
printTest( "specialEleven(12) → true", specialEleven(12), true );
printTest( "specialEleven(10) → false", specialEleven(10), false );
printTest( "specialEleven(9) → false", specialEleven(9), false );
printTest( "specialEleven(8) → false", specialEleven(8), false );
printTest( "specialEleven(0) → true", specialEleven(0), true );
printTest( "specialEleven(1) → true", specialEleven(1), true );
printTest( "specialEleven(2) → false", specialEleven(2), false );
printTest( "specialEleven(121) → true", specialEleven(121), true );
printTest( "specialEleven(122) → true", specialEleven(122), true );
printTest( "specialEleven(123) → false", specialEleven(123), false );
printTest( "specialEleven(46) → false", specialEleven(46), false );
printTest( "specialEleven(49) → false", specialEleven(49), false );
printTest( "specialEleven(52) → false", specialEleven(52), false );
printTest( "specialEleven(54) → false", specialEleven(54), false );
printTest( "specialEleven(55) → true", specialEleven(55), true );

// %% [markdown]
// # Logic-1 > more20

// %%
/*


more20(20) → false
more20(21) → true
more20(22) → true
*/

bool more20(int n) {
    return false;
}


// tests:
printTest( "more20(20) → false", more20(20), false );
printTest( "more20(21) → true", more20(21), true );
printTest( "more20(22) → true", more20(22), true );
printTest( "more20(23) → false", more20(23), false );
printTest( "more20(25) → false", more20(25), false );
printTest( "more20(30) → false", more20(30), false );
printTest( "more20(31) → false", more20(31), false );
printTest( "more20(59) → false", more20(59), false );
printTest( "more20(60) → false", more20(60), false );
printTest( "more20(61) → true", more20(61), true );
printTest( "more20(62) → true", more20(62), true );
printTest( "more20(1020) → false", more20(1020), false );
printTest( "more20(1021) → true", more20(1021), true );
printTest( "more20(1000) → false", more20(1000), false );
printTest( "more20(1001) → true", more20(1001), true );
printTest( "more20(50) → false", more20(50), false );
printTest( "more20(55) → false", more20(55), false );
printTest( "more20(40) → false", more20(40), false );
printTest( "more20(41) → true", more20(41), true );
printTest( "more20(39) → false", more20(39), false );
printTest( "more20(42) → true", more20(42), true );

// %% [markdown]
// # Logic-1 > old35

// %%
/*


old35(3) → true
old35(10) → true
old35(15) → false
*/

bool old35(int n) {
    return false;
}


// tests:
printTest( "old35(3) → true", old35(3), true );
printTest( "old35(10) → true", old35(10), true );
printTest( "old35(15) → false", old35(15), false );
printTest( "old35(5) → true", old35(5), true );
printTest( "old35(9) → true", old35(9), true );
printTest( "old35(8) → false", old35(8), false );
printTest( "old35(7) → false", old35(7), false );
printTest( "old35(6) → true", old35(6), true );
printTest( "old35(17) → false", old35(17), false );
printTest( "old35(18) → true", old35(18), true );
printTest( "old35(29) → false", old35(29), false );
printTest( "old35(20) → true", old35(20), true );
printTest( "old35(21) → true", old35(21), true );
printTest( "old35(22) → false", old35(22), false );
printTest( "old35(45) → false", old35(45), false );
printTest( "old35(99) → true", old35(99), true );

// %% [markdown]
// # Logic-1 > less20

// %%
/*


less20(18) → true
less20(19) → true
less20(20) → false
*/

bool less20(int n) {
    return false;
}


// tests:
printTest( "less20(18) → true", less20(18), true );
printTest( "less20(19) → true", less20(19), true );
printTest( "less20(20) → false", less20(20), false );
printTest( "less20(8) → false", less20(8), false );
printTest( "less20(17) → false", less20(17), false );
printTest( "less20(23) → false", less20(23), false );
printTest( "less20(25) → false", less20(25), false );
printTest( "less20(30) → false", less20(30), false );
printTest( "less20(31) → false", less20(31), false );
printTest( "less20(58) → true", less20(58), true );
printTest( "less20(59) → true", less20(59), true );
printTest( "less20(60) → false", less20(60), false );
printTest( "less20(61) → false", less20(61), false );
printTest( "less20(62) → false", less20(62), false );
printTest( "less20(1017) → false", less20(1017), false );
printTest( "less20(1018) → true", less20(1018), true );
printTest( "less20(1019) → true", less20(1019), true );
printTest( "less20(1020) → false", less20(1020), false );
printTest( "less20(1021) → false", less20(1021), false );
printTest( "less20(1022) → false", less20(1022), false );
printTest( "less20(1023) → false", less20(1023), false );
printTest( "less20(37) → false", less20(37), false );

// %% [markdown]
// # Logic-1 > nearTen

// %%
/*


nearTen(12) → true
nearTen(17) → false
nearTen(19) → true
*/

bool nearTen(int num) {
    return false;
}


// tests:
printTest( "nearTen(12) → true", nearTen(12), true );
printTest( "nearTen(17) → false", nearTen(17), false );
printTest( "nearTen(19) → true", nearTen(19), true );
printTest( "nearTen(31) → true", nearTen(31), true );
printTest( "nearTen(6) → false", nearTen(6), false );
printTest( "nearTen(10) → true", nearTen(10), true );
printTest( "nearTen(11) → true", nearTen(11), true );
printTest( "nearTen(21) → true", nearTen(21), true );
printTest( "nearTen(22) → true", nearTen(22), true );
printTest( "nearTen(23) → false", nearTen(23), false );
printTest( "nearTen(54) → false", nearTen(54), false );
printTest( "nearTen(155) → false", nearTen(155), false );
printTest( "nearTen(158) → true", nearTen(158), true );
printTest( "nearTen(3) → false", nearTen(3), false );
printTest( "nearTen(1) → true", nearTen(1), true );

// %% [markdown]
// # Logic-1 > teenSum

// %%
/*
Given 2 ints, a and b, return their sum. However, "teen" values in the range
13..19 inclusive, are extra lucky. So if either value is a teen, just return 19.

teenSum(3, 4) → 7
teenSum(10, 13) → 19
teenSum(13, 2) → 19
*/

int teenSum(int a, int b) {
    return 0;
}


// tests:
printTest( "teenSum(3, 4) → 7", teenSum(3, 4), 7 );
printTest( "teenSum(10, 13) → 19", teenSum(10, 13), 19 );
printTest( "teenSum(13, 2) → 19", teenSum(13, 2), 19 );
printTest( "teenSum(3, 19) → 19", teenSum(3, 19), 19 );
printTest( "teenSum(13, 13) → 19", teenSum(13, 13), 19 );
printTest( "teenSum(10, 10) → 20", teenSum(10, 10), 20 );
printTest( "teenSum(6, 14) → 19", teenSum(6, 14), 19 );
printTest( "teenSum(15, 2) → 19", teenSum(15, 2), 19 );
printTest( "teenSum(19, 19) → 19", teenSum(19, 19), 19 );
printTest( "teenSum(19, 20) → 19", teenSum(19, 20), 19 );
printTest( "teenSum(2, 18) → 19", teenSum(2, 18), 19 );
printTest( "teenSum(12, 4) → 16", teenSum(12, 4), 16 );
printTest( "teenSum(2, 20) → 22", teenSum(2, 20), 22 );
printTest( "teenSum(2, 17) → 19", teenSum(2, 17), 19 );
printTest( "teenSum(2, 16) → 19", teenSum(2, 16), 19 );
printTest( "teenSum(6, 7) → 13", teenSum(6, 7), 13 );

// %% [markdown]
// # Logic-1 > answerCell

// %%
/*
Your cell phone rings. Return true if you should answer it. Normally you answer,
except in the morning you only answer if it is your mom calling. In all cases,
if you are asleep, you do not answer.

answerCell(false, false, false) → true
answerCell(false, false, true) → false
answerCell(true, false, false) → false
*/

bool answerCell(bool isMorning, bool isMom, bool isAsleep) {
    return false;
}


// tests:
printTest( "answerCell(false, false, false) → true", answerCell(false, false, false), true );
printTest( "answerCell(false, false, true) → false", answerCell(false, false, true), false );
printTest( "answerCell(true, false, false) → false", answerCell(true, false, false), false );
printTest( "answerCell(true, true, false) → true", answerCell(true, true, false), true );
printTest( "answerCell(false, true, false) → true", answerCell(false, true, false), true );
printTest( "answerCell(true, true, true) → false", answerCell(true, true, true), false );

// %% [markdown]
// # Logic-1 > teaParty

// %%
/*
We are having a party with amounts of tea and candy. Return the int outcome of
the party encoded as 0=bad, 1=good, or 2=great. A party is good (1) if both tea
and candy are at least 5. However, if either tea or candy is at least double the
amount of the other one, the party is great (2). However, in all cases, if
either tea or candy is less than 5, the party is always bad (0).

teaParty(6, 8) → 1
teaParty(3, 8) → 0
teaParty(20, 6) → 2
*/

int teaParty(int tea, int candy) {
    return 0;
}


// tests:
printTest( "teaParty(6, 8) → 1", teaParty(6, 8), 1 );
printTest( "teaParty(3, 8) → 0", teaParty(3, 8), 0 );
printTest( "teaParty(20, 6) → 2", teaParty(20, 6), 2 );
printTest( "teaParty(12, 6) → 2", teaParty(12, 6), 2 );
printTest( "teaParty(11, 6) → 1", teaParty(11, 6), 1 );
printTest( "teaParty(11, 4) → 0", teaParty(11, 4), 0 );
printTest( "teaParty(4, 5) → 0", teaParty(4, 5), 0 );
printTest( "teaParty(5, 5) → 1", teaParty(5, 5), 1 );
printTest( "teaParty(6, 6) → 1", teaParty(6, 6), 1 );
printTest( "teaParty(5, 10) → 2", teaParty(5, 10), 2 );
printTest( "teaParty(5, 9) → 1", teaParty(5, 9), 1 );
printTest( "teaParty(10, 4) → 0", teaParty(10, 4), 0 );
printTest( "teaParty(10, 20) → 2", teaParty(10, 20), 2 );

// %% [markdown]
// # Logic-1 > fizzString

// %%
/*


fizzString("fig") → "Fizz"
fizzString("dib") → "Buzz"
fizzString("fib") → "FizzBuzz"
*/

string fizzString(string str) {
    return "";
}


// tests:
printTest( "fizzString(\"fig\") → \"Fizz\"", fizzString("fig"), "Fizz" );
printTest( "fizzString(\"dib\") → \"Buzz\"", fizzString("dib"), "Buzz" );
printTest( "fizzString(\"fib\") → \"FizzBuzz\"", fizzString("fib"), "FizzBuzz" );
printTest( "fizzString(\"abc\") → \"abc\"", fizzString("abc"), "abc" );
printTest( "fizzString(\"fooo\") → \"Fizz\"", fizzString("fooo"), "Fizz" );
printTest( "fizzString(\"booo\") → \"booo\"", fizzString("booo"), "booo" );
printTest( "fizzString(\"ooob\") → \"Buzz\"", fizzString("ooob"), "Buzz" );
printTest( "fizzString(\"fooob\") → \"FizzBuzz\"", fizzString("fooob"), "FizzBuzz" );
printTest( "fizzString(\"f\") → \"Fizz\"", fizzString("f"), "Fizz" );
printTest( "fizzString(\"b\") → \"Buzz\"", fizzString("b"), "Buzz" );
printTest( "fizzString(\"abcb\") → \"Buzz\"", fizzString("abcb"), "Buzz" );
printTest( "fizzString(\"Hello\") → \"Hello\"", fizzString("Hello"), "Hello" );
printTest( "fizzString(\"Hellob\") → \"Buzz\"", fizzString("Hellob"), "Buzz" );
printTest( "fizzString(\"af\") → \"af\"", fizzString("af"), "af" );
printTest( "fizzString(\"bf\") → \"bf\"", fizzString("bf"), "bf" );
printTest( "fizzString(\"fb\") → \"FizzBuzz\"", fizzString("fb"), "FizzBuzz" );

// %% [markdown]
// # Logic-1 > fizzString2

// %%
/*


fizzString2(1) → "1!"
fizzString2(2) → "2!"
fizzString2(3) → "Fizz!"
*/

string fizzString2(int n) {
    return "";
}


// tests:
printTest( "fizzString2(1) → \"1!\"", fizzString2(1), "1!" );
printTest( "fizzString2(2) → \"2!\"", fizzString2(2), "2!" );
printTest( "fizzString2(3) → \"Fizz!\"", fizzString2(3), "Fizz!" );
printTest( "fizzString2(4) → \"4!\"", fizzString2(4), "4!" );
printTest( "fizzString2(5) → \"Buzz!\"", fizzString2(5), "Buzz!" );
printTest( "fizzString2(6) → \"Fizz!\"", fizzString2(6), "Fizz!" );
printTest( "fizzString2(7) → \"7!\"", fizzString2(7), "7!" );
printTest( "fizzString2(8) → \"8!\"", fizzString2(8), "8!" );
printTest( "fizzString2(9) → \"Fizz!\"", fizzString2(9), "Fizz!" );
printTest( "fizzString2(15) → \"FizzBuzz!\"", fizzString2(15), "FizzBuzz!" );
printTest( "fizzString2(16) → \"16!\"", fizzString2(16), "16!" );
printTest( "fizzString2(18) → \"Fizz!\"", fizzString2(18), "Fizz!" );
printTest( "fizzString2(19) → \"19!\"", fizzString2(19), "19!" );
printTest( "fizzString2(21) → \"Fizz!\"", fizzString2(21), "Fizz!" );
printTest( "fizzString2(44) → \"44!\"", fizzString2(44), "44!" );
printTest( "fizzString2(45) → \"FizzBuzz!\"", fizzString2(45), "FizzBuzz!" );
printTest( "fizzString2(100) → \"Buzz!\"", fizzString2(100), "Buzz!" );

// %% [markdown]
// # Logic-1 > twoAsOne

// %%
/*
Given three ints, a b c, return true if it is possible to add two of the ints to
get the third.

twoAsOne(1, 2, 3) → true
twoAsOne(3, 1, 2) → true
twoAsOne(3, 2, 2) → false
*/

bool twoAsOne(int a, int b, int c) {
    return false;
}


// tests:
printTest( "twoAsOne(1, 2, 3) → true", twoAsOne(1, 2, 3), true );
printTest( "twoAsOne(3, 1, 2) → true", twoAsOne(3, 1, 2), true );
printTest( "twoAsOne(3, 2, 2) → false", twoAsOne(3, 2, 2), false );
printTest( "twoAsOne(2, 3, 1) → true", twoAsOne(2, 3, 1), true );
printTest( "twoAsOne(5, 3, -2) → true", twoAsOne(5, 3, -2), true );
printTest( "twoAsOne(5, 3, -3) → false", twoAsOne(5, 3, -3), false );
printTest( "twoAsOne(2, 5, 3) → true", twoAsOne(2, 5, 3), true );
printTest( "twoAsOne(9, 5, 5) → false", twoAsOne(9, 5, 5), false );
printTest( "twoAsOne(9, 4, 5) → true", twoAsOne(9, 4, 5), true );
printTest( "twoAsOne(5, 4, 9) → true", twoAsOne(5, 4, 9), true );
printTest( "twoAsOne(3, 3, 0) → true", twoAsOne(3, 3, 0), true );
printTest( "twoAsOne(3, 3, 2) → false", twoAsOne(3, 3, 2), false );

// %% [markdown]
// # Logic-1 > inOrder

// %%
/*
Given three ints, a b c, return true if b is greater than a, and c is greater
than b. However, with the exception that if "bOk" is true, b does not need to be
greater than a.

inOrder(1, 2, 4, false) → true
inOrder(1, 2, 1, false) → false
inOrder(1, 1, 2, true) → true
*/

bool inOrder(int a, int b, int c, bool bOk) {
    return false;
}


// tests:
printTest( "inOrder(1, 2, 4, false) → true", inOrder(1, 2, 4, false), true );
printTest( "inOrder(1, 2, 1, false) → false", inOrder(1, 2, 1, false), false );
printTest( "inOrder(1, 1, 2, true) → true", inOrder(1, 1, 2, true), true );
printTest( "inOrder(3, 2, 4, false) → false", inOrder(3, 2, 4, false), false );
printTest( "inOrder(2, 3, 4, false) → true", inOrder(2, 3, 4, false), true );
printTest( "inOrder(3, 2, 4, true) → true", inOrder(3, 2, 4, true), true );
printTest( "inOrder(4, 2, 2, true) → false", inOrder(4, 2, 2, true), false );
printTest( "inOrder(4, 5, 2, true) → false", inOrder(4, 5, 2, true), false );
printTest( "inOrder(2, 4, 6, true) → true", inOrder(2, 4, 6, true), true );
printTest( "inOrder(7, 9, 10, false) → true", inOrder(7, 9, 10, false), true );
printTest( "inOrder(7, 5, 6, true) → true", inOrder(7, 5, 6, true), true );
printTest( "inOrder(7, 5, 4, true) → false", inOrder(7, 5, 4, true), false );

// %% [markdown]
// # Logic-1 > inOrderEqual

// %%
/*
Given three ints, a b c, return true if they are in strict increasing order,
such as 2 5 11, or 5 6 7, but not 6 5 7 or 5 5 7. However, with the exception
that if "equalOk" is true, equality is allowed, such as 5 5 7 or 5 5 5.

inOrderEqual(2, 5, 11, false) → true
inOrderEqual(5, 7, 6, false) → false
inOrderEqual(5, 5, 7, true) → true
*/

bool inOrderEqual(int a, int b, int c, bool equalOk) {
    return false;
}


// tests:
printTest( "inOrderEqual(2, 5, 11, false) → true", inOrderEqual(2, 5, 11, false), true );
printTest( "inOrderEqual(5, 7, 6, false) → false", inOrderEqual(5, 7, 6, false), false );
printTest( "inOrderEqual(5, 5, 7, true) → true", inOrderEqual(5, 5, 7, true), true );
printTest( "inOrderEqual(5, 5, 7, false) → false", inOrderEqual(5, 5, 7, false), false );
printTest( "inOrderEqual(2, 5, 4, false) → false", inOrderEqual(2, 5, 4, false), false );
printTest( "inOrderEqual(3, 4, 3, false) → false", inOrderEqual(3, 4, 3, false), false );
printTest( "inOrderEqual(3, 4, 4, false) → false", inOrderEqual(3, 4, 4, false), false );
printTest( "inOrderEqual(3, 4, 3, true) → false", inOrderEqual(3, 4, 3, true), false );
printTest( "inOrderEqual(3, 4, 4, true) → true", inOrderEqual(3, 4, 4, true), true );
printTest( "inOrderEqual(1, 5, 5, true) → true", inOrderEqual(1, 5, 5, true), true );
printTest( "inOrderEqual(5, 5, 5, true) → true", inOrderEqual(5, 5, 5, true), true );
printTest( "inOrderEqual(2, 2, 1, true) → false", inOrderEqual(2, 2, 1, true), false );
printTest( "inOrderEqual(9, 2, 2, true) → false", inOrderEqual(9, 2, 2, true), false );
printTest( "inOrderEqual(0, 1, 0, true) → false", inOrderEqual(0, 1, 0, true), false );

// %% [markdown]
// # Logic-1 > lastDigit

// %%
/*
Given three ints, a b c, return true if two or more of them have the same
rightmost digit. The ints are non-negative. Note: the % "mod" operator computes
the remainder, e.g. 17 % 10 is 7.

lastDigit(23, 19, 13) → true
lastDigit(23, 19, 12) → false
lastDigit(23, 19, 3) → true
*/

bool lastDigit(int a, int b, int c) {
    return false;
}


// tests:
printTest( "lastDigit(23, 19, 13) → true", lastDigit(23, 19, 13), true );
printTest( "lastDigit(23, 19, 12) → false", lastDigit(23, 19, 12), false );
printTest( "lastDigit(23, 19, 3) → true", lastDigit(23, 19, 3), true );
printTest( "lastDigit(23, 19, 39) → true", lastDigit(23, 19, 39), true );
printTest( "lastDigit(1, 2, 3) → false", lastDigit(1, 2, 3), false );
printTest( "lastDigit(1, 1, 2) → true", lastDigit(1, 1, 2), true );
printTest( "lastDigit(1, 2, 2) → true", lastDigit(1, 2, 2), true );
printTest( "lastDigit(14, 25, 43) → false", lastDigit(14, 25, 43), false );
printTest( "lastDigit(14, 25, 45) → true", lastDigit(14, 25, 45), true );
printTest( "lastDigit(248, 106, 1002) → false", lastDigit(248, 106, 1002), false );
printTest( "lastDigit(248, 106, 1008) → true", lastDigit(248, 106, 1008), true );
printTest( "lastDigit(10, 11, 20) → true", lastDigit(10, 11, 20), true );
printTest( "lastDigit(0, 11, 0) → true", lastDigit(0, 11, 0), true );

// %% [markdown]
// # Logic-1 > lessBy10

// %%
/*
Given three ints, a b c, return true if one of them is 10 or more less than one
of the others.

lessBy10(1, 7, 11) → true
lessBy10(1, 7, 10) → false
lessBy10(11, 1, 7) → true
*/

bool lessBy10(int a, int b, int c) {
    return false;
}


// tests:
printTest( "lessBy10(1, 7, 11) → true", lessBy10(1, 7, 11), true );
printTest( "lessBy10(1, 7, 10) → false", lessBy10(1, 7, 10), false );
printTest( "lessBy10(11, 1, 7) → true", lessBy10(11, 1, 7), true );
printTest( "lessBy10(10, 7, 1) → false", lessBy10(10, 7, 1), false );
printTest( "lessBy10(-10, 2, 2) → true", lessBy10(-10, 2, 2), true );
printTest( "lessBy10(2, 11, 11) → false", lessBy10(2, 11, 11), false );
printTest( "lessBy10(3, 3, 30) → true", lessBy10(3, 3, 30), true );
printTest( "lessBy10(3, 3, 3) → false", lessBy10(3, 3, 3), false );
printTest( "lessBy10(10, 1, 11) → true", lessBy10(10, 1, 11), true );
printTest( "lessBy10(10, 11, 1) → true", lessBy10(10, 11, 1), true );
printTest( "lessBy10(10, 11, 2) → false", lessBy10(10, 11, 2), false );
printTest( "lessBy10(3, 30, 3) → true", lessBy10(3, 30, 3), true );
printTest( "lessBy10(2, 2, -8) → true", lessBy10(2, 2, -8), true );
printTest( "lessBy10(2, 8, 12) → true", lessBy10(2, 8, 12), true );

// %% [markdown]
// # Logic-1 > withoutDoubles

// %%
/*
Return the sum of two 6-sided dice rolls, each in the range 1..6. However, if
noDoubles is true, if the two dice show the same value, increment one die to the
next value, wrapping around to 1 if its value was 6.

withoutDoubles(2, 3, true) → 5
withoutDoubles(3, 3, true) → 7
withoutDoubles(3, 3, false) → 6
*/

int withoutDoubles(int die1, int die2, bool noDoubles) {
    return 0;
}


// tests:
printTest( "withoutDoubles(2, 3, true) → 5", withoutDoubles(2, 3, true), 5 );
printTest( "withoutDoubles(3, 3, true) → 7", withoutDoubles(3, 3, true), 7 );
printTest( "withoutDoubles(3, 3, false) → 6", withoutDoubles(3, 3, false), 6 );
printTest( "withoutDoubles(2, 3, false) → 5", withoutDoubles(2, 3, false), 5 );
printTest( "withoutDoubles(5, 4, true) → 9", withoutDoubles(5, 4, true), 9 );
printTest( "withoutDoubles(5, 4, false) → 9", withoutDoubles(5, 4, false), 9 );
printTest( "withoutDoubles(5, 5, true) → 11", withoutDoubles(5, 5, true), 11 );
printTest( "withoutDoubles(5, 5, false) → 10", withoutDoubles(5, 5, false), 10 );
printTest( "withoutDoubles(6, 6, true) → 7", withoutDoubles(6, 6, true), 7 );
printTest( "withoutDoubles(6, 6, false) → 12", withoutDoubles(6, 6, false), 12 );
printTest( "withoutDoubles(1, 6, true) → 7", withoutDoubles(1, 6, true), 7 );
printTest( "withoutDoubles(6, 1, false) → 7", withoutDoubles(6, 1, false), 7 );

// %% [markdown]
// # Logic-1 > maxMod5

// %%
/*
Given two int values, return whichever value is larger. However if the two
values have the same remainder when divided by 5, then the return the smaller
value. However, in all cases, if the two values are the same, return 0. Note:
the % "mod" operator computes the remainder, e.g. 7 % 5 is 2.

maxMod5(2, 3) → 3
maxMod5(6, 2) → 6
maxMod5(3, 2) → 3
*/

int maxMod5(int a, int b) {
    return 0;
}


// tests:
printTest( "maxMod5(2, 3) → 3", maxMod5(2, 3), 3 );
printTest( "maxMod5(6, 2) → 6", maxMod5(6, 2), 6 );
printTest( "maxMod5(3, 2) → 3", maxMod5(3, 2), 3 );
printTest( "maxMod5(8, 12) → 12", maxMod5(8, 12), 12 );
printTest( "maxMod5(7, 12) → 7", maxMod5(7, 12), 7 );
printTest( "maxMod5(11, 6) → 6", maxMod5(11, 6), 6 );
printTest( "maxMod5(2, 7) → 2", maxMod5(2, 7), 2 );
printTest( "maxMod5(7, 7) → 0", maxMod5(7, 7), 0 );
printTest( "maxMod5(9, 1) → 9", maxMod5(9, 1), 9 );
printTest( "maxMod5(9, 14) → 9", maxMod5(9, 14), 9 );
printTest( "maxMod5(1, 2) → 2", maxMod5(1, 2), 2 );

// %% [markdown]
// # Logic-1 > redTicket

// %%
/*
You have a red lottery ticket showing ints a, b, and c, each of which is 0, 1,
or 2. If they are all the value 2, the result is 10. Otherwise if they are all
the same, the result is 5. Otherwise so long as both b and c are different from
a, the result is 1. Otherwise the result is 0.

redTicket(2, 2, 2) → 10
redTicket(2, 2, 1) → 0
redTicket(0, 0, 0) → 5
*/

int redTicket(int a, int b, int c) {
    return 0;
}


// tests:
printTest( "redTicket(2, 2, 2) → 10", redTicket(2, 2, 2), 10 );
printTest( "redTicket(2, 2, 1) → 0", redTicket(2, 2, 1), 0 );
printTest( "redTicket(0, 0, 0) → 5", redTicket(0, 0, 0), 5 );
printTest( "redTicket(2, 0, 0) → 1", redTicket(2, 0, 0), 1 );
printTest( "redTicket(1, 1, 1) → 5", redTicket(1, 1, 1), 5 );
printTest( "redTicket(1, 2, 1) → 0", redTicket(1, 2, 1), 0 );
printTest( "redTicket(1, 2, 0) → 1", redTicket(1, 2, 0), 1 );
printTest( "redTicket(0, 2, 2) → 1", redTicket(0, 2, 2), 1 );
printTest( "redTicket(1, 2, 2) → 1", redTicket(1, 2, 2), 1 );
printTest( "redTicket(0, 2, 0) → 0", redTicket(0, 2, 0), 0 );
printTest( "redTicket(1, 1, 2) → 0", redTicket(1, 1, 2), 0 );

// %% [markdown]
// # Logic-1 > greenTicket

// %%
/*
You have a green lottery ticket, with ints a, b, and c on it. If the numbers are
all different from each other, the result is 0. If all of the numbers are the
same, the result is 20. If two of the numbers are the same, the result is 10.

greenTicket(1, 2, 3) → 0
greenTicket(2, 2, 2) → 20
greenTicket(1, 1, 2) → 10
*/

int greenTicket(int a, int b, int c) {
    return 0;
}


// tests:
printTest( "greenTicket(1, 2, 3) → 0", greenTicket(1, 2, 3), 0 );
printTest( "greenTicket(2, 2, 2) → 20", greenTicket(2, 2, 2), 20 );
printTest( "greenTicket(1, 1, 2) → 10", greenTicket(1, 1, 2), 10 );
printTest( "greenTicket(2, 1, 1) → 10", greenTicket(2, 1, 1), 10 );
printTest( "greenTicket(1, 2, 1) → 10", greenTicket(1, 2, 1), 10 );
printTest( "greenTicket(3, 2, 1) → 0", greenTicket(3, 2, 1), 0 );
printTest( "greenTicket(0, 0, 0) → 20", greenTicket(0, 0, 0), 20 );
printTest( "greenTicket(2, 0, 0) → 10", greenTicket(2, 0, 0), 10 );
printTest( "greenTicket(0, 9, 10) → 0", greenTicket(0, 9, 10), 0 );
printTest( "greenTicket(0, 10, 0) → 10", greenTicket(0, 10, 0), 10 );
printTest( "greenTicket(9, 9, 9) → 20", greenTicket(9, 9, 9), 20 );
printTest( "greenTicket(9, 0, 9) → 10", greenTicket(9, 0, 9), 10 );

// %% [markdown]
// # Logic-1 > blueTicket

// %%
/*
You have a blue lottery ticket, with ints a, b, and c on it. This makes three
pairs, which we'll call ab, bc, and ac. Consider the sum of the numbers in each
pair. If any pair sums to exactly 10, the result is 10. Otherwise if the ab sum
is exactly 10 more than either bc or ac sums, the result is 5. Otherwise the
result is 0.

blueTicket(9, 1, 0) → 10
blueTicket(9, 2, 0) → 0
blueTicket(6, 1, 4) → 10
*/

int blueTicket(int a, int b, int c) {
    return 0;
}


// tests:
printTest( "blueTicket(9, 1, 0) → 10", blueTicket(9, 1, 0), 10 );
printTest( "blueTicket(9, 2, 0) → 0", blueTicket(9, 2, 0), 0 );
printTest( "blueTicket(6, 1, 4) → 10", blueTicket(6, 1, 4), 10 );
printTest( "blueTicket(6, 1, 5) → 0", blueTicket(6, 1, 5), 0 );
printTest( "blueTicket(10, 0, 0) → 10", blueTicket(10, 0, 0), 10 );
printTest( "blueTicket(15, 0, 5) → 5", blueTicket(15, 0, 5), 5 );
printTest( "blueTicket(5, 15, 5) → 10", blueTicket(5, 15, 5), 10 );
printTest( "blueTicket(4, 11, 1) → 5", blueTicket(4, 11, 1), 5 );
printTest( "blueTicket(13, 2, 3) → 5", blueTicket(13, 2, 3), 5 );
printTest( "blueTicket(8, 4, 3) → 0", blueTicket(8, 4, 3), 0 );
printTest( "blueTicket(8, 4, 2) → 10", blueTicket(8, 4, 2), 10 );
printTest( "blueTicket(8, 4, 1) → 0", blueTicket(8, 4, 1), 0 );

// %% [markdown]
// # Logic-1 > shareDigit

// %%
/*
Given two ints, each in the range 10..99, return true if there is a digit that
appears in both numbers, such as the 2 in 12 and 23. (Note: division, e.g. n/10,
gives the left digit while the % "mod" n%10 gives the right digit.)

shareDigit(12, 23) → true
shareDigit(12, 43) → false
shareDigit(12, 44) → false
*/

bool shareDigit(int a, int b) {
    return false;
}


// tests:
printTest( "shareDigit(12, 23) → true", shareDigit(12, 23), true );
printTest( "shareDigit(12, 43) → false", shareDigit(12, 43), false );
printTest( "shareDigit(12, 44) → false", shareDigit(12, 44), false );
printTest( "shareDigit(23, 12) → true", shareDigit(23, 12), true );
printTest( "shareDigit(23, 39) → true", shareDigit(23, 39), true );
printTest( "shareDigit(23, 19) → false", shareDigit(23, 19), false );
printTest( "shareDigit(30, 90) → true", shareDigit(30, 90), true );
printTest( "shareDigit(30, 91) → false", shareDigit(30, 91), false );
printTest( "shareDigit(55, 55) → true", shareDigit(55, 55), true );
printTest( "shareDigit(55, 44) → false", shareDigit(55, 44), false );

// %% [markdown]
// # Logic-1 > sumLimit

// %%
/*
Given 2 non-negative ints, a and b, return their sum, so long as the sum has the
same number of digits as a. If the sum has more digits than a, just return a
without b. (Note: one way to compute the number of digits of a non-negative int
n is to convert it to a string with String.valueOf(n) and then check the length
of the string.)

sumLimit(2, 3) → 5
sumLimit(8, 3) → 8
sumLimit(8, 1) → 9
*/

int sumLimit(int a, int b) {
    return 0;
}


// tests:
printTest( "sumLimit(2, 3) → 5", sumLimit(2, 3), 5 );
printTest( "sumLimit(8, 3) → 8", sumLimit(8, 3), 8 );
printTest( "sumLimit(8, 1) → 9", sumLimit(8, 1), 9 );
printTest( "sumLimit(11, 39) → 50", sumLimit(11, 39), 50 );
printTest( "sumLimit(11, 99) → 11", sumLimit(11, 99), 11 );
printTest( "sumLimit(0, 0) → 0", sumLimit(0, 0), 0 );
printTest( "sumLimit(99, 0) → 99", sumLimit(99, 0), 99 );
printTest( "sumLimit(99, 1) → 99", sumLimit(99, 1), 99 );
printTest( "sumLimit(123, 1) → 124", sumLimit(123, 1), 124 );
printTest( "sumLimit(1, 123) → 1", sumLimit(1, 123), 1 );
printTest( "sumLimit(23, 60) → 83", sumLimit(23, 60), 83 );
printTest( "sumLimit(23, 80) → 23", sumLimit(23, 80), 23 );
printTest( "sumLimit(9000, 1) → 9001", sumLimit(9000, 1), 9001 );
printTest( "sumLimit(90000000, 1) → 90000001", sumLimit(90000000, 1), 90000001 );
printTest( "sumLimit(9000, 1000) → 9000", sumLimit(9000, 1000), 9000 );
