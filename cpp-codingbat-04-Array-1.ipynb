// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
}
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # Array-1 > firstLast6

// %%
/*
Given an array of ints, return true if 6 appears as either the first or last
element in the array. The array will be length 1 or more.

firstLast6([1, 2, 6]) → true
firstLast6([6, 1, 2, 3]) → true
firstLast6([13, 6, 1, 2, 3]) → false
*/

bool firstLast6(vector<int> nums) {
    return false;
}


// tests:
printTest( "firstLast6([1, 2, 6]) → true", firstLast6({1, 2, 6}), true );
printTest( "firstLast6([6, 1, 2, 3]) → true", firstLast6({6, 1, 2, 3}), true );
printTest( "firstLast6([13, 6, 1, 2, 3]) → false", firstLast6({13, 6, 1, 2, 3}), false );
printTest( "firstLast6([13, 6, 1, 2, 6]) → true", firstLast6({13, 6, 1, 2, 6}), true );
printTest( "firstLast6([3, 2, 1]) → false", firstLast6({3, 2, 1}), false );
printTest( "firstLast6([3, 6, 1]) → false", firstLast6({3, 6, 1}), false );
printTest( "firstLast6([3, 6]) → true", firstLast6({3, 6}), true );
printTest( "firstLast6([6]) → true", firstLast6({6}), true );
printTest( "firstLast6([3]) → false", firstLast6({3}), false );
printTest( "firstLast6([5, 6]) → true", firstLast6({5, 6}), true );
printTest( "firstLast6([5, 5]) → false", firstLast6({5, 5}), false );
printTest( "firstLast6([1, 2, 3, 4, 6]) → true", firstLast6({1, 2, 3, 4, 6}), true );
printTest( "firstLast6([1, 2, 3, 4]) → false", firstLast6({1, 2, 3, 4}), false );

// %% [markdown]
// # Array-1 > sameFirstLast

// %%
/*
Given an array of ints, return true if the array is length 1 or more, and the
first element and the last element are equal.

sameFirstLast([1, 2, 3]) → false
sameFirstLast([1, 2, 3, 1]) → true
sameFirstLast([1, 2, 1]) → true
*/

bool sameFirstLast(vector<int> nums) {
    return false;
}


// tests:
printTest( "sameFirstLast([1, 2, 3]) → false", sameFirstLast({1, 2, 3}), false );
printTest( "sameFirstLast([1, 2, 3, 1]) → true", sameFirstLast({1, 2, 3, 1}), true );
printTest( "sameFirstLast([1, 2, 1]) → true", sameFirstLast({1, 2, 1}), true );
printTest( "sameFirstLast([7]) → true", sameFirstLast({7}), true );
printTest( "sameFirstLast([]) → false", sameFirstLast({}), false );
printTest( "sameFirstLast([1, 2, 3, 4, 5, 1]) → true", sameFirstLast({1, 2, 3, 4, 5, 1}), true );
printTest( "sameFirstLast([1, 2, 3, 4, 5, 13]) → false", sameFirstLast({1, 2, 3, 4, 5, 13}), false );
printTest( "sameFirstLast([13, 2, 3, 4, 5, 13]) → true", sameFirstLast({13, 2, 3, 4, 5, 13}), true );
printTest( "sameFirstLast([7, 7]) → true", sameFirstLast({7, 7}), true );

// %% [markdown]
// # Array-1 > makePi

// %%
/*
Return an int array length 3 containing the first 3 digits of pi, {3, 1, 4}.

makePi() → [3, 1, 4]
*/

vector<int> makePi() {
    return vector<int>{};
}


// tests:
printTest( "makePi() → [3, 1, 4]", makePi(), {3, 1, 4} );

// %% [markdown]
// # Array-1 > commonEnd

// %%
/*
Given 2 arrays of ints, a and b, return true if they have the same first element
or they have the same last element. Both arrays will be length 1 or more.

commonEnd([1, 2, 3], [7, 3]) → true
commonEnd([1, 2, 3], [7, 3, 2]) → false
commonEnd([1, 2, 3], [1, 3]) → true
*/

bool commonEnd(vector<int> a, vector<int> b) {
    return false;
}


// tests:
printTest( "commonEnd([1, 2, 3], [7, 3]) → true", commonEnd({1, 2, 3}, {7, 3}), true );
printTest( "commonEnd([1, 2, 3], [7, 3, 2]) → false", commonEnd({1, 2, 3}, {7, 3, 2}), false );
printTest( "commonEnd([1, 2, 3], [1, 3]) → true", commonEnd({1, 2, 3}, {1, 3}), true );
printTest( "commonEnd([1, 2, 3], [1]) → true", commonEnd({1, 2, 3}, {1}), true );
printTest( "commonEnd([1, 2, 3], [2]) → false", commonEnd({1, 2, 3}, {2}), false );

// %% [markdown]
// # Array-1 > sum3

// %%
/*
Given an array of ints length 3, return the sum of all the elements.

sum3([1, 2, 3]) → 6
sum3([5, 11, 2]) → 18
sum3([7, 0, 0]) → 7
*/

int sum3(vector<int> nums) {
    return 0;
}


// tests:
printTest( "sum3([1, 2, 3]) → 6", sum3({1, 2, 3}), 6 );
printTest( "sum3([5, 11, 2]) → 18", sum3({5, 11, 2}), 18 );
printTest( "sum3([7, 0, 0]) → 7", sum3({7, 0, 0}), 7 );
printTest( "sum3([1, 2, 1]) → 4", sum3({1, 2, 1}), 4 );
printTest( "sum3([1, 1, 1]) → 3", sum3({1, 1, 1}), 3 );
printTest( "sum3([2, 7, 2]) → 11", sum3({2, 7, 2}), 11 );

// %% [markdown]
// # Array-1 > rotateLeft3

// %%
/*
Given an array of ints length 3, return an array with the elements "rotated
left" so {1, 2, 3} yields {2, 3, 1}.

rotateLeft3([1, 2, 3]) → [2, 3, 1]
rotateLeft3([5, 11, 9]) → [11, 9, 5]
rotateLeft3([7, 0, 0]) → [0, 0, 7]
*/

vector<int> rotateLeft3(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "rotateLeft3([1, 2, 3]) → [2, 3, 1]", rotateLeft3({1, 2, 3}), {2, 3, 1} );
printTest( "rotateLeft3([5, 11, 9]) → [11, 9, 5]", rotateLeft3({5, 11, 9}), {11, 9, 5} );
printTest( "rotateLeft3([7, 0, 0]) → [0, 0, 7]", rotateLeft3({7, 0, 0}), {0, 0, 7} );
printTest( "rotateLeft3([1, 2, 1]) → [2, 1, 1]", rotateLeft3({1, 2, 1}), {2, 1, 1} );
printTest( "rotateLeft3([0, 0, 1]) → [0, 1, 0]", rotateLeft3({0, 0, 1}), {0, 1, 0} );

// %% [markdown]
// # Array-1 > reverse3

// %%
/*
Given an array of ints length 3, return a new array with the elements in reverse
order, so {1, 2, 3} becomes {3, 2, 1}.

reverse3([1, 2, 3]) → [3, 2, 1]
reverse3([5, 11, 9]) → [9, 11, 5]
reverse3([7, 0, 0]) → [0, 0, 7]
*/

vector<int> reverse3(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "reverse3([1, 2, 3]) → [3, 2, 1]", reverse3({1, 2, 3}), {3, 2, 1} );
printTest( "reverse3([5, 11, 9]) → [9, 11, 5]", reverse3({5, 11, 9}), {9, 11, 5} );
printTest( "reverse3([7, 0, 0]) → [0, 0, 7]", reverse3({7, 0, 0}), {0, 0, 7} );
printTest( "reverse3([2, 1, 2]) → [2, 1, 2]", reverse3({2, 1, 2}), {2, 1, 2} );
printTest( "reverse3([1, 2, 1]) → [1, 2, 1]", reverse3({1, 2, 1}), {1, 2, 1} );
printTest( "reverse3([2, 11, 3]) → [3, 11, 2]", reverse3({2, 11, 3}), {3, 11, 2} );
printTest( "reverse3([0, 6, 5]) → [5, 6, 0]", reverse3({0, 6, 5}), {5, 6, 0} );
printTest( "reverse3([7, 2, 3]) → [3, 2, 7]", reverse3({7, 2, 3}), {3, 2, 7} );

// %% [markdown]
// # Array-1 > maxEnd3

// %%
/*
Given an array of ints length 3, figure out which is larger, the first or last
element in the array, and set all the other elements to be that value. Return
the changed array.

maxEnd3([1, 2, 3]) → [3, 3, 3]
maxEnd3([11, 5, 9]) → [11, 11, 11]
maxEnd3([2, 11, 3]) → [3, 3, 3]
*/

vector<int> maxEnd3(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "maxEnd3([1, 2, 3]) → [3, 3, 3]", maxEnd3({1, 2, 3}), {3, 3, 3} );
printTest( "maxEnd3([11, 5, 9]) → [11, 11, 11]", maxEnd3({11, 5, 9}), {11, 11, 11} );
printTest( "maxEnd3([2, 11, 3]) → [3, 3, 3]", maxEnd3({2, 11, 3}), {3, 3, 3} );
printTest( "maxEnd3([11, 3, 3]) → [11, 11, 11]", maxEnd3({11, 3, 3}), {11, 11, 11} );
printTest( "maxEnd3([3, 11, 11]) → [11, 11, 11]", maxEnd3({3, 11, 11}), {11, 11, 11} );
printTest( "maxEnd3([2, 2, 2]) → [2, 2, 2]", maxEnd3({2, 2, 2}), {2, 2, 2} );
printTest( "maxEnd3([2, 11, 2]) → [2, 2, 2]", maxEnd3({2, 11, 2}), {2, 2, 2} );
printTest( "maxEnd3([0, 0, 1]) → [1, 1, 1]", maxEnd3({0, 0, 1}), {1, 1, 1} );

// %% [markdown]
// # Array-1 > sum2

// %%
/*
Given an array of ints, return the sum of the first 2 elements in the array. If
the array length is less than 2, just sum up the elements that exist, returning
0 if the array is length 0.

sum2([1, 2, 3]) → 3
sum2([1, 1]) → 2
sum2([1, 1, 1, 1]) → 2
*/

int sum2(vector<int> nums) {
    return 0;
}


// tests:
printTest( "sum2([1, 2, 3]) → 3", sum2({1, 2, 3}), 3 );
printTest( "sum2([1, 1]) → 2", sum2({1, 1}), 2 );
printTest( "sum2([1, 1, 1, 1]) → 2", sum2({1, 1, 1, 1}), 2 );
printTest( "sum2([1, 2]) → 3", sum2({1, 2}), 3 );
printTest( "sum2([1]) → 1", sum2({1}), 1 );
printTest( "sum2([]) → 0", sum2({}), 0 );
printTest( "sum2([4, 5, 6]) → 9", sum2({4, 5, 6}), 9 );
printTest( "sum2([4]) → 4", sum2({4}), 4 );

// %% [markdown]
// # Array-1 > middleWay

// %%
/*
Given 2 int arrays, a and b, each length 3, return a new array length 2
containing their middle elements.

middleWay([1, 2, 3], [4, 5, 6]) → [2, 5]
middleWay([7, 7, 7], [3, 8, 0]) → [7, 8]
middleWay([5, 2, 9], [1, 4, 5]) → [2, 4]
*/

vector<int> middleWay(vector<int> a, vector<int> b) {
    return vector<int>{};
}


// tests:
printTest( "middleWay([1, 2, 3], [4, 5, 6]) → [2, 5]", middleWay({1, 2, 3}, {4, 5, 6}), {2, 5} );
printTest( "middleWay([7, 7, 7], [3, 8, 0]) → [7, 8]", middleWay({7, 7, 7}, {3, 8, 0}), {7, 8} );
printTest( "middleWay([5, 2, 9], [1, 4, 5]) → [2, 4]", middleWay({5, 2, 9}, {1, 4, 5}), {2, 4} );
printTest( "middleWay([1, 9, 7], [4, 8, 8]) → [9, 8]", middleWay({1, 9, 7}, {4, 8, 8}), {9, 8} );
printTest( "middleWay([1, 2, 3], [3, 1, 4]) → [2, 1]", middleWay({1, 2, 3}, {3, 1, 4}), {2, 1} );
printTest( "middleWay([1, 2, 3], [4, 1, 1]) → [2, 1]", middleWay({1, 2, 3}, {4, 1, 1}), {2, 1} );

// %% [markdown]
// # Array-1 > makeEnds

// %%
/*
Given an array of ints, return a new array length 2 containing the first and
last elements from the original array. The original array will be length 1 or
more.

makeEnds([1, 2, 3]) → [1, 3]
makeEnds([1, 2, 3, 4]) → [1, 4]
makeEnds([7, 4, 6, 2]) → [7, 2]
*/

vector<int> makeEnds(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "makeEnds([1, 2, 3]) → [1, 3]", makeEnds({1, 2, 3}), {1, 3} );
printTest( "makeEnds([1, 2, 3, 4]) → [1, 4]", makeEnds({1, 2, 3, 4}), {1, 4} );
printTest( "makeEnds([7, 4, 6, 2]) → [7, 2]", makeEnds({7, 4, 6, 2}), {7, 2} );
printTest( "makeEnds([1, 2, 2, 2, 2, 2, 2, 3]) → [1, 3]", makeEnds({1, 2, 2, 2, 2, 2, 2, 3}), {1, 3} );
printTest( "makeEnds([7, 4]) → [7, 4]", makeEnds({7, 4}), {7, 4} );
printTest( "makeEnds([7]) → [7, 7]", makeEnds({7}), {7, 7} );
printTest( "makeEnds([5, 2, 9]) → [5, 9]", makeEnds({5, 2, 9}), {5, 9} );
printTest( "makeEnds([2, 3, 4, 1]) → [2, 1]", makeEnds({2, 3, 4, 1}), {2, 1} );

// %% [markdown]
// # Array-1 > has23

// %%
/*
Given an int array length 2, return true if it contains a 2 or a 3.

has23([2, 5]) → true
has23([4, 3]) → true
has23([4, 5]) → false
*/

bool has23(vector<int> nums) {
    return false;
}


// tests:
printTest( "has23([2, 5]) → true", has23({2, 5}), true );
printTest( "has23([4, 3]) → true", has23({4, 3}), true );
printTest( "has23([4, 5]) → false", has23({4, 5}), false );
printTest( "has23([2, 2]) → true", has23({2, 2}), true );
printTest( "has23([3, 2]) → true", has23({3, 2}), true );
printTest( "has23([3, 3]) → true", has23({3, 3}), true );
printTest( "has23([7, 7]) → false", has23({7, 7}), false );
printTest( "has23([3, 9]) → true", has23({3, 9}), true );
printTest( "has23([9, 5]) → false", has23({9, 5}), false );

// %% [markdown]
// # Array-1 > no23

// %%
/*
Given an int array length 2, return true if it does not contain a 2 or 3.

no23([4, 5]) → true
no23([4, 2]) → false
no23([3, 5]) → false
*/

bool no23(vector<int> nums) {
    return false;
}


// tests:
printTest( "no23([4, 5]) → true", no23({4, 5}), true );
printTest( "no23([4, 2]) → false", no23({4, 2}), false );
printTest( "no23([3, 5]) → false", no23({3, 5}), false );
printTest( "no23([1, 9]) → true", no23({1, 9}), true );
printTest( "no23([2, 9]) → false", no23({2, 9}), false );
printTest( "no23([1, 3]) → false", no23({1, 3}), false );
printTest( "no23([1, 1]) → true", no23({1, 1}), true );
printTest( "no23([2, 2]) → false", no23({2, 2}), false );
printTest( "no23([3, 3]) → false", no23({3, 3}), false );
printTest( "no23([7, 8]) → true", no23({7, 8}), true );
printTest( "no23([8, 7]) → true", no23({8, 7}), true );

// %% [markdown]
// # Array-1 > makeLast

// %%
/*
Given an int array, return a new array with double the length where its last
element is the same as the original array, and all the other elements are 0. The
original array will be length 1 or more. Note: by default, a new int array
contains all 0's.

makeLast([4, 5, 6]) → [0, 0, 0, 0, 0, 6]
makeLast([1, 2]) → [0, 0, 0, 2]
makeLast([3]) → [0, 3]
*/

vector<int> makeLast(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "makeLast([4, 5, 6]) → [0, 0, 0, 0, 0, 6]", makeLast({4, 5, 6}), {0, 0, 0, 0, 0, 6} );
printTest( "makeLast([1, 2]) → [0, 0, 0, 2]", makeLast({1, 2}), {0, 0, 0, 2} );
printTest( "makeLast([3]) → [0, 3]", makeLast({3}), {0, 3} );
printTest( "makeLast([0]) → [0, 0]", makeLast({0}), {0, 0} );
printTest( "makeLast([7, 7, 7]) → [0, 0, 0, 0, 0, 7]", makeLast({7, 7, 7}), {0, 0, 0, 0, 0, 7} );
printTest( "makeLast([3, 1, 4]) → [0, 0, 0, 0, 0, 4]", makeLast({3, 1, 4}), {0, 0, 0, 0, 0, 4} );
printTest( "makeLast([1, 2, 3, 4]) → [0, 0, 0, 0, 0, 0, 0, 4]", makeLast({1, 2, 3, 4}), {0, 0, 0, 0, 0, 0, 0, 4} );
printTest( "makeLast([1, 2, 3, 0]) → [0, 0, 0, 0, 0, 0, 0, 0]", makeLast({1, 2, 3, 0}), {0, 0, 0, 0, 0, 0, 0, 0} );
printTest( "makeLast([2, 4]) → [0, 0, 0, 4]", makeLast({2, 4}), {0, 0, 0, 4} );

// %% [markdown]
// # Array-1 > double23

// %%
/*
Given an int array, return true if the array contains 2 twice, or 3 twice. The
array will be length 0, 1, or 2.

double23([2, 2]) → true
double23([3, 3]) → true
double23([2, 3]) → false
*/

bool double23(vector<int> nums) {
    return false;
}


// tests:
printTest( "double23([2, 2]) → true", double23({2, 2}), true );
printTest( "double23([3, 3]) → true", double23({3, 3}), true );
printTest( "double23([2, 3]) → false", double23({2, 3}), false );
printTest( "double23([3, 2]) → false", double23({3, 2}), false );
printTest( "double23([4, 5]) → false", double23({4, 5}), false );
printTest( "double23([2]) → false", double23({2}), false );
printTest( "double23([3]) → false", double23({3}), false );
printTest( "double23([]) → false", double23({}), false );
printTest( "double23([3, 4]) → false", double23({3, 4}), false );

// %% [markdown]
// # Array-1 > fix23

// %%
/*
Given an int array length 3, if there is a 2 in the array immediately followed
by a 3, set the 3 element to 0. Return the changed array.

fix23([1, 2, 3]) → [1, 2, 0]
fix23([2, 3, 5]) → [2, 0, 5]
fix23([1, 2, 1]) → [1, 2, 1]
*/

vector<int> fix23(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "fix23([1, 2, 3]) → [1, 2, 0]", fix23({1, 2, 3}), {1, 2, 0} );
printTest( "fix23([2, 3, 5]) → [2, 0, 5]", fix23({2, 3, 5}), {2, 0, 5} );
printTest( "fix23([1, 2, 1]) → [1, 2, 1]", fix23({1, 2, 1}), {1, 2, 1} );
printTest( "fix23([3, 2, 1]) → [3, 2, 1]", fix23({3, 2, 1}), {3, 2, 1} );
printTest( "fix23([2, 2, 3]) → [2, 2, 0]", fix23({2, 2, 3}), {2, 2, 0} );
printTest( "fix23([2, 3, 3]) → [2, 0, 3]", fix23({2, 3, 3}), {2, 0, 3} );

// %% [markdown]
// # Array-1 > start1

// %%
/*
Start with 2 int arrays, a and b, of any length. Return how many of the arrays
have 1 as their first element.

start1([1, 2, 3], [1, 3]) → 2
start1([7, 2, 3], [1]) → 1
start1([1, 2], []) → 1
*/

int start1(vector<int> a, vector<int> b) {
    return 0;
}


// tests:
printTest( "start1([1, 2, 3], [1, 3]) → 2", start1({1, 2, 3}, {1, 3}), 2 );
printTest( "start1([7, 2, 3], [1]) → 1", start1({7, 2, 3}, {1}), 1 );
printTest( "start1([1, 2], []) → 1", start1({1, 2}, {}), 1 );
printTest( "start1([], [1, 2]) → 1", start1({}, {1, 2}), 1 );
printTest( "start1([7], []) → 0", start1({7}, {}), 0 );
printTest( "start1([7], [1]) → 1", start1({7}, {1}), 1 );
printTest( "start1([1], [1]) → 2", start1({1}, {1}), 2 );
printTest( "start1([7], [8]) → 0", start1({7}, {8}), 0 );
printTest( "start1([], []) → 0", start1({}, {}), 0 );
printTest( "start1([1, 3], [1]) → 2", start1({1, 3}, {1}), 2 );

// %% [markdown]
// # Array-1 > biggerTwo

// %%
/*
Start with 2 int arrays, a and b, each length 2. Consider the sum of the values
in each array. Return the array which has the largest sum. In event of a tie,
return a.

biggerTwo([1, 2], [3, 4]) → [3, 4]
biggerTwo([3, 4], [1, 2]) → [3, 4]
biggerTwo([1, 1], [1, 2]) → [1, 2]
*/

vector<int> biggerTwo(vector<int> a, vector<int> b) {
    return vector<int>{};
}


// tests:
printTest( "biggerTwo([1, 2], [3, 4]) → [3, 4]", biggerTwo({1, 2}, {3, 4}), {3, 4} );
printTest( "biggerTwo([3, 4], [1, 2]) → [3, 4]", biggerTwo({3, 4}, {1, 2}), {3, 4} );
printTest( "biggerTwo([1, 1], [1, 2]) → [1, 2]", biggerTwo({1, 1}, {1, 2}), {1, 2} );
printTest( "biggerTwo([2, 1], [1, 1]) → [2, 1]", biggerTwo({2, 1}, {1, 1}), {2, 1} );
printTest( "biggerTwo([2, 2], [1, 3]) → [2, 2]", biggerTwo({2, 2}, {1, 3}), {2, 2} );
printTest( "biggerTwo([1, 3], [2, 2]) → [1, 3]", biggerTwo({1, 3}, {2, 2}), {1, 3} );
printTest( "biggerTwo([6, 7], [3, 1]) → [6, 7]", biggerTwo({6, 7}, {3, 1}), {6, 7} );

// %% [markdown]
// # Array-1 > makeMiddle

// %%
/*
Given an array of ints of even length, return a new array length 2 containing
the middle two elements from the original array. The original array will be
length 2 or more.

makeMiddle([1, 2, 3, 4]) → [2, 3]
makeMiddle([7, 1, 2, 3, 4, 9]) → [2, 3]
makeMiddle([1, 2]) → [1, 2]
*/

vector<int> makeMiddle(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "makeMiddle([1, 2, 3, 4]) → [2, 3]", makeMiddle({1, 2, 3, 4}), {2, 3} );
printTest( "makeMiddle([7, 1, 2, 3, 4, 9]) → [2, 3]", makeMiddle({7, 1, 2, 3, 4, 9}), {2, 3} );
printTest( "makeMiddle([1, 2]) → [1, 2]", makeMiddle({1, 2}), {1, 2} );
printTest( "makeMiddle([5, 2, 4, 7]) → [2, 4]", makeMiddle({5, 2, 4, 7}), {2, 4} );
printTest( "makeMiddle([9, 0, 4, 3, 9, 1]) → [4, 3]", makeMiddle({9, 0, 4, 3, 9, 1}), {4, 3} );

// %% [markdown]
// # Array-1 > plusTwo

// %%
/*
Given 2 int arrays, each length 2, return a new array length 4 containing all
their elements.

plusTwo([1, 2], [3, 4]) → [1, 2, 3, 4]
plusTwo([4, 4], [2, 2]) → [4, 4, 2, 2]
plusTwo([9, 2], [3, 4]) → [9, 2, 3, 4]
*/

vector<int> plusTwo(vector<int> a, vector<int> b) {
    return vector<int>{};
}


// tests:
printTest( "plusTwo([1, 2], [3, 4]) → [1, 2, 3, 4]", plusTwo({1, 2}, {3, 4}), {1, 2, 3, 4} );
printTest( "plusTwo([4, 4], [2, 2]) → [4, 4, 2, 2]", plusTwo({4, 4}, {2, 2}), {4, 4, 2, 2} );
printTest( "plusTwo([9, 2], [3, 4]) → [9, 2, 3, 4]", plusTwo({9, 2}, {3, 4}), {9, 2, 3, 4} );

// %% [markdown]
// # Array-1 > swapEnds

// %%
/*
Given an array of ints, swap the first and last elements in the array. Return
the modified array. The array length will be at least 1.

swapEnds([1, 2, 3, 4]) → [4, 2, 3, 1]
swapEnds([1, 2, 3]) → [3, 2, 1]
swapEnds([8, 6, 7, 9, 5]) → [5, 6, 7, 9, 8]
*/

vector<int> swapEnds(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "swapEnds([1, 2, 3, 4]) → [4, 2, 3, 1]", swapEnds({1, 2, 3, 4}), {4, 2, 3, 1} );
printTest( "swapEnds([1, 2, 3]) → [3, 2, 1]", swapEnds({1, 2, 3}), {3, 2, 1} );
printTest( "swapEnds([8, 6, 7, 9, 5]) → [5, 6, 7, 9, 8]", swapEnds({8, 6, 7, 9, 5}), {5, 6, 7, 9, 8} );
printTest( "swapEnds([3, 1, 4, 1, 5, 9]) → [9, 1, 4, 1, 5, 3]", swapEnds({3, 1, 4, 1, 5, 9}), {9, 1, 4, 1, 5, 3} );
printTest( "swapEnds([1, 2]) → [2, 1]", swapEnds({1, 2}), {2, 1} );
printTest( "swapEnds([1]) → [1]", swapEnds({1}), {1} );

// %% [markdown]
// # Array-1 > midThree

// %%
/*
Given an array of ints of odd length, return a new array length 3 containing the
elements from the middle of the array. The array length will be at least 3.

midThree([1, 2, 3, 4, 5]) → [2, 3, 4]
midThree([8, 6, 7, 5, 3, 0, 9]) → [7, 5, 3]
midThree([1, 2, 3]) → [1, 2, 3]
*/

vector<int> midThree(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "midThree([1, 2, 3, 4, 5]) → [2, 3, 4]", midThree({1, 2, 3, 4, 5}), {2, 3, 4} );
printTest( "midThree([8, 6, 7, 5, 3, 0, 9]) → [7, 5, 3]", midThree({8, 6, 7, 5, 3, 0, 9}), {7, 5, 3} );
printTest( "midThree([1, 2, 3]) → [1, 2, 3]", midThree({1, 2, 3}), {1, 2, 3} );

// %% [markdown]
// # Array-1 > maxTriple

// %%
/*
Given an array of ints of odd length, look at the first, last, and middle values
in the array and return the largest. The array length will be a least 1.

maxTriple([1, 2, 3]) → 3
maxTriple([1, 5, 3]) → 5
maxTriple([5, 2, 3]) → 5
*/

int maxTriple(vector<int> nums) {
    return 0;
}


// tests:
printTest( "maxTriple([1, 2, 3]) → 3", maxTriple({1, 2, 3}), 3 );
printTest( "maxTriple([1, 5, 3]) → 5", maxTriple({1, 5, 3}), 5 );
printTest( "maxTriple([5, 2, 3]) → 5", maxTriple({5, 2, 3}), 5 );
printTest( "maxTriple([1, 2, 3, 1, 1]) → 3", maxTriple({1, 2, 3, 1, 1}), 3 );
printTest( "maxTriple([1, 7, 3, 1, 5]) → 5", maxTriple({1, 7, 3, 1, 5}), 5 );
printTest( "maxTriple([5, 1, 3, 7, 1]) → 5", maxTriple({5, 1, 3, 7, 1}), 5 );
printTest( "maxTriple([5, 1, 7, 3, 7, 8, 1]) → 5", maxTriple({5, 1, 7, 3, 7, 8, 1}), 5 );
printTest( "maxTriple([5, 1, 7, 9, 7, 8, 1]) → 9", maxTriple({5, 1, 7, 9, 7, 8, 1}), 9 );
printTest( "maxTriple([5, 1, 7, 3, 7, 8, 9]) → 9", maxTriple({5, 1, 7, 3, 7, 8, 9}), 9 );
printTest( "maxTriple([2, 2, 5, 1, 1]) → 5", maxTriple({2, 2, 5, 1, 1}), 5 );

// %% [markdown]
// # Array-1 > frontPiece

// %%
/*
Given an int array of any length, return a new array of its first 2 elements. If
the array is smaller than length 2, use whatever elements are present.

frontPiece([1, 2, 3]) → [1, 2]
frontPiece([1, 2]) → [1, 2]
frontPiece([1]) → [1]
*/

vector<int> frontPiece(vector<int> nums) {
    return vector<int>{};
}


// tests:
printTest( "frontPiece([1, 2, 3]) → [1, 2]", frontPiece({1, 2, 3}), {1, 2} );
printTest( "frontPiece([1, 2]) → [1, 2]", frontPiece({1, 2}), {1, 2} );
printTest( "frontPiece([1]) → [1]", frontPiece({1}), {1} );
printTest( "frontPiece([]) → []", frontPiece({}), {} );
printTest( "frontPiece([6, 5, 0]) → [6, 5]", frontPiece({6, 5, 0}), {6, 5} );
printTest( "frontPiece([6, 5]) → [6, 5]", frontPiece({6, 5}), {6, 5} );
printTest( "frontPiece([3, 1, 4, 1, 5]) → [3, 1]", frontPiece({3, 1, 4, 1, 5}), {3, 1} );
printTest( "frontPiece([6]) → [6]", frontPiece({6}), {6} );

// %% [markdown]
// # Array-1 > unlucky1

// %%
/*
We'll say that a 1 immediately followed by a 3 in an array is an "unlucky" 1.
Return true if the given array contains an unlucky 1 in the first 2 or last 2
positions in the array.

unlucky1([1, 3, 4, 5]) → true
unlucky1([2, 1, 3, 4, 5]) → true
unlucky1([1, 1, 1]) → false
*/

bool unlucky1(vector<int> nums) {
    return false;
}


// tests:
printTest( "unlucky1([1, 3, 4, 5]) → true", unlucky1({1, 3, 4, 5}), true );
printTest( "unlucky1([2, 1, 3, 4, 5]) → true", unlucky1({2, 1, 3, 4, 5}), true );
printTest( "unlucky1([1, 1, 1]) → false", unlucky1({1, 1, 1}), false );
printTest( "unlucky1([1, 3, 1]) → true", unlucky1({1, 3, 1}), true );
printTest( "unlucky1([1, 1, 3]) → true", unlucky1({1, 1, 3}), true );
printTest( "unlucky1([1, 2, 3]) → false", unlucky1({1, 2, 3}), false );
printTest( "unlucky1([3, 3, 3]) → false", unlucky1({3, 3, 3}), false );
printTest( "unlucky1([1, 3]) → true", unlucky1({1, 3}), true );
printTest( "unlucky1([1, 4]) → false", unlucky1({1, 4}), false );
printTest( "unlucky1([1]) → false", unlucky1({1}), false );
printTest( "unlucky1([]) → false", unlucky1({}), false );
printTest( "unlucky1([1, 1, 1, 3, 1]) → false", unlucky1({1, 1, 1, 3, 1}), false );
printTest( "unlucky1([1, 1, 3, 1, 1]) → true", unlucky1({1, 1, 3, 1, 1}), true );
printTest( "unlucky1([1, 1, 1, 1, 3]) → true", unlucky1({1, 1, 1, 1, 3}), true );
printTest( "unlucky1([1, 4, 1, 5]) → false", unlucky1({1, 4, 1, 5}), false );
printTest( "unlucky1([1, 1, 2, 3]) → false", unlucky1({1, 1, 2, 3}), false );
printTest( "unlucky1([2, 3, 2, 1]) → false", unlucky1({2, 3, 2, 1}), false );
printTest( "unlucky1([2, 3, 1, 3]) → true", unlucky1({2, 3, 1, 3}), true );
printTest( "unlucky1([1, 2, 3, 4, 1, 3]) → true", unlucky1({1, 2, 3, 4, 1, 3}), true );

// %% [markdown]
// # Array-1 > make2

// %%
/*
Given 2 int arrays, a and b, return a new array length 2 containing, as much as
will fit, the elements from a followed by the elements from b. The arrays may be
any length, including 0, but there will be 2 or more elements available between
the 2 arrays.

make2([4, 5], [1, 2, 3]) → [4, 5]
make2([4], [1, 2, 3]) → [4, 1]
make2([], [1, 2]) → [1, 2]
*/

vector<int> make2(vector<int> a, vector<int> b) {
    return vector<int>{};
}


// tests:
printTest( "make2([4, 5], [1, 2, 3]) → [4, 5]", make2({4, 5}, {1, 2, 3}), {4, 5} );
printTest( "make2([4], [1, 2, 3]) → [4, 1]", make2({4}, {1, 2, 3}), {4, 1} );
printTest( "make2([], [1, 2]) → [1, 2]", make2({}, {1, 2}), {1, 2} );
printTest( "make2([1, 2], []) → [1, 2]", make2({1, 2}, {}), {1, 2} );
printTest( "make2([3], [1, 2, 3]) → [3, 1]", make2({3}, {1, 2, 3}), {3, 1} );
printTest( "make2([3], [1]) → [3, 1]", make2({3}, {1}), {3, 1} );
printTest( "make2([3, 1, 4], []) → [3, 1]", make2({3, 1, 4}, {}), {3, 1} );
printTest( "make2([1], [1]) → [1, 1]", make2({1}, {1}), {1, 1} );
printTest( "make2([1, 2, 3], [7, 8]) → [1, 2]", make2({1, 2, 3}, {7, 8}), {1, 2} );
printTest( "make2([7, 8], [1, 2, 3]) → [7, 8]", make2({7, 8}, {1, 2, 3}), {7, 8} );
printTest( "make2([7], [1, 2, 3]) → [7, 1]", make2({7}, {1, 2, 3}), {7, 1} );
printTest( "make2([5, 4], [2, 3, 7]) → [5, 4]", make2({5, 4}, {2, 3, 7}), {5, 4} );

// %% [markdown]
// # Array-1 > front11

// %%
/*
Given 2 int arrays, a and b, of any length, return a new array with the first
element of each array. If either array is length 0, ignore that array.

front11([1, 2, 3], [7, 9, 8]) → [1, 7]
front11([1], [2]) → [1, 2]
front11([1, 7], []) → [1]
*/

vector<int> front11(vector<int> a, vector<int> b) {
    return vector<int>{};
}


// tests:
printTest( "front11([1, 2, 3], [7, 9, 8]) → [1, 7]", front11({1, 2, 3}, {7, 9, 8}), {1, 7} );
printTest( "front11([1], [2]) → [1, 2]", front11({1}, {2}), {1, 2} );
printTest( "front11([1, 7], []) → [1]", front11({1, 7}, {}), {1} );
printTest( "front11([], [2, 8]) → [2]", front11({}, {2, 8}), {2} );
printTest( "front11([], []) → []", front11({}, {}), {} );
printTest( "front11([3], [1, 4, 1, 9]) → [3, 1]", front11({3}, {1, 4, 1, 9}), {3, 1} );
printTest( "front11([1, 4, 1, 9], []) → [1]", front11({1, 4, 1, 9}, {}), {1} );
