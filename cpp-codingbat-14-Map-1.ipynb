// %%
#include <iostream>
#include <iomanip>
#include <vector>

using namespace std;

// %%
namespace testns { template<class A> void printTest( string str, A run, A expected )
{
    if( run == expected )
        cout << boolalpha << "\033[1;32m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tOK"
            << "\033[0m" << endl;
    else
        cerr << boolalpha << "\033[1;31m"
            << "Expected: " << setw(60) << left << str << " Run: " << setw(20) << left << run << "\t\tX"
            << "\033[0m" << endl;
} } using namespace testns;
void printTest( string str, string run, const char* expected ){ printTest( str, "\""+run+"\"", "\""+string( expected )+"\"" ); }
template<class A> void printTest( string str, vector<A> run, vector<A> expected )
{
    string runStr = "["; for( A a : run ) runStr += to_string( a ) + ", ";
    if( runStr.length() > 1 ) runStr = runStr.substr(0, runStr.length()-2); runStr += "]";
    string expStr = "["; for( A a : expected ) expStr += to_string( a ) + ", ";
    if( expStr.length() > 1 ) expStr = expStr.substr(0, expStr.length()-2); expStr += "]";
    printTest( str, runStr, expStr );
}

// %% [markdown]
// # Map-1 > mapBully

// %%
/*
Modify and return the given map as follows: if the key "a" has a value, set the
key "b" to have that value, and set the key "a" to have the value "". Basically
"b" is a bully, taking the value and replacing it with the empty string.

mapBully({"a": "candy", "b": "dirt"}) → {"a": "", "b": "candy"}
mapBully({"a": "candy"}) → {"a": "", "b": "candy"}
mapBully({"a": "candy", "b": "carrot", "c": "meh"}) → {"a": "", "b": "candy",
"c": "meh"}
*/

Map<string, string> mapBully(Map<string, string> map) {
    return null;
}


// tests:
printTest( "mapBully({\"a\": \"candy\", \"b\": \"dirt\"}) → {\"a\": \"\", \"b\": \"candy\"}", mapBully({"a": "candy", "b": "dirt"}), {"a": "", "b": "candy"} );
printTest( "mapBully({\"a\": \"candy\"}) → {\"a\": \"\", \"b\": \"candy\"}", mapBully({"a": "candy"}), {"a": "", "b": "candy"} );
printTest( "mapBully({\"a\": \"candy\", \"b\": \"carrot\", \"c\": \"meh\"}) → {\"a\": \"\", \"b\": \"candy\", \"c\": \"meh\"}", mapBully({"a": "candy", "b": "carrot", "c": "meh"}), {"a": "", "b": "candy", "c": "meh"} );
printTest( "mapBully({\"b\": \"carrot\"}) → {\"b\": \"carrot\"}", mapBully({"b": "carrot"}), {"b": "carrot"} );
printTest( "mapBully({\"c\": \"meh\"}) → {\"c\": \"meh\"}", mapBully({"c": "meh"}), {"c": "meh"} );
printTest( "mapBully({\"a\": \"sparkle\", \"c\": \"meh\"}) → {\"a\": \"\", \"b\": \"sparkle\", \"c\": \"meh\"}", mapBully({"a": "sparkle", "c": "meh"}), {"a": "", "b": "sparkle", "c": "meh"} );

// %% [markdown]
// # Map-1 > mapShare

// %%
/*
Modify and return the given map as follows: if the key "a" has a value, set the
key "b" to have that same value. In all cases remove the key "c", leaving the
rest of the map unchanged.

mapShare({"a": "aaa", "b": "bbb", "c": "ccc"}) → {"a": "aaa", "b": "aaa"}
mapShare({"b": "xyz", "c": "ccc"}) → {"b": "xyz"}
mapShare({"a": "aaa", "c": "meh", "d": "hi"}) → {"a": "aaa", "b": "aaa", "d":
"hi"}
*/

Map<string, string> mapShare(Map<string, string> map) {
    return null;
}


// tests:
printTest( "mapShare({\"a\": \"aaa\", \"b\": \"bbb\", \"c\": \"ccc\"}) → {\"a\": \"aaa\", \"b\": \"aaa\"}", mapShare({"a": "aaa", "b": "bbb", "c": "ccc"}), {"a": "aaa", "b": "aaa"} );
printTest( "mapShare({\"b\": \"xyz\", \"c\": \"ccc\"}) → {\"b\": \"xyz\"}", mapShare({"b": "xyz", "c": "ccc"}), {"b": "xyz"} );
printTest( "mapShare({\"a\": \"aaa\", \"c\": \"meh\", \"d\": \"hi\"}) → {\"a\": \"aaa\", \"b\": \"aaa\", \"d\": \"hi\"}", mapShare({"a": "aaa", "c": "meh", "d": "hi"}), {"a": "aaa", "b": "aaa", "d": "hi"} );
printTest( "mapShare({\"a\": \"xyz\", \"b\": \"1234\", \"c\": \"yo\", \"z\": \"zzz\"}) → {\"a\": \"xyz\", \"b\": \"xyz\", \"z\": \"zzz\"}", mapShare({"a": "xyz", "b": "1234", "c": "yo", "z": "zzz"}), {"a": "xyz", "b": "xyz", "z": "zzz"} );
printTest( "mapShare({\"a\": \"xyz\", \"b\": \"1234\", \"c\": \"yo\", \"d\": \"ddd\", \"e\": \"everything\"}) → {\"a\": \"xyz\", \"b\": \"xyz\", \"d\": \"ddd\", \"e\": \"everything\"}", mapShare({"a": "xyz", "b": "1234", "c": "yo", "d": "ddd", "e": "everything"}), {"a": "xyz", "b": "xyz", "d": "ddd", "e": "everything"} );

// %% [markdown]
// # Map-1 > mapAB

// %%
/*
Modify and return the given map as follows: for this problem the map may or may
not contain the "a" and "b" keys. If both keys are present, append their 2
string values together and store the result under the key "ab".

mapAB({"a": "Hi", "b": "There"}) → {"a": "Hi", "ab": "HiThere", "b": "There"}
mapAB({"a": "Hi"}) → {"a": "Hi"}
mapAB({"b": "There"}) → {"b": "There"}
*/

Map<string, string> mapAB(Map<string, string> map) {
    return null;
}


// tests:
printTest( "mapAB({\"a\": \"Hi\", \"b\": \"There\"}) → {\"a\": \"Hi\", \"ab\": \"HiThere\", \"b\": \"There\"}", mapAB({"a": "Hi", "b": "There"}), {"a": "Hi", "ab": "HiThere", "b": "There"} );
printTest( "mapAB({\"a\": \"Hi\"}) → {\"a\": \"Hi\"}", mapAB({"a": "Hi"}), {"a": "Hi"} );
printTest( "mapAB({\"b\": \"There\"}) → {\"b\": \"There\"}", mapAB({"b": "There"}), {"b": "There"} );
printTest( "mapAB({\"c\": \"meh\"}) → {\"c\": \"meh\"}", mapAB({"c": "meh"}), {"c": "meh"} );
printTest( "mapAB({\"a\": \"aaa\", \"ab\": \"nope\", \"b\": \"bbb\", \"c\": \"ccc\"}) → {\"a\": \"aaa\", \"ab\": \"aaabbb\", \"b\": \"bbb\", \"c\": \"ccc\"}", mapAB({"a": "aaa", "ab": "nope", "b": "bbb", "c": "ccc"}), {"a": "aaa", "ab": "aaabbb", "b": "bbb", "c": "ccc"} );
printTest( "mapAB({\"ab\": \"nope\", \"b\": \"bbb\", \"c\": \"ccc\"}) → {\"ab\": \"nope\", \"b\": \"bbb\", \"c\": \"ccc\"}", mapAB({"ab": "nope", "b": "bbb", "c": "ccc"}), {"ab": "nope", "b": "bbb", "c": "ccc"} );

// %% [markdown]
// # Map-1 > topping1

// %%
/*
Given a map of food keys and topping values, modify and return the map as
follows: if the key "ice cream" is present, set its value to "cherry". In all
cases, set the key "bread" to have the value "butter".

topping1({"ice cream": "peanuts"}) → {"bread": "butter", "ice cream": "cherry"}
topping1({}) → {"bread": "butter"}
topping1({"pancake": "syrup"}) → {"bread": "butter", "pancake": "syrup"}
*/

Map<string, string> topping1(Map<string, string> map) {
    return null;
}


// tests:
printTest( "topping1({\"ice cream\": \"peanuts\"}) → {\"bread\": \"butter\", \"ice cream\": \"cherry\"}", topping1({"ice cream": "peanuts"}), {"bread": "butter", "ice cream": "cherry"} );
printTest( "topping1({}) → {\"bread\": \"butter\"}", topping1({}), {"bread": "butter"} );
printTest( "topping1({\"pancake\": \"syrup\"}) → {\"bread\": \"butter\", \"pancake\": \"syrup\"}", topping1({"pancake": "syrup"}), {"bread": "butter", "pancake": "syrup"} );
printTest( "topping1({\"bread\": \"dirt\", \"ice cream\": \"strawberries\"}) → {\"bread\": \"butter\", \"ice cream\": \"cherry\"}", topping1({"bread": "dirt", "ice cream": "strawberries"}), {"bread": "butter", "ice cream": "cherry"} );
printTest( "topping1({\"bread\": \"jam\", \"ice cream\": \"strawberries\", \"salad\": \"oil\"}) → {\"bread\": \"butter\", \"ice cream\": \"cherry\", \"salad\": \"oil\"}", topping1({"bread": "jam", "ice cream": "strawberries", "salad": "oil"}), {"bread": "butter", "ice cream": "cherry", "salad": "oil"} );

// %% [markdown]
// # Map-1 > topping2

// %%
/*
Given a map of food keys and their topping values, modify and return the map as
follows: if the key "ice cream" has a value, set that as the value for the key
"yogurt" also. If the key "spinach" has a value, change that value to "nuts".

topping2({"ice cream": "cherry"}) → {"yogurt": "cherry", "ice cream": "cherry"}
topping2({"spinach": "dirt", "ice cream": "cherry"}) → {"yogurt": "cherry",
"spinach": "nuts", "ice cream": "cherry"}
topping2({"yogurt": "salt"}) → {"yogurt": "salt"}
*/

Map<string, string> topping2(Map<string, string> map) {
    return null;
}


// tests:
printTest( "topping2({\"ice cream\": \"cherry\"}) → {\"yogurt\": \"cherry\", \"ice cream\": \"cherry\"}", topping2({"ice cream": "cherry"}), {"yogurt": "cherry", "ice cream": "cherry"} );
printTest( "topping2({\"spinach\": \"dirt\", \"ice cream\": \"cherry\"}) → {\"yogurt\": \"cherry\", \"spinach\": \"nuts\", \"ice cream\": \"cherry\"}", topping2({"spinach": "dirt", "ice cream": "cherry"}), {"yogurt": "cherry", "spinach": "nuts", "ice cream": "cherry"} );
printTest( "topping2({\"yogurt\": \"salt\"}) → {\"yogurt\": \"salt\"}", topping2({"yogurt": "salt"}), {"yogurt": "salt"} );
printTest( "topping2({\"yogurt\": \"salt\", \"bread\": \"butter\"}) → {\"yogurt\": \"salt\", \"bread\": \"butter\"}", topping2({"yogurt": "salt", "bread": "butter"}), {"yogurt": "salt", "bread": "butter"} );
printTest( "topping2({}) → {}", topping2({}), {} );
printTest( "topping2({\"ice cream\": \"air\", \"salad\": \"oil\"}) → {\"yogurt\": \"air\", \"ice cream\": \"air\", \"salad\": \"oil\"}", topping2({"ice cream": "air", "salad": "oil"}), {"yogurt": "air", "ice cream": "air", "salad": "oil"} );

// %% [markdown]
// # Map-1 > topping3

// %%
/*
Given a map of food keys and topping values, modify and return the map as
follows:  if the key "potato" has a value, set that as the value for the key
"fries". If the key "salad" has a value, set that as the value for the key
"spinach".

topping3({"potato": "ketchup"}) → {"potato": "ketchup", "fries": "ketchup"}
topping3({"potato": "butter"}) → {"potato": "butter", "fries": "butter"}
topping3({"salad": "oil", "potato": "ketchup"}) → {"spinach": "oil", "salad":
"oil", "potato": "ketchup", "fries": "ketchup"}
*/

Map<string, string> topping3(Map<string, string> map) {
    return null;
}


// tests:
printTest( "topping3({\"potato\": \"ketchup\"}) → {\"potato\": \"ketchup\", \"fries\": \"ketchup\"}", topping3({"potato": "ketchup"}), {"potato": "ketchup", "fries": "ketchup"} );
printTest( "topping3({\"potato\": \"butter\"}) → {\"potato\": \"butter\", \"fries\": \"butter\"}", topping3({"potato": "butter"}), {"potato": "butter", "fries": "butter"} );
printTest( "topping3({\"salad\": \"oil\", \"potato\": \"ketchup\"}) → {\"spinach\": \"oil\", \"salad\": \"oil\", \"potato\": \"ketchup\", \"fries\": \"ketchup\"}", topping3({"salad": "oil", "potato": "ketchup"}), {"spinach": "oil", "salad": "oil", "potato": "ketchup", "fries": "ketchup"} );
printTest( "topping3({\"toast\": \"butter\", \"salad\": \"oil\", \"potato\": \"ketchup\"}) → {\"toast\": \"butter\", \"spinach\": \"oil\", \"salad\": \"oil\", \"potato\": \"ketchup\", \"fries\": \"ketchup\"}", topping3({"toast": "butter", "salad": "oil", "potato": "ketchup"}), {"toast": "butter", "spinach": "oil", "salad": "oil", "potato": "ketchup", "fries": "ketchup"} );
printTest( "topping3({}) → {}", topping3({}), {} );
printTest( "topping3({\"salad\": \"pepper\", \"fries\": \"salt\"}) → {\"spinach\": \"pepper\", \"salad\": \"pepper\", \"fries\": \"salt\"}", topping3({"salad": "pepper", "fries": "salt"}), {"spinach": "pepper", "salad": "pepper", "fries": "salt"} );

// %% [markdown]
// # Map-1 > mapAB2

// %%
/*
Modify and return the given map as follows: if the keys "a" and "b" are both in
the map and have equal values, remove them both.

mapAB2({"a": "aaa", "b": "aaa", "c": "cake"}) → {"c": "cake"}
mapAB2({"a": "aaa", "b": "bbb"}) → {"a": "aaa", "b": "bbb"}
mapAB2({"a": "aaa", "b": "bbb", "c": "aaa"}) → {"a": "aaa", "b": "bbb", "c":
"aaa"}
*/

Map<string, string> mapAB2(Map<string, string> map) {
    return null;
}


// tests:
printTest( "mapAB2({\"a\": \"aaa\", \"b\": \"aaa\", \"c\": \"cake\"}) → {\"c\": \"cake\"}", mapAB2({"a": "aaa", "b": "aaa", "c": "cake"}), {"c": "cake"} );
printTest( "mapAB2({\"a\": \"aaa\", \"b\": \"bbb\"}) → {\"a\": \"aaa\", \"b\": \"bbb\"}", mapAB2({"a": "aaa", "b": "bbb"}), {"a": "aaa", "b": "bbb"} );
printTest( "mapAB2({\"a\": \"aaa\", \"b\": \"bbb\", \"c\": \"aaa\"}) → {\"a\": \"aaa\", \"b\": \"bbb\", \"c\": \"aaa\"}", mapAB2({"a": "aaa", "b": "bbb", "c": "aaa"}), {"a": "aaa", "b": "bbb", "c": "aaa"} );
printTest( "mapAB2({\"a\": \"aaa\"}) → {\"a\": \"aaa\"}", mapAB2({"a": "aaa"}), {"a": "aaa"} );
printTest( "mapAB2({\"b\": \"bbb\"}) → {\"b\": \"bbb\"}", mapAB2({"b": "bbb"}), {"b": "bbb"} );
printTest( "mapAB2({\"a\": \"\", \"b\": \"\", \"c\": \"ccc\"}) → {\"c\": \"ccc\"}", mapAB2({"a": "", "b": "", "c": "ccc"}), {"c": "ccc"} );
printTest( "mapAB2({}) → {}", mapAB2({}), {} );
printTest( "mapAB2({\"a\": \"a\", \"b\": \"b\", \"z\": \"zebra\"}) → {\"a\": \"a\", \"b\": \"b\", \"z\": \"zebra\"}", mapAB2({"a": "a", "b": "b", "z": "zebra"}), {"a": "a", "b": "b", "z": "zebra"} );

// %% [markdown]
// # Map-1 > mapAB3

// %%
/*
Modify and return the given map as follows: if exactly one of the keys "a" or
"b" has a value in the map (but not both), set the other to have that same value
in the map.

mapAB3({"a": "aaa", "c": "cake"}) → {"a": "aaa", "b": "aaa", "c": "cake"}
mapAB3({"b": "bbb", "c": "cake"}) → {"a": "bbb", "b": "bbb", "c": "cake"}
mapAB3({"a": "aaa", "b": "bbb", "c": "cake"}) → {"a": "aaa", "b": "bbb", "c":
"cake"}
*/

Map<string, string> mapAB3(Map<string, string> map) {
    return null;
}


// tests:
printTest( "mapAB3({\"a\": \"aaa\", \"c\": \"cake\"}) → {\"a\": \"aaa\", \"b\": \"aaa\", \"c\": \"cake\"}", mapAB3({"a": "aaa", "c": "cake"}), {"a": "aaa", "b": "aaa", "c": "cake"} );
printTest( "mapAB3({\"b\": \"bbb\", \"c\": \"cake\"}) → {\"a\": \"bbb\", \"b\": \"bbb\", \"c\": \"cake\"}", mapAB3({"b": "bbb", "c": "cake"}), {"a": "bbb", "b": "bbb", "c": "cake"} );
printTest( "mapAB3({\"a\": \"aaa\", \"b\": \"bbb\", \"c\": \"cake\"}) → {\"a\": \"aaa\", \"b\": \"bbb\", \"c\": \"cake\"}", mapAB3({"a": "aaa", "b": "bbb", "c": "cake"}), {"a": "aaa", "b": "bbb", "c": "cake"} );
printTest( "mapAB3({\"ccc\": \"ccc\"}) → {\"ccc\": \"ccc\"}", mapAB3({"ccc": "ccc"}), {"ccc": "ccc"} );
printTest( "mapAB3({\"c\": \"a\", \"d\": \"b\"}) → {\"c\": \"a\", \"d\": \"b\"}", mapAB3({"c": "a", "d": "b"}), {"c": "a", "d": "b"} );
printTest( "mapAB3({}) → {}", mapAB3({}), {} );
printTest( "mapAB3({\"a\": \"\"}) → {\"a\": \"\", \"b\": \"\"}", mapAB3({"a": ""}), {"a": "", "b": ""} );
printTest( "mapAB3({\"b\": \"\"}) → {\"a\": \"\", \"b\": \"\"}", mapAB3({"b": ""}), {"a": "", "b": ""} );
printTest( "mapAB3({\"a\": \"\", \"b\": \"\"}) → {\"a\": \"\", \"b\": \"\"}", mapAB3({"a": "", "b": ""}), {"a": "", "b": ""} );
printTest( "mapAB3({\"aa\": \"aa\", \"a\": \"apple\", \"z\": \"zzz\"}) → {\"aa\": \"aa\", \"a\": \"apple\", \"b\": \"apple\", \"z\": \"zzz\"}", mapAB3({"aa": "aa", "a": "apple", "z": "zzz"}), {"aa": "aa", "a": "apple", "b": "apple", "z": "zzz"} );

// %% [markdown]
// # Map-1 > mapAB4

// %%
/*
Modify and return the given map as follows: if the keys "a" and "b" have values
that have different lengths, then set "c" to have the longer value. If the
values exist and have the same length, change them both to the empty string in
the map.

mapAB4({"a": "aaa", "b": "bb", "c": "cake"}) → {"a": "aaa", "b": "bb", "c":
"aaa"}
mapAB4({"a": "aa", "b": "bbb", "c": "cake"}) → {"a": "aa", "b": "bbb", "c":
"bbb"}
mapAB4({"a": "aa", "b": "bbb"}) → {"a": "aa", "b": "bbb", "c": "bbb"}
*/

Map<string, string> mapAB4(Map<string, string> map) {
    return null;
}


// tests:
printTest( "mapAB4({\"a\": \"aaa\", \"b\": \"bb\", \"c\": \"cake\"}) → {\"a\": \"aaa\", \"b\": \"bb\", \"c\": \"aaa\"}", mapAB4({"a": "aaa", "b": "bb", "c": "cake"}), {"a": "aaa", "b": "bb", "c": "aaa"} );
printTest( "mapAB4({\"a\": \"aa\", \"b\": \"bbb\", \"c\": \"cake\"}) → {\"a\": \"aa\", \"b\": \"bbb\", \"c\": \"bbb\"}", mapAB4({"a": "aa", "b": "bbb", "c": "cake"}), {"a": "aa", "b": "bbb", "c": "bbb"} );
printTest( "mapAB4({\"a\": \"aa\", \"b\": \"bbb\"}) → {\"a\": \"aa\", \"b\": \"bbb\", \"c\": \"bbb\"}", mapAB4({"a": "aa", "b": "bbb"}), {"a": "aa", "b": "bbb", "c": "bbb"} );
printTest( "mapAB4({\"a\": \"aaa\"}) → {\"a\": \"aaa\"}", mapAB4({"a": "aaa"}), {"a": "aaa"} );
printTest( "mapAB4({\"b\": \"bbb\"}) → {\"b\": \"bbb\"}", mapAB4({"b": "bbb"}), {"b": "bbb"} );
printTest( "mapAB4({\"a\": \"aaa\", \"b\": \"bbb\", \"c\": \"cake\"}) → {\"a\": \"\", \"b\": \"\", \"c\": \"cake\"}", mapAB4({"a": "aaa", "b": "bbb", "c": "cake"}), {"a": "", "b": "", "c": "cake"} );
printTest( "mapAB4({\"a\": \"a\", \"b\": \"b\", \"c\": \"cake\"}) → {\"a\": \"\", \"b\": \"\", \"c\": \"cake\"}", mapAB4({"a": "a", "b": "b", "c": "cake"}), {"a": "", "b": "", "c": "cake"} );
printTest( "mapAB4({\"a\": \"\", \"b\": \"b\", \"c\": \"cake\"}) → {\"a\": \"\", \"b\": \"b\", \"c\": \"b\"}", mapAB4({"a": "", "b": "b", "c": "cake"}), {"a": "", "b": "b", "c": "b"} );
printTest( "mapAB4({\"a\": \"a\", \"b\": \"\", \"c\": \"cake\"}) → {\"a\": \"a\", \"b\": \"\", \"c\": \"a\"}", mapAB4({"a": "a", "b": "", "c": "cake"}), {"a": "a", "b": "", "c": "a"} );
printTest( "mapAB4({\"c\": \"cat\", \"d\": \"dog\"}) → {\"c\": \"cat\", \"d\": \"dog\"}", mapAB4({"c": "cat", "d": "dog"}), {"c": "cat", "d": "dog"} );
printTest( "mapAB4({\"ccc\": \"ccc\"}) → {\"ccc\": \"ccc\"}", mapAB4({"ccc": "ccc"}), {"ccc": "ccc"} );
printTest( "mapAB4({\"c\": \"a\", \"d\": \"b\"}) → {\"c\": \"a\", \"d\": \"b\"}", mapAB4({"c": "a", "d": "b"}), {"c": "a", "d": "b"} );
printTest( "mapAB4({}) → {}", mapAB4({}), {} );
printTest( "mapAB4({\"a\": \"\", \"z\": \"z\"}) → {\"a\": \"\", \"z\": \"z\"}", mapAB4({"a": "", "z": "z"}), {"a": "", "z": "z"} );
printTest( "mapAB4({\"b\": \"\", \"z\": \"z\"}) → {\"b\": \"\", \"z\": \"z\"}", mapAB4({"b": "", "z": "z"}), {"b": "", "z": "z"} );
